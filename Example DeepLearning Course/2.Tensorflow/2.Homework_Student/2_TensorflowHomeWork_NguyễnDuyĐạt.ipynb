# %% [markdown]
# # 1. Lý thuyết
#
# **1) Để khởi tạo model trong tensorflow chúng ta sử dụng class nào?**
#
# A. Sequential hoặc Model
#
# B. Dense
#
# C. Adam
#
# D. Variable
#
# **2) Điểm khác biệt giữa fit và fit_generator trong tensorflow là gì ?**
#
# A. fit sẽ yêu cầu load toàn bộ dữ liệu lên RAM trong khi fit_generator sẽ sử dụng một hàm generator để sinh dữ liệu tại mỗi mini-batch. Từ đó giúp tiết kiệm bộ nhớ.
#
# B. fit sẽ sử dụng hàm generator để sinh dữ liệu tại thời điểm huấn luyện còn fit_generator sẽ load toàn bộ dữ liệu.
#
# C. fit sẽ huấn luyện model theo mini-batch còn fit_generator thì huấn luyện trên toàn bộ dataset.
#
# D. trong hàm fit chúng ta có thể khai báo tập validation dataset còn trong fit_generator thì không.
#
#
# **3) Các modules chính trong tensorflow dùng để xây dựng và huấn luyện model.**
#
# A. `tf.keras.layers`: khởi tạo activation function; `tf.keras.Sequential`: khởi tạo model; `tf.keras.activations`: để khởi tạo các layers; `tf.keras.optimizers`: Khởi tạo optimizer cho bài toán tối ưu loss function; `tf.keras.losses`: khởi tạo loss function; `tf.keras.preprocessing`: Preprocessing data.
#
# B. `tf.keras.layers`: để khởi tạo các layers; `tf.keras.Sequential`: khởi tạo model; `tf.keras.activations`: khởi tạo activation function; `tf.keras.optimizers`: Khởi tạo optimizer cho bài toán tối ưu loss function; `tf.keras.losses`: khởi tạo loss function; `tf.keras.preprocessing`: Preprocessing data.
#
# C. `tf.keras.layers`: để khởi tạo các layers; `tf.keras.Sequential`: Preprocessing data; `tf.keras.activations`: khởi tạo activation function; `tf.keras.optimizers`: Khởi tạo optimizer cho bài toán tối ưu loss function; `tf.keras.losses`: khởi tạo loss function; `tf.keras.preprocessing`: khởi tạo model
#
# D. `tf.keras.layers`: để khởi tạo các layers; `tf.keras.Sequential`: khởi tạo model; `tf.keras.activations`: khởi tạo activation function; `tf.keras.optimizers`: khởi tạo loss function; `tf.keras.losses`: Khởi tạo optimizer cho bài toán tối ưu loss function; `tf.keras.preprocessing`: Preprocessing data.
#
#
# **4) Các bước trong huấn luyện model bao gồm:**
#
# A. 1. Train/test data split --> 2. Initialize the optimizer algorithm --> 3. Build up model architecture --> 4. Train model on train --> 5. Evaluation on test --> 6. Save and use trained model
#
# B. 1. Train/test data split --> 2. Build up model architecture --> 3. Train model on train --> 4. Initialize the optimizer algorithm --> 5. Evaluation on test --> 6. Save and use trained model
#
# C. 1. Train/test data split --> 2. Build up model architecture --> 3. Initialize the optimizer algorithm --> 4. Evaluation on test --> 5. Train model on train --> 6. Save and use trained model
#
# D. 1. Train/test data split --> 2. Build up model architecture --> 3. Initialize the optimizer algorithm --> 4. Train model on train --> 5. Evaluation on test --> 6. Save and use trained model
#
# **5) Ý nghĩa của tham số epochs và batch_size trong huấn luyện mô hình là gì?**
#
# A. epochs là kích thước của một mini-batch, batch_size là số lượt lặp lại toàn bộ dữ liệu khi huấn luyện.
#
# B. epochs là số lượt lặp lại toàn bộ dữ liệu validation khi huấn luyện, batch_size là kích thước của một mini-batch.
#
# C. epochs là số lượt lặp lại toàn bộ dữ liệu train khi huấn luyện, batch_size là kích thước của một mini-batch.
#
# D. epochs là số lượng vòng lặp, mỗi vòng lặp là một lượt fit mini-batch, trên bộ dữ liệu khi huấn luyện; batch_size là kích thước của một mini-batch.

# %% [markdown]
# # Chữa: Câu 5 đáp án đúng là C

# %% [markdown]
# 1A - 2A - 3B - 4D - 5D

# %% [markdown]
# # 2. Thực hành
#
# 6) Khởi tạo một tensor 3 chiều với định dạng là float và kích thước là 32x32x3
#
# 7) Nếu coi tensor trên là một bức ảnh RGB với số channel là 3 ở cuối. Hãy truy suất các ma trận ảnh tương ứng với mỗi kênh R, G, B.
#
# 8) Thực hiện tích hadamard và tích thông thường giữa ma trận R và G.
#
# 9) Từ bộ dữ liệu [Income-Classification](https://www.kaggle.com/t/090688c8d33a40b68be9e271d6ba6bae) hãy chuẩn hóa dữ liệu và phân chia tập train/test theo tỷ lệ 80/20.
#
# 10) Xây dựng một mạng deep-neural-network để huấn luyện mô hình trên dữ liệu train và đánh giá mô hình trên dữ liệu test.

# %%
#6
import tensorflow as tf
t = tf.random.normal([32, 32, 3], dtype=tf.float64)
t
# Out:
# <tf.Tensor: shape=(32, 32, 3), dtype=float64, numpy=
# array([[[ 1.27695883, -0.50539873, -1.68870324],
#         [-0.77648433,  0.9972343 , -0.14193623],
#         [-0.6497622 , -0.17079418, -2.22045319],
#         ...,
#         [ 1.70271368, -1.53041469,  1.60570961],
#         [-0.99754912,  0.74373443, -1.0078744 ],
#         [ 2.2852793 , -1.33985932, -2.00976402]],
#
#        [[ 0.15131234,  0.13218653,  1.30162429],
#         [-0.83199716, -0.81797848, -0.36312821],
#         [-0.28343568,  0.61669347, -2.31150665],
#         ...,
#         [-0.43594371,  0.7425843 , -0.76698361],
#         [ 1.09188938, -0.07894196, -2.14776895],
#         [-1.90190927, -2.16450758, -0.04819991]],
#
#        [[ 0.75099528, -0.97951875, -0.45128216],
#         [-0.91485073,  0.90538641, -1.2225124 ],
#         [-0.85836746,  1.00085841, -0.59217114],
#         ...,
#         [-0.79890558, -0.51101884,  1.1826099 ],
#         [-0.58162242, -0.96166741,  2.16423734],
#         [-1.19981843, -3.22426038, -0.08544905]],
#
#        ...,
#
#        [[ 0.43109191, -0.83058968, -2.40995421],
#         [ 1.27727502, -0.31431635,  0.14380202],
#         [ 0.65757699, -1.77560381,  0.30730448],
#         ...,
#         [-2.53515605,  1.11965309, -1.19076217],
#         [-1.3569693 ,  0.20905789,  1.17072907],
#         [-0.37451891,  0.93900683, -0.23800954]],
#
#        [[ 0.06937785,  0.01467464, -1.58837728],
#         [ 0.07183239, -0.88997832, -1.25458982],
#         [-0.5380481 ,  0.97363116, -0.0503646 ],
#         ...,
#         [ 0.2924148 , -1.23010777,  0.68950927],
#         [-1.30494687,  1.43850681, -1.35230732],
#         [-0.5996021 ,  1.26915907, -0.81182926]],
#
#        [[-1.98889445,  0.46896154, -0.77865823],
#         [-0.00884699, -1.76000717, -0.88073991],
#         [-0.99027477,  0.22179495, -0.95410688],
#         ...,
#         [-0.57433361, -0.49199807, -2.65943004],
#         [-0.30103743, -0.27472716,  1.41907548],
#         [-0.71732476,  0.33492834,  0.70320478]]])>

# %%
#7
print("red_matrix")
R = t[:, : ,:1]
print(R)
print("------------------------------------------------------------------------------------------------")

print("green_matrix")
G = t[:, : ,1:2]
print(G)
print("------------------------------------------------------------------------------------------------")

print("blue_matrix")
B = t[:, : ,2:3]
print(B)
print("------------------------------------------------------------------------------------------------")
# Out:
# red_matrix
# tf.Tensor(
# [[[ 1.27695883]
#   [-0.77648433]
#   [-0.6497622 ]
#   ...
#   [ 1.70271368]
#   [-0.99754912]
#   [ 2.2852793 ]]
#
#  [[ 0.15131234]
#   [-0.83199716]
#   [-0.28343568]
#   ...
#   [-0.43594371]
#   [ 1.09188938]
#   [-1.90190927]]
#
#  [[ 0.75099528]
#   [-0.91485073]
#   [-0.85836746]
#   ...
#   [-0.79890558]
#   [-0.58162242]
#   [-1.19981843]]
#
#  ...
#
#  [[ 0.43109191]
#   [ 1.27727502]
#   [ 0.65757699]
#   ...
#   [-2.53515605]
#   [-1.3569693 ]
#   [-0.37451891]]
#
#  [[ 0.06937785]
#   [ 0.07183239]
#   [-0.5380481 ]
#   ...
#   [ 0.2924148 ]
#   [-1.30494687]
#   [-0.5996021 ]]
#
#  [[-1.98889445]
#   [-0.00884699]
#   [-0.99027477]
#   ...
#   [-0.57433361]
#   [-0.30103743]
#   [-0.71732476]]], shape=(32, 32, 1), dtype=float64)
# ------------------------------------------------------------------------------------------------
# green_matrix
# tf.Tensor(
# [[[-0.50539873]
#   [ 0.9972343 ]
#   [-0.17079418]
#   ...
#   [-1.53041469]
#   [ 0.74373443]
#   [-1.33985932]]
#
#  [[ 0.13218653]
#   [-0.81797848]
#   [ 0.61669347]
#   ...
#   [ 0.7425843 ]
#   [-0.07894196]
#   [-2.16450758]]
#
#  [[-0.97951875]
#   [ 0.90538641]
#   [ 1.00085841]
#   ...
#   [-0.51101884]
#   [-0.96166741]
#   [-3.22426038]]
#
#  ...
#
#  [[-0.83058968]
#   [-0.31431635]
#   [-1.77560381]
#   ...
#   [ 1.11965309]
#   [ 0.20905789]
#   [ 0.93900683]]
#
#  [[ 0.01467464]
#   [-0.88997832]
#   [ 0.97363116]
#   ...
#   [-1.23010777]
#   [ 1.43850681]
#   [ 1.26915907]]
#
#  [[ 0.46896154]
#   [-1.76000717]
#   [ 0.22179495]
#   ...
#   [-0.49199807]
#   [-0.27472716]
#   [ 0.33492834]]], shape=(32, 32, 1), dtype=float64)
# ------------------------------------------------------------------------------------------------
# blue_matrix
# tf.Tensor(
# [[[-1.68870324]
#   [-0.14193623]
#   [-2.22045319]
#   ...
#   [ 1.60570961]
#   [-1.0078744 ]
#   [-2.00976402]]
#
#  [[ 1.30162429]
#   [-0.36312821]
#   [-2.31150665]
#   ...
#   [-0.76698361]
#   [-2.14776895]
#   [-0.04819991]]
#
#  [[-0.45128216]
#   [-1.2225124 ]
#   [-0.59217114]
#   ...
#   [ 1.1826099 ]
#   [ 2.16423734]
#   [-0.08544905]]
#
#  ...
#
#  [[-2.40995421]
#   [ 0.14380202]
#   [ 0.30730448]
#   ...
#   [-1.19076217]
#   [ 1.17072907]
#   [-0.23800954]]
#
#  [[-1.58837728]
#   [-1.25458982]
#   [-0.0503646 ]
#   ...
#   [ 0.68950927]
#   [-1.35230732]
#   [-0.81182926]]
#
#  [[-0.77865823]
#   [-0.88073991]
#   [-0.95410688]
#   ...
#   [-2.65943004]
#   [ 1.41907548]
#   [ 0.70320478]]], shape=(32, 32, 1), dtype=float64)
# ------------------------------------------------------------------------------------------------

# %%
#8
print("_Hadamard_product")
print(R*G)
print("------------------------------------------------------------------------------------------------")
print("_Inner_product")
tf.transpose(R)@G
# Out:
# _Hadamard_product
# tf.Tensor(
# [[[-6.45373371e-01]
#   [-7.74336809e-01]
#   [ 1.10975604e-01]
#   ...
#   [-2.60585804e+00]
#   [-7.41911629e-01]
#   [-3.06195277e+00]]
#
#  [[ 2.00014525e-02]
#   [ 6.80555769e-01]
#   [-1.74792933e-01]
#   ...
#   [-3.23724953e-01]
#   [-8.61958904e-02]
#   [ 4.11669704e+00]]
#
#  [[-7.35613964e-01]
#   [-8.28293422e-01]
#   [-8.59104289e-01]
#   ...
#   [ 4.08255806e-01]
#   [ 5.59327329e-01]
#   [ 3.86852702e+00]]
#
#  ...
#
#  [[-3.58060493e-01]
#   [-4.01468424e-01]
#   [-1.16759622e+00]
#   ...
#   [-2.83849531e+00]
#   [-2.83685137e-01]
#   [-3.51675811e-01]]
#
#  [[ 1.01809495e-03]
#   [-6.39292705e-02]
#   [-5.23860395e-01]
#   ...
#   [-3.59701723e-01]
#   [-1.87717497e+00]
#   [-7.60990441e-01]]
#
#  [[-9.32714999e-01]
#   [ 1.55707590e-02]
#   [-2.19637948e-01]
#   ...
#   [ 2.82571029e-01]
#   [ 8.27031596e-02]
#   [-2.40252391e-01]]], shape=(32, 32, 1), dtype=float64)
# ------------------------------------------------------------------------------------------------
# _Inner_product
# <tf.Tensor: shape=(32, 32, 1), dtype=float64, numpy=
# array([[[ 7.14708906],
#         [-3.94408753],
#         [ 2.29960419],
#         ...,
#         [14.71651914],
#         [ 4.00586597],
#         [ 6.26639642]],
#
#        [[ 2.23484409],
#         [-1.052394  ],
#         [-2.49191366],
#         ...,
#         [-2.92926997],
#         [ 5.48234344],
#         [-2.35996971]],
#
#        [[-2.16812698],
#         [ 3.00642872],
#         [ 4.48101203],
#         ...,
#         [ 3.98437795],
#         [ 0.05830412],
#         [ 2.57869121]],
#
#        ...,
#
#        [[-3.34307648],
#         [ 7.46017288],
#         [-1.11754593],
#         ...,
#         [-7.36120213],
#         [-5.83495092],
#         [-3.19324665]],
#
#        [[ 5.19469498],
#         [-5.50219565],
#         [-0.89115403],
#         ...,
#         [-4.4800507 ],
#         [-3.63896435],
#         [ 0.18101002]],
#
#        [[11.06635366],
#         [-2.3198384 ],
#         [ 2.0741828 ],
#         ...,
#         [11.00774805],
#         [ 6.68242732],
#         [ 8.10781304]]])>

# %% [markdown]
# Câu 9

# %%
#9
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/train_IC.csv", index_col = 0)
df
# Out:
#        age         work_type  ...  nationality target_income
# ID                            ...
# 0       45           Private  ...           US             0
# 1       23           Private  ...           US             0
# 2       22           Private  ...        South             0
# 3       27           Private  ...           US             0
# 4       18           Private  ...           US             0
# ...    ...               ...  ...          ...           ...
# 24995   47         State-gov  ...           US             1
# 24996   23           Private  ...           US             0
# 24997   24           Private  ...           US             0
# 24998   44  Self-emp-not-inc  ...           US             0
# 24999   42                 ?  ...      Ecuador             0
#
# [25000 rows x 15 columns]

# %%
# Xử lí missing data dạng "?"
df = df.replace('?', np.NaN)
df = df.fillna(method="ffill")
df
# Out:
#        age         work_type  ...  nationality target_income
# ID                            ...
# 0       45           Private  ...           US             0
# 1       23           Private  ...           US             0
# 2       22           Private  ...        South             0
# 3       27           Private  ...           US             0
# 4       18           Private  ...           US             0
# ...    ...               ...  ...          ...           ...
# 24995   47         State-gov  ...           US             1
# 24996   23           Private  ...           US             0
# 24997   24           Private  ...           US             0
# 24998   44  Self-emp-not-inc  ...           US             0
# 24999   42  Self-emp-not-inc  ...      Ecuador             0
#
# [25000 rows x 15 columns]

# %%
# Chuẩn hóa dữ liệu

from sklearn import preprocessing
 
label_encoder = preprocessing.LabelEncoder()
 
df['work_type'] = label_encoder.fit_transform(df['work_type'])
df['education'] = label_encoder.fit_transform(df['education'])
df['marital_state'] = label_encoder.fit_transform(df['marital_state'])
df['job'] = label_encoder.fit_transform(df['job'])
df['status'] = label_encoder.fit_transform(df['status'])
df['ethnicity'] = label_encoder.fit_transform(df['ethnicity'])
df['sex'] = label_encoder.fit_transform(df['sex'])
df['nationality'] = label_encoder.fit_transform(df['nationality'])

df['final_weight'] = df['final_weight'] /10000
df.sample(5)
# Out:
#        age  work_type  final_weight  ...  hrs_per_week  nationality  target_income
# ID                                   ...
# 8747    48          1       12.3075  ...            35           38              1
# 4585    35          3       11.2271  ...            40           38              0
# 4680    59          3       15.7932  ...            40           38              0
# 11347   40          3       16.1285  ...            25           38              0
# 18014   32          5       26.7161  ...            30           38              0
#
# [5 rows x 15 columns]

# %%
# Phân chia tập train/test theo tỷ lệ 80/20
from sklearn.model_selection import train_test_split
   
df_train, df_test = train_test_split(df, test_size=0.2, stratify = df['target_income'])
X_train = df_train.copy()
y_train = X_train.pop("target_income")

X_test = df_test.copy()
y_test = X_test.pop("target_income")

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (20000, 14) (20000,)
# (5000, 14) (5000,)

# %% [markdown]
# Câu 10

# %%
# !pip freeze | grep tensorflow
# Out:
# tensorflow @ file:///tensorflow-2.7.0-cp37-cp37m-linux_x86_64.whl
# tensorflow-datasets==4.0.1
# tensorflow-estimator==2.7.0
# tensorflow-gcs-config==2.7.0
# tensorflow-hub==0.12.0
# tensorflow-io-gcs-filesystem==0.23.1
# tensorflow-metadata==1.6.0
# tensorflow-probability==0.15.0

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import utils
from tensorflow.keras import optimizers

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# Set data types for categorical labels
y_train = utils.to_categorical(y_train)
y_test = utils.to_categorical(y_test)

# %%
features = ['age', 'work_type', 'final_weight', 'education', 'total_education_yrs', 'marital_state', 'job', 'status',
            'ethnicity', 'sex', 'capital_gain', 'capital_loss', 'hrs_per_week', 'nationality']
label = 'target_income'

income_classes = ['0', '1']

# %%
# Define a classifier network
hl = 10 # Number of hidden layer nodes

model = Sequential()
model.add(Dense(hl, input_dim=len(features), activation='relu'))
model.add(Dense(hl, input_dim=hl, activation='relu'))
model.add(Dense(len(income_classes), input_dim=hl, activation='sigmoid'))

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                150
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 282
# Trainable params: 282
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#hyper-parameters for optimizer
learning_rate = 0.001
opt = optimizers.Adam(lr=learning_rate)

model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# Train the model over 50 epochs using 10-observation batches and using the test holdout dataset for validation
num_epochs = 50
history = model.fit(X_train, y_train, epochs=num_epochs, batch_size=10, validation_data=(X_test, y_test))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/50
# 2000/2000 [==============================] - 5s 2ms/step - loss: 1.5974 - accuracy: 0.7473 - val_loss: 0.4630 - val_accuracy: 0.8090
# Epoch 2/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.8528 - accuracy: 0.7971 - val_loss: 0.5495 - val_accuracy: 0.8130
# Epoch 3/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.9881 - accuracy: 0.8009 - val_loss: 0.5988 - val_accuracy: 0.7922
# Epoch 4/50
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.5804 - accuracy: 0.8087 - val_loss: 0.4622 - val_accuracy: 0.7914
# Epoch 5/50
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.6794 - accuracy: 0.8104 - val_loss: 0.4230 - val_accuracy: 0.8208
# Epoch 6/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.6104 - accuracy: 0.8112 - val_loss: 0.4150 - val_accuracy: 0.8190
# Epoch 7/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.5201 - accuracy: 0.8155 - val_loss: 0.4508 - val_accuracy: 0.8140
# Epoch 8/50
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.4667 - accuracy: 0.8185 - val_loss: 0.7063 - val_accuracy: 0.7890
# Epoch 9/50
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.4081 - accuracy: 0.8230 - val_loss: 0.4047 - val_accuracy: 0.8098
# Epoch 10/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.4027 - accuracy: 0.8195 - val_loss: 0.3783 - val_accuracy: 0.8252
# Epoch 11/50
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.3880 - accuracy: 0.8259 - val_loss: 0.3719 - val_accuracy: 0.8330
# Epoch 12/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3852 - accuracy: 0.8232 - val_loss: 0.3686 - val_accuracy: 0.8418
# Epoch 13/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3771 - accuracy: 0.8295 - val_loss: 0.3686 - val_accuracy: 0.8328
# Epoch 14/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3732 - accuracy: 0.8286 - val_loss: 0.3560 - val_accuracy: 0.8444
# Epoch 15/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3687 - accuracy: 0.8332 - val_loss: 0.3548 - val_accuracy: 0.8432
# Epoch 16/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3680 - accuracy: 0.8314 - val_loss: 0.3479 - val_accuracy: 0.8444
# Epoch 17/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3641 - accuracy: 0.8314 - val_loss: 0.3507 - val_accuracy: 0.8354
# Epoch 18/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3609 - accuracy: 0.8321 - val_loss: 0.3491 - val_accuracy: 0.8384
# Epoch 19/50
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.3581 - accuracy: 0.8347 - val_loss: 0.3479 - val_accuracy: 0.8426
# Epoch 20/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3565 - accuracy: 0.8356 - val_loss: 0.3457 - val_accuracy: 0.8394
# Epoch 21/50
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.3554 - accuracy: 0.8339 - val_loss: 0.3503 - val_accuracy: 0.8396
# Epoch 22/50
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.3542 - accuracy: 0.8358 - val_loss: 0.3374 - val_accuracy: 0.8414
# Epoch 23/50
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.3515 - accuracy: 0.8359 - val_loss: 0.3374 - val_accuracy: 0.8424
# Epoch 24/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3519 - accuracy: 0.8370 - val_loss: 0.3440 - val_accuracy: 0.8408
# Epoch 25/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3518 - accuracy: 0.8370 - val_loss: 0.3386 - val_accuracy: 0.8438
# Epoch 26/50
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.3487 - accuracy: 0.8388 - val_loss: 0.3393 - val_accuracy: 0.8478
# Epoch 27/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3485 - accuracy: 0.8368 - val_loss: 0.3398 - val_accuracy: 0.8466
# Epoch 28/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3499 - accuracy: 0.8374 - val_loss: 0.3373 - val_accuracy: 0.8370
# Epoch 29/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3463 - accuracy: 0.8392 - val_loss: 0.3352 - val_accuracy: 0.8368
# Epoch 30/50
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.3480 - accuracy: 0.8375 - val_loss: 0.3428 - val_accuracy: 0.8316
# Epoch 31/50
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.3466 - accuracy: 0.8391 - val_loss: 0.3405 - val_accuracy: 0.8426
# Epoch 32/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3468 - accuracy: 0.8393 - val_loss: 0.3411 - val_accuracy: 0.8392
# Epoch 33/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3466 - accuracy: 0.8397 - val_loss: 0.3377 - val_accuracy: 0.8394
# Epoch 34/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3459 - accuracy: 0.8393 - val_loss: 0.3353 - val_accuracy: 0.8352
# Epoch 35/50
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.3453 - accuracy: 0.8393 - val_loss: 0.3262 - val_accuracy: 0.8428
# Epoch 36/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3449 - accuracy: 0.8398 - val_loss: 0.3258 - val_accuracy: 0.8510
# Epoch 37/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3436 - accuracy: 0.8391 - val_loss: 0.3280 - val_accuracy: 0.8404
# Epoch 38/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3442 - accuracy: 0.8399 - val_loss: 0.3340 - val_accuracy: 0.8492
# Epoch 39/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3458 - accuracy: 0.8382 - val_loss: 0.3291 - val_accuracy: 0.8472
# Epoch 40/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3439 - accuracy: 0.8407 - val_loss: 0.3282 - val_accuracy: 0.8466
# Epoch 41/50
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.3434 - accuracy: 0.8407 - val_loss: 0.3304 - val_accuracy: 0.8424
# Epoch 42/50
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.3425 - accuracy: 0.8419 - val_loss: 0.3301 - val_accuracy: 0.8452
# Epoch 43/50
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.3424 - accuracy: 0.8414 - val_loss: 0.3323 - val_accuracy: 0.8442
# Epoch 44/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3434 - accuracy: 0.8408 - val_loss: 0.3349 - val_accuracy: 0.8432
# Epoch 45/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3531 - accuracy: 0.8422 - val_loss: 0.3405 - val_accuracy: 0.8310
# Epoch 46/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3433 - accuracy: 0.8391 - val_loss: 0.3264 - val_accuracy: 0.8554
# Epoch 47/50
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.3431 - accuracy: 0.8409 - val_loss: 0.3281 - val_accuracy: 0.8418
# Epoch 48/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3421 - accuracy: 0.8411 - val_loss: 0.3349 - val_accuracy: 0.8386
# Epoch 49/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3414 - accuracy: 0.8419 - val_loss: 0.3245 - val_accuracy: 0.8478
# Epoch 50/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.3419 - accuracy: 0.8423 - val_loss: 0.3303 - val_accuracy: 0.8484

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

epoch_nums = range(1,num_epochs+1)
training_loss = history.history["loss"]
validation_loss = history.history["val_loss"]
plt.plot(epoch_nums, training_loss)
plt.plot(epoch_nums, validation_loss)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training', 'validation'], loc='upper right')
plt.show()

# %% [markdown]
# -Nhận xét:
# + Hàm loss giảm dần sau mỗi epoch, mô hình tìm trọng số và độ lệch phù hợp để dự đoán đúng các nhãn.
# + Hàm loss training và validaion có trend gần như nhau càng về sau cho thấy mô hình khả năng cao không bị overfitting.

# %% [markdown]
# # Chữa: Nên hiển thị kết quả acc của mô hình sau khi đã huấn luyện. CÓ thể đưa ra một vài nhận xét. Thử nghiệm thêm thay đổi tham số của mô hình, normalize dữ liệu
