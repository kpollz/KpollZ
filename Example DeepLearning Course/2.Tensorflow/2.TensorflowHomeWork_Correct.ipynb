# %% [markdown]
# # 1. Lý thuyết
#
# **1) Để khởi tạo model trong tensorflow chúng ta sử dụng class nào?**
#
# A. Sequential hoặc Model
#
# B. Dense
#
# C. Adam
#
# D. Variable
#
# Đáp án: A
#
# **2) Điểm khác biệt giữa fit và fit_generator trong tensorflow là gì ?**
#
# A. fit sẽ yêu cầu load toàn bộ dữ liệu lên RAM trong khi fit_generator sẽ sử dụng một hàm generator để sinh dữ liệu tại mỗi mini-batch. Từ đó giúp tiết kiệm bộ nhớ.
#
# B. fit sẽ sử dụng hàm generator để sinh dữ liệu tại thời điểm huấn luyện còn fit_generator sẽ load toàn bộ dữ liệu.
#
# C. fit sẽ huấn luyện model theo mini-batch còn fit_generator thì huấn luyện trên toàn bộ dataset.
#
# D. trong hàm fit chúng ta có thể khai báo tập validation dataset còn trong fit_generator thì không.
#
# Đáp án: A
#
# **3) Các modules chính trong tensorflow dùng để xây dựng và huấn luyện model.**
#
# A. `tf.keras.layers`: khởi tạo activation function; `tf.keras.Sequential`: khởi tạo model; `tf.keras.activations`: để khởi tạo các layers; `tf.keras.optimizers`: Khởi tạo optimizer cho bài toán tối ưu loss function; `tf.keras.losses`: khởi tạo loss function; `tf.keras.preprocessing`: Preprocessing data.
#
# B. `tf.keras.layers`: để khởi tạo các layers; `tf.keras.Sequential`: khởi tạo model; `tf.keras.activations`: khởi tạo activation function; `tf.keras.optimizers`: Khởi tạo optimizer cho bài toán tối ưu loss function; `tf.keras.losses`: khởi tạo loss function; `tf.keras.preprocessing`: Preprocessing data.
#
# C. `tf.keras.layers`: để khởi tạo các layers; `tf.keras.Sequential`: Preprocessing data; `tf.keras.activations`: khởi tạo activation function; `tf.keras.optimizers`: Khởi tạo optimizer cho bài toán tối ưu loss function; `tf.keras.losses`: khởi tạo loss function; `tf.keras.preprocessing`: khởi tạo model
#
# D. `tf.keras.layers`: để khởi tạo các layers; `tf.keras.Sequential`: khởi tạo model; `tf.keras.activations`: khởi tạo activation function; `tf.keras.optimizers`: khởi tạo loss function; `tf.keras.losses`: Khởi tạo optimizer cho bài toán tối ưu loss function; `tf.keras.preprocessing`: Preprocessing data.
#
# Đáp án: B
#
# **4) Các bước trong huấn luyện model bao gồm:**
#
# A. 1. Train/test data split --> 2. Initialize the optimizer algorithm --> 3. Build up model architecture --> 4. Train model on train --> 5. Evaluation on test --> 6. Save and use trained model
#
# B. 1. Train/test data split --> 2. Build up model architecture --> 3. Train model on train --> 4. Initialize the optimizer algorithm --> 5. Evaluation on test --> 6. Save and use trained model
#
# C. 1. Train/test data split --> 2. Build up model architecture --> 3. Initialize the optimizer algorithm --> 4. Evaluation on test --> 5. Train model on train --> 6. Save and use trained model
#
# D. 1. Train/test data split --> 2. Build up model architecture --> 3. Initialize the optimizer algorithm --> 4. Train model on train --> 5. Evaluation on test --> 6. Save and use trained model
#
# Đáp án: D
#
# **5) Ý nghĩa của tham số epochs và batch_size trong huấn luyện mô hình là gì?**
#
# A. epochs là kích thước của một mini-batch, batch_size là số lượt lặp lại toàn bộ dữ liệu khi huấn luyện.
#
# B. epochs là số lượt lặp lại toàn bộ dữ liệu validation khi huấn luyện, batch_size là kích thước của một mini-batch.
#
# C. epochs là số lượt lặp lại toàn bộ dữ liệu train khi huấn luyện, batch_size là kích thước của một mini-batch.
#
# D. epochs là số lượng vòng lặp, mỗi vòng lặp là một lượt fit mini-batch, trên bộ dữ liệu khi huấn luyện; batch_size là kích thước của một mini-batch.
#
# Đáp án: C

# %% [markdown]
# # 2. Thực hành
#
# 6) Khởi tạo một tensor 3 chiều với định dạng là float và kích thước là 32x32x3

# %%
#6
import tensorflow as tf
a=tf.random.uniform(shape=[32,32,3],dtype=tf.float32)

# %% [markdown]
# 7) Nếu coi tensor trên là một bức ảnh RGB với số channel là 3 ở cuối. Hãy truy suất các ma trận ảnh tương ứng với mỗi kênh R, G, B.

# %%
#7
R=a[:,:,0]
G=a[:,:,1]
B=a[:,:,2]

# %% [markdown]
# 8) Thực hiện tích hadamard và tích thông thường giữa ma trận R và G.

# %%
#8 
# hadamard
hadamard= tf.multiply(R,G)
# normal
normal= tf.matmul(R, G)

# %% [markdown]
# 9) Từ bộ dữ liệu [Income-Classification](https://www.kaggle.com/c/ml-hands-on-python-kaggle-01) hãy chuẩn hóa dữ liệu và phân chia tập train/test theo tỷ lệ 80/20.

# %%
#9
from google.colab import drive
import os
drive.mount("/content/gdrive")
os.chdir('gdrive/My Drive/Colab Notebooks/DeepLearning2/2.Tensorflow')
# !ls
# Out:
# Mounted at /content/gdrive
# '05a - Deep Neural Networks (TensorFlow).ipynb'
# '05b - Convolutional Neural Networks (Tensorflow).ipynb'
# '05c - Transfer Learning (Tensorflow).ipynb'
#  2.Tensorflow.gslides
#  2.TensorflowHomeWork_Correct.ipynb
#  2.TensorflowHomeWork.ipynb
#  keras_cheatsheet.pdf
#  models
#  TensorflowLayer.gsheet

# %%
import numpy as np
import random
def seed_all(seed):
    np.random.seed(seed)
    random.seed(seed)
seed = 42 
seed_all(seed)

# %%
import pandas as pd
import re
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, classification_report

# %%
#metric
def get_metrics(y_test, y_pred):
    print('ACCURACY_SCORE: ', round(accuracy_score(y_test, y_pred), 4))
    print('F1_SCORE: ', round(f1_score(y_test, y_pred, average='macro'), 4))
    print('CONFUSION_MATRIX:\n', confusion_matrix(y_test, y_pred),'\n')
    print(classification_report(y_test, y_pred, digits=4), '\n')

# %%
df_all = pd.read_csv('../data/income_classification/train.csv')

# %%
# normalize string
def str_normalize(s):
    # convert into lowercase and replace multiple spaces into single space
    s = str(s).strip().lower()
    s = re.sub(' +', " ", s)
    return s
# Encode category and object columns 
def process(df):        
  for col in df.columns:
      if df[col].dtype.name == "object" or df[col].dtype.name == "category":
          df[col] = df[col].apply(str_normalize).astype("category")
  return df
df_all = process(df_all.copy())
IDs=df_all.pop('ID')
label = df_all.pop('target_income')
df_all_one_hot = pd.get_dummies(df_all)

# %%
features = df_all_one_hot.columns.tolist()
label = label.values

# %%
# features

# %%
features = df_all_one_hot.columns.tolist()

x_train, x_test, y_train, y_test = train_test_split(df_all_one_hot[features].values, # input variable
                                                    label, # output variable
                                                    test_size=0.2, # test dataset proportion
                                                    # stratify=df_all['target_income'], # assign equal proportion of target label in train/test 
                                                    random_state=0) # keep train/test split the same if run again. 
print ('Training Set: %d, Test Set: %d \n' % (len(x_train), len(x_test)))
#normalize
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
# Out:
# Training Set: 20000, Test Set: 5000

# %%
# !pip freeze | grep tensorflow
# !pip install --upgrade tensorflow

# %% [markdown]
# 10) Xây dựng một mạng deep-neural-network để huấn luyện mô hình trên dữ liệu train và đánh giá mô hình trên dữ liệu test.

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import utils
from tensorflow.keras import optimizers

# Set random seed for reproducability
tensorflow.random.set_seed(0)

print("Libraries imported.")
print('Keras version:',keras.__version__)
print('TensorFlow version:',tensorflow.__version__)
# Out:
# Libraries imported.
# Keras version: 2.7.0
# TensorFlow version: 2.7.0

# %% [markdown]
# # Tìm kiếm learning rate
#
# Learning rate là một trong những siêu tham số quan trọng ảnh hưởng trực tiếp tới tốc độ huấn luyện và khả năng hội tụ của model. Việc lựa chọn learning rate rất quan trọng nhưng thường được bỏ qua trong quá trình huấn luyện model. Phần này nhằm giới thiệu tới bạn một phương pháp đơn giản nhưng thường được lựa chọn khi tìm kiếm learning rate cho huấn luyện.
#
# **Các TH của learning rate**
# Tăng dần learning rate theo batch iteration và đo lường hàm loss function trên từng batch. Những vị trí learning rate nhỏ sẽ khiến cho hàm loss function nằm ngang, khi learning rate phù hợp thì loss function giảm dần, và khi learning rate function tăng cao sẽ khiến cho hàm loss function tăng và dao động ngẫu nhiên như hình 1:
# ![](https://imgur.com/pWz4X6b.png)
#
# **Learning rate phù hợp**
# Khi đó chúng ta sẽ lựa chọn learning rate là điểm màu đỏ nằm giữa đường hạ dốc của loss function như hình 2:
# ![](https://imgur.com/9uuNdp0.png)

# %%
# Define a classifier network
hl = 10 # Number of hidden layer nodes

def _init_model(hl = 10):
  model = Sequential()
  model.add(Dense(hl, input_dim=len(features), activation='relu'))
  model.add(Dense(hl, input_dim=hl, activation='relu'))
  model.add(Dense(6, input_dim=hl, activation='relu'))
  model.add(Dense(1, input_dim=6, activation='sigmoid'))
  print(model.summary())
  return model

model = _init_model(hl=hl)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                1090
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 6)                 66
#
#  dense_3 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 1,273
# Trainable params: 1,273
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
class LRFind(tf.keras.callbacks.Callback): 
    def __init__(self, min_lr, max_lr, n_rounds): 
        self.min_lr = min_lr
        self.max_lr = max_lr
        self.step_up = (max_lr / min_lr) ** (1 / n_rounds)
        self.lrs = []
        self.losses = []
     
    def on_train_begin(self, logs=None):
        self.weights = self.model.get_weights()
        self.model.optimizer.lr = self.min_lr

    def on_train_batch_end(self, batch, logs=None):
        self.lrs.append(self.model.optimizer.lr.numpy())
        self.losses.append(logs["loss"])
        self.model.optimizer.lr = self.model.optimizer.lr * self.step_up
        if self.model.optimizer.lr > self.max_lr:
            self.model.stop_training = True
        
    def on_train_end(self, logs=None):
        self.model.set_weights(self.weights)

# %%
# Define a classifier network
model = _init_model(hl=hl)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 10)                1090
#
#  dense_5 (Dense)             (None, 10)                110
#
#  dense_6 (Dense)             (None, 6)                 66
#
#  dense_7 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 1,273
# Trainable params: 1,273
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
opt = optimizers.Adam()

model.compile(loss='binary_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
import matplotlib.pyplot as plt

EPOCHS = 1
BATCH_SIZE = 16
lr_finder_steps = 400
lr_find = LRFind(1e-6, 1e1, lr_finder_steps)

history = model.fit(x_train, y_train,
                    steps_per_epoch=lr_finder_steps,
                    epochs=EPOCHS, batch_size=BATCH_SIZE, 
                    validation_data=(x_test, y_test), 
                    callbacks=[lr_find])

plt.plot(lr_find.lrs, lr_find.losses)
plt.xscale('log')
plt.show()
# Out:
#   1/400 [..............................] - ETA: 4:06 - loss: 0.8792 - accuracy: 0.3125WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0015s vs `on_train_batch_end` time: 0.0017s). Check your callbacks.
# 400/400 [==============================] - 2s 4ms/step - loss: 0.6635 - accuracy: 0.5311 - val_loss: 0.8077 - val_accuracy: 0.7622

# %% [markdown]
# Chọn `learning_rate` nằm ở giữa phần xuống dốc nằm giữa [1e-3, 1e-1]. Như vậy learning_rate phù hợp là 1e-2.

# %% [markdown]
# # Huấn luyện ngẫu nhiên

# %%
# Define a classifier network
model = _init_model(hl=hl)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 10)                1090
#
#  dense_9 (Dense)             (None, 10)                110
#
#  dense_10 (Dense)            (None, 6)                 66
#
#  dense_11 (Dense)            (None, 1)                 7
#
# =================================================================
# Total params: 1,273
# Trainable params: 1,273
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#hyper-parameters for optimizer
learning_rate = 0.01
opt = optimizers.Adam(lr=learning_rate)

model.compile(loss='binary_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# Train the model
num_epochs = 50
history = model.fit(x_train, y_train, epochs=num_epochs, batch_size=16, validation_data=(x_test, y_test))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.3535 - accuracy: 0.8343 - val_loss: 0.3173 - val_accuracy: 0.8460
# Epoch 2/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.3243 - accuracy: 0.8482 - val_loss: 0.3239 - val_accuracy: 0.8514
# Epoch 3/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.3181 - accuracy: 0.8521 - val_loss: 0.3164 - val_accuracy: 0.8536
# Epoch 4/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.3136 - accuracy: 0.8540 - val_loss: 0.3135 - val_accuracy: 0.8546
# Epoch 5/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.3105 - accuracy: 0.8565 - val_loss: 0.3186 - val_accuracy: 0.8524
# Epoch 6/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.3078 - accuracy: 0.8565 - val_loss: 0.3129 - val_accuracy: 0.8528
# Epoch 7/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.3063 - accuracy: 0.8571 - val_loss: 0.3115 - val_accuracy: 0.8526
# Epoch 8/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.3038 - accuracy: 0.8589 - val_loss: 0.3119 - val_accuracy: 0.8516
# Epoch 9/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.3030 - accuracy: 0.8607 - val_loss: 0.3194 - val_accuracy: 0.8550
# Epoch 10/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.3027 - accuracy: 0.8593 - val_loss: 0.3106 - val_accuracy: 0.8560
# Epoch 11/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.3010 - accuracy: 0.8604 - val_loss: 0.3136 - val_accuracy: 0.8572
# Epoch 12/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.3010 - accuracy: 0.8615 - val_loss: 0.3165 - val_accuracy: 0.8554
# Epoch 13/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2996 - accuracy: 0.8612 - val_loss: 0.3149 - val_accuracy: 0.8510
# Epoch 14/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2977 - accuracy: 0.8623 - val_loss: 0.3148 - val_accuracy: 0.8534
# Epoch 15/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2984 - accuracy: 0.8634 - val_loss: 0.3158 - val_accuracy: 0.8510
# Epoch 16/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2960 - accuracy: 0.8641 - val_loss: 0.3158 - val_accuracy: 0.8544
# Epoch 17/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2957 - accuracy: 0.8638 - val_loss: 0.3121 - val_accuracy: 0.8554
# Epoch 18/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2955 - accuracy: 0.8645 - val_loss: 0.3227 - val_accuracy: 0.8522
# Epoch 19/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2951 - accuracy: 0.8643 - val_loss: 0.3167 - val_accuracy: 0.8490
# Epoch 20/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2934 - accuracy: 0.8656 - val_loss: 0.3311 - val_accuracy: 0.8498
# Epoch 21/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2949 - accuracy: 0.8640 - val_loss: 0.3199 - val_accuracy: 0.8530
# Epoch 22/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2921 - accuracy: 0.8661 - val_loss: 0.3202 - val_accuracy: 0.8532
# Epoch 23/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2930 - accuracy: 0.8670 - val_loss: 0.3162 - val_accuracy: 0.8542
# Epoch 24/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2927 - accuracy: 0.8674 - val_loss: 0.3263 - val_accuracy: 0.8560
# Epoch 25/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2913 - accuracy: 0.8673 - val_loss: 0.3223 - val_accuracy: 0.8558
# Epoch 26/50
# 1250/1250 [==============================] - 3s 3ms/step - loss: 0.2915 - accuracy: 0.8665 - val_loss: 0.3163 - val_accuracy: 0.8550
# Epoch 27/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2905 - accuracy: 0.8686 - val_loss: 0.3323 - val_accuracy: 0.8512
# Epoch 28/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2912 - accuracy: 0.8665 - val_loss: 0.3145 - val_accuracy: 0.8566
# Epoch 29/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2891 - accuracy: 0.8678 - val_loss: 0.3268 - val_accuracy: 0.8562
# Epoch 30/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2910 - accuracy: 0.8672 - val_loss: 0.3150 - val_accuracy: 0.8526
# Epoch 31/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2891 - accuracy: 0.8688 - val_loss: 0.3279 - val_accuracy: 0.8544
# Epoch 32/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2903 - accuracy: 0.8685 - val_loss: 0.3168 - val_accuracy: 0.8540
# Epoch 33/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2896 - accuracy: 0.8691 - val_loss: 0.3274 - val_accuracy: 0.8510
# Epoch 34/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2888 - accuracy: 0.8673 - val_loss: 0.3211 - val_accuracy: 0.8520
# Epoch 35/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2887 - accuracy: 0.8686 - val_loss: 0.3153 - val_accuracy: 0.8570
# Epoch 36/50
# 1250/1250 [==============================] - 3s 3ms/step - loss: 0.2885 - accuracy: 0.8682 - val_loss: 0.3282 - val_accuracy: 0.8538
# Epoch 37/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2886 - accuracy: 0.8679 - val_loss: 0.3321 - val_accuracy: 0.8516
# Epoch 38/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2878 - accuracy: 0.8716 - val_loss: 0.3183 - val_accuracy: 0.8548
# Epoch 39/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2881 - accuracy: 0.8686 - val_loss: 0.3202 - val_accuracy: 0.8540
# Epoch 40/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2859 - accuracy: 0.8697 - val_loss: 0.3180 - val_accuracy: 0.8516
# Epoch 41/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2866 - accuracy: 0.8706 - val_loss: 0.3196 - val_accuracy: 0.8506
# Epoch 42/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2870 - accuracy: 0.8677 - val_loss: 0.3446 - val_accuracy: 0.8556
# Epoch 43/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2872 - accuracy: 0.8694 - val_loss: 0.3202 - val_accuracy: 0.8534
# Epoch 44/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2856 - accuracy: 0.8684 - val_loss: 0.3251 - val_accuracy: 0.8532
# Epoch 45/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2853 - accuracy: 0.8689 - val_loss: 0.3292 - val_accuracy: 0.8544
# Epoch 46/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2839 - accuracy: 0.8709 - val_loss: 0.3389 - val_accuracy: 0.8522
# Epoch 47/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2844 - accuracy: 0.8684 - val_loss: 0.3451 - val_accuracy: 0.8494
# Epoch 48/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2846 - accuracy: 0.8713 - val_loss: 0.3264 - val_accuracy: 0.8514
# Epoch 49/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2839 - accuracy: 0.8705 - val_loss: 0.3431 - val_accuracy: 0.8468
# Epoch 50/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2870 - accuracy: 0.8682 - val_loss: 0.3202 - val_accuracy: 0.8532

# %% [markdown]
# # Đánh giá model

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline



def _evaluate(model, x_test):
  y_pred = model.predict(x_test)
  predictions = (y_pred > 0.5)
  print('Evaluation on test dataset')
  get_metrics(y_test, predictions)

  # Plot the confusion matrix
  classes=['0','1']
  cm = confusion_matrix(y_test, predictions)
  plt.imshow(cm, interpolation="nearest", cmap=plt.cm.Blues)
  plt.colorbar()
  tick_marks = np.arange(2)
  plt.xticks(tick_marks, classes, rotation=85)
  plt.yticks(tick_marks, classes)
  plt.xlabel("Predicted")
  plt.ylabel("Actual")
  plt.show()

_evaluate(model, x_test)
# Out:
# Evaluation on test dataset
# ACCURACY_SCORE:  0.8532
# F1_SCORE:  0.7828
# CONFUSION_MATRIX:
#  [[3556  255]
#  [ 479  710]]
#
#               precision    recall  f1-score   support
#
#            0     0.8813    0.9331    0.9064      3811
#            1     0.7358    0.5971    0.6592      1189
#
#     accuracy                         0.8532      5000
#    macro avg     0.8085    0.7651    0.7828      5000
# weighted avg     0.8467    0.8532    0.8477      5000

# %% [markdown]
# # Thay activation function

# %%
# Define a classifier network
hl = 10 # Number of hidden layer nodes

def _init_model(hl = 10):
  model = Sequential()
  model.add(Dense(hl, input_dim=len(features), activation='sigmoid'))
  model.add(Dense(hl, input_dim=hl, activation='sigmoid'))
  model.add(Dense(6, input_dim=hl, activation='sigmoid'))
  model.add(Dense(1, input_dim=6, activation='sigmoid'))
  print(model.summary())
  return model

model = _init_model(hl=hl)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 10)                1090
#
#  dense_13 (Dense)            (None, 10)                110
#
#  dense_14 (Dense)            (None, 6)                 66
#
#  dense_15 (Dense)            (None, 1)                 7
#
# =================================================================
# Total params: 1,273
# Trainable params: 1,273
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#hyper-parameters for optimizer
learning_rate = 0.01
opt = optimizers.Adam(lr=learning_rate)

model.compile(loss='binary_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# Train the model
num_epochs = 50
history = model.fit(x_train, y_train, epochs=num_epochs, batch_size=16, validation_data=(x_test, y_test))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.3734 - accuracy: 0.8302 - val_loss: 0.3243 - val_accuracy: 0.8526
# Epoch 2/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.3307 - accuracy: 0.8498 - val_loss: 0.3238 - val_accuracy: 0.8472
# Epoch 3/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.3207 - accuracy: 0.8521 - val_loss: 0.3218 - val_accuracy: 0.8540
# Epoch 4/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.3154 - accuracy: 0.8540 - val_loss: 0.3249 - val_accuracy: 0.8454
# Epoch 5/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.3107 - accuracy: 0.8567 - val_loss: 0.3196 - val_accuracy: 0.8498
# Epoch 6/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.3070 - accuracy: 0.8583 - val_loss: 0.3241 - val_accuracy: 0.8486
# Epoch 7/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.3061 - accuracy: 0.8580 - val_loss: 0.3170 - val_accuracy: 0.8516
# Epoch 8/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.3030 - accuracy: 0.8575 - val_loss: 0.3212 - val_accuracy: 0.8452
# Epoch 9/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.3020 - accuracy: 0.8591 - val_loss: 0.3229 - val_accuracy: 0.8528
# Epoch 10/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.3009 - accuracy: 0.8605 - val_loss: 0.3252 - val_accuracy: 0.8498
# Epoch 11/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2998 - accuracy: 0.8594 - val_loss: 0.3252 - val_accuracy: 0.8492
# Epoch 12/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2975 - accuracy: 0.8593 - val_loss: 0.3231 - val_accuracy: 0.8468
# Epoch 13/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2957 - accuracy: 0.8619 - val_loss: 0.3212 - val_accuracy: 0.8498
# Epoch 14/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2949 - accuracy: 0.8625 - val_loss: 0.3222 - val_accuracy: 0.8480
# Epoch 15/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2943 - accuracy: 0.8616 - val_loss: 0.3205 - val_accuracy: 0.8506
# Epoch 16/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2943 - accuracy: 0.8621 - val_loss: 0.3190 - val_accuracy: 0.8484
# Epoch 17/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2927 - accuracy: 0.8626 - val_loss: 0.3238 - val_accuracy: 0.8494
# Epoch 18/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2917 - accuracy: 0.8638 - val_loss: 0.3244 - val_accuracy: 0.8518
# Epoch 19/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2903 - accuracy: 0.8648 - val_loss: 0.3226 - val_accuracy: 0.8506
# Epoch 20/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2913 - accuracy: 0.8641 - val_loss: 0.3249 - val_accuracy: 0.8482
# Epoch 21/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2900 - accuracy: 0.8653 - val_loss: 0.3298 - val_accuracy: 0.8480
# Epoch 22/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2896 - accuracy: 0.8639 - val_loss: 0.3320 - val_accuracy: 0.8480
# Epoch 23/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2887 - accuracy: 0.8673 - val_loss: 0.3279 - val_accuracy: 0.8460
# Epoch 24/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2881 - accuracy: 0.8643 - val_loss: 0.3354 - val_accuracy: 0.8490
# Epoch 25/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2867 - accuracy: 0.8662 - val_loss: 0.3312 - val_accuracy: 0.8498
# Epoch 26/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2862 - accuracy: 0.8665 - val_loss: 0.3286 - val_accuracy: 0.8474
# Epoch 27/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2864 - accuracy: 0.8666 - val_loss: 0.3394 - val_accuracy: 0.8470
# Epoch 28/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2853 - accuracy: 0.8654 - val_loss: 0.3268 - val_accuracy: 0.8482
# Epoch 29/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2847 - accuracy: 0.8672 - val_loss: 0.3344 - val_accuracy: 0.8486
# Epoch 30/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2850 - accuracy: 0.8664 - val_loss: 0.3362 - val_accuracy: 0.8474
# Epoch 31/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2839 - accuracy: 0.8678 - val_loss: 0.3346 - val_accuracy: 0.8470
# Epoch 32/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2836 - accuracy: 0.8688 - val_loss: 0.3323 - val_accuracy: 0.8476
# Epoch 33/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2833 - accuracy: 0.8687 - val_loss: 0.3352 - val_accuracy: 0.8514
# Epoch 34/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2834 - accuracy: 0.8688 - val_loss: 0.3315 - val_accuracy: 0.8492
# Epoch 35/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2827 - accuracy: 0.8689 - val_loss: 0.3399 - val_accuracy: 0.8426
# Epoch 36/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2824 - accuracy: 0.8676 - val_loss: 0.3376 - val_accuracy: 0.8494
# Epoch 37/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2813 - accuracy: 0.8683 - val_loss: 0.3355 - val_accuracy: 0.8466
# Epoch 38/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2817 - accuracy: 0.8690 - val_loss: 0.3373 - val_accuracy: 0.8472
# Epoch 39/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2801 - accuracy: 0.8699 - val_loss: 0.3338 - val_accuracy: 0.8498
# Epoch 40/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2811 - accuracy: 0.8695 - val_loss: 0.3335 - val_accuracy: 0.8474
# Epoch 41/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2804 - accuracy: 0.8692 - val_loss: 0.3404 - val_accuracy: 0.8464
# Epoch 42/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2784 - accuracy: 0.8709 - val_loss: 0.3430 - val_accuracy: 0.8462
# Epoch 43/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2814 - accuracy: 0.8698 - val_loss: 0.3353 - val_accuracy: 0.8484
# Epoch 44/50
# 1250/1250 [==============================] - 3s 3ms/step - loss: 0.2787 - accuracy: 0.8690 - val_loss: 0.3372 - val_accuracy: 0.8450
# Epoch 45/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2787 - accuracy: 0.8708 - val_loss: 0.3390 - val_accuracy: 0.8506
# Epoch 46/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2791 - accuracy: 0.8694 - val_loss: 0.3422 - val_accuracy: 0.8486
# Epoch 47/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2785 - accuracy: 0.8696 - val_loss: 0.3463 - val_accuracy: 0.8436
# Epoch 48/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2785 - accuracy: 0.8697 - val_loss: 0.3329 - val_accuracy: 0.8464
# Epoch 49/50
# 1250/1250 [==============================] - 2s 2ms/step - loss: 0.2777 - accuracy: 0.8706 - val_loss: 0.3351 - val_accuracy: 0.8470
# Epoch 50/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2782 - accuracy: 0.8709 - val_loss: 0.3427 - val_accuracy: 0.8478

# %%
_evaluate(model, x_test)
# Out:
# Evaluation on test dataset
# ACCURACY_SCORE:  0.8504
# F1_SCORE:  0.788
# CONFUSION_MATRIX:
#  [[3482  329]
#  [ 419  770]]
#
#               precision    recall  f1-score   support
#
#            0     0.8926    0.9137    0.9030      3811
#            1     0.7006    0.6476    0.6731      1189
#
#     accuracy                         0.8504      5000
#    macro avg     0.7966    0.7806    0.7880      5000
# weighted avg     0.8469    0.8504    0.8483      5000

# %% [markdown]
# Nhận xét: Khi sử dụng hàm activation function là hàm `sigmoid` có thể khiến cho accuracy tăng lên một chút so với `relu` nhưng gây tốn kém hơn về mặt chi phí tính toán.
