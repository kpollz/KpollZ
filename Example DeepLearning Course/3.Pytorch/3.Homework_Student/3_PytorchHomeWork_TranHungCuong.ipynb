# %% [markdown]
# # 1. Lý thuyết

# %% [markdown]
# Đáp án đúng được **tô đậm**

# %% [markdown]
# **1) Để khởi tạo model trong pytorch chúng ta sử dụng class nào?**
#
# **A. nn.Module**
#
# B. nn.Dense
#
# C. nn.optim.Adam
#
# D. nn.Dropout
#
# **2) Để khởi tạo mạng neural network trong pytorch chúng ta cần làm gì ?**
#
# A. Kế thừa lại class `nn.Model`. Khởi tạo các layers trong hàm tạo `__init__()` và sử dụng các layers để tính toán dữ liệu trong hàm `forward()`.
#
# B. Khởi tạo một object của class `nn.Model` và sử dụng hàm `add()` để thêm từng layer vào mô hình.
#
# C. Sử dụng class `nn.Model` để khởi tạo mô hình. Truyền vào bên trong class này một list gồm các layers.
#
# **D. Kế thừa lại class `nn.Module`. Khởi tạo các layers trong hàm tạo `__init__()` và sử dụng các layers để tính toán dữ liệu trong hàm `forward()`.**
#
#
# **3) Các modules chính trong pytorch dùng để xây dựng và huấn luyện model.**
#
# A. `torch.nn`: Dùng để khởi tạo các layers và activations function và loss function, `torch.optim`: Khởi tạo optimizer, `torch.data`: Khởi tạo dataset và dataloader.
#
# **B. `torch.nn`: Dùng để khởi tạo các layers và activations function và loss function, `torch.optim`: Khởi tạo optimizer, `torch.utils.data`: Khởi tạo dataset và dataloader.**
#
# C. `torch.nn`: Dùng để khởi tạo các layers và activations function, `torch.optim`: Khởi tạo optimizer, `torch.data`: Khởi tạo dataset và dataloader, `torch.loss`: Khởi tạo loss function.
#
# D. `torch.nn`: Dùng để khởi tạo các layers và loss function, `torch.optim`: Khởi tạo optimizer, `torch.data`: Khởi tạo dataset và dataloader, `torch.activations`: Khởi tạo activations function.
#
#
# **4) Để customize một Dataset trên pytorch chúng ta cần thực hiện như thế nào?**
#
# A. Sử dụng thuộc tính `transformer` để qui định các biến đổi trên dữ liệu. Những biến đổi này được thực hiện trên hàm tạo.
#
# **B. Khởi tạo một class kế thừa lại `torch.utils.data.Dataset`. Khai báo các thuộc tính cần sử dụng trong hàm tạo của dataset như list đường dẫn, list label. Override lại hàm `__getitem__()` để thực hiện các xử lý trên dữ liệu**.
#
# C. Kế thừa lại một class `Dataset`. Các điều chỉnh trên dữ liệu được thực hiện trên hàm `transformer()`.
#
# D. Sử dụng hàm `__getitem__()` để trả về toàn bộ các quan sát khi huấn luyện.
#
# **5) Ý nghĩa của tham số epochs và batch_size trong huấn luyện mô hình là gì?**
#
# A. epochs là kích thước của một mini-batch, batch_size là số lượt lặp lại toàn bộ dữ liệu khi huấn luyện.
#
# B. epochs là số lượt lặp lại toàn bộ dữ liệu validation khi huấn luyện, batch_size là kích thước của một mini-batch.
#
# **C. epochs là số lượt lặp lại toàn bộ dữ liệu train khi huấn luyện, batch_size là kích thước của một mini-batch.**
#
# D. epochs là số lượng vòng lặp, mỗi vòng lặp là một lượt fit mini-batch, trên bộ dữ liệu khi huấn luyện; batch_size là kích thước của một mini-batch.

# %% [markdown]
# # 2. Thực hành
#
# 6) Khởi tạo một tensor 3 chiều với định dạng là float và kích thước là 32x32x3

# %%
import torch
A = torch.randn((32, 32, 3))
print(A)
# Out:
# tensor([[[-7.7260e-01,  4.7699e-02, -2.6123e-01],
#          [-4.0675e-01, -1.2968e+00,  7.5365e-01],
#          [-2.7620e-01,  3.1500e-01,  3.0793e-01],
#          ...,
#          [ 7.4117e-01, -6.6821e-01, -2.2895e-01],
#          [ 2.8328e-01, -4.9768e-01,  7.8538e-01],
#          [ 1.8295e-01, -2.7105e-01,  4.2766e-01]],
#
#         [[-4.3645e-01,  4.2502e-01, -2.4842e+00],
#          [-6.6668e-02,  4.7872e-01, -1.5022e-01],
#          [-4.4809e-01, -2.8034e-01,  3.4022e-02],
#          ...,
#          [-1.1441e+00,  1.4940e+00, -1.3237e+00],
#          [-1.1424e+00, -5.6397e-01,  1.2559e+00],
#          [-7.9169e-01, -2.3798e+00, -4.3214e-01]],
#
#         [[ 1.0982e+00,  8.9615e-01,  1.1107e+00],
#          [ 1.0041e+00,  1.2680e+00, -5.7640e-01],
#          [ 1.7992e+00, -2.3098e+00, -1.3206e+00],
#          ...,
#          [-8.5041e-01, -3.4088e+00,  2.2002e-03],
#          [ 1.1173e-01,  2.6251e+00,  2.5920e+00],
#          [-8.2787e-01, -4.4273e-01,  1.1565e+00]],
#
#         ...,
#
#         [[-1.5024e+00,  1.8242e+00, -6.5725e-01],
#          [ 5.5663e-01,  3.1052e-01, -1.0726e+00],
#          [-1.1407e+00,  9.9645e-02,  6.2425e-02],
#          ...,
#          [-7.6785e-02,  1.4347e+00,  1.9366e+00],
#          [-9.3952e-01,  8.1015e-01,  4.1191e-01],
#          [-3.0320e-01, -6.1056e-01,  1.1405e-01]],
#
#         [[-1.7333e+00, -4.5580e-01,  1.8459e-01],
#          [-2.0626e+00, -2.1657e-01,  2.1721e+00],
#          [ 5.5929e-01,  2.7797e-01,  1.6471e+00],
#          ...,
#          [-1.3184e+00, -4.5298e-01, -1.1570e-01],
#          [ 1.4008e+00,  8.7912e-01, -6.2225e-02],
#          [-3.5272e-01, -4.6495e-01,  8.7995e-01]],
#
#         [[-2.5217e-01,  8.1763e-02, -1.2690e+00],
#          [ 2.0576e-01,  5.3178e-01,  6.6728e-01],
#          [-3.2465e-02,  4.0499e-01, -9.1630e-01],
#          ...,
#          [ 8.9473e-01,  1.1005e+00,  1.5906e+00],
#          [-2.3843e-01, -3.3052e-01, -2.9105e-01],
#          [-1.2069e+00, -3.7894e-01, -2.1483e-01]]])

# %%
print(A.shape)
# Out:
# torch.Size([32, 32, 3])

# %% [markdown]
# 7) Nếu coi tensor trên là một bức ảnh RGB với số channel là 3 ở cuối. Hãy truy suất các ma trận ảnh tương ứng với mỗi kênh R, G, B.

# %%
R_matrix = A[:,:,0]
print(R_matrix)
# Out:
# tensor([[-0.7726, -0.4067, -0.2762,  ...,  0.7412,  0.2833,  0.1829],
#         [-0.4365, -0.0667, -0.4481,  ..., -1.1441, -1.1424, -0.7917],
#         [ 1.0982,  1.0041,  1.7992,  ..., -0.8504,  0.1117, -0.8279],
#         ...,
#         [-1.5024,  0.5566, -1.1407,  ..., -0.0768, -0.9395, -0.3032],
#         [-1.7333, -2.0626,  0.5593,  ..., -1.3184,  1.4008, -0.3527],
#         [-0.2522,  0.2058, -0.0325,  ...,  0.8947, -0.2384, -1.2069]])

# %%
G_matrix = A[:,:,1]
print(G_matrix)
# Out:
# tensor([[ 0.0477, -1.2968,  0.3150,  ..., -0.6682, -0.4977, -0.2711],
#         [ 0.4250,  0.4787, -0.2803,  ...,  1.4940, -0.5640, -2.3798],
#         [ 0.8961,  1.2680, -2.3098,  ..., -3.4088,  2.6251, -0.4427],
#         ...,
#         [ 1.8242,  0.3105,  0.0996,  ...,  1.4347,  0.8101, -0.6106],
#         [-0.4558, -0.2166,  0.2780,  ..., -0.4530,  0.8791, -0.4649],
#         [ 0.0818,  0.5318,  0.4050,  ...,  1.1005, -0.3305, -0.3789]])

# %%
B_matrix = A[:,:,2]
print(B_matrix)
# Out:
# tensor([[-2.6123e-01,  7.5365e-01,  3.0793e-01,  ..., -2.2895e-01,
#           7.8538e-01,  4.2766e-01],
#         [-2.4842e+00, -1.5022e-01,  3.4022e-02,  ..., -1.3237e+00,
#           1.2559e+00, -4.3214e-01],
#         [ 1.1107e+00, -5.7640e-01, -1.3206e+00,  ...,  2.2002e-03,
#           2.5920e+00,  1.1565e+00],
#         ...,
#         [-6.5725e-01, -1.0726e+00,  6.2425e-02,  ...,  1.9366e+00,
#           4.1191e-01,  1.1405e-01],
#         [ 1.8459e-01,  2.1721e+00,  1.6471e+00,  ..., -1.1570e-01,
#          -6.2225e-02,  8.7995e-01],
#         [-1.2690e+00,  6.6728e-01, -9.1630e-01,  ...,  1.5906e+00,
#          -2.9105e-01, -2.1483e-01]])

# %% [markdown]
# 8) Thực hiện tích hadamard và tích thông thường giữa ma trận R và G.

# %% [markdown]
# Tích hadamard

# %%
#Cách 1
RG = R_matrix*G_matrix
print(RG)
# Out:
# tensor([[-0.0369,  0.5275, -0.0870,  ..., -0.4953, -0.1410, -0.0496],
#         [-0.1855, -0.0319,  0.1256,  ..., -1.7092,  0.6443,  1.8840],
#         [ 0.9842,  1.2732, -4.1557,  ...,  2.8989,  0.2933,  0.3665],
#         ...,
#         [-2.7407,  0.1728, -0.1137,  ..., -0.1102, -0.7611,  0.1851],
#         [ 0.7900,  0.4467,  0.1555,  ...,  0.5972,  1.2315,  0.1640],
#         [-0.0206,  0.1094, -0.0131,  ...,  0.9847,  0.0788,  0.4574]])

# %%
#Cách 2
RG = R_matrix.mul(G_matrix)
print(RG)
# Out:
# tensor([[-0.0369,  0.5275, -0.0870,  ..., -0.4953, -0.1410, -0.0496],
#         [-0.1855, -0.0319,  0.1256,  ..., -1.7092,  0.6443,  1.8840],
#         [ 0.9842,  1.2732, -4.1557,  ...,  2.8989,  0.2933,  0.3665],
#         ...,
#         [-2.7407,  0.1728, -0.1137,  ..., -0.1102, -0.7611,  0.1851],
#         [ 0.7900,  0.4467,  0.1555,  ...,  0.5972,  1.2315,  0.1640],
#         [-0.0206,  0.1094, -0.0131,  ...,  0.9847,  0.0788,  0.4574]])

# %%
#Cách 3
RG = torch.mul(R_matrix,G_matrix)
print(RG)
# Out:
# tensor([[-0.0369,  0.5275, -0.0870,  ..., -0.4953, -0.1410, -0.0496],
#         [-0.1855, -0.0319,  0.1256,  ..., -1.7092,  0.6443,  1.8840],
#         [ 0.9842,  1.2732, -4.1557,  ...,  2.8989,  0.2933,  0.3665],
#         ...,
#         [-2.7407,  0.1728, -0.1137,  ..., -0.1102, -0.7611,  0.1851],
#         [ 0.7900,  0.4467,  0.1555,  ...,  0.5972,  1.2315,  0.1640],
#         [-0.0206,  0.1094, -0.0131,  ...,  0.9847,  0.0788,  0.4574]])

# %% [markdown]
# Tích thông thường

# %%
#Cách 1
RG= R_matrix@G_matrix
print(RG)
print(RG.size())
# Out:
# tensor([[-1.5982e+00,  3.1170e+00, -2.7501e+00,  ...,  7.0757e+00,
#           8.9572e+00,  1.4851e+00],
#         [ 2.8609e-03, -7.0525e+00,  2.2002e+00,  ...,  1.3512e+00,
#          -5.7802e+00, -1.7299e+00],
#         [-3.9302e-01, -5.3099e-01, -6.7555e+00,  ..., -1.4306e+01,
#           2.1588e-01,  8.7812e-01],
#         ...,
#         [-8.6597e-01,  1.1642e+01,  3.9984e+00,  ...,  7.5806e+00,
#          -9.3452e+00,  5.1443e+00],
#         [-7.7007e-01, -5.6553e+00, -1.9450e+00,  ..., -3.8462e+00,
#           4.1375e+00,  1.1356e+01],
#         [ 1.2619e+00, -5.7139e-01, -7.6536e-01,  ..., -5.1212e-01,
#           4.1116e+00, -1.8514e+00]])
# torch.Size([32, 32])

# %%
#Cách 2
RG= torch.matmul(R_matrix,G_matrix)
print(RG) 
print(RG.size())
# Out:
# tensor([[-1.5982e+00,  3.1170e+00, -2.7501e+00,  ...,  7.0757e+00,
#           8.9572e+00,  1.4851e+00],
#         [ 2.8609e-03, -7.0525e+00,  2.2002e+00,  ...,  1.3512e+00,
#          -5.7802e+00, -1.7299e+00],
#         [-3.9302e-01, -5.3099e-01, -6.7555e+00,  ..., -1.4306e+01,
#           2.1588e-01,  8.7812e-01],
#         ...,
#         [-8.6597e-01,  1.1642e+01,  3.9984e+00,  ...,  7.5806e+00,
#          -9.3452e+00,  5.1443e+00],
#         [-7.7007e-01, -5.6553e+00, -1.9450e+00,  ..., -3.8462e+00,
#           4.1375e+00,  1.1356e+01],
#         [ 1.2619e+00, -5.7139e-01, -7.6536e-01,  ..., -5.1212e-01,
#           4.1116e+00, -1.8514e+00]])
# torch.Size([32, 32])

# %% [markdown]
# 9) Từ bộ dữ liệu [Income-Classification](https://www.kaggle.com/t/090688c8d33a40b68be9e271d6ba6bae) hãy chuẩn hóa dữ liệu và phân chia tập train/test theo tỷ lệ 80/20

# %% [markdown]
# (Cách xử lý dữ liệu tương tự như bài tập 2)

# %%
from google.colab import drive
import os
drive.mount("/content/drive")
folder_path = "/content/drive/MyDrive/Deep learning K1/2.Data"
os.chdir(folder_path)
# Out:
# Mounted at /content/drive

# %%
# Working with data
import numpy as np
import pandas as pd

# Visualizations
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
# %matplotlib inline

# Ignore warnings
import warnings
warnings.filterwarnings('ignore');

# %%
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix, plot_confusion_matrix

# %% [markdown]
# #1.Đọc dữ liệu

# %%
#Đọc dữ liệu
d_train = pd.read_csv("train.csv")
d_train.head()
# Out:
#    ID  age work_type  ...  hrs_per_week nationality  target_income
# 0   0   45   Private  ...            40          US              0
# 1   1   23   Private  ...            30          US              0
# 2   2   22   Private  ...            20       South              0
# 3   3   27   Private  ...            40          US              0
# 4   4   18   Private  ...            20          US              0
#
# [5 rows x 16 columns]

# %% [markdown]
# #2.Xử lý dữ liệu

# %%
d_train.describe()
# Out:
#                  ID           age  ...  hrs_per_week  target_income
# count  25000.000000  25000.000000  ...  25000.000000    25000.00000
# mean   12499.500000     38.568800  ...     40.392200        0.23944
# std     7217.022701     13.642694  ...     12.350547        0.42675
# min        0.000000     17.000000  ...      1.000000        0.00000
# 25%     6249.750000     28.000000  ...     40.000000        0.00000
# 50%    12499.500000     37.000000  ...     40.000000        0.00000
# 75%    18749.250000     48.000000  ...     45.000000        0.00000
# max    24999.000000     90.000000  ...     99.000000        1.00000
#
# [8 rows x 8 columns]

# %%
#Thông tin của các thuộc tính
d_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   25000 non-null  int64
#  1   age                  25000 non-null  int64
#  2   work_type            25000 non-null  object
#  3   final_weight         25000 non-null  int64
#  4   education            25000 non-null  object
#  5   total_education_yrs  25000 non-null  int64
#  6   marital_state        25000 non-null  object
#  7   job                  25000 non-null  object
#  8   status               25000 non-null  object
#  9   ethnicity            25000 non-null  object
#  10  sex                  25000 non-null  object
#  11  capital_gain         25000 non-null  int64
#  12  capital_loss         25000 non-null  int64
#  13  hrs_per_week         25000 non-null  int64
#  14  nationality          25000 non-null  object
#  15  target_income        25000 non-null  int64
# dtypes: int64(8), object(8)
# memory usage: 3.1+ MB

# %%
#Xóa thuộc tính ID
d_train = d_train.drop(['ID'], axis = 1)
d_train.head(20)
# Out:
#     age         work_type  ...  nationality target_income
# 0    45           Private  ...           US             0
# 1    23           Private  ...           US             0
# 2    22           Private  ...        South             0
# 3    27           Private  ...           US             0
# 4    18           Private  ...           US             0
# 5    44           Private  ...           US             0
# 6    27           Private  ...           US             0
# 7    38           Private  ...           US             1
# 8    59           Private  ...           US             1
# 9    69                 ?  ...           US             0
# 10   73  Self-emp-not-inc  ...           US             0
# 11   37           Private  ...           US             0
# 12   52         State-gov  ...           US             0
# 13   24           Private  ...           US             0
# 14   28         Local-gov  ...           US             0
# 15   27           Private  ...           US             0
# 16   38           Private  ...           US             1
# 17   36           Private  ...           US             0
# 18   49         Local-gov  ...           US             1
# 19   41           Private  ...           US             0
#
# [20 rows x 15 columns]

# %%
#Vẽ biểu đồ thuộc tính số
rcParams['figure.figsize'] = 15, 8
d_train[['age',		'final_weight',	'total_education_yrs',	'capital_gain',	'capital_loss',	'hrs_per_week']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f11ce8f19d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f11ce6d52d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f11ce68bf50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f11cf132b50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f11cf1ee1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f11d02aaa90>]],
#       dtype=object)

# %%
#Phân chia miền giá trị của các thuộc tính số thành các bins
d_train['age'] = pd.cut(d_train['age'], bins = [0, 25, 50, 100], labels = ['Young', 'Adult', 'Old'])

# %%
d_train['hrs_per_week'] = pd.cut(d_train['hrs_per_week'], 
                                   bins = [0, 30, 40, 100], 
                                   labels = ['Lesser Hours', 'Normal Hours', 'Extra Hours'])

# %%
sns.countplot(x = 'hrs_per_week', hue = 'target_income', data = d_train)

# %%
#Ma trận tương quan giữa thuộc tính số với thuộc tính mục tiêu
plt.matshow(d_train.corr())
plt.colorbar()
plt.xticks(np.arange(len(d_train.corr().columns)), d_train.corr().columns.values, rotation = 45) 
plt.yticks(np.arange(len(d_train.corr().columns)), d_train.corr().columns.values) 
for (i, j), corr in np.ndenumerate(d_train.corr()):
    plt.text(j, i, '{:0.1f}'.format(corr), ha='center', va='center', color='white', fontsize=14)

# %%
#Xóa thuộc tính final_weight do hệ số tương quan nhỏ nhất (xấp xỉ 0.0)
d_train = d_train.drop(['final_weight'], axis = 1)

# %%
sns.countplot(x = 'work_type', hue = 'target_income', data = d_train)

# %%
#Xóa 2 giá trị có tần xuất gần như bằng 0
d_train = d_train.drop(d_train[d_train['work_type'] == 'Without-pay'].index)
d_train = d_train.drop(d_train[d_train['work_type'] == 'Never-worked'].index)

# %%
#Xét sự tương đương giữa 2 thuộc tính `education` và `total_education_yrs'
education_classes = d_train['education'].unique()
for edu_class in education_classes:
    print("Trình độ {} có Education number là {}"
          .format(edu_class, d_train[d_train['education'] == edu_class]['total_education_yrs'].unique()))
# Out:
# Trình độ HS-grad có Education number là [9]
# Trình độ Some-college có Education number là [10]
# Trình độ Prof-school có Education number là [15]
# Trình độ 11th có Education number là [7]
# Trình độ Bachelors có Education number là [13]
# Trình độ Masters có Education number là [14]
# Trình độ 9th có Education number là [5]
# Trình độ Doctorate có Education number là [16]
# Trình độ 7th-8th có Education number là [4]
# Trình độ 10th có Education number là [6]
# Trình độ 1st-4th có Education number là [2]
# Trình độ Assoc-acdm có Education number là [12]
# Trình độ Assoc-voc có Education number là [11]
# Trình độ 12th có Education number là [8]
# Trình độ 5th-6th có Education number là [3]
# Trình độ Preschool có Education number là [1]

# %%
d_train.drop(['total_education_yrs'], axis = 1, inplace = True)
d_train['education'].replace([' 11th', ' 9th', ' 7th-8th', ' 5th-6th', ' 10th', ' 1st-4th', ' Preschool', ' 12th'],
                             ' School', inplace = True)
d_train['education'].value_counts()
# Out:
# HS-grad         8054
# Some-college    5667
# Bachelors       4053
# Masters         1323
# Assoc-voc       1059
# 11th             871
# Assoc-acdm       825
# 10th             727
# 7th-8th          464
# Prof-school      460
# 9th              411
# 12th             333
# Doctorate        307
# 5th-6th          263
# 1st-4th          130
# Preschool         38
# Name: education, dtype: int64

# %%
d_train['education'].replace(['11th', '9th', '7th-8th', '5th-6th', '10th', '1st-4th', 'Preschool', '12th'], 'School', inplace = True)

# %%
sns.countplot(x = 'ethnicity', hue = 'target_income', data = d_train)

# %%
d_train['ethnicity'].unique()
d_train['ethnicity'].replace([' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo', ' Other'],' Other', inplace = True)

# %%
#Thuộc tính mục tiêu
rcParams['figure.figsize'] = 10, 5
d_train[['target_income']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f11ce2e9f90>]],
#       dtype=object)

# %%
print('Tổng số quan sát : {}\n'.format(len(d_train)))

print('Số người thu nhập >50K : {}%\n'.format(
    round((len(d_train[d_train['target_income']==1])/32561)*100, 2)))

print('Số người thu nhập <=50K : {}%'.format(
    round((len(d_train[d_train['target_income']==0])/32561)*100, 2)))
# Out:
# Tổng số quan sát : 24985
#
# Số người thu nhập >50K : 18.38%
#
# Số người thu nhập <=50K : 58.35%

# %% [markdown]
# Dữ liệu mất cân bằng (không nghiêm trọng) nên để đánh giá mô hình ngoài accuracy, ta có thể sử dụng thêm F1-score, ROC, AUC.

# %%
country_count = d_train['nationality'].value_counts()
country_count
# Out:
# US                            22382
# Mexico                          489
# ?                               443
# Philippines                     152
# Germany                         104
# Canada                           95
# Puerto-Rico                      91
# El-Salvador                      83
# India                            79
# Cuba                             78
# England                          73
# South                            63
# China                            61
# Italy                            59
# Jamaica                          57
# Dominican-Republic               53
# Japan                            48
# Guatemala                        48
# Columbia                         46
# Poland                           46
# Vietnam                          45
# Haiti                            33
# Iran                             33
# Taiwan                           33
# Portugal                         28
# Nicaragua                        26
# Peru                             23
# Ecuador                          22
# France                           21
# Ireland                          19
# Greece                           18
# Thailand                         16
# Cambodia                         16
# Trinadad&Tobago                  15
# Yugoslavia                       14
# Laos                             13
# Outlying-US(Guam-USVI-etc)       13
# Hong                             13
# Hungary                          12
# Scotland                         11
# Honduras                         10
# Holand-Netherlands                1
# Name: nationality, dtype: int64

# %%
plt.bar(country_count.index, country_count.values)
plt.xticks(rotation = 90)
plt.xlabel('nationality')
plt.ylabel('Count')
plt.title('Tổng số người lớn từ mỗi quốc gia')
# Out:
# Text(0.5, 1.0, 'Tổng số người lớn từ mỗi quốc gia')

# %% [markdown]
# Đa số quốc tịch US, nên ta phân giá trị của thuộc tính này thành hai loại `US` và `Other`

# %%
countries = np.array(d_train['nationality'].unique())
countries = np.delete(countries, 0)

# %%
d_train['nationality'].replace(countries, 'Other', inplace = True)

# %%
sns.countplot(x = 'nationality', hue = 'target_income', data = d_train)

# %% [markdown]
# ###Phân chia dữ liệu 80:20

# %%
dtrain = d_train.drop(['target_income'], axis = 1)
y_train = d_train['target_income']

# %%
dtrain.head(10)
# Out:
#      age work_type     education  ... capital_loss  hrs_per_week nationality
# 0  Adult   Private       HS-grad  ...            0  Normal Hours          US
# 1  Young   Private  Some-college  ...            0  Lesser Hours          US
# 2  Young   Private  Some-college  ...            0  Lesser Hours       Other
# 3  Adult   Private   Prof-school  ...            0  Normal Hours          US
# 4  Young   Private        School  ...            0  Lesser Hours          US
# 5  Adult   Private     Bachelors  ...            0   Extra Hours          US
# 6  Adult   Private        School  ...            0  Normal Hours          US
# 7  Adult   Private     Bachelors  ...            0   Extra Hours          US
# 8    Old   Private     Bachelors  ...         1977   Extra Hours          US
# 9    Old         ?       HS-grad  ...            0  Normal Hours          US
#
# [10 rows x 12 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(dtrain, y_train, test_size=0.2)

# %%
#Loại bỏ khoảng trống không cần thiết
Xtrain=Xtrain.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
Xtest=Xtest.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
#Thống kê thuộc tính có giá trị '?'
Xtrain.isin(['?']).sum()
# Out:
# age                 0
# work_type        1104
# education           0
# marital_state       0
# job              1104
# status              0
# ethnicity           0
# sex                 0
# capital_gain        0
# capital_loss        0
# hrs_per_week        0
# nationality         0
# dtype: int64

# %%
Xtest.isin(['?']).sum()
# Out:
# age                0
# work_type        275
# education          0
# marital_state      0
# job              275
# status             0
# ethnicity          0
# sex                0
# capital_gain       0
# capital_loss       0
# hrs_per_week       0
# nationality        0
# dtype: int64

# %%
# Thay thế '?' bằng np.nan
Xtrain = Xtrain.replace(to_replace='?', value=np.nan)
Xtest = Xtest.replace(to_replace='?', value=np.nan)

# %%
#Thay thế np.nan bằng từ có tần suất xuất hiện lớn nhất
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="most_frequent")

# %%
imputer.fit(Xtrain[['work_type']])
imputer.fit(Xtrain[['job']])
#imputer.fit(Xtrain[['nationality']])
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
Xtrain['work_type'] = imputer.transform(Xtrain[['work_type']])
Xtrain['job'] = imputer.transform(Xtrain[['job']])
#Xtrain['nationality'] = imputer.transform(Xtrain[['nationality']])

# %%
Xtest['work_type'] = imputer.transform(Xtest[['work_type']])
Xtest['job'] = imputer.transform(Xtest[['job']])
#Xtest['nationality'] = imputer.transform(Xtest[['nationality']])

# %%
Xtrain.isin(['?']).sum()
# Out:
# age              0
# work_type        0
# education        0
# marital_state    0
# job              0
# status           0
# ethnicity        0
# sex              0
# capital_gain     0
# capital_loss     0
# hrs_per_week     0
# nationality      0
# dtype: int64

# %%
#Chuẩn hóa dữ liệu
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(Xtrain[['capital_gain', 'capital_loss']])
# Out:
# StandardScaler()

# %%
input_minmax_xtrain = scaler.transform(Xtrain[['capital_gain', 'capital_loss']])
scaled_xtrain = pd.DataFrame(input_minmax_xtrain,columns=['capital_gain', 'capital_loss'])

# %%
input_minmax_xtest = scaler.transform(Xtest[['capital_gain', 'capital_loss']])
scaled_xtest = pd.DataFrame(input_minmax_xtest,columns=['capital_gain', 'capital_loss'])

# %%
Xtrain_minmax_scaled = scaled_xtrain.join(Xtrain.drop(['capital_gain', 'capital_loss'],axis=1))

# %%
Xtest_minmax_scaled = scaled_xtest.join(Xtest.drop(['capital_gain', 'capital_loss'],axis=1))

# %%
Xtrain_minmax_scaled.head(20)
# Out:
#     capital_gain  capital_loss    age  ...  sex  hrs_per_week nationality
# 0      -0.146839     -0.212994  Adult  ...    M  Normal Hours          US
# 1      -0.146839      3.513878  Young  ...    M  Lesser Hours          US
# 2      -0.146839     -0.212994    NaN  ...  NaN           NaN         NaN
# 3      -0.146839     -0.212994  Adult  ...    M  Normal Hours          US
# 4      -0.146839     -0.212994  Young  ...    F  Lesser Hours          US
# 5      -0.146839     -0.212994  Adult  ...    M   Extra Hours          US
# 6      -0.146839     -0.212994  Adult  ...    M  Normal Hours          US
# 7      -0.146839     -0.212994  Adult  ...    M   Extra Hours          US
# 8      -0.146839     -0.212994    NaN  ...  NaN           NaN         NaN
# 9       0.501788     -0.212994    Old  ...    F  Normal Hours          US
# 10      0.554768     -0.212994    Old  ...    F  Normal Hours          US
# 11      0.554768     -0.212994    NaN  ...  NaN           NaN         NaN
# 12     -0.146839     -0.212994    Old  ...    F  Normal Hours          US
# 13     -0.146839     -0.212994  Young  ...    M  Normal Hours          US
# 14     -0.146839     -0.212994    NaN  ...  NaN           NaN         NaN
# 15     -0.146839     -0.212994  Adult  ...    F  Normal Hours          US
# 16     -0.146839     -0.212994  Adult  ...    M   Extra Hours          US
# 17     -0.146839     -0.212994  Adult  ...    F   Extra Hours          US
# 18     13.402803     -0.212994    NaN  ...  NaN           NaN         NaN
# 19     -0.146839     -0.212994    NaN  ...  NaN           NaN         NaN
#
# [20 rows x 12 columns]

# %%
print(Xtrain.shape, Xtest.shape)
# Out:
# (19988, 12) (4997, 12)

# %%
#Chuyển ữ liệu về dạng 0-1
X_train = pd.get_dummies(Xtrain_minmax_scaled)
X_test = pd.get_dummies(Xtest_minmax_scaled)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (19988, 60) (4997, 60)

# %%
X_train.head(10)
# Out:
#    capital_gain  capital_loss  ...  nationality_Other  nationality_US
# 0     -0.146839     -0.212994  ...                  0               1
# 1     -0.146839      3.513878  ...                  0               1
# 2     -0.146839     -0.212994  ...                  0               0
# 3     -0.146839     -0.212994  ...                  0               1
# 4     -0.146839     -0.212994  ...                  0               1
# 5     -0.146839     -0.212994  ...                  0               1
# 6     -0.146839     -0.212994  ...                  0               1
# 7     -0.146839     -0.212994  ...                  0               1
# 8     -0.146839     -0.212994  ...                  0               0
# 9      0.501788     -0.212994  ...                  0               1
#
# [10 rows x 60 columns]

# %%
X_test.head(10)
# Out:
#    capital_gain  capital_loss  ...  nationality_Other  nationality_US
# 0     -0.146839     -0.212994  ...                  0               0
# 1     -0.146839     -0.212994  ...                  0               0
# 2     -0.146839     -0.212994  ...                  1               0
# 3      0.842023     -0.212994  ...                  0               0
# 4     -0.146839     -0.212994  ...                  0               0
# 5     -0.146839     -0.212994  ...                  0               0
# 6     -0.146839     -0.212994  ...                  0               0
# 7     -0.146839      4.106162  ...                  0               0
# 8     -0.146839     -0.212994  ...                  0               1
# 9     -0.146839     -0.212994  ...                  0               0
#
# [10 rows x 60 columns]

# %%
print(X_train.shape, X_test.shape)
# Out:
# (19988, 60) (4997, 60)

# %% [markdown]
# ###Ghi dữ liệu

# %%
X_train.to_csv("xtrain2.csv", index=None)
ytrain.to_csv("ytrain2.csv", index=None)
X_test.to_csv("xtest2.csv", index=None)
ytest.to_csv("ytest2.csv", index=None)

# %% [markdown]
# 10) Xây dựng một mạng deep-neural-network để huấn luyện mô hình trên dữ liệu train và đánh giá mô hình trên dữ liệu test.

# %% [markdown]
# Đọc dữ liệu vừa được ghi

# %%
Xtrain = pd.read_csv("xtrain2.csv")
ytrain = pd.read_csv("ytrain2.csv")
Xtest = pd.read_csv("xtest2.csv")
ytest = pd.read_csv("ytest2.csv")

# %%
print(Xtrain.shape, Xtest.shape)
# Out:
# (19988, 60) (4997, 60)

# %%
Xtrain.head(10)
# Out:
#    capital_gain  capital_loss  ...  nationality_Other  nationality_US
# 0     -0.146839     -0.212994  ...                  0               1
# 1     -0.146839      3.513878  ...                  0               1
# 2     -0.146839     -0.212994  ...                  0               0
# 3     -0.146839     -0.212994  ...                  0               1
# 4     -0.146839     -0.212994  ...                  0               1
# 5     -0.146839     -0.212994  ...                  0               1
# 6     -0.146839     -0.212994  ...                  0               1
# 7     -0.146839     -0.212994  ...                  0               1
# 8     -0.146839     -0.212994  ...                  0               0
# 9      0.501788     -0.212994  ...                  0               1
#
# [10 rows x 60 columns]

# %%
# !pip freeze | grep torch
# Out:
# torch @ https://download.pytorch.org/whl/cu111/torch-1.10.0%2Bcu111-cp37-cp37m-linux_x86_64.whl
# torchaudio @ https://download.pytorch.org/whl/cu111/torchaudio-0.10.0%2Bcu111-cp37-cp37m-linux_x86_64.whl
# torchsummary==1.5.1
# torchtext==0.11.0
# torchvision @ https://download.pytorch.org/whl/cu111/torchvision-0.11.1%2Bcu111-cp37-cp37m-linux_x86_64.whl

# %%
import torch
import torch.nn as nn
import torch.utils.data as td

# Set random seed for reproducability
torch.manual_seed(0)

print("Libraries imported - ready to use PyTorch", torch.__version__)
# Out:
# Libraries imported - ready to use PyTorch 1.10.0+cu111

# %%
# Create a dataset and loader for the training data and labels
train_x = torch.Tensor(Xtrain.values).float()
train_y = torch.Tensor(ytrain.values).float()
train_ds = td.TensorDataset(train_x,train_y)
train_loader = td.DataLoader(train_ds, batch_size=20, shuffle=True, num_workers=1)

# %%
print(train_x.shape)
# Out:
# torch.Size([19988, 60])

# %%
print(len(train_x[1]))
# Out:
# 60

# %%
print(train_x[:5])
# Out:
# tensor([[-0.1468, -0.2130,  0.0000,  1.0000,  0.0000,  0.0000,  0.0000,  1.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           1.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  1.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  1.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000,
#           1.0000,  0.0000,  0.0000,  1.0000],
#         [-0.1468,  3.5139,  1.0000,  0.0000,  0.0000,  0.0000,  0.0000,  1.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  1.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  1.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  1.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  1.0000,
#           0.0000,  0.0000,  0.0000,  1.0000],
#         [-0.1468, -0.2130,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000],
#         [-0.1468, -0.2130,  0.0000,  1.0000,  0.0000,  0.0000,  0.0000,  1.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  1.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  1.0000,  0.0000,  0.0000,  0.0000,  0.0000,  1.0000,  0.0000,
#           1.0000,  0.0000,  0.0000,  1.0000],
#         [-0.1468, -0.2130,  1.0000,  0.0000,  0.0000,  0.0000,  0.0000,  1.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  1.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  1.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  1.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  1.0000,  1.0000,  0.0000,  1.0000,
#           0.0000,  0.0000,  0.0000,  1.0000]])

# %%
# Create a dataset and loader for the test data and labels
test_x = torch.Tensor(Xtest.values).float()
test_y = torch.Tensor(ytest.values).float()
test_ds = td.TensorDataset(test_x,test_y)
test_loader = td.DataLoader(test_ds, batch_size=20, shuffle=False, num_workers=1)

# %%
print(Xtest.values)
# Out:
# [[-0.14683947 -0.21299354  0.         ...  0.          0.
#    0.        ]
#  [-0.14683947 -0.21299354  0.         ...  0.          0.
#    0.        ]
#  [-0.14683947 -0.21299354  1.         ...  0.          1.
#    0.        ]
#  ...
#  [-0.14683947 -0.21299354  0.         ...  0.          0.
#    0.        ]
#  [-0.14683947 -0.21299354  0.         ...  0.          0.
#    0.        ]
#  [-0.14683947 -0.21299354  0.         ...  1.          0.
#    1.        ]]

# %%
print(test_x)
# Out:
# tensor([[-0.1468, -0.2130,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [-0.1468, -0.2130,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [-0.1468, -0.2130,  1.0000,  ...,  0.0000,  1.0000,  0.0000],
#         ...,
#         [-0.1468, -0.2130,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [-0.1468, -0.2130,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [-0.1468, -0.2130,  0.0000,  ...,  1.0000,  0.0000,  1.0000]])

# %%
print(test_x.shape)
# Out:
# torch.Size([4997, 60])

# %% [markdown]
# #Xây dựng mô hình

# %%
# Number of hidden layer nodes
hl1 = 8
hl2 = 4

# Define the neural network
class IncomeCL(nn.Module):
    def __init__(self):
        super(IncomeCL, self).__init__()
        self.fc1 = nn.Linear(len(train_x[1]), hl1)
        self.fc2 = nn.Linear(hl1, hl2)
        self.fc3 = nn.Linear(hl2, 1)
        self.random_state = 42

    def forward(self, x):
        x = torch.sigmoid(self.fc1(x))
        x = torch.sigmoid(self.fc2(x))
        x = torch.sigmoid(self.fc3(x))
        return x

# Create a model instance from the network
model = IncomeCL()
print(model)
# Out:
# IncomeCL(
#   (fc1): Linear(in_features=60, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=4, bias=True)
#   (fc3): Linear(in_features=4, out_features=1, bias=True)
# )

# %%
params = list(model.parameters())
print(len(params))
print(params[0].size())
# Out:
# 6
# torch.Size([8, 60])

# %%
# !pip install torchviz

# %% [markdown]
# #Huấn luyện mô hình

# %%
def train(model, data_loader, optimizer):
    # Set the model to training mode
    model.train()
    train_loss = 0
    
    for batch, tensor in enumerate(data_loader):
        data, target = tensor
        
        #Lan truyền tiến
        #feedforward: calculate y_pred and loss function
        optimizer.zero_grad()
        out = model(data)
        loss = nn.BCELoss()
        output = loss(out, target)
        train_loss += output.item()

        #Lan truyền ngược
        #backpropagate: compute gradient descent and update weights
        output.backward()
        optimizer.step()

    #Return average loss
    avg_loss = train_loss / (batch+1)
    print('Training set: Average loss: {:.4f}'.format(avg_loss))
    return avg_loss

# %%
def test(model, data_loader):
    # Switch the model to evaluation mode (so we don't backpropagate)
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
        batch_count = 0
        for batch, tensor in enumerate(data_loader):
            batch_count += 1
            data, target = tensor
            # Get the predictions
            out = model(data)

            # calculate the loss
            loss_criteria = nn.BCELoss()
            test_loss += loss_criteria(out, target).item()

            # Calculate the accuracy
            #print(out.data)
            predicted = out.data > 0.5
            correct += torch.sum(target==predicted).item()
            #print(target)
            #print(predicted)
            
    # Calculate the average loss and total accuracy for this epoch
    avg_loss = test_loss/batch_count
    print('Validation set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        avg_loss, correct, len(data_loader.dataset),
        100. * correct / len(data_loader.dataset)))
    avg_acc = correct / len(data_loader.dataset)
    
    # return average loss for the epoch
    return avg_loss, avg_acc

# %%
from pandas.core.common import random_state
def train_model(l_r):
  learning_rate = l_r #0.001
  random_state=42
  optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
  optimizer.zero_grad()

  # We'll track metrics for each epoch in these arrays
  epoch_nums = []
  training_loss = []
  validation_loss = []
  acc = []

  # Train over 50 epochs
  epochs = 50
  for epoch in range(1, epochs + 1):

      # print the epoch number
      print('Epoch: {}'.format(epoch))
      
      # Feed training data into the model to optimize the weights
      train_loss = train(model, train_loader, optimizer)
      
      # Feed the test data into the model to check its performance
      test_loss, test_acc = test(model, test_loader)
      
      # Log the metrics for this epoch
      epoch_nums.append(epoch)
      training_loss.append(train_loss)
      validation_loss.append(test_loss)
      acc.append(test_acc)
  return (epoch_nums, training_loss, validation_loss, acc)

# %%
def _train_model(l_r, ep):
  learning_rate = l_r #0.001
  random_state=42
  optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
  optimizer.zero_grad()

  # We'll track metrics for each epoch in these arrays
  epoch_nums = []
  training_loss = []
  validation_loss = []
  acc = []

  # Train over 50 epochs
  epochs = ep
  for epoch in range(1, epochs + 1):

      # print the epoch number
      print('Epoch: {}'.format(epoch))
      
      # Feed training data into the model to optimize the weights
      train_loss = train(model, train_loader, optimizer)
      
      # Feed the test data into the model to check its performance
      test_loss, test_acc = test(model, test_loader)
      
      # Log the metrics for this epoch
      epoch_nums.append(epoch)
      training_loss.append(train_loss)
      validation_loss.append(test_loss)
      acc.append(test_acc)
  return (epoch_nums, training_loss, validation_loss, acc)

# %%
epoch_nums, training_loss, validation_loss, acc = train_model(0.001)
# Out:
# Epoch: 1
# Training set: Average loss: 0.5570
# Validation set: Average loss: 0.5371, Accuracy: 3816/4997 (76%)
#
# Epoch: 2
# Training set: Average loss: 0.5316
  plt.xlabel('epoch')
  plt.ylabel('loss')
  plt.legend(['training', 'validation'], loc='upper right')
  plt.show()

# %% [markdown]
# Đồ thị của hàm loss

# %%
_plot(epoch_nums, training_loss, validation_loss)

# %% [markdown]
# Đồ thị của hàm loss trên tập train và trên tập valdid khá gần nhau. Điều này cho thấy mô hình khá ổn định.

# %%
#accuracy tương ứng với learning_rate = 0.001
plt.plot(epoch_nums, acc)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['accuracy'], loc='upper right')
plt.show()

# %% [markdown]
# Căn cứ trên đồ thị, ta có thấy epoch < 30 là tốt nhất

# %% [markdown]
# Thử với learning_rate = 0.0001, 0.001, và 0.1

# %%
epoch_nums2, training_loss2, validation_loss2, acc2 = train_model(0.0001)
# Out:
# Epoch: 1
# Training set: Average loss: 0.5986
# Validation set: Average loss: 0.5756, Accuracy: 3816/4997 (76%)
#
# Epoch: 2
# Training set: Average loss: 0.5649
# Validation set: Average loss: 0.5551, Accuracy: 3816/4997 (76%)
#
# Epoch: 3
# Training set: Average loss: 0.5537
# Validation set: Average loss: 0.5483, Accuracy: 3816/4997 (76%)
#
# Epoch: 4
# Training set: Average loss: 0.5503
# Validation set: Average loss: 0.5460, Accuracy: 3816/4997 (76%)
#
# Epoch: 5
# Training set: Average loss: 0.5492
# Validation set: Average loss: 0.5448, Accuracy: 3816/4997 (76%)
#
# Epoch: 6
# Training set: Average loss: 0.5485
# Validation set: Average loss: 0.5438, Accuracy: 3816/4997 (76%)
#
# Epoch: 7
# Training set: Average loss: 0.5473
# Validation set: Average loss: 0.5428, Accuracy: 3816/4997 (76%)
#
# Epoch: 8
# Training set: Average loss: 0.5463
# Validation set: Average loss: 0.5417, Accuracy: 3816/4997 (76%)
#
# Epoch: 9
# Training set: Average loss: 0.5448
# Validation set: Average loss: 0.5404, Accuracy: 3816/4997 (76%)
#
# Epoch: 10
# Training set: Average loss: 0.5435
# Validation set: Average loss: 0.5389, Accuracy: 3816/4997 (76%)
#
# Epoch: 11
# Training set: Average loss: 0.5416
# Validation set: Average loss: 0.5373, Accuracy: 3816/4997 (76%)
#
# Epoch: 12
# Training set: Average loss: 0.5398
# Validation set: Average loss: 0.5356, Accuracy: 3816/4997 (76%)
#
# Epoch: 13
# Training set: Average loss: 0.5379
# Validation set: Average loss: 0.5336, Accuracy: 3816/4997 (76%)
#
# Epoch: 14
# Training set: Average loss: 0.5357
# Validation set: Average loss: 0.5315, Accuracy: 3816/4997 (76%)
#
# Epoch: 15
# Training set: Average loss: 0.5335
# Validation set: Average loss: 0.5293, Accuracy: 3816/4997 (76%)
#
# Epoch: 16
# Training set: Average loss: 0.5308
# Validation set: Average loss: 0.5271, Accuracy: 3816/4997 (76%)
#
# Epoch: 17
# Training set: Average loss: 0.5283
# Validation set: Average loss: 0.5247, Accuracy: 3816/4997 (76%)
#
# Epoch: 18
# Training set: Average loss: 0.5258
# Validation set: Average loss: 0.5224, Accuracy: 3816/4997 (76%)
#
# Epoch: 19
# Training set: Average loss: 0.5230
# Validation set: Average loss: 0.5201, Accuracy: 3816/4997 (76%)
#
# Epoch: 20
# Training set: Average loss: 0.5206
# Validation set: Average loss: 0.5180, Accuracy: 3816/4997 (76%)
#
# Epoch: 21
# Training set: Average loss: 0.5179
# Validation set: Average loss: 0.5159, Accuracy: 3816/4997 (76%)
#
# Epoch: 22
# Validation set: Average loss: 0.4911, Accuracy: 3993/4997 (80%)
#
# Epoch: 48
# Training set: Average loss: 0.4896
# Validation set: Average loss: 0.4908, Accuracy: 3995/4997 (80%)
#
# Epoch: 49
# Training set: Average loss: 0.4862
# Validation set: Average loss: 0.5118, Accuracy: 3996/4997 (80%)
#
# Epoch: 50
# Training set: Average loss: 0.4858
# Validation set: Average loss: 0.4828, Accuracy: 4001/4997 (80%)

# %%
#Đồ thị hàm loss tương ướng với các learning_rate khác nhau
plt.plot(training_loss, label = "lr = 0.001", linestyle="-")
plt.plot(training_loss2, label = "lr = 0.0001", linestyle="--")
plt.plot(training_loss3, label = "lr = 0.1", linestyle="-.")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()

# %% [markdown]
# **Nhận xét**: Từ đồ thị trên ta có thể thấy rằng hệ số học learning_rate = 0.001 cho hàm loss tốt nhất (hàm loss giảm đều và nhỏ nhất).

# %%
#Accuracy với các learning_rate khác nhau
plt.plot(acc, label = "lr = 0.001", linestyle="-")
plt.plot(acc2, label = "lr = 0.0001", linestyle="--")
plt.plot(acc3, label = "lr = 0.1", linestyle="-.")
plt.xlabel("epoch")
plt.ylabel("accurcy")
plt.legend()
plt.show()

# %% [markdown]
# Hệ số learning_rate = 0.001 cho accuracy cao nhất.

# %% [markdown]
# #Đánh giá kết quả trên tập test

# %%
def _scores(model, Xtest):
  # predict probabilities for test set
  x = torch.Tensor(Xtest.values).float()
  predicted = model(x).data 
  yhat_probs= predicted >= 0.5

  # predict crisp classes for test set
  #yhat_classes = classifier.predict_classes(testX, verbose=0)
  yhat_classes = yhat_probs
  # reduce to 1d array
  yhat_probs = yhat_probs[:, 0]
  yhat_classes = yhat_classes[:, 0]
  
  # accuracy: (tp + tn) / (p + n)
  accuracy = accuracy_score(ytest, yhat_classes)
  print('Accuracy: %f' % accuracy)

  # precision tp / (tp + fp)
  precision = precision_score(ytest, yhat_classes)
  print('Precision: %f' % precision)

  # recall: tp / (tp + fn)
  recall = recall_score(ytest, yhat_classes)
  print('Recall: %f' % recall)

  # f1: 2 tp / (2 tp + fp + fn)
  f1 = f1_score(ytest, yhat_classes)
  print('F1 score: %f' % f1)
  
  # ROC AUC
  auc = roc_auc_score(ytest, yhat_probs)
  print('ROC AUC: %f' % auc)
  # confusion matrix
  print("confusion matrix:")
  matrix = confusion_matrix(ytest, yhat_classes)
  print(matrix)

# %% [markdown]
# Đánh giá mô hình

# %%
_scores(model, Xtest)
# Out:
# Accuracy: 0.802281
# Precision: 0.729216
# Recall: 0.259949
# F1 score: 0.383271
# ROC AUC: 0.615037
# confusion matrix:
# [[3702  114]
#  [ 874  307]]

# %% [markdown]
# ROC và AUC

# %%
from sklearn.metrics import roc_curve, auc
plt.figure(figsize = (12, 5))
plt.plot([0,1], [0,1], 'r--')
x = torch.Tensor(Xtest.values).float()
probs = model(x).data 
fpr, tpr, thresholds = roc_curve(ytest, probs)
roc_auc = auc(fpr, tpr)
label = 'AUC:' + ' {0:.2f}'.format(roc_auc)
plt.plot(fpr, tpr, label = label, linewidth = 4)

plt.xlabel('False Positive Rate', fontsize = 16)
plt.ylabel('True Positive Rate', fontsize = 16)
plt.title('Receiver Operating Characteristic', fontsize = 16)
plt.legend(loc = 'lower right', fontsize = 16)
