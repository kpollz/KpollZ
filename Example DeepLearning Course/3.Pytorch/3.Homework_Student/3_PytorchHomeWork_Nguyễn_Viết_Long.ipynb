# %% [markdown]
# # 1. Lý thuyết
#
# **1) Để khởi tạo model trong pytorch chúng ta sử dụng class nào?**
#
# A. nn.Module
#
# B. nn.Dense
#
# C. nn.optim.Adam
#
# D. nn.Dropout
#
# => Đáp án A
#
# **2) Để khởi tạo mạng neural network trong pytorch chúng ta cần làm gì ?**
#
# A. Kế thừa lại class `nn.Model`. Khởi tạo các layers trong hàm tạo `__init__()` và sử dụng các layers để tính toán dữ liệu trong hàm `forward()`.
#
# B. Khởi tạo một object của class `nn.Model` và sử dụng hàm `add()` để thêm từng layer vào mô hình.
#
# C. Sử dụng class `nn.Model` để khởi tạo mô hình. Truyền vào bên trong class này một list gồm các layers.
#
# D. Kế thừa lại class `nn.Module`. Khởi tạo các layers trong hàm tạo `__init__()` và sử dụng các layers để tính toán dữ liệu trong hàm `forward()`.
#
# => Đáp án D
#
# **3) Các modules chính trong pytorch dùng để xây dựng và huấn luyện model.**
#
# A. `torch.nn`: Dùng để khởi tạo các layers và activations function và loss function, `torch.optim`: Khởi tạo optimizer, `torch.data`: Khởi tạo dataset và dataloader.
#
# B. `torch.nn`: Dùng để khởi tạo các layers và activations function và loss function, `torch.optim`: Khởi tạo optimizer, `torch.utils.data`: Khởi tạo dataset và dataloader.
#
# C. `torch.nn`: Dùng để khởi tạo các layers và activations function, `torch.optim`: Khởi tạo optimizer, `torch.data`: Khởi tạo dataset và dataloader, `torch.loss`: Khởi tạo loss function.
#
# D. `torch.nn`: Dùng để khởi tạo các layers và loss function, `torch.optim`: Khởi tạo optimizer, `torch.data`: Khởi tạo dataset và dataloader, `torch.activations`: Khởi tạo activations function.
#
# => Đáp án B
#
# **4) Để customize một Dataset trên pytorch chúng ta cần thực hiện như thế nào?**
#
# A. Sử dụng thuộc tính `transformer` để qui định các biến đổi trên dữ liệu. Những biến đổi này được thực hiện trên hàm tạo.
#
# B. Khởi tạo một class kế thừa lại `torch.utils.data.Dataset`. Khai báo các thuộc tính cần sử dụng trong hàm tạo của dataset như list đường dẫn, list label. Override lại hàm `__getitem__()` để thực hiện các xử lý trên dữ liệu.
#
# C. Kế thừa lại một class `Dataset`. Các điều chỉnh trên dữ liệu được thực hiện trên hàm `transformer()`.
#
# D. Sử dụng hàm `__getitem__()` để trả về toàn bộ các quan sát khi huấn luyện.
#
# => Đáp án B
#
# **5) Ý nghĩa của tham số epochs và batch_size trong huấn luyện mô hình là gì?**
#
# A. epochs là kích thước của một mini-batch, batch_size là số lượt lặp lại toàn bộ dữ liệu khi huấn luyện.
#
# B. epochs là số lượt lặp lại toàn bộ dữ liệu validation khi huấn luyện, batch_size là kích thước của một mini-batch.
#
# C. epochs là số lượt lặp lại toàn bộ dữ liệu train khi huấn luyện, batch_size là kích thước của một mini-batch.
#
# D. epochs là số lượng vòng lặp, mỗi vòng lặp là một lượt fit mini-batch, trên bộ dữ liệu khi huấn luyện; batch_size là kích thước của một mini-batch.
#
# => Đáp án C

# %% [markdown]
# # 2. Thực hành
#
# 6) Khởi tạo một tensor 3 chiều với định dạng là float và kích thước là 32x32x3
#
# 7) Nếu coi tensor trên là một bức ảnh RGB với số channel là 3 ở cuối. Hãy truy suất các ma trận ảnh tương ứng với mỗi kênh R, G, B.
#
# 8) Thực hiện tích hadamard và tích thông thường giữa ma trận R và G.
#
# 9) Từ bộ dữ liệu [Income-Classification](https://www.kaggle.com/t/090688c8d33a40b68be9e271d6ba6bae) hãy chuẩn hóa dữ liệu và phân chia tập train/test theo tỷ lệ 80/20.
#
# 10) Xây dựng một mạng deep-neural-network để huấn luyện mô hình trên dữ liệu train và đánh giá mô hình trên dữ liệu test.

# %%
#6
import torch
a = torch.randn([32,32,3])
print("shape of tensor: {}\ndtype: {}".format(a.shape,a.dtype))
# Out:
# shape of tensor: torch.Size([32, 32, 3])
# dtype: torch.float32

# %%
#7
R = a[:,:,0]
G =  a[:,:,1]
B =  a[:,:,2]

# %%
#8
normal_mul = R@G
hada_mul = R*G
print('tích hadamard: \n{0}\n tích thông thường: \n{1}'.format(hada_mul, normal_mul))
# Out:
# tích hadamard:
# tensor([[-0.6542,  0.0097,  0.0462,  ..., -0.9044, -0.2381, -0.3049],
#         [-0.3874,  1.2285,  1.3224,  ..., -0.8451, -0.7118,  1.4514],
#         [ 0.8759, -0.7008,  0.0093,  ..., -2.0499,  0.1137,  0.0506],
#         ...,
#         [ 1.0634,  1.3117,  1.8204,  ..., -0.1131,  0.1581, -1.8181],
#         [ 3.2506, -1.4296,  0.0557,  ...,  0.1351,  1.8077, -0.3620],
#         [ 2.2282, -0.0088, -0.6619,  ...,  0.1993, -0.1081,  0.7736]])
#  tích thông thường:
# tensor([[  4.4625,   5.3843, -12.4086,  ...,   2.2395,   9.3771,  13.8915],
#         [  5.6573,   1.3434,  -1.5513,  ...,   1.6747,  -0.2497,   3.6736],
#         [ -9.3397,  -3.9877,   3.5241,  ...,  -4.6935,   0.9177,   0.7641],
#         ...,
#         [  2.2161,   4.6965, -10.6390,  ...,   8.5443,   3.7303,   3.6466],
#         [  2.2132,   3.7186,   3.3925,  ...,   3.8174,  10.4318,  14.8565],
#         [ -1.5097,  -6.9970,   4.3173,  ...,  -2.9250,  10.4301,  -4.2386]])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 9. Data preprocesing and train/test split

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/lesson 2/train.csv").dropna()
df.sample(10)
# Out:
#           ID  age  work_type  ...  hrs_per_week nationality  target_income
# 21254  21254   48  Local-gov  ...            40          US              1
# 12645  12645   40    Private  ...            40       China              1
# 10580  10580   31    Private  ...            40      Mexico              0
# 3331    3331   38    Private  ...            40          US              1
# 2001    2001   32    Private  ...            60          US              1
# 3560    3560   21    Private  ...            40          US              0
# 10063  10063   54    Private  ...            40          US              0
# 12087  12087   25    Private  ...            40          US              0
# 14292  14292   43  Local-gov  ...            40          US              0
# 7683    7683   48    Private  ...            48          US              0
#
# [10 rows x 16 columns]

# %%
df = df.drop("ID", axis = 1)
df.describe()
# Out:
#                 age  final_weight  ...  hrs_per_week  target_income
# count  25000.000000  2.500000e+04  ...  25000.000000    25000.00000
# mean      38.568800  1.900156e+05  ...     40.392200        0.23944
# std       13.642694  1.059694e+05  ...     12.350547        0.42675
# min       17.000000  1.228500e+04  ...      1.000000        0.00000
# 25%       28.000000  1.178315e+05  ...     40.000000        0.00000
# 50%       37.000000  1.786440e+05  ...     40.000000        0.00000
# 75%       48.000000  2.368040e+05  ...     45.000000        0.00000
# max       90.000000  1.484705e+06  ...     99.000000        1.00000
#
# [8 rows x 7 columns]

# %%
# Observe the outliers by histogram 
df['age'].hist(bins=20)

# %%
df['hrs_per_week'].hist(bins=10)

# %%
df['final_weight'].hist()

# %%
# Remove outliers from dataframe
df = df[df['age']<65]
df = df[df['hrs_per_week']>12]
df = df[df['hrs_per_week']<65]
df = df[df['final_weight']<420000]

# %%
df.shape
# Out:
# (21998, 15)

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
# Label Encoding
le = LabelEncoder()
col = ['work_type', 'education', 'marital_state', 'job', 'ethnicity', 'status', 'sex', 'nationality']
for i in col:
    df[i] =  le.fit_transform(df[i])
df
# Out:
#        age  work_type  final_weight  ...  hrs_per_week  nationality  target_income
# 0       45          4        175925  ...            40           39              0
# 1       23          4        113601  ...            30           39              0
# 2       22          4        112137  ...            20           35              0
# 3       27          4        153078  ...            40           39              0
# 4       18          4        375515  ...            20           39              0
# ...    ...        ...           ...  ...           ...          ...            ...
# 24995   47          7        188386  ...            45           39              1
# 24996   23          4         71864  ...            35           39              0
# 24997   24          4        395297  ...            35           39              0
# 24998   44          6        138975  ...            55           39              0
# 24999   42          0        167678  ...            22            7              0
#
# [21998 rows x 15 columns]

# %%
from sklearn.model_selection import train_test_split
# Split data 80/20 into training set and test set
x = df.iloc[:,:-1]
y = df.iloc[:,-1]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, 
                                                    stratify = y, # assign equal proportion of target label in train/test 
                                                    random_state = 0) # keep train/test split the same if run again.

# %%
# Rescaling the data 
scaler = StandardScaler() 
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
print ('Training Set: %d, Test Set: %d \n' % (len(x_train), len(x_test)))
# Out:
# Training Set: 17598, Test Set: 4400

# %% [markdown]
# #10. Train model and evaluate

# %%
import torch
import torch.nn as nn
import torch.utils.data as td

# Set random seed for reproducability => gieo hat de tai tao ket qua chay cho nhung luot tiep theo
torch.manual_seed(0)

print("Libraries imported - ready to use PyTorch", torch.__version__)
# Out:
# Libraries imported - ready to use PyTorch 1.10.0+cu111

# %% [markdown]
# ## Prepare the data for PyTorch
#
# PyTorch makes use of *data loaders* to load training and validation data in batches. We've already loaded the data into numpy arrays, but we need to wrap those in PyTorch datasets (in which the data is converted to PyTorch *tensor* objects) and create loaders to read batches from those datasets.

# %%
# Create a dataset and loader for the training data and labels
train_x = torch.Tensor(x_train).float()
train_y = torch.Tensor(list(y_train)).long()
train_ds = td.TensorDataset(train_x,train_y)
train_loader = td.DataLoader(train_ds, batch_size=20,
    shuffle=True, num_workers=1)

# Create a dataset and loader for the test data and labels
test_x = torch.Tensor(x_test).float()
test_y = torch.Tensor(list(y_test)).long()
test_ds = td.TensorDataset(test_x,test_y)
test_loader = td.DataLoader(test_ds, batch_size=20,
    shuffle=False, num_workers=1)
print('Ready to load data')
# Out:
# Ready to load data

# %% [markdown]
# ## Define a neural network

# %%
features = list(df.columns)[:-1]

# %%
# Number of hidden layer nodes
hl = 10

# Define the neural network
class IncomeNet(nn.Module):
    def __init__(self):
        super(IncomeNet, self).__init__()
        self.fc1 = nn.Linear(len(features), hl)
        self.fc2 = nn.Linear(hl, hl)
        self.fc3 = nn.Linear(hl,6)
        self.fc4 = nn.Linear(6, 2)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        x = torch.sigmoid(self.fc4(x))
        return x

# Create a model instance from the network
model = IncomeNet()
print(model)
# Out:
# IncomeNet(
#   (fc1): Linear(in_features=14, out_features=10, bias=True)
#   (fc2): Linear(in_features=10, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=6, bias=True)
#   (fc4): Linear(in_features=6, out_features=2, bias=True)
# )

# %% [markdown]
# ## Train the model

# %%
def train(model, data_loader, optimizer):
    # Set the model to training mode
    model.train()
    train_loss = 0
    
    for batch, tensor in enumerate(data_loader):
        data, target = tensor
        #feedforward: calculate y_pred and loss function
        optimizer.zero_grad() #=> update gra-des về 0 để ko cộng dồn trong những lần tiếp theo
        out = model(data)
        loss = loss_criteria(out, target)
        train_loss += loss.item()
        # backpropagate: compute gradient descent and update weights
        loss.backward()
        optimizer.step()

    #Return average loss
    avg_loss = train_loss / (batch+1)
    print('Training set: Average loss: {:.6f}'.format(avg_loss))
    return avg_loss
           
def test(model, data_loader):
    # Switch the model to evaluation mode (so we don't backpropagate)
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad(): #ngăn chặn cập nhật grades để ko làm thay đổi weights
        batch_count = 0
        for batch, tensor in enumerate(data_loader):
            batch_count += 1
            data, target = tensor
            # Get the predictions
            out = model(data)

            # calculate the loss
            test_loss += loss_criteria(out, target).item()

            # Calculate the accuracy
            _, predicted = torch.max(out.data, 1)
            correct += torch.sum(target==predicted).item()
            
    # Calculate the average loss and total accuracy for this epoch
    avg_loss = test_loss/batch_count
    print('Validation set: Average loss: {:.6f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        avg_loss, correct, len(data_loader.dataset),
        100. * correct / len(data_loader.dataset)))
    
    # return average loss for the epoch
    return avg_loss

# %%
# Specify the loss criteria (we'll use CrossEntropyLoss for multi-class classification)
loss_criteria = nn.CrossEntropyLoss()

learning_rate = 0.01
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
optimizer.zero_grad() #=> tránh trường hợp chạy lại khiến gra-des lớn => mô hình bị sai 

# We'll track metrics for each epoch in these arrays
epoch_nums = []
training_loss = []
validation_loss = []

# Train over 50 epochs
epochs = 50
for epoch in range(1, epochs + 1):

    # print the epoch number
    print('Epoch: {}'.format(epoch))
    
    # Feed training data into the model to optimize the weights
    train_loss = train(model, train_loader, optimizer)
    
    # Feed the test data into the model to check its performance
    test_loss = test(model, test_loader)
    
    # Log the metrics for this epoch
    epoch_nums.append(epoch)
    training_loss.append(train_loss)
    validation_loss.append(test_loss)
# Out:
# Epoch: 1
# Training set: Average loss: 0.476614
# Validation set: Average loss: 0.462682, Accuracy: 3681/4400 (84%)
#
# Epoch: 2
# Training set: Average loss: 0.460885
# Validation set: Average loss: 0.461473, Accuracy: 3702/4400 (84%)
#
# Epoch: 3
# Training set: Average loss: 0.458161
# Validation set: Average loss: 0.459300, Accuracy: 3694/4400 (84%)
#
# Epoch: 4
# Training set: Average loss: 0.456096
# Validation set: Average loss: 0.463747, Accuracy: 3694/4400 (84%)
#
# Epoch: 5
# Training set: Average loss: 0.455391
# Validation set: Average loss: 0.456739, Accuracy: 3716/4400 (84%)
#
# Epoch: 6
# Training set: Average loss: 0.454933
# Validation set: Average loss: 0.458312, Accuracy: 3706/4400 (84%)
#
# Epoch: 7
# Training set: Average loss: 0.453925
# Validation set: Average loss: 0.460429, Accuracy: 3706/4400 (84%)
#
# Epoch: 8
# Training set: Average loss: 0.453338
# Validation set: Average loss: 0.460043, Accuracy: 3693/4400 (84%)
#
# Epoch: 9
# Training set: Average loss: 0.454369
# Validation set: Average loss: 0.458709, Accuracy: 3703/4400 (84%)
#
# Epoch: 10
# Training set: Average loss: 0.453156
# Validation set: Average loss: 0.457640, Accuracy: 3723/4400 (85%)
#
# Epoch: 11
# Training set: Average loss: 0.452278
# Validation set: Average loss: 0.456698, Accuracy: 3730/4400 (85%)
#
# Epoch: 12
# Training set: Average loss: 0.451382
# Validation set: Average loss: 0.456655, Accuracy: 3707/4400 (84%)
#
# Epoch: 13
# Training set: Average loss: 0.452628
# Validation set: Average loss: 0.457581, Accuracy: 3713/4400 (84%)
#
# Epoch: 14
# Training set: Average loss: 0.452503
# Validation set: Average loss: 0.456072, Accuracy: 3729/4400 (85%)
#
# Epoch: 15
# Training set: Average loss: 0.450868
# Validation set: Average loss: 0.459152, Accuracy: 3716/4400 (84%)
#
# Epoch: 16
# Training set: Average loss: 0.450589
# Validation set: Average loss: 0.455707, Accuracy: 3723/4400 (85%)
#
# Epoch: 17
# Training set: Average loss: 0.451474
# Validation set: Average loss: 0.456760, Accuracy: 3717/4400 (84%)
#
# Epoch: 18
# Training set: Average loss: 0.451254
# Validation set: Average loss: 0.455996, Accuracy: 3719/4400 (85%)
#
# Epoch: 19
# Training set: Average loss: 0.452732
# Validation set: Average loss: 0.458492, Accuracy: 3714/4400 (84%)
#
# Epoch: 20
# Training set: Average loss: 0.451379
# Validation set: Average loss: 0.455965, Accuracy: 3728/4400 (85%)
#
# Epoch: 21
# Training set: Average loss: 0.449752
# Validation set: Average loss: 0.458512, Accuracy: 3713/4400 (84%)
#
# Epoch: 22
# Training set: Average loss: 0.450739
# Validation set: Average loss: 0.457625, Accuracy: 3710/4400 (84%)
#
# Epoch: 23
# Training set: Average loss: 0.449042
# Validation set: Average loss: 0.457290, Accuracy: 3716/4400 (84%)
#
# Epoch: 24
# Training set: Average loss: 0.449368
# Validation set: Average loss: 0.456628, Accuracy: 3726/4400 (85%)
#
# Epoch: 25
# Training set: Average loss: 0.449882
# Validation set: Average loss: 0.456658, Accuracy: 3718/4400 (84%)
#
# Epoch: 26
# Training set: Average loss: 0.450018
# Validation set: Average loss: 0.459573, Accuracy: 3708/4400 (84%)
#
# Epoch: 27
# Training set: Average loss: 0.449314
# Validation set: Average loss: 0.458451, Accuracy: 3721/4400 (85%)
#
# Epoch: 28
# Training set: Average loss: 0.449222
# Validation set: Average loss: 0.456695, Accuracy: 3713/4400 (84%)
#
# Epoch: 29
# Training set: Average loss: 0.448827
# Validation set: Average loss: 0.455835, Accuracy: 3723/4400 (85%)
#
# Epoch: 30
# Training set: Average loss: 0.448647
# Validation set: Average loss: 0.456465, Accuracy: 3722/4400 (85%)
#
# Epoch: 31
# Training set: Average loss: 0.448556
# Validation set: Average loss: 0.455132, Accuracy: 3711/4400 (84%)
#
# Epoch: 32
# Training set: Average loss: 0.447516
# Validation set: Average loss: 0.459551, Accuracy: 3702/4400 (84%)
#
# Epoch: 33
# Training set: Average loss: 0.448450
# Validation set: Average loss: 0.454017, Accuracy: 3732/4400 (85%)
#
# Epoch: 34
# Training set: Average loss: 0.448958
# Validation set: Average loss: 0.454095, Accuracy: 3737/4400 (85%)
#
# Epoch: 35
# Training set: Average loss: 0.447459
# Validation set: Average loss: 0.455215, Accuracy: 3731/4400 (85%)
#
# Epoch: 36
# Training set: Average loss: 0.447685
# Validation set: Average loss: 0.456044, Accuracy: 3737/4400 (85%)
#
# Epoch: 37
# Training set: Average loss: 0.447564
# Validation set: Average loss: 0.454228, Accuracy: 3736/4400 (85%)
#
# Epoch: 38
# Training set: Average loss: 0.448068
# Validation set: Average loss: 0.455856, Accuracy: 3725/4400 (85%)
#
# Epoch: 39
# Training set: Average loss: 0.450377
# Validation set: Average loss: 0.455526, Accuracy: 3725/4400 (85%)
#
# Epoch: 40
# Training set: Average loss: 0.448103
# Validation set: Average loss: 0.452881, Accuracy: 3737/4400 (85%)
#
# Epoch: 41
# Training set: Average loss: 0.447200
# Validation set: Average loss: 0.454820, Accuracy: 3734/4400 (85%)
#
# Epoch: 42
# Training set: Average loss: 0.447629
# Validation set: Average loss: 0.455481, Accuracy: 3724/4400 (85%)
#
# Epoch: 43
# Training set: Average loss: 0.448464
# Validation set: Average loss: 0.456077, Accuracy: 3720/4400 (85%)
#
# Epoch: 44
# Training set: Average loss: 0.447773
# Validation set: Average loss: 0.456748, Accuracy: 3720/4400 (85%)
#
# Epoch: 45
# Training set: Average loss: 0.448827
# Validation set: Average loss: 0.458971, Accuracy: 3702/4400 (84%)
#
# Epoch: 46
# Training set: Average loss: 0.448384
# Validation set: Average loss: 0.456194, Accuracy: 3729/4400 (85%)
#
# Epoch: 47
# Training set: Average loss: 0.447865
# Validation set: Average loss: 0.453637, Accuracy: 3731/4400 (85%)
#
# Epoch: 48
# Training set: Average loss: 0.447337
# Validation set: Average loss: 0.455786, Accuracy: 3733/4400 (85%)
#
# Epoch: 49
# Training set: Average loss: 0.448017
# Validation set: Average loss: 0.456227, Accuracy: 3713/4400 (84%)
#
# Epoch: 50
# Training set: Average loss: 0.448000
# Validation set: Average loss: 0.454729, Accuracy: 3732/4400 (85%)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

plt.plot(epoch_nums, training_loss)
plt.plot(epoch_nums, validation_loss)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training', 'validation'], loc='upper right')
plt.show()

# %%
#Pytorch doesn't have a built-in confusion matrix metric, so we'll use SciKit-Learn
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, classification_report
import numpy as np

# Set the model to evaluate mode
model.eval()

# Get predictions for the test data
x = torch.Tensor(x_test).float()
_, predicted = torch.max(model(x).data, 1)

# Plot the confusion matrix
cm = confusion_matrix(y_test, predicted.numpy())
plt.imshow(cm, interpolation="nearest", cmap=plt.cm.Blues)
plt.colorbar()
tick_marks = np.arange(2)
plt.xticks(tick_marks, [0, 1])
plt.yticks(tick_marks, [0, 1])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
print('ACCURACY_SCORE: ', round(accuracy_score(y_test, predicted), 4))
print(classification_report(y_test, predicted, digits=4))
# Out:
# ACCURACY_SCORE:  0.8482
#               precision    recall  f1-score   support
#
#            0     0.8932    0.9087    0.9009      3340
#            1     0.6956    0.6575    0.6760      1060
#
#     accuracy                         0.8482      4400
#    macro avg     0.7944    0.7831    0.7885      4400
# weighted avg     0.8456    0.8482    0.8467      4400
