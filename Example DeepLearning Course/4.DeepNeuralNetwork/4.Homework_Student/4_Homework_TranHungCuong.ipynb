# %% [markdown]
# # I. Lý thuyết
#
# 1) Tại sao các mô hình deep learning lại chiếm ưu thế hơn so với các mô hình machine learning truyền thống đối với dữ liệu lớn ?
#
# **A. Do mô hình deep learning có thể được thiết kế với kích thước tùy ý nên có khả năng xấp xỉ mọi hàm số. Do đó nó có khả năng biểu diễn tốt và hoạt động hiệu quả trên dữ liệu lớn.**
#
# B. Các mô hình machine learning thường bị overfitting đối với dữ liệu lớn ?
#
# C. Các mô hình deep learning có chi phí huấn luyện tốn kém hơn so với machine learning.
#
# D. Do kiến trúc của mô hình Machine Learning bao gồm nhiều layers xếp chồng.
#
#
# 2) Ý nghĩa của hàm loss function trong mạng neural network là gì ?
#
# A. Là hàm số đánh giá độ chính xác của mô hình.
#
# **B. Mục tiêu của quá trình huấn luyện là tối thiểu hóa hàm loss function bằng thuật toán gradient descent. Giá trị của hàm số này giúp đo lường mức độ khớp của dự báo từ mô hình trên dữ liệu huấn luyện.**
#
# C. Khi loss function giảm thì luôn đảm bảo độ chính xác của mô hình tăng.
#
# D. Là hàm số cần tối đa hóa trong quá trình huấn luyện.
#
#
# 3) Khi huấn luyện trên các bộ dữ liệu bigdata thì chúng ta nên sử dụng phương pháp nào ?
#
# A) Sử dụng gradient descent trên toàn bộ dữ liệu.
#
# B) Sử dụng stochastic gradient descent trên từng điểm dữ liệu.
#
# **C) Mini-batch gradient descent huấn luyện mô hình trên từng tập dữ liệu con có kích thước nhỏ hơn memory CPU/GPU.**
#
# D) Có thể sử dụng stochastic gradient descent hoặc mini-batch gradient descent.
#
#
# 4) Quá trình feed forward và backpropagation thực hiện những gì ?
#
# **A) feed forward tính toán output và loss function, backpropagation tính đạo hàm trên từng layer và cập nhật trọng số.**
#
# B) feed forward cập nhật trọng số cho mô hình, backpropagation tính toán output và loss function.
#
# C) feed forward tính ra output của mô hình, backpropagation tính toán loss function
#
# D) feed forward được thực hiện sau backpropagation.
#
# 5) Tác dụng của batch normalization là gì ?
#
# A) Loại bỏ một tỷ lệ ngẫu nhiên số lượng units tại mỗi layer để tạo thành nhiều kiến trúc kết hợp ngẫu nhiên.
#
# B) Tìm ra các tham số phân phối là trung bình và phương sai trên từng mini-batch.
#
# C) Đồng nhất phân phối xác suất của $z^{[l]}$ trên mỗi layer $l$.
#
# **D) Giảm thiểu ảnh hưởng của input distribution shift nhằm giúp huấn luyện loss function nhanh và ổn định hơn.**

# %% [markdown]
# # II. Thực hành
#
# Xuất phát từ mô hình tốt nhất của bạn xây dựng được đối với bài toán phân loại income classification tại bài trước. Bạn hãy thực hiện một số thử nghiệm sau:

# %% [markdown]
# ##6) Thay đổi hàm loss function, batch size và optimizer.

# %% [markdown]
# ###Xử lý dữ liệu

# %%
from google.colab import drive
import os
drive.mount("/content/drive")
folder_path = "/content/drive/MyDrive/Deep learning K1/2.Data"
os.chdir(folder_path)
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import random
import pandas as pd
import re
import torch.nn as nn
import torch

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, classification_report

# %%
import torch
import torch.nn as nn
import torch.utils.data as td
# Set random seed for reproducability
torch.manual_seed(0)

# %%
def seed_all(seed):
    np.random.seed(seed)
    random.seed(seed)
seed = 42 
seed_all(seed)

# %%
#Đọc dữ liệu
d_train = pd.read_csv("train.csv")
d_train.head()
# Out:
#    ID  age work_type  ...  hrs_per_week nationality  target_income
# 0   0   45   Private  ...            40          US              0
# 1   1   23   Private  ...            30          US              0
# 2   2   22   Private  ...            20       South              0
# 3   3   27   Private  ...            40          US              0
# 4   4   18   Private  ...            20          US              0
#
# [5 rows x 16 columns]

# %%
# normalize string
def str_normalize(s):
    # convert into lowercase and replace multiple spaces into single space
    s = str(s).strip().lower()
    s = re.sub(' +', " ", s)
    return s

# %%
# Encode category and object columns 
def process(df):        
  for col in df.columns:
      if df[col].dtype.name == "object" or df[col].dtype.name == "category":
          df[col] = df[col].apply(str_normalize).astype("category")
  return df
df_all = process(d_train.copy())
IDs=df_all.pop('ID')
label = df_all.pop('target_income')
df_all_one_hot = pd.get_dummies(df_all)

# %%
features = df_all_one_hot.columns.tolist()
label = label.values

# %%
x_train, x_test, y_train, y_test = train_test_split(df_all_one_hot[features].values, # input variable
                                                    label, # output variable
                                                    test_size=0.2, # test dataset proportion
                                                    # stratify=df_all['target_income'], # assign equal proportion of target label in train/test 
                                                    random_state=0) # keep train/test split the same if run again. 
print ('Training Set: %d, Test Set: %d \n' % (len(x_train), len(x_test)))
#normalize
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
# Out:
# Training Set: 20000, Test Set: 5000

# %%
# Create a dataset and loader for the training data and labels
train_x = torch.Tensor(x_train).float()
# Reshape y target into [-1, 1] to fit with Binary Cross Entropy
train_y = torch.Tensor(y_train).view(-1, 1).float()
train_ds = td.TensorDataset(train_x,train_y)
train_loader = td.DataLoader(train_ds, batch_size=16, shuffle=True, num_workers=1)

# Create a dataset and loader for the test data and labels
test_x = torch.Tensor(x_test).float()
test_y = torch.Tensor(y_test).view(-1, 1).float()
test_ds = td.TensorDataset(test_x,test_y)
test_loader = td.DataLoader(test_ds, batch_size=16, shuffle=False, num_workers=1)
print('Ready to load data')
# Out:
# Ready to load data

# %%
#creating data with batch_size
def creatData(batch_size):
    # Create a dataset and loader for the training data and labels
    train_x = torch.Tensor(x_train).float()
    # Reshape y target into [-1, 1] to fit with Binary Cross Entropy
    train_y = torch.Tensor(y_train).view(-1, 1).float()
    train_ds = td.TensorDataset(train_x,train_y)
    train_loader = td.DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=1)

    # Create a dataset and loader for the test data and labels
    test_x = torch.Tensor(x_test).float()
    test_y = torch.Tensor(y_test).view(-1, 1).float()
    test_ds = td.TensorDataset(test_x,test_y)
    test_loader = td.DataLoader(test_ds, batch_size=batch_size, shuffle=False, num_workers=1)
    print('Ready to load data')

# %%
# Number of hidden layer nodes
hl1 = 8
hl2 = 4

# Define the neural network
class IncomeCL(nn.Module):
    def __init__(self):
        super(IncomeCL, self).__init__()
        self.fc1 = nn.Linear(len(train_x[1]), hl1)
        self.fc2 = nn.Linear(hl1, hl2)
        self.fc3 = nn.Linear(hl2, 1)
        self.random_state = 42

    def forward(self, x):
        x = torch.sigmoid(self.fc1(x))
        x = torch.sigmoid(self.fc2(x))
        x = torch.sigmoid(self.fc3(x))
        return x

# Create a model instance from the network
model = IncomeCL()
print(model)
# Out:
# IncomeCL(
#   (fc1): Linear(in_features=108, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=4, bias=True)
#   (fc3): Linear(in_features=4, out_features=1, bias=True)
# )

# %%
def train(model, data_loader, optimizer):
    # Set the model to training mode
    model.train()
    train_loss = 0
    
    for batch, tensor in enumerate(data_loader):
        data, target = tensor
        
        #Lan truyền tiến
        #feedforward: calculate y_pred and loss function
        optimizer.zero_grad()
        out = model(data)
        loss = nn.BCELoss()
        output = loss(out, target)
        train_loss += output.item()

        #Lan truyền ngược
        #backpropagate: compute gradient descent and update weights
        output.backward()
        optimizer.step()

    #Return average loss
    avg_loss = train_loss / (batch+1)
    print('Training set: Average loss: {:.4f}'.format(avg_loss))
    return avg_loss

# %%
def test(model, data_loader):
    # Switch the model to evaluation mode (so we don't backpropagate)
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
        batch_count = 0
        for batch, tensor in enumerate(data_loader):
            batch_count += 1
            data, target = tensor
            # Get the predictions
            out = model(data)

            # calculate the loss
            loss_criteria = nn.BCELoss()
            test_loss += loss_criteria(out, target).item()

            # Calculate the accuracy
            #print(out.data)
            predicted = out.data > 0.5
            correct += torch.sum(target==predicted).item()
            #print(target)
            #print(predicted)
            
    # Calculate the average loss and total accuracy for this epoch
    avg_loss = test_loss/batch_count
    print('Validation set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        avg_loss, correct, len(data_loader.dataset),
        100. * correct / len(data_loader.dataset)))
    avg_acc = correct / len(data_loader.dataset)
    
    # return average loss for the epoch
    return avg_loss, avg_acc

# %% [markdown]
# ###Thay đổi optimizers

# %%
from pandas.core.common import random_state
def train_model(l_r, optim):
  learning_rate = l_r #0.001
  random_state=42
  if optim == 1:
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
  elif optim == 2:
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
  elif optim == 3:
    optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate)
  optimizer.zero_grad()

  # We'll track metrics for each epoch in these arrays
  epoch_nums = []
  training_loss = []
  validation_loss = []
  acc = []

  # Train over 50 epochs
  epochs = 50
  for epoch in range(1, epochs + 1):

      # print the epoch number
      print('Epoch: {}'.format(epoch))
      
      # Feed training data into the model to optimize the weights
      train_loss = train(model, train_loader, optimizer)
      
      # Feed the test data into the model to check its performance
      test_loss, test_acc = test(model, test_loader)
      
      # Log the metrics for this epoch
      epoch_nums.append(epoch)
      training_loss.append(train_loss)
      validation_loss.append(test_loss)
      acc.append(test_acc)
  return (epoch_nums, training_loss, validation_loss, acc)

# %%
def _train_model(l_r, optim, ep):
  learning_rate = l_r #0.001
  random_state=42
  if optim == 1:
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
  elif optim == 2:
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
  elif optim == 3:
    optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate)
  optimizer.zero_grad()

  # We'll track metrics for each epoch in these arrays
  epoch_nums = []
  training_loss = []
  validation_loss = []
  acc = []

  # Train over 50 epochs
  epochs = ep
  for epoch in range(1, epochs + 1):

      # print the epoch number
      print('Epoch: {}'.format(epoch))
      
      # Feed training data into the model to optimize the weights
      train_loss = train(model, train_loader, optimizer)
      
      # Feed the test data into the model to check its performance
      test_loss, test_acc = test(model, test_loader)
      
      # Log the metrics for this epoch
      epoch_nums.append(epoch)
      training_loss.append(train_loss)
      validation_loss.append(test_loss)
      acc.append(test_acc)
  return (epoch_nums, training_loss, validation_loss, acc)

# %%
from matplotlib import pyplot as plt

def _plot(epoch_nums, training_loss, validation_loss):
  plt.plot(epoch_nums, training_loss)
  plt.plot(epoch_nums, validation_loss)
  plt.xlabel('epoch')
  plt.ylabel('loss')
  plt.legend(['training', 'validation'], loc='upper right')
  plt.show()

# %%
#optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
epoch_nums1, training_loss1, validation_loss1, acc1 = train_model(0.001, 1)
# Out:
# Epoch: 1
# Training set: Average loss: 0.4940
# Validation set: Average loss: 0.3840, Accuracy: 3811/5000 (76%)
#
# Epoch: 2
# Training set: Average loss: 0.3660
# Validation set: Average loss: 0.3395, Accuracy: 4243/5000 (85%)
#
# Epoch: 3
# Training set: Average loss: 0.3459
# Validation set: Average loss: 0.3298, Accuracy: 4242/5000 (85%)
#
# Epoch: 4
# Training set: Average loss: 0.3372
# Validation set: Average loss: 0.3250, Accuracy: 4241/5000 (85%)
#
# Epoch: 5
# Training set: Average loss: 0.3318
# Validation set: Average loss: 0.3220, Accuracy: 4243/5000 (85%)
#
# Epoch: 6
# Training set: Average loss: 0.3270
# Validation set: Average loss: 0.3202, Accuracy: 4237/5000 (85%)
#
# Epoch: 7
# Training set: Average loss: 0.3233
# Validation set: Average loss: 0.3187, Accuracy: 4257/5000 (85%)
#
# Epoch: 8
# Training set: Average loss: 0.3204
# Validation set: Average loss: 0.3161, Accuracy: 4247/5000 (85%)
#
# Epoch: 9
# Training set: Average loss: 0.3176
# Validation set: Average loss: 0.3153, Accuracy: 4249/5000 (85%)
#
# Epoch: 10
# Training set: Average loss: 0.3152
# Validation set: Average loss: 0.3138, Accuracy: 4265/5000 (85%)
#
# Epoch: 11
# Training set: Average loss: 0.3131
# Validation set: Average loss: 0.3144, Accuracy: 4263/5000 (85%)
#
# Epoch: 12
# Training set: Average loss: 0.3112
# Validation set: Average loss: 0.3122, Accuracy: 4266/5000 (85%)
#
# Epoch: 13
# Training set: Average loss: 0.3094
# Validation set: Average loss: 0.3121, Accuracy: 4267/5000 (85%)
#
# Epoch: 14
# Training set: Average loss: 0.3078
# Validation set: Average loss: 0.3118, Accuracy: 4269/5000 (85%)
#
# Epoch: 15
# Training set: Average loss: 0.3065
# Validation set: Average loss: 0.3105, Accuracy: 4272/5000 (85%)
#
# Epoch: 16
# Training set: Average loss: 0.3048
# Validation set: Average loss: 0.3106, Accuracy: 4264/5000 (85%)
#
# Epoch: 17
# Training set: Average loss: 0.3038
# Validation set: Average loss: 0.3111, Accuracy: 4278/5000 (86%)
#
# Epoch: 18
# Training set: Average loss: 0.3028
# Validation set: Average loss: 0.3120, Accuracy: 4267/5000 (85%)
#
# Epoch: 19
# Training set: Average loss: 0.3018
# Validation set: Average loss: 0.3111, Accuracy: 4270/5000 (85%)
#
# Epoch: 20
# Validation set: Average loss: 0.3178, Accuracy: 4257/5000 (85%)
#
# Epoch: 46
# Training set: Average loss: 0.2879
# Validation set: Average loss: 0.3181, Accuracy: 4260/5000 (85%)
#
# Epoch: 47
# Training set: Average loss: 0.2880
# Validation set: Average loss: 0.3184, Accuracy: 4249/5000 (85%)
#
# Epoch: 48
# Training set: Average loss: 0.2877
# Validation set: Average loss: 0.3172, Accuracy: 4255/5000 (85%)
#
# Epoch: 49
# Training set: Average loss: 0.2874
# Validation set: Average loss: 0.3196, Accuracy: 4256/5000 (85%)
#
# Epoch: 50
# Training set: Average loss: 0.2876
# Validation set: Average loss: 0.3189, Accuracy: 4240/5000 (85%)

# %%
_plot(epoch_nums1, training_loss1, validation_loss1)

# %%
#optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
epoch_nums2, training_loss2, validation_loss2, acc2 = train_model(0.001, 2)
# Out:
# Epoch: 1
# Training set: Average loss: 0.6118
# Validation set: Average loss: 0.5807, Accuracy: 3811/5000 (76%)
#
# Epoch: 2
# Training set: Average loss: 0.5688
# Validation set: Average loss: 0.5589, Accuracy: 3811/5000 (76%)
#
# Epoch: 3
# Training set: Average loss: 0.5563
# Validation set: Average loss: 0.5521, Accuracy: 3811/5000 (76%)
#
# Epoch: 4
# Training set: Average loss: 0.5523
# Validation set: Average loss: 0.5496, Accuracy: 3811/5000 (76%)
#
# Epoch: 5
# Training set: Average loss: 0.5507
# Validation set: Average loss: 0.5486, Accuracy: 3811/5000 (76%)
#
# Epoch: 6
# Training set: Average loss: 0.5500
# Validation set: Average loss: 0.5480, Accuracy: 3811/5000 (76%)
#
# Epoch: 7
# Training set: Average loss: 0.5496
# Validation set: Average loss: 0.5475, Accuracy: 3811/5000 (76%)
#
# Epoch: 8
# Training set: Average loss: 0.5492
# Validation set: Average loss: 0.5472, Accuracy: 3811/5000 (76%)
#
# Epoch: 9
# Training set: Average loss: 0.5488
# Validation set: Average loss: 0.5468, Accuracy: 3811/5000 (76%)
#
# Epoch: 10
# Training set: Average loss: 0.5485
# Validation set: Average loss: 0.5464, Accuracy: 3811/5000 (76%)
#
# Epoch: 11
# Training set: Average loss: 0.5481
# Validation set: Average loss: 0.5460, Accuracy: 3811/5000 (76%)
#
# Epoch: 12
# Training set: Average loss: 0.5478
# Validation set: Average loss: 0.5457, Accuracy: 3811/5000 (76%)
#
# Epoch: 13
# Training set: Average loss: 0.5474
# Validation set: Average loss: 0.5453, Accuracy: 3811/5000 (76%)
#
# Epoch: 14
# Training set: Average loss: 0.5470
# Validation set: Average loss: 0.5449, Accuracy: 3811/5000 (76%)
#
# Epoch: 15
# Training set: Average loss: 0.5466
# Validation set: Average loss: 0.5445, Accuracy: 3811/5000 (76%)
#
# Epoch: 16
# Training set: Average loss: 0.5462
# Validation set: Average loss: 0.5440, Accuracy: 3811/5000 (76%)
#
# Epoch: 17
# Training set: Average loss: 0.5458
# Validation set: Average loss: 0.5436, Accuracy: 3811/5000 (76%)
#
# Epoch: 18
# Training set: Average loss: 0.5453
# Validation set: Average loss: 0.5431, Accuracy: 3811/5000 (76%)
#
# Epoch: 19
# Training set: Average loss: 0.5449
# Validation set: Average loss: 0.5427, Accuracy: 3811/5000 (76%)
#
# Epoch: 20
# Training set: Average loss: 0.5444
# Validation set: Average loss: 0.5422, Accuracy: 3811/5000 (76%)
#
# Epoch: 21
# Training set: Average loss: 0.5439
# Validation set: Average loss: 0.5416, Accuracy: 3811/5000 (76%)
#
# Epoch: 22
# Training set: Average loss: 0.5434
# Validation set: Average loss: 0.5411, Accuracy: 3811/5000 (76%)
#
# Epoch: 23
# Training set: Average loss: 0.5428
# Validation set: Average loss: 0.5405, Accuracy: 3811/5000 (76%)
#
# Epoch: 24
# Training set: Average loss: 0.5423
# Validation set: Average loss: 0.5399, Accuracy: 3811/5000 (76%)
#
# Epoch: 25
# Training set: Average loss: 0.5416
# Validation set: Average loss: 0.5393, Accuracy: 3811/5000 (76%)
#
# Epoch: 26
# Training set: Average loss: 0.5410
# Validation set: Average loss: 0.5386, Accuracy: 3811/5000 (76%)
#
# Epoch: 27
# Training set: Average loss: 0.5404
# Validation set: Average loss: 0.5379, Accuracy: 3811/5000 (76%)
#
# Epoch: 28
# Training set: Average loss: 0.5396
# Validation set: Average loss: 0.5372, Accuracy: 3811/5000 (76%)
#
# Epoch: 29
# Training set: Average loss: 0.5389
# Validation set: Average loss: 0.5364, Accuracy: 3811/5000 (76%)
#
# Epoch: 30
# Training set: Average loss: 0.5381
# Validation set: Average loss: 0.5356, Accuracy: 3811/5000 (76%)
#
# Epoch: 31
# Training set: Average loss: 0.5373
# Validation set: Average loss: 0.5347, Accuracy: 3811/5000 (76%)
#
# Epoch: 32
# Training set: Average loss: 0.5364
# Validation set: Average loss: 0.5338, Accuracy: 3811/5000 (76%)
#
# Epoch: 33
# Training set: Average loss: 0.5355
# Validation set: Average loss: 0.5328, Accuracy: 3811/5000 (76%)
#
# Epoch: 34
# Training set: Average loss: 0.5345
# Validation set: Average loss: 0.5318, Accuracy: 3811/5000 (76%)
#
# Epoch: 35
# Training set: Average loss: 0.5335
# Validation set: Average loss: 0.5307, Accuracy: 3811/5000 (76%)
#
# Epoch: 36
# Training set: Average loss: 0.5324
# Validation set: Average loss: 0.5295, Accuracy: 3811/5000 (76%)
#
# Epoch: 37
# Training set: Average loss: 0.5313
# Validation set: Average loss: 0.5283, Accuracy: 3811/5000 (76%)
#
# Epoch: 38
# Training set: Average loss: 0.5301
# Validation set: Average loss: 0.5270, Accuracy: 3811/5000 (76%)
#
# Epoch: 39
# Training set: Average loss: 0.5288
# Validation set: Average loss: 0.5257, Accuracy: 3811/5000 (76%)
#
# Epoch: 40
# Training set: Average loss: 0.5274
# Validation set: Average loss: 0.5242, Accuracy: 3811/5000 (76%)
#
# Epoch: 41
# Training set: Average loss: 0.5260
# Validation set: Average loss: 0.5227, Accuracy: 3811/5000 (76%)
#
# Epoch: 42
# Training set: Average loss: 0.5244
# Validation set: Average loss: 0.5211, Accuracy: 3811/5000 (76%)
#
# Epoch: 43
# Training set: Average loss: 0.5228
# Validation set: Average loss: 0.5193, Accuracy: 3811/5000 (76%)
#
# Epoch: 44
# Training set: Average loss: 0.5211
# Validation set: Average loss: 0.5175, Accuracy: 3811/5000 (76%)
#
# Epoch: 45
# Training set: Average loss: 0.5193
# Validation set: Average loss: 0.5156, Accuracy: 3811/5000 (76%)
#
# Epoch: 46
# Training set: Average loss: 0.5174
# Validation set: Average loss: 0.5136, Accuracy: 3811/5000 (76%)
#
# Epoch: 47
# Training set: Average loss: 0.5153
# Validation set: Average loss: 0.5114, Accuracy: 3811/5000 (76%)
#
# Epoch: 48
# Training set: Average loss: 0.5132
# Validation set: Average loss: 0.5092, Accuracy: 3811/5000 (76%)
#
# Epoch: 49
# Training set: Average loss: 0.5109
# Validation set: Average loss: 0.5068, Accuracy: 3811/5000 (76%)
#
# Epoch: 50
# Training set: Average loss: 0.5085
# Validation set: Average loss: 0.5042, Accuracy: 3811/5000 (76%)

# %%
#optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate)
epoch_nums3, training_loss3, validation_loss3, acc3 = train_model(0.001, 3)
# Out:
# Epoch: 1
# Training set: Average loss: 0.4483
# Validation set: Average loss: 0.3642, Accuracy: 4221/5000 (84%)
#
# Epoch: 2
# Training set: Average loss: 0.3563
# Validation set: Average loss: 0.3355, Accuracy: 4238/5000 (85%)
#
# Epoch: 3
# Training set: Average loss: 0.3415
# Validation set: Average loss: 0.3266, Accuracy: 4240/5000 (85%)
#
# Epoch: 4
# Training set: Average loss: 0.3340
# Validation set: Average loss: 0.3226, Accuracy: 4250/5000 (85%)
#
# Epoch: 5
# Training set: Average loss: 0.3281
# Validation set: Average loss: 0.3190, Accuracy: 4248/5000 (85%)
#
# Epoch: 6
# Training set: Average loss: 0.3252
# Validation set: Average loss: 0.3183, Accuracy: 4262/5000 (85%)
#
# Epoch: 7
# Training set: Average loss: 0.3221
# Validation set: Average loss: 0.3168, Accuracy: 4258/5000 (85%)
#
# Epoch: 8
# Training set: Average loss: 0.3198
# Validation set: Average loss: 0.3157, Accuracy: 4264/5000 (85%)
#
# Epoch: 9
# Training set: Average loss: 0.3176
# Validation set: Average loss: 0.3140, Accuracy: 4276/5000 (86%)
#
# Epoch: 10
# Training set: Average loss: 0.3156
# Validation set: Average loss: 0.3133, Accuracy: 4273/5000 (85%)
#
# Epoch: 11
# Training set: Average loss: 0.3139
# Validation set: Average loss: 0.3124, Accuracy: 4277/5000 (86%)
#
# Epoch: 12
# Training set: Average loss: 0.3118
# Validation set: Average loss: 0.3122, Accuracy: 4273/5000 (85%)
#
# Epoch: 13
# Training set: Average loss: 0.3105
# Validation set: Average loss: 0.3099, Accuracy: 4280/5000 (86%)
#
# Epoch: 14
# Training set: Average loss: 0.3090
# Validation set: Average loss: 0.3093, Accuracy: 4282/5000 (86%)
#
# Epoch: 15
# Training set: Average loss: 0.3079
# Validation set: Average loss: 0.3097, Accuracy: 4287/5000 (86%)
#
# Epoch: 16
# Training set: Average loss: 0.3066
# Validation set: Average loss: 0.3092, Accuracy: 4288/5000 (86%)
#
# Epoch: 17
# Training set: Average loss: 0.3059
# Validation set: Average loss: 0.3088, Accuracy: 4289/5000 (86%)
#
# Epoch: 18
# Training set: Average loss: 0.3049
# Validation set: Average loss: 0.3098, Accuracy: 4291/5000 (86%)
#
# Epoch: 19
# Training set: Average loss: 0.3040
# Validation set: Average loss: 0.3088, Accuracy: 4291/5000 (86%)
#
# Epoch: 20
# Training set: Average loss: 0.3029
# Validation set: Average loss: 0.3081, Accuracy: 4302/5000 (86%)
#
# Epoch: 21
# Training set: Average loss: 0.3026
# Validation set: Average loss: 0.3081, Accuracy: 4305/5000 (86%)
#
# Epoch: 22
# Training set: Average loss: 0.3018
# Validation set: Average loss: 0.3081, Accuracy: 4296/5000 (86%)
#
# Epoch: 23
# Training set: Average loss: 0.3011
# Validation set: Average loss: 0.3096, Accuracy: 4288/5000 (86%)
#
# Epoch: 24
# Training set: Average loss: 0.3006
# Validation set: Average loss: 0.3081, Accuracy: 4304/5000 (86%)
#
# Epoch: 25
# Training set: Average loss: 0.2999
# Validation set: Average loss: 0.3084, Accuracy: 4303/5000 (86%)
#
# Epoch: 26
# Training set: Average loss: 0.2994
# Validation set: Average loss: 0.3093, Accuracy: 4302/5000 (86%)
#
# Epoch: 27
# Training set: Average loss: 0.2989
# Validation set: Average loss: 0.3103, Accuracy: 4296/5000 (86%)
#
# Epoch: 28
# Training set: Average loss: 0.2983
# Validation set: Average loss: 0.3087, Accuracy: 4304/5000 (86%)
#
# Epoch: 29
# Training set: Average loss: 0.2980
# Validation set: Average loss: 0.3093, Accuracy: 4301/5000 (86%)
#
# Epoch: 30
# Training set: Average loss: 0.2973
# Validation set: Average loss: 0.3099, Accuracy: 4294/5000 (86%)
#
# Epoch: 31
# Training set: Average loss: 0.2971
# Validation set: Average loss: 0.3104, Accuracy: 4284/5000 (86%)
#
# Epoch: 32
# Training set: Average loss: 0.2967
# Validation set: Average loss: 0.3107, Accuracy: 4292/5000 (86%)
#
# Epoch: 33
# Training set: Average loss: 0.2962
# Validation set: Average loss: 0.3105, Accuracy: 4282/5000 (86%)
#
# Epoch: 34
# Training set: Average loss: 0.2958
# Validation set: Average loss: 0.3111, Accuracy: 4302/5000 (86%)
#
# Epoch: 35
# Training set: Average loss: 0.2958
# Validation set: Average loss: 0.3105, Accuracy: 4293/5000 (86%)
#
# Epoch: 36
# Training set: Average loss: 0.2953
# Validation set: Average loss: 0.3112, Accuracy: 4306/5000 (86%)
#
# Epoch: 37
# Training set: Average loss: 0.2948
# Validation set: Average loss: 0.3115, Accuracy: 4293/5000 (86%)
#
# Epoch: 38
# Training set: Average loss: 0.2947
# Validation set: Average loss: 0.3141, Accuracy: 4285/5000 (86%)
#
# Epoch: 39
# Training set: Average loss: 0.2944
# Validation set: Average loss: 0.3124, Accuracy: 4290/5000 (86%)
#
# Epoch: 40
# Training set: Average loss: 0.2941
# Validation set: Average loss: 0.3127, Accuracy: 4282/5000 (86%)
#
# Epoch: 41
# Training set: Average loss: 0.2941
# Validation set: Average loss: 0.3128, Accuracy: 4284/5000 (86%)
#
# Epoch: 42
# Training set: Average loss: 0.2939
# Validation set: Average loss: 0.3122, Accuracy: 4280/5000 (86%)
#
# Epoch: 43
# Training set: Average loss: 0.2934
# Validation set: Average loss: 0.3121, Accuracy: 4294/5000 (86%)
#
# Epoch: 44
# Training set: Average loss: 0.2931
# Validation set: Average loss: 0.3126, Accuracy: 4285/5000 (86%)
#
# Epoch: 45
# Training set: Average loss: 0.2932
# Validation set: Average loss: 0.3124, Accuracy: 4274/5000 (85%)
#
# Epoch: 46
# Training set: Average loss: 0.2929
# Validation set: Average loss: 0.3150, Accuracy: 4288/5000 (86%)
#
# Epoch: 47
# Training set: Average loss: 0.2926
# Validation set: Average loss: 0.3135, Accuracy: 4295/5000 (86%)
#
# Epoch: 48
# Training set: Average loss: 0.2923
# Validation set: Average loss: 0.3131, Accuracy: 4274/5000 (85%)
#
# Epoch: 49
# Training set: Average loss: 0.2923
# Validation set: Average loss: 0.3141, Accuracy: 4279/5000 (86%)
#
# Epoch: 50
# Training set: Average loss: 0.2923
# Validation set: Average loss: 0.3137, Accuracy: 4275/5000 (86%)

# %%
#Đồ thị hàm loss tương ướng với các thuật toán tối ưu khác nnhau
plt.plot(training_loss1, label = "Adam", linestyle="-")
plt.plot(training_loss2, label = "SGD", linestyle="--")
plt.plot(training_loss3, label = "RMSprop", linestyle="-.")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()

# %% [markdown]
# Nhận xét: Thuật toán Adam cho hàm loss tốt nhất.

# %% [markdown]
# ###Thay đổi batch_size

# %%
#Thay đổi batch_size = 64
creatData(64)
# Out:
# Ready to load data

# %%
epoch_nums4, training_loss4, validation_loss4, acc4 = train_model(0.001, 1)
# Out:
# Epoch: 1
# Training set: Average loss: 0.5421
# Validation set: Average loss: 0.4017, Accuracy: 4191/5000 (84%)
#
# Epoch: 2
# Training set: Average loss: 0.3726
# Validation set: Average loss: 0.3439, Accuracy: 4238/5000 (85%)
#
# Epoch: 3
# Training set: Average loss: 0.3460
# Validation set: Average loss: 0.3308, Accuracy: 4239/5000 (85%)
#
# Epoch: 4
# Training set: Average loss: 0.3364
# Validation set: Average loss: 0.3231, Accuracy: 4256/5000 (85%)
#
# Epoch: 5
# Training set: Average loss: 0.3298
# Validation set: Average loss: 0.3197, Accuracy: 4259/5000 (85%)
#
# Epoch: 6
# Training set: Average loss: 0.3249
# Validation set: Average loss: 0.3183, Accuracy: 4255/5000 (85%)
#
# Epoch: 7
# Training set: Average loss: 0.3212
# Validation set: Average loss: 0.3150, Accuracy: 4260/5000 (85%)
#
# Epoch: 8
# Training set: Average loss: 0.3181
# Validation set: Average loss: 0.3145, Accuracy: 4268/5000 (85%)
#
# Epoch: 9
# Training set: Average loss: 0.3155
# Validation set: Average loss: 0.3132, Accuracy: 4257/5000 (85%)
#
# Epoch: 10
# Training set: Average loss: 0.3136
# Validation set: Average loss: 0.3121, Accuracy: 4267/5000 (85%)
#
# Epoch: 11
# Training set: Average loss: 0.3112
# Validation set: Average loss: 0.3119, Accuracy: 4267/5000 (85%)
#
# Epoch: 12
# Training set: Average loss: 0.3093
# Validation set: Average loss: 0.3124, Accuracy: 4258/5000 (85%)
#
# Epoch: 13
# Training set: Average loss: 0.3080
# Validation set: Average loss: 0.3151, Accuracy: 4256/5000 (85%)
#
# Epoch: 39
# Training set: Average loss: 0.2902
# Validation set: Average loss: 0.3154, Accuracy: 4254/5000 (85%)
#
# Epoch: 40
# Training set: Average loss: 0.2896
# Validation set: Average loss: 0.3174, Accuracy: 4245/5000 (85%)
#
# Epoch: 41
# Training set: Average loss: 0.2896
# Validation set: Average loss: 0.3149, Accuracy: 4255/5000 (85%)
#
# Epoch: 42
# Training set: Average loss: 0.2890
# Validation set: Average loss: 0.3166, Accuracy: 4248/5000 (85%)
#
# Epoch: 43
# Training set: Average loss: 0.2890
# Validation set: Average loss: 0.3162, Accuracy: 4251/5000 (85%)
#
# Epoch: 44
# Training set: Average loss: 0.2887
# Validation set: Average loss: 0.3166, Accuracy: 4244/5000 (85%)
#
# Epoch: 45
# Training set: Average loss: 0.2883
# Validation set: Average loss: 0.3168, Accuracy: 4246/5000 (85%)
#
# Epoch: 46
# Training set: Average loss: 0.2883
# Validation set: Average loss: 0.3164, Accuracy: 4249/5000 (85%)
#
# Epoch: 47
# Training set: Average loss: 0.2883
# Validation set: Average loss: 0.3169, Accuracy: 4251/5000 (85%)
#
# Epoch: 48
# Training set: Average loss: 0.2878
# Validation set: Average loss: 0.3174, Accuracy: 4247/5000 (85%)
#
# Epoch: 49
# Training set: Average loss: 0.2876
# Validation set: Average loss: 0.3186, Accuracy: 4244/5000 (85%)
#
# Epoch: 50
# Training set: Average loss: 0.2873
# Validation set: Average loss: 0.3184, Accuracy: 4260/5000 (85%)

# %%
#Thay đổi batch_size = 128
creatData(128)
# Out:
# Ready to load data

# %%
epoch_nums5, training_loss5, validation_loss5, acc5 = train_model(0.001, 1)
# Out:
# Epoch: 1
# Training set: Average loss: 0.4854
# Validation set: Average loss: 0.3875, Accuracy: 4220/5000 (84%)
#
# Epoch: 2
# Training set: Average loss: 0.3672
# Validation set: Average loss: 0.3415, Accuracy: 4249/5000 (85%)
#
# Epoch: 3
# Training set: Average loss: 0.3462
# Validation set: Average loss: 0.3322, Accuracy: 4251/5000 (85%)
#
# Epoch: 4
# Training set: Average loss: 0.3382
# Validation set: Average loss: 0.3271, Accuracy: 4254/5000 (85%)
#
# Epoch: 5
# Training set: Average loss: 0.3331
# Validation set: Average loss: 0.3234, Accuracy: 4255/5000 (85%)
#
# Epoch: 6
# Training set: Average loss: 0.3292
# Validation set: Average loss: 0.3203, Accuracy: 4259/5000 (85%)
#
# Epoch: 7
# Training set: Average loss: 0.3259
# Validation set: Average loss: 0.3193, Accuracy: 4244/5000 (85%)
#
# Epoch: 8
# Training set: Average loss: 0.3232
# Validation set: Average loss: 0.3184, Accuracy: 4251/5000 (85%)
#
# Epoch: 9
# Training set: Average loss: 0.3207
# Validation set: Average loss: 0.3167, Accuracy: 4251/5000 (85%)
#
# Epoch: 10
# Training set: Average loss: 0.3182
# Validation set: Average loss: 0.3154, Accuracy: 4261/5000 (85%)
#
# Epoch: 11
# Training set: Average loss: 0.3164
# Validation set: Average loss: 0.3148, Accuracy: 4265/5000 (85%)
#
# Epoch: 12
# Training set: Average loss: 0.3146
# Validation set: Average loss: 0.3162, Accuracy: 4255/5000 (85%)
#
# Epoch: 38
# Training set: Average loss: 0.2914
# Validation set: Average loss: 0.3164, Accuracy: 4255/5000 (85%)
#
# Epoch: 39
# Training set: Average loss: 0.2910
# Validation set: Average loss: 0.3167, Accuracy: 4251/5000 (85%)
#
# Epoch: 40
# Training set: Average loss: 0.2908
# Validation set: Average loss: 0.3171, Accuracy: 4255/5000 (85%)
#
# Epoch: 41
# Training set: Average loss: 0.2900
# Validation set: Average loss: 0.3183, Accuracy: 4244/5000 (85%)
#
# Epoch: 42
# Training set: Average loss: 0.2899
# Validation set: Average loss: 0.3178, Accuracy: 4247/5000 (85%)
#
# Epoch: 43
# Training set: Average loss: 0.2896
# Validation set: Average loss: 0.3175, Accuracy: 4246/5000 (85%)
#
# Epoch: 44
# Training set: Average loss: 0.2894
# Validation set: Average loss: 0.3187, Accuracy: 4244/5000 (85%)
#
# Epoch: 45
# Training set: Average loss: 0.2890
# Validation set: Average loss: 0.3187, Accuracy: 4253/5000 (85%)
#
# Epoch: 46
# Training set: Average loss: 0.2887
# Validation set: Average loss: 0.3190, Accuracy: 4252/5000 (85%)
#
# Epoch: 47
# Training set: Average loss: 0.2885
# Validation set: Average loss: 0.3194, Accuracy: 4254/5000 (85%)
#
# Epoch: 48
# Training set: Average loss: 0.2884
# Validation set: Average loss: 0.3199, Accuracy: 4237/5000 (85%)
#
# Epoch: 49
# Training set: Average loss: 0.2882
# Validation set: Average loss: 0.3207, Accuracy: 4246/5000 (85%)
#
# Epoch: 50
# Training set: Average loss: 0.2877
# Validation set: Average loss: 0.3208, Accuracy: 4245/5000 (85%)

# %%
#Đồ thị hàm loss tương ướng với các thuật toán tối ưu khác nnhau
plt.plot(training_loss1, label = "batch_size=16", linestyle="-")
plt.plot(training_loss4, label = "batch_size=64", linestyle="--")
plt.plot(training_loss5, label = "batch_size=128", linestyle="-.")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()

# %% [markdown]
# Từ đồ thị ta thấy rằng, Hàm loss cho kết quả như nhau với các batch_size khác nhau.

# %% [markdown]
# ###Thay đổi hàm loss

# %%
hl1 = 8
hl2 = 4

# Define the neural network
class IncomeCLNet(nn.Module):
    def __init__(self):
        super(IncomeCLNet, self).__init__()
        self.fc1 = nn.Linear(len(train_x[1]), hl1)
        self.fc2 = nn.Linear(hl1, hl2)
        self.fc3 = nn.Linear(hl2, 2)
        self.random_state = 42

    def forward(self, x):
        x = torch.sigmoid(self.fc1(x))
        x = torch.sigmoid(self.fc2(x))
        x = torch.nn.Softmax()(self.fc3(x))
        return x

# Create a model instance from the network
model2 = IncomeCLNet()
print(model2)
# Out:
# IncomeCLNet(
#   (fc1): Linear(in_features=108, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=4, bias=True)
#   (fc3): Linear(in_features=4, out_features=2, bias=True)
# )

# %%
def train2(model, data_loader, optimizer):
    # Set the model to training mode
    model.train()
    train_loss = 0
    
    for batch, tensor in enumerate(data_loader):
        data, target = tensor
        
        #Lan truyền tiến
        #feedforward: calculate y_pred and loss function
        optimizer.zero_grad()
        out = model(data)
        #hàm loss khác
        loss = nn.CrossEntropyLoss()
        #print("out:", out)
        #print("target:", target)
        output = loss(out, target)
        train_loss += output.item()

        #Lan truyền ngược
        #backpropagate: compute gradient descent and update weights
        output.backward()
        optimizer.step()

    #Return average loss
    avg_loss = train_loss / (batch+1)
    print('Training set: Average loss: {:.4f}'.format(avg_loss))
    return avg_loss

# %%
def test2(model, data_loader):
    # Switch the model to evaluation mode (so we don't backpropagate)
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
        batch_count = 0
        for batch, tensor in enumerate(data_loader):
            batch_count += 1
            data, target = tensor
            # Get the predictions
            out = model(data)
            # calculate the loss
            loss_criteria = nn.CrossEntropyLoss()
            test_loss += loss_criteria(out, target).item()
            # Calculate the accuracy
            #print(out.data)
            predicted = torch.tensor(out.data[:, 1]>=0.5).float()
            correct += torch.sum(target==predicted).item()
            #print(target)
            #print(predicted)
            
    # Calculate the average loss and total accuracy for this epoch
    avg_loss = test_loss/batch_count
    print('Validation set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        avg_loss, correct, len(data_loader.dataset),
        100. * correct / len(data_loader.dataset)))
    avg_acc = correct / len(data_loader.dataset)
    
    # return average loss for the epoch
    return avg_loss, avg_acc

# %%
from pandas.core.common import random_state
def train_model2(model, l_r, optim):
  learning_rate = l_r #0.001
  random_state=42
  if optim == 1:
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
  elif optim == 2:
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
  elif optim == 3:
    optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate)
  optimizer.zero_grad()

  # We'll track metrics for each epoch in these arrays
  epoch_nums = []
  training_loss = []
  validation_loss = []
  acc = []

  # Train over 50 epochs
  epochs = 50
  for epoch in range(1, epochs + 1):

      # print the epoch number
      print('Epoch: {}'.format(epoch))
      
      # Feed training data into the model to optimize the weights
      train_loss = train2(model2, train_loader, optimizer)
      
      # Feed the test data into the model to check its performance
      test_loss, test_acc = test2(model2, test_loader)
      
      # Log the metrics for this epoch
      epoch_nums.append(epoch)
      training_loss.append(train_loss)
      validation_loss.append(test_loss)
      acc.append(test_acc)
  return (training_loss, validation_loss, acc)

# %%
training_loss10, validation_loss10, acc10 = train_model2(model2, 0.001, 1)
# Out:
# Epoch: 1
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   app.launch_new_instance()
# Training set: Average loss: 0.4608
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Validation set: Average loss: 0.4569, Accuracy: 4254/5000 (85%)
#
# Epoch: 2
# Training set: Average loss: 0.4572
# Validation set: Average loss: 0.4556, Accuracy: 4262/5000 (85%)
#
# Epoch: 3
# Training set: Average loss: 0.4552
# Validation set: Average loss: 0.4549, Accuracy: 4259/5000 (85%)
#
# Epoch: 4
# Training set: Average loss: 0.4537
# Validation set: Average loss: 0.4538, Accuracy: 4260/5000 (85%)
#
# Epoch: 5
# Training set: Average loss: 0.4528
# Validation set: Average loss: 0.4538, Accuracy: 4259/5000 (85%)
#
# Epoch: 6
# Training set: Average loss: 0.4517
# Validation set: Average loss: 0.4532, Accuracy: 4257/5000 (85%)
#
# Epoch: 7
# Training set: Average loss: 0.4509
# Validation set: Average loss: 0.4530, Accuracy: 4264/5000 (85%)
#
# Epoch: 8
# Validation set: Average loss: 0.4516, Accuracy: 4266/5000 (85%)
#
# Epoch: 34
# Training set: Average loss: 0.4374
# Validation set: Average loss: 0.4521, Accuracy: 4269/5000 (85%)
#
# Epoch: 35
# Training set: Average loss: 0.4370
# Validation set: Average loss: 0.4523, Accuracy: 4272/5000 (85%)
#
# Epoch: 36
# Training set: Average loss: 0.4367
# Validation set: Average loss: 0.4521, Accuracy: 4266/5000 (85%)
#
# Epoch: 37
# Training set: Average loss: 0.4365
# Validation set: Average loss: 0.4517, Accuracy: 4272/5000 (85%)
#
# Epoch: 38
# Training set: Average loss: 0.4365
# Validation set: Average loss: 0.4528, Accuracy: 4278/5000 (86%)
#
# Epoch: 39
# Training set: Average loss: 0.4361
# Validation set: Average loss: 0.4533, Accuracy: 4259/5000 (85%)
#
# Epoch: 40
# Training set: Average loss: 0.4361
# Validation set: Average loss: 0.4524, Accuracy: 4272/5000 (85%)
#
# Epoch: 41
# Training set: Average loss: 0.4357
# Validation set: Average loss: 0.4525, Accuracy: 4273/5000 (85%)
#
# Epoch: 42
# Training set: Average loss: 0.4353
# Validation set: Average loss: 0.4526, Accuracy: 4266/5000 (85%)
#
# Epoch: 43
# Training set: Average loss: 0.4352
# Validation set: Average loss: 0.4530, Accuracy: 4267/5000 (85%)
#
# Epoch: 44
# Training set: Average loss: 0.4350
# Validation set: Average loss: 0.4525, Accuracy: 4275/5000 (86%)
#
# Epoch: 45
# Training set: Average loss: 0.4347
# Validation set: Average loss: 0.4533, Accuracy: 4271/5000 (85%)
#
# Epoch: 46
# Training set: Average loss: 0.4346
# Validation set: Average loss: 0.4527, Accuracy: 4273/5000 (85%)
#
# Epoch: 47
# Training set: Average loss: 0.4343
# Validation set: Average loss: 0.4528, Accuracy: 4276/5000 (86%)
#
# Epoch: 48
# Training set: Average loss: 0.4341
# Validation set: Average loss: 0.4536, Accuracy: 4263/5000 (85%)
#
# Epoch: 49
# Training set: Average loss: 0.4340
# Validation set: Average loss: 0.4534, Accuracy: 4268/5000 (85%)
#
# Epoch: 50
# Training set: Average loss: 0.4339
# Validation set: Average loss: 0.4531, Accuracy: 4267/5000 (85%)

# %%
#Đồ thị hàm loss tương ứng với các hàm loss khác nhau
plt.plot(training_loss1, label = "BCELoss()", linestyle="-")
plt.plot(training_loss10, label = "CrossEntropyLoss()", linestyle="--")
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

# %%
#Đồ thị accuracy tương ứng với các cách khởi tạo khác nhau
plt.plot(acc1, label = "BCELoss()", linestyle="-")
plt.plot(acc10, label = "CrossEntropyLoss()", linestyle="--")
plt.xlabel("epoch")
plt.ylabel("Accuracy")
plt.legend()

# %% [markdown]
# **Nhận xét**: Hàm loss `BCELoss()` cho kết quả tốt hơn

# %% [markdown]
# ##7) Thử nghiệm thêm các layers mà bạn đã học được trong bài này vào kiến trúc của mình.

# %%
#Thêm 2 lớp ẩn
# Number of hidden layer nodes
hl1 = 128
hl2 = 64
hl3 = 16
hl4 = 8

# Define the neural network
class IncomeCL(nn.Module):
    def __init__(self):
        super(IncomeCL, self).__init__()
        self.fc1 = nn.Linear(len(train_x[1]), hl1)
        self.fc2 = nn.Linear(hl1, hl2)
        self.fc3 = nn.Linear(hl2, hl3)
        self.fc4 = nn.Linear(hl3, hl4)
        self.fc5 = nn.Linear(hl4, 1)
        self.random_state = 42

    def forward(self, x):
        x = torch.sigmoid(self.fc1(x))
        x = torch.sigmoid(self.fc2(x))
        x = torch.sigmoid(self.fc3(x))
        x = torch.sigmoid(self.fc4(x))
        x = torch.sigmoid(self.fc5(x))
        return x

# Create a model instance from the network
model = IncomeCL()
print(model)
# Out:
# IncomeCL(
#   (fc1): Linear(in_features=108, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=16, bias=True)
#   (fc4): Linear(in_features=16, out_features=8, bias=True)
#   (fc5): Linear(in_features=8, out_features=1, bias=True)
# )

# %%
epoch_nums6, training_loss6, validation_loss6, acc6 = train_model(0.001, 1)
# Out:
# Epoch: 1
# Training set: Average loss: 0.4388
# Validation set: Average loss: 0.3583, Accuracy: 4211/5000 (84%)
#
# Epoch: 2
# Training set: Average loss: 0.3520
# Validation set: Average loss: 0.3259, Accuracy: 4253/5000 (85%)
#
# Epoch: 3
# Training set: Average loss: 0.3317
# Validation set: Average loss: 0.3192, Accuracy: 4261/5000 (85%)
#
# Epoch: 4
# Training set: Average loss: 0.3240
# Validation set: Average loss: 0.3152, Accuracy: 4274/5000 (85%)
#
# Epoch: 5
# Training set: Average loss: 0.3195
# Validation set: Average loss: 0.3145, Accuracy: 4264/5000 (85%)
#
# Epoch: 6
# Training set: Average loss: 0.3166
# Validation set: Average loss: 0.3123, Accuracy: 4273/5000 (85%)
#
# Epoch: 7
# Training set: Average loss: 0.3138
# Validation set: Average loss: 0.3144, Accuracy: 4270/5000 (85%)
#
# Epoch: 8
# Training set: Average loss: 0.3109
# Validation set: Average loss: 0.3125, Accuracy: 4275/5000 (86%)
#
# Epoch: 9
# Training set: Average loss: 0.3088
# Validation set: Average loss: 0.3125, Accuracy: 4264/5000 (85%)
#
# Epoch: 10
# Training set: Average loss: 0.3055
# Validation set: Average loss: 0.3090, Accuracy: 4258/5000 (85%)
#
# Epoch: 11
# Training set: Average loss: 0.3018
# Validation set: Average loss: 0.3129, Accuracy: 4278/5000 (86%)
#
# Epoch: 12
# Training set: Average loss: 0.2995
# Validation set: Average loss: 0.3128, Accuracy: 4272/5000 (85%)
#
# Epoch: 13
# Training set: Average loss: 0.2967
# Validation set: Average loss: 0.3105, Accuracy: 4266/5000 (85%)
#
# Epoch: 14
# Training set: Average loss: 0.2937
# Validation set: Average loss: 0.3131, Accuracy: 4265/5000 (85%)
#
# Epoch: 15
# Training set: Average loss: 0.2914
# Validation set: Average loss: 0.3143, Accuracy: 4271/5000 (85%)
#
# Epoch: 16
# Training set: Average loss: 0.2896
# Validation set: Average loss: 0.3154, Accuracy: 4264/5000 (85%)
#
# Epoch: 17
# Training set: Average loss: 0.2867
# Validation set: Average loss: 0.3157, Accuracy: 4273/5000 (85%)
#
# Epoch: 18
# Training set: Average loss: 0.2845
# Validation set: Average loss: 0.3195, Accuracy: 4262/5000 (85%)
#
# Epoch: 44
# Training set: Average loss: 0.2045
# Validation set: Average loss: 0.4175, Accuracy: 4175/5000 (84%)
#
# Epoch: 45
# Training set: Average loss: 0.2047
# Validation set: Average loss: 0.4341, Accuracy: 4178/5000 (84%)
#
# Epoch: 46
# Training set: Average loss: 0.2022
# Validation set: Average loss: 0.4481, Accuracy: 4214/5000 (84%)
#
# Epoch: 47
# Training set: Average loss: 0.1993
# Validation set: Average loss: 0.4329, Accuracy: 4200/5000 (84%)
#
# Epoch: 48
# Training set: Average loss: 0.1966
# Validation set: Average loss: 0.4376, Accuracy: 4169/5000 (83%)
#
# Epoch: 49
# Training set: Average loss: 0.1962
# Validation set: Average loss: 0.4489, Accuracy: 4196/5000 (84%)
#
# Epoch: 50
# Training set: Average loss: 0.1930
# Validation set: Average loss: 0.4536, Accuracy: 4129/5000 (83%)

# %%
#Đồ thị hàm loss tương ướng với các kiến trúc khác nhau
plt.plot(training_loss1, label = "3 lớp", linestyle="-")
plt.plot(training_loss6, label = "6 lớp", linestyle="--")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()

# %% [markdown]
# Hàm loss của mô hình 6 lớp có giá trị nhỏ hơn so với mô hình 3 lớp.

# %%
#Đồ thị accuracy tương ứng với các kiến trúc khác nhau
plt.plot(acc1, label = "3 lớp", linestyle="-")
plt.plot(acc6, label = "6 lớp", linestyle="--")
plt.xlabel("epoch")
plt.ylabel("Accuracy")
plt.legend()

# %% [markdown]
# Với epoch <=20, kiến trúc với 6 lớp cho accuracy cao hơn so với kiến trúc 3 lớp.
#
#
# Với epoch >20, accuracy của mô hình 3 lớp cao hơn so với mô hình 6 lớp

# %% [markdown]
# ##8) Thay đổi các khởi tạo trọng số theo các phân phối khác nhau và đánh giá độ chính xác của kết quả huấn luyện.

# %%
"""
import torch.nn as nn        
h_size = 8
# a simple network
rand_net = nn.Sequential(nn.Linear(len(features), h_size),
                         nn.BatchNorm1d(h_size),
                         nn.ReLU(),
                         nn.Linear(h_size, h_size),
                         nn.BatchNorm1d(h_size),
                         nn.ReLU(),
                         nn.Linear(h_size, 1),
                         nn.Sigmoid())
"""

# initialization function, first checks the module type,
# then applies the desired changes to the weights
def init_normal(m):
    if type(m) == nn.Linear:
        nn.init.uniform_(m.weight)

# use the modules apply function to recursively apply the initialization
model.apply(init_normal)
# Out:
# IncomeCL(
#   (fc1): Linear(in_features=108, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=4, bias=True)
#   (fc3): Linear(in_features=4, out_features=1, bias=True)
# )

# %%
epoch_nums7, training_loss7, validation_loss7, acc7 = train_model(0.001, 1)
# Out:
# Epoch: 1
# Training set: Average loss: 0.6595
# Validation set: Average loss: 0.4928, Accuracy: 3811/5000 (76%)
#
# Epoch: 2
# Training set: Average loss: 0.4248
# Validation set: Average loss: 0.3681, Accuracy: 4217/5000 (84%)
#
# Epoch: 3
# Training set: Average loss: 0.3605
# Validation set: Average loss: 0.3376, Accuracy: 4253/5000 (85%)
#
# Epoch: 4
# Training set: Average loss: 0.3429
# Validation set: Average loss: 0.3289, Accuracy: 4254/5000 (85%)
#
# Epoch: 30
# Training set: Average loss: 0.2976
# Validation set: Average loss: 0.3159, Accuracy: 4263/5000 (85%)
#
# Epoch: 31
# Training set: Average loss: 0.2974
# Validation set: Average loss: 0.3165, Accuracy: 4250/5000 (85%)
#
# Epoch: 32
# Training set: Average loss: 0.2973
# Validation set: Average loss: 0.3169, Accuracy: 4262/5000 (85%)
#
# Epoch: 33
# Training set: Average loss: 0.2968
# Validation set: Average loss: 0.3173, Accuracy: 4256/5000 (85%)
#
# Epoch: 34
# Training set: Average loss: 0.2965
# Validation set: Average loss: 0.3180, Accuracy: 4251/5000 (85%)
#
# Epoch: 35
# Training set: Average loss: 0.2960
# Validation set: Average loss: 0.3179, Accuracy: 4256/5000 (85%)
#
# Epoch: 36
# Training set: Average loss: 0.2957
# Validation set: Average loss: 0.3184, Accuracy: 4254/5000 (85%)
#
# Epoch: 37
# Training set: Average loss: 0.2953
# Validation set: Average loss: 0.3187, Accuracy: 4254/5000 (85%)
#
# Epoch: 38
# Training set: Average loss: 0.2951
# Validation set: Average loss: 0.3204, Accuracy: 4247/5000 (85%)
#
# Epoch: 39
# Training set: Average loss: 0.2945
# Validation set: Average loss: 0.3212, Accuracy: 4242/5000 (85%)
#
# Epoch: 40
# Training set: Average loss: 0.2944
# Validation set: Average loss: 0.3198, Accuracy: 4260/5000 (85%)
#
# Epoch: 41
# Training set: Average loss: 0.2940
# Validation set: Average loss: 0.3203, Accuracy: 4254/5000 (85%)
#
# Epoch: 42
# Training set: Average loss: 0.2939
# Validation set: Average loss: 0.3206, Accuracy: 4246/5000 (85%)
#
# Epoch: 43
# Training set: Average loss: 0.2934
# Validation set: Average loss: 0.3221, Accuracy: 4249/5000 (85%)
#
# Epoch: 44
# Training set: Average loss: 0.2934
# Validation set: Average loss: 0.3210, Accuracy: 4246/5000 (85%)
#
# Epoch: 45
# Training set: Average loss: 0.2930
# Validation set: Average loss: 0.3208, Accuracy: 4249/5000 (85%)
#
# Epoch: 46
# Training set: Average loss: 0.2931
# Validation set: Average loss: 0.3225, Accuracy: 4252/5000 (85%)
#
# Epoch: 47
# Training set: Average loss: 0.2925
# Validation set: Average loss: 0.3222, Accuracy: 4253/5000 (85%)
#
# Epoch: 48
# Training set: Average loss: 0.2924
# Validation set: Average loss: 0.3223, Accuracy: 4249/5000 (85%)
#
# Epoch: 49
# Training set: Average loss: 0.2921
# Validation set: Average loss: 0.3228, Accuracy: 4234/5000 (85%)
#
# Epoch: 50
# Training set: Average loss: 0.2916
# Validation set: Average loss: 0.3237, Accuracy: 4249/5000 (85%)

# %%
#General rule for setting weights
# takes in a module and applies the specified weight initialization
def weights_init_uniform_rule(m):
    classname = m.__class__.__name__
    # for every Linear layer in a model..
    if classname.find('Linear') != -1:
        # get the number of the inputs
        n = m.in_features
        y = 1.0/np.sqrt(n)
        m.weight.data.uniform_(-y, y)
        m.bias.data.fill_(0)

# create a new model with these weights
model = IncomeCL()
model.apply(weights_init_uniform_rule)
# Out:
# IncomeCL(
#   (fc1): Linear(in_features=108, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=4, bias=True)
#   (fc3): Linear(in_features=4, out_features=1, bias=True)
# )

# %%
epoch_nums8, training_loss8, validation_loss8, acc8 = train_model(0.001, 1)
# Out:
# Epoch: 1
# Training set: Average loss: 0.5458
# Validation set: Average loss: 0.4373, Accuracy: 3811/5000 (76%)
#
# Epoch: 2
# Training set: Average loss: 0.3917
# Validation set: Average loss: 0.3534, Accuracy: 4255/5000 (85%)
#
# Epoch: 3
# Training set: Average loss: 0.3526
# Validation set: Average loss: 0.3361, Accuracy: 4252/5000 (85%)
#
# Epoch: 4
# Training set: Average loss: 0.3397
# Validation set: Average loss: 0.3288, Accuracy: 4251/5000 (85%)
#
# Epoch: 5
# Training set: Average loss: 0.3321
# Validation set: Average loss: 0.3229, Accuracy: 4260/5000 (85%)
#
# Epoch: 6
# Training set: Average loss: 0.3267
# Validation set: Average loss: 0.3197, Accuracy: 4266/5000 (85%)
#
# Epoch: 7
# Training set: Average loss: 0.3226
# Validation set: Average loss: 0.3175, Accuracy: 4262/5000 (85%)
#
# Epoch: 8
# Training set: Average loss: 0.3194
# Validation set: Average loss: 0.3160, Accuracy: 4261/5000 (85%)
#
# Epoch: 9
# Training set: Average loss: 0.3163
# Validation set: Average loss: 0.3148, Accuracy: 4267/5000 (85%)
#
# Epoch: 10
# Training set: Average loss: 0.3141
# Validation set: Average loss: 0.3128, Accuracy: 4266/5000 (85%)
#
# Epoch: 11
# Training set: Average loss: 0.3118
# Validation set: Average loss: 0.3140, Accuracy: 4261/5000 (85%)
#
# Epoch: 12
# Training set: Average loss: 0.3099
# Validation set: Average loss: 0.3121, Accuracy: 4265/5000 (85%)
#
# Epoch: 13
# Training set: Average loss: 0.3082
# Validation set: Average loss: 0.3122, Accuracy: 4271/5000 (85%)
#
# Epoch: 14
# Training set: Average loss: 0.3067
# Validation set: Average loss: 0.3123, Accuracy: 4255/5000 (85%)
#
# Epoch: 15
# Training set: Average loss: 0.3055
# Validation set: Average loss: 0.3101, Accuracy: 4272/5000 (85%)
#
# Epoch: 16
# Training set: Average loss: 0.3043
# Validation set: Average loss: 0.3095, Accuracy: 4275/5000 (86%)
#
# Epoch: 17
# Training set: Average loss: 0.3030
# Validation set: Average loss: 0.3116, Accuracy: 4278/5000 (86%)
#
# Epoch: 18
# Training set: Average loss: 0.3020
# Validation set: Average loss: 0.3106, Accuracy: 4274/5000 (85%)
#
# Epoch: 19
# Training set: Average loss: 0.3010
# Validation set: Average loss: 0.3101, Accuracy: 4278/5000 (86%)
#
# Epoch: 20
# Training set: Average loss: 0.3000
# Validation set: Average loss: 0.3099, Accuracy: 4281/5000 (86%)
#
# Epoch: 21
# Training set: Average loss: 0.2990
# Validation set: Average loss: 0.3095, Accuracy: 4284/5000 (86%)
#
# Epoch: 22
# Training set: Average loss: 0.2986
# Validation set: Average loss: 0.3104, Accuracy: 4273/5000 (85%)
#
# Epoch: 23
# Training set: Average loss: 0.2976
# Validation set: Average loss: 0.3101, Accuracy: 4272/5000 (85%)
#
# Epoch: 24
# Training set: Average loss: 0.2969
# Validation set: Average loss: 0.3153, Accuracy: 4272/5000 (85%)
#
# Epoch: 50
# Training set: Average loss: 0.2875
# Validation set: Average loss: 0.3151, Accuracy: 4261/5000 (85%)

# %%
#normal distribution to initialize the weights
# takes in a module and applies the specified weight initialization
def weights_init_normal(m):
    '''Takes in a module and initializes all linear layers with weight
        values taken from a normal distribution.'''

    classname = m.__class__.__name__
    # for every Linear layer in a model
    if classname.find('Linear') != -1:
        y = m.in_features
    # m.weight.data shoud be taken from a normal distribution
        m.weight.data.normal_(0.0,1/np.sqrt(y))
    # m.bias.data should be 0
        m.bias.data.fill_(0)

# %%
model = IncomeCL()
model.apply(weights_init_uniform_rule)
# Out:
# IncomeCL(
#   (fc1): Linear(in_features=108, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=4, bias=True)
#   (fc3): Linear(in_features=4, out_features=1, bias=True)
# )

# %%
epoch_nums9, training_loss9, validation_loss9, acc9 = train_model(0.001, 1)
# Out:
# Epoch: 1
# Training set: Average loss: 0.4893
# Validation set: Average loss: 0.3923, Accuracy: 3811/5000 (76%)
#
# Epoch: 2
# Training set: Average loss: 0.3696
# Validation set: Average loss: 0.3411, Accuracy: 4251/5000 (85%)
#
# Epoch: 3
# Training set: Average loss: 0.3459
# Validation set: Average loss: 0.3297, Accuracy: 4259/5000 (85%)
#
# Epoch: 4
# Training set: Average loss: 0.3367
# Validation set: Average loss: 0.3238, Accuracy: 4253/5000 (85%)
#
# Epoch: 5
# Training set: Average loss: 0.3303
# Validation set: Average loss: 0.3202, Accuracy: 4262/5000 (85%)
#
# Epoch: 6
# Training set: Average loss: 0.3256
# Validation set: Average loss: 0.3181, Accuracy: 4264/5000 (85%)
#
# Epoch: 7
# Training set: Average loss: 0.3225
# Validation set: Average loss: 0.3164, Accuracy: 4264/5000 (85%)
#
# Epoch: 8
# Training set: Average loss: 0.3192
# Validation set: Average loss: 0.3163, Accuracy: 4249/5000 (85%)
#
# Epoch: 9
# Training set: Average loss: 0.3167
# Validation set: Average loss: 0.3154, Accuracy: 4262/5000 (85%)
#
# Epoch: 10
# Training set: Average loss: 0.3147
# Validation set: Average loss: 0.3141, Accuracy: 4259/5000 (85%)
#
# Epoch: 11
# Training set: Average loss: 0.3124
# Validation set: Average loss: 0.3133, Accuracy: 4255/5000 (85%)
#
# Epoch: 12
# Training set: Average loss: 0.3106
# Validation set: Average loss: 0.3126, Accuracy: 4258/5000 (85%)
#
# Epoch: 13
# Training set: Average loss: 0.3089
# Validation set: Average loss: 0.3129, Accuracy: 4255/5000 (85%)
#
# Epoch: 14
# Training set: Average loss: 0.3073
# Validation set: Average loss: 0.3121, Accuracy: 4264/5000 (85%)
#
# Epoch: 15
# Training set: Average loss: 0.3060
# Validation set: Average loss: 0.3113, Accuracy: 4250/5000 (85%)
#
# Epoch: 16
# Training set: Average loss: 0.3048
# Validation set: Average loss: 0.3111, Accuracy: 4262/5000 (85%)
#
# Epoch: 17
# Training set: Average loss: 0.3033
# Validation set: Average loss: 0.3109, Accuracy: 4271/5000 (85%)
#
# Epoch: 18
# Training set: Average loss: 0.2905
# Validation set: Average loss: 0.3144, Accuracy: 4273/5000 (85%)
#
# Epoch: 44
# Training set: Average loss: 0.2904
# Validation set: Average loss: 0.3141, Accuracy: 4274/5000 (85%)
#
# Epoch: 45
# Training set: Average loss: 0.2902
# Validation set: Average loss: 0.3137, Accuracy: 4282/5000 (86%)
#
# Epoch: 46
# Training set: Average loss: 0.2897
# Validation set: Average loss: 0.3154, Accuracy: 4276/5000 (86%)
#
# Epoch: 47
# Training set: Average loss: 0.2898
# Validation set: Average loss: 0.3155, Accuracy: 4279/5000 (86%)
#
# Epoch: 48
# Training set: Average loss: 0.2895
# Validation set: Average loss: 0.3168, Accuracy: 4276/5000 (86%)
#
# Epoch: 49
# Training set: Average loss: 0.2892
# Validation set: Average loss: 0.3167, Accuracy: 4265/5000 (85%)
#
# Epoch: 50
# Training set: Average loss: 0.2890
# Validation set: Average loss: 0.3167, Accuracy: 4267/5000 (85%)

# %%
#Đồ thị accuracy tương ứng với các cách khởi tạo khác nhau
plt.plot(acc8, label = "uniform-distribution", linestyle="-")
plt.plot(acc9, label = "normal-distribution", linestyle="--")
plt.xlabel("epoch")
plt.ylabel("Accuracy")
plt.legend()

# %%
#Đồ thị accuracy tương ứng với các cách khởi tạo khác nhau
plt.plot(acc8, label = "uniform-distribution", linestyle="-")
plt.plot(acc9, label = "normal-distribution", linestyle="--")
plt.xlabel("epoch")
plt.ylabel("Accuracy")
plt.legend()

# %% [markdown]
# Cách khởi tạo trọng số theo normal-distribution cho độ chính xác cao hơn

# %%
#Đồ thị accuracy tương ứng với các cách khởi tạo khác nhau
plt.plot(acc1, label = "zero_grad", linestyle="-.")
plt.plot(acc8, label = "uniform-distribution", linestyle="-")
plt.plot(acc9, label = "normal-distribution", linestyle="--")
plt.xlabel("epoch")
plt.ylabel("Accuracy")
plt.legend()

# %%
#Đồ thị hàm loss tương ứng với các cách khởi tạo khác nhau
plt.plot(training_loss8, label = "uniform-distribution", linestyle="-")
plt.plot(training_loss9, label = "normal-distribution", linestyle="--")
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

# %% [markdown]
# Hàm loss của hai cách khởi tạo này cũng cho kết quả như nhau.

# %%
def init_weights(m, init_type = 'xavier'):
    if type(m) == nn.Linear:
      if init_type == 'xavier':
        torch.nn.init.xavier_uniform_(m.weight)
        m.bias.data.fill_(0.01)
      elif init_type == 'normal':
        torch.nn.init.normal_(m.weight)
        m.bias.data.fill_(0.01)
      elif init_type == 'he':
        m.bias.kaiming_uniform_(m.weight)
        m.bias.data.fill_(0.01)

# %%
model = IncomeCL()
model.apply(lambda m: init_weights(m, init_type = 'normal'))
# Out:
# IncomeCL(
#   (fc1): Linear(in_features=108, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=4, bias=True)
#   (fc3): Linear(in_features=4, out_features=1, bias=True)
# )

# %%
epoch_nums12, training_loss12, validation_loss12, acc12 = train_model(0.001, 1)
# Out:
# Epoch: 1
# Training set: Average loss: 0.5241
# Validation set: Average loss: 0.4492, Accuracy: 3811/5000 (76%)
#
# Epoch: 27
# Training set: Average loss: 0.3056
# Validation set: Average loss: 0.3229, Accuracy: 4214/5000 (84%)
#
# Epoch: 28
# Training set: Average loss: 0.3049
# Validation set: Average loss: 0.3228, Accuracy: 4215/5000 (84%)
#
# Epoch: 29
# Training set: Average loss: 0.3044
# Validation set: Average loss: 0.3227, Accuracy: 4219/5000 (84%)
#
# Epoch: 30
# Training set: Average loss: 0.3038
# Validation set: Average loss: 0.3230, Accuracy: 4229/5000 (85%)
#
# Epoch: 31
# Training set: Average loss: 0.3035
# Validation set: Average loss: 0.3225, Accuracy: 4217/5000 (84%)
#
# Epoch: 32
# Training set: Average loss: 0.3027
# Validation set: Average loss: 0.3223, Accuracy: 4217/5000 (84%)
#
# Epoch: 33
# Training set: Average loss: 0.3024
# Validation set: Average loss: 0.3225, Accuracy: 4214/5000 (84%)
#
# Epoch: 34
# Training set: Average loss: 0.3018
# Validation set: Average loss: 0.3231, Accuracy: 4219/5000 (84%)
#
# Epoch: 35
# Training set: Average loss: 0.3015
# Validation set: Average loss: 0.3232, Accuracy: 4221/5000 (84%)
#
# Epoch: 36
# Training set: Average loss: 0.3011
# Validation set: Average loss: 0.3227, Accuracy: 4209/5000 (84%)
#
# Epoch: 37
# Training set: Average loss: 0.3007
# Validation set: Average loss: 0.3235, Accuracy: 4212/5000 (84%)
#
# Epoch: 38
# Training set: Average loss: 0.3003
# Validation set: Average loss: 0.3238, Accuracy: 4211/5000 (84%)
#
# Epoch: 39
# Training set: Average loss: 0.3001
# Validation set: Average loss: 0.3234, Accuracy: 4221/5000 (84%)
#
# Epoch: 40
# Training set: Average loss: 0.2997
# Validation set: Average loss: 0.3233, Accuracy: 4218/5000 (84%)
#
# Epoch: 41
# Training set: Average loss: 0.2995
# Validation set: Average loss: 0.3231, Accuracy: 4213/5000 (84%)
#
# Epoch: 42
# Training set: Average loss: 0.2991
# Validation set: Average loss: 0.3238, Accuracy: 4228/5000 (85%)
#
# Epoch: 43
# Training set: Average loss: 0.2988
# Validation set: Average loss: 0.3233, Accuracy: 4223/5000 (84%)
#
# Epoch: 44
# Training set: Average loss: 0.2985
# Validation set: Average loss: 0.3240, Accuracy: 4217/5000 (84%)
#
# Epoch: 45
# Training set: Average loss: 0.2983
# Validation set: Average loss: 0.3240, Accuracy: 4225/5000 (84%)
#
# Epoch: 46
# Training set: Average loss: 0.2981
# Validation set: Average loss: 0.3239, Accuracy: 4219/5000 (84%)
#
# Epoch: 47
# Training set: Average loss: 0.2979
# Validation set: Average loss: 0.3245, Accuracy: 4227/5000 (85%)
#
# Epoch: 48
# Training set: Average loss: 0.2976
# Validation set: Average loss: 0.3238, Accuracy: 4226/5000 (85%)
#
# Epoch: 49
# Training set: Average loss: 0.2973
# Validation set: Average loss: 0.3245, Accuracy: 4217/5000 (84%)
#
# Epoch: 50
# Training set: Average loss: 0.2971
# Validation set: Average loss: 0.3240, Accuracy: 4227/5000 (85%)

# %%
model = IncomeCL()
model.apply(lambda m: init_weights(m, init_type = 'xavier'))
# Out:
# IncomeCL(
#   (fc1): Linear(in_features=108, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=4, bias=True)
#   (fc3): Linear(in_features=4, out_features=1, bias=True)
# )

# %%
epoch_nums13, training_loss13, validation_loss13, acc13 = train_model(0.001, 1)
# Out:
# Epoch: 1
# Training set: Average loss: 0.4530
# Validation set: Average loss: 0.3622, Accuracy: 4221/5000 (84%)
#
# Epoch: 2
# Training set: Average loss: 0.3540
# Validation set: Average loss: 0.3327, Accuracy: 4241/5000 (85%)
#
# Epoch: 3
# Training set: Average loss: 0.3377
# Validation set: Average loss: 0.3238, Accuracy: 4246/5000 (85%)
#
# Epoch: 4
# Training set: Average loss: 0.3298
# Validation set: Average loss: 0.3210, Accuracy: 4257/5000 (85%)
#
# Epoch: 5
# Training set: Average loss: 0.3243
# Validation set: Average loss: 0.3177, Accuracy: 4251/5000 (85%)
#
# Epoch: 6
# Training set: Average loss: 0.3210
# Validation set: Average loss: 0.3163, Accuracy: 4261/5000 (85%)
#
# Epoch: 7
# Training set: Average loss: 0.3181
# Validation set: Average loss: 0.3159, Accuracy: 4260/5000 (85%)
#
# Epoch: 8
# Training set: Average loss: 0.3155
# Validation set: Average loss: 0.3152, Accuracy: 4258/5000 (85%)
#
# Epoch: 9
# Training set: Average loss: 0.3133
# Validation set: Average loss: 0.3141, Accuracy: 4264/5000 (85%)
#
# Epoch: 10
# Training set: Average loss: 0.3110
# Validation set: Average loss: 0.3141, Accuracy: 4266/5000 (85%)
#
# Epoch: 11
# Training set: Average loss: 0.3095
# Validation set: Average loss: 0.3136, Accuracy: 4271/5000 (85%)
#
# Epoch: 12
# Training set: Average loss: 0.3080
# Validation set: Average loss: 0.3124, Accuracy: 4284/5000 (86%)
#
# Epoch: 13
# Training set: Average loss: 0.3066
# Validation set: Average loss: 0.3118, Accuracy: 4279/5000 (86%)
#
# Epoch: 14
# Training set: Average loss: 0.3048
# Validation set: Average loss: 0.3122, Accuracy: 4278/5000 (86%)
#
# Epoch: 15
# Training set: Average loss: 0.3036
# Validation set: Average loss: 0.3113, Accuracy: 4284/5000 (86%)
#
# Epoch: 16
# Training set: Average loss: 0.3025
# Validation set: Average loss: 0.3116, Accuracy: 4264/5000 (85%)
#
# Epoch: 17
# Training set: Average loss: 0.3012
# Validation set: Average loss: 0.3116, Accuracy: 4276/5000 (86%)
#
# Epoch: 18
# Training set: Average loss: 0.3003
# Validation set: Average loss: 0.3119, Accuracy: 4273/5000 (85%)
#
# Epoch: 19
# Training set: Average loss: 0.2994
# Validation set: Average loss: 0.3128, Accuracy: 4261/5000 (85%)
#
# Epoch: 20
# Training set: Average loss: 0.2988
# Validation set: Average loss: 0.3115, Accuracy: 4259/5000 (85%)
#
# Epoch: 21
# Training set: Average loss: 0.2979
# Validation set: Average loss: 0.3129, Accuracy: 4281/5000 (86%)
#
# Epoch: 22
# Training set: Average loss: 0.2977
# Validation set: Average loss: 0.3121, Accuracy: 4271/5000 (85%)
#
# Epoch: 23
# Training set: Average loss: 0.2969
# Validation set: Average loss: 0.3114, Accuracy: 4277/5000 (86%)
#
# Epoch: 49
# Training set: Average loss: 0.2875
# Validation set: Average loss: 0.3167, Accuracy: 4268/5000 (85%)
#
# Epoch: 50
# Training set: Average loss: 0.2872
# Validation set: Average loss: 0.3158, Accuracy: 4262/5000 (85%)

# %%
#Đồ thị accuracy tương ứng với các cách khởi tạo khác nhau 
plt.plot(acc7, label = "uniform_", linestyle="-.")
plt.plot(acc8, label = "uniform_(-y, y)", linestyle="--")
#plt.plot(acc9, label = "normal_", linestyle="-.")
plt.plot(acc12, label = "normal", linestyle="-.")
plt.plot(acc13, label = "xavier", linestyle="-")
plt.xlabel("epoch")
plt.ylabel("Accuracy")
plt.legend()

# %% [markdown]
# Phương pháp khởi tạo `xavier` và uniform(-y, y) cho độ chính xác cao nhất

# %%
#Đồ thị accuracy tương ứng với các cách khởi tạo khác nhau 
plt.plot(training_loss7, label = "uniform_", linestyle="-.")
plt.plot(training_loss8, label = "uniform_(-y, y)", linestyle="--")
#plt.plot(acc9, label = "normal_", linestyle="-.")
plt.plot(training_loss12, label = "normal", linestyle="-.")
plt.plot(training_loss13, label = "xavier", linestyle="-")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()

# %% [markdown]
# Phương pháp khởi tạo `xavier` cho hàm loss tốt nhất.

# %% [markdown]
# ##9) Thiết lập không gian search và tự động hóa tìm kiếm kiến trúc tốt nhất trên optuna.

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-2.10.0-py3-none-any.whl (308 kB)
#      |████████████████████████████████| 308 kB 4.2 MB/s
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from optuna) (3.13)
# Collecting alembic
#   Downloading alembic-1.7.6-py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 49.9 MB/s
# Collecting cliff
#   Downloading cliff-3.10.0-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 10.7 MB/s
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.31)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (21.3)
# Collecting cmaes>=0.8.2
#   Downloading cmaes-0.8.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna) (4.62.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from optuna) (1.21.5)
# Collecting colorlog
#   Downloading colorlog-6.6.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna) (3.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (1.1.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (4.11.0)
# Collecting Mako
#   Downloading Mako-1.1.6-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 4.6 MB/s
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (5.4.0)
# Collecting stevedore>=2.0.1
#   Downloading stevedore-3.5.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 4.2 MB/s
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.8.1-py2.py3-none-any.whl (113 kB)
#      |████████████████████████████████| 113 kB 43.5 MB/s
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.3.3-py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 48.1 MB/s
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.0.0)
# Collecting autopage>=0.4.0
#   Downloading autopage-0.5.0-py3-none-any.whl (29 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (3.10.0.2)
# Collecting pyperclip>=1.6
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (21.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy>=1.1.0->optuna) (3.7.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna) (2.0.1)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11137 sha256=d33eea381fd64064ae63642803b277973a12bdac5a247842760ecd500dab5383
#   Stored in directory: /root/.cache/pip/wheels/9f/18/84/8f69f8b08169c7bae2dde6bd7daf0c19fca8c8e500ee620a28
# Successfully built pyperclip
# Installing collected packages: pyperclip, pbr, stevedore, Mako, cmd2, autopage, colorlog, cmaes, cliff, alembic, optuna
# Successfully installed Mako-1.1.6 alembic-1.7.6 autopage-0.5.0 cliff-3.10.0 cmaes-0.8.2 cmd2-2.3.3 colorlog-6.6.0 optuna-2.10.0 pbr-5.8.1 pyperclip-1.8.2 stevedore-3.5.0

# %%
import optuna
from optuna.trial import TrialState
import torch.optim as optim
import torch.nn.functional as F

# %%
import torch
import torch.nn as nn
import torch.utils.data as td

# Set random seed for reproducability
torch.manual_seed(0)

# %%
# Create a dataset and loader for the training data and labels
train_x = torch.Tensor(x_train).float()
# Reshape y target into [-1, 1] to fit with Binary Cross Entropy
train_y = torch.Tensor(y_train).view(-1, 1).float()
train_ds = td.TensorDataset(train_x,train_y)
train_loader = td.DataLoader(train_ds, batch_size=16,
    shuffle=True, num_workers=1)

# Create a dataset and loader for the test data and labels
test_x = torch.Tensor(x_test).float()
test_y = torch.Tensor(y_test).view(-1, 1).float()
test_ds = td.TensorDataset(test_x,test_y)
test_loader = td.DataLoader(test_ds, batch_size=16,
    shuffle=False, num_workers=1)
print('Ready to load data')
# Out:
# Ready to load data

# %%
def define_model(trial):
    # We optimize the number of layers, hidden units and dropout ratio in each layer.
    n_layers = trial.suggest_int("n_layers", 2, 6)
    layers = []

    in_features = len(features)
    for i in range(n_layers):
        out_features = trial.suggest_int("n_units_l{}".format(i), 4, 128)
        layers.append(nn.Linear(in_features, out_features))
        layers.append(nn.ReLU())
        p = trial.suggest_float("dropout_l{}".format(i), 0.2, 0.5)
        layers.append(nn.Dropout(p))

        in_features = out_features
    layers.append(nn.Linear(in_features, 1))
    layers.append(nn.Sigmoid())

    return nn.Sequential(*layers)

# %%
DEVICE = torch.device("cpu")
BATCHSIZE = 16
EPOCHS = 30
LOG_INTERVAL = 10
N_TRAIN_EXAMPLES = BATCHSIZE * 300
N_VALID_EXAMPLES = BATCHSIZE * 100

def objective(trial):

    # Generate the model.
    model = define_model(trial).to(DEVICE)

    # Generate the optimizers.
    optimizer_name = trial.suggest_categorical("optimizer", ["Adam", "RMSprop", "SGD"])
    lr = trial.suggest_float("lr", 1e-5, 1e-1, log=True)
    optimizer = getattr(optim, optimizer_name)(model.parameters(), lr=lr)
    loss_criteria = nn.BCELoss()
    # Training of the model.
    for epoch in range(EPOCHS):
        model.train()
        for batch_idx, (data, target) in enumerate(train_loader):
            # Limiting training data for faster epochs.
            if batch_idx * BATCHSIZE >= N_TRAIN_EXAMPLES:
                break

            data, target = data.view(data.size(0), -1).to(DEVICE), target.to(DEVICE)

            optimizer.zero_grad()
            output = model(data)
            # loss = F.nll_loss(output, target)
            loss = loss_criteria(output, target)
            loss.backward()
            optimizer.step()

        # Validation of the model.
        model.eval()
        correct = 0
        with torch.no_grad():
            for batch_idx, (data, target) in enumerate(test_loader):
                # Limiting validation data.
                if batch_idx * BATCHSIZE >= N_VALID_EXAMPLES:
                    break
                data, target = data.view(data.size(0), -1).to(DEVICE), target.to(DEVICE)
                output = model(data)
                # Get the index of the max log-probability.
                pred = torch.tensor(output.data>=0.5).float()
                correct += pred.eq(target.view_as(pred)).sum().item()

        accuracy = correct / min(len(test_loader.dataset), N_VALID_EXAMPLES)

        trial.report(accuracy, epoch)

        # Handle pruning based on the intermediate value.
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()

    return accuracy

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100, timeout=600)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

print("Study statistics: ")
print("  Number of finished trials: ", len(study.trials))
print("  Number of pruned trials: ", len(pruned_trials))
print("  Number of complete trials: ", len(complete_trials))

print("Best trial:")
trial = study.best_trial

print("  Value: ", trial.value)

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2022-02-16 02:49:45,641] A new study created in memory with name: no-name-db4b60aa-d01f-4955-948f-9470e2f59e07
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# [I 2022-02-16 02:50:22,892] Trial 0 finished with value: 0.764375 and parameters: {'n_layers': 3, 'n_units_l0': 46, 'dropout_l0': 0.2844120796964156, 'n_units_l1': 49, 'dropout_l1': 0.46774502230335635, 'n_units_l2': 56, 'dropout_l2': 0.36102295799041767, 'optimizer': 'RMSprop', 'lr': 0.07998916891677069}. Best is trial 0 with value: 0.764375.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# [I 2022-02-16 02:50:51,700] Trial 1 finished with value: 0.755 and parameters: {'n_layers': 3, 'n_units_l0': 99, 'dropout_l0': 0.21439169428920973, 'n_units_l1': 110, 'dropout_l1': 0.2282139664053958, 'n_units_l2': 47, 'dropout_l2': 0.40235070082849034, 'optimizer': 'SGD', 'lr': 1.3141651874841667e-05}. Best is trial 0 with value: 0.764375.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# [I 2022-02-16 02:51:20,542] Trial 2 finished with value: 0.854375 and parameters: {'n_layers': 2, 'n_units_l0': 95, 'dropout_l0': 0.30026806268873385, 'n_units_l1': 40, 'dropout_l1': 0.3805502891291824, 'optimizer': 'RMSprop', 'lr': 5.885769242510616e-05}. Best is trial 2 with value: 0.854375.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# [I 2022-02-16 02:51:51,876] Trial 3 finished with value: 0.764375 and parameters: {'n_layers': 5, 'n_units_l0': 36, 'dropout_l0': 0.4994008032238336, 'n_units_l1': 110, 'dropout_l1': 0.27968608118248867, 'n_units_l2': 48, 'dropout_l2': 0.42315098199354123, 'n_units_l3': 85, 'dropout_l3': 0.3978066521882847, 'n_units_l4': 16, 'dropout_l4': 0.43874878348255875, 'optimizer': 'SGD', 'lr': 1.2095113035271762e-05}. Best is trial 2 with value: 0.854375.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# [I 2022-02-16 02:52:22,716] Trial 4 finished with value: 0.856875 and parameters: {'n_layers': 4, 'n_units_l0': 19, 'dropout_l0': 0.3648160034031953, 'n_units_l1': 70, 'dropout_l1': 0.22257937831492802, 'n_units_l2': 64, 'dropout_l2': 0.3051383151504939, 'n_units_l3': 74, 'dropout_l3': 0.40408824305877195, 'optimizer': 'SGD', 'lr': 0.05012803987538683}. Best is trial 4 with value: 0.856875.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# [I 2022-02-16 02:52:23,820] Trial 5 pruned.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# [I 2022-02-16 02:53:00,568] Trial 6 finished with value: 0.764375 and parameters: {'n_layers': 6, 'n_units_l0': 9, 'dropout_l0': 0.33312639737982364, 'n_units_l1': 106, 'dropout_l1': 0.3214869976172726, 'n_units_l2': 18, 'dropout_l2': 0.4424253077063447, 'n_units_l3': 86, 'dropout_l3': 0.49492674376131135, 'n_units_l4': 28, 'dropout_l4': 0.44341319351768643, 'n_units_l5': 112, 'dropout_l5': 0.35520188044805334, 'optimizer': 'Adam', 'lr': 2.7940103289935626e-05}. Best is trial 4 with value: 0.856875.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# [I 2022-02-16 02:59:55,687] Trial 26 finished with value: 0.863125 and parameters: {'n_layers': 5, 'n_units_l0': 46, 'dropout_l0': 0.3504804530374013, 'n_units_l1': 95, 'dropout_l1': 0.41500069658053385, 'n_units_l2': 101, 'dropout_l2': 0.23766071796667104, 'n_units_l3': 68, 'dropout_l3': 0.449088547930642, 'n_units_l4': 95, 'dropout_l4': 0.4118963192266708, 'optimizer': 'RMSprop', 'lr': 0.00076748942379295}. Best is trial 26 with value: 0.863125.
# Study statistics:
#   Number of finished trials:  27
#   Number of pruned trials:  9
#   Number of complete trials:  18
# Best trial:
#   Value:  0.863125
#   Params:
#     n_layers: 5
#     n_units_l0: 46
#     dropout_l0: 0.3504804530374013
#     n_units_l1: 95
#     dropout_l1: 0.41500069658053385
#     n_units_l2: 101
#     dropout_l2: 0.23766071796667104
#     n_units_l3: 68
#     dropout_l3: 0.449088547930642
#     n_units_l4: 95
#     dropout_l4: 0.4118963192266708
#     optimizer: RMSprop
#     lr: 0.00076748942379295

# %%
model = define_model(trial)

# %%
print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=108, out_features=46, bias=True)
#   (1): ReLU()
#   (2): Dropout(p=0.3504804530374013, inplace=False)
#   (3): Linear(in_features=46, out_features=95, bias=True)
#   (4): ReLU()
#   (5): Dropout(p=0.41500069658053385, inplace=False)
#   (6): Linear(in_features=95, out_features=101, bias=True)
#   (7): ReLU()
#   (8): Dropout(p=0.23766071796667104, inplace=False)
#   (9): Linear(in_features=101, out_features=68, bias=True)
#   (10): ReLU()
#   (11): Dropout(p=0.449088547930642, inplace=False)
#   (12): Linear(in_features=68, out_features=95, bias=True)
#   (13): ReLU()
#   (14): Dropout(p=0.4118963192266708, inplace=False)
#   (15): Linear(in_features=95, out_features=1, bias=True)
#   (16): Sigmoid()
# )

# %%
def train_model_optuna(model, l_r, optim):
  learning_rate = l_r
  random_state=42
  if optim == 1:
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
  elif optim == 2:
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
  elif optim == 3:
    optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate)
  optimizer.zero_grad()

  # We'll track metrics for each epoch in these arrays
  epoch_nums = []
  training_loss = []
  validation_loss = []
  acc = []

  # Train over 50 epochs
  epochs = 50
  for epoch in range(1, epochs + 1):

      # print the epoch number
      print('Epoch: {}'.format(epoch))
      
      # Feed training data into the model to optimize the weights
      train_loss = train(model, train_loader, optimizer)
      
      # Feed the test data into the model to check its performance
      test_loss, test_acc = test(model, test_loader)
      
      # Log the metrics for this epoch
      epoch_nums.append(epoch)
      training_loss.append(train_loss)
      validation_loss.append(test_loss)
      acc.append(test_acc)
  return (epoch_nums, training_loss, validation_loss, acc)

# %%
epoch_nums11, training_loss11, validation_loss11, acc11 = train_model_optuna(model, 0.00076748942379295, 3)
# Out:
# Epoch: 1
# Training set: Average loss: 0.3768
# Validation set: Average loss: 0.3360, Accuracy: 4240/5000 (85%)
#
# Epoch: 2
# Training set: Average loss: 0.3424
# Validation set: Average loss: 0.3112, Accuracy: 4259/5000 (85%)
#
# Epoch: 3
# Training set: Average loss: 0.3358
# Validation set: Average loss: 0.3161, Accuracy: 4253/5000 (85%)
#
# Epoch: 4
# Training set: Average loss: 0.3296
# Validation set: Average loss: 0.3110, Accuracy: 4273/5000 (85%)
#
# Epoch: 5
# Training set: Average loss: 0.3275
# Validation set: Average loss: 0.3130, Accuracy: 4269/5000 (85%)
#
# Epoch: 6
# Training set: Average loss: 0.3289
# Validation set: Average loss: 0.3142, Accuracy: 4271/5000 (85%)
#
# Epoch: 7
# Training set: Average loss: 0.3281
# Validation set: Average loss: 0.3133, Accuracy: 4269/5000 (85%)
#
# Epoch: 8
# Training set: Average loss: 0.3225
# Validation set: Average loss: 0.3204, Accuracy: 4285/5000 (86%)
#
# Epoch: 9
# Training set: Average loss: 0.3352
# Validation set: Average loss: 0.3112, Accuracy: 4283/5000 (86%)
#
# Epoch: 10
# Training set: Average loss: 0.3308
# Validation set: Average loss: 0.3118, Accuracy: 4276/5000 (86%)
#
# Epoch: 11
# Training set: Average loss: 0.3219
# Validation set: Average loss: 0.3116, Accuracy: 4278/5000 (86%)
#
# Epoch: 12
# Training set: Average loss: 0.3199
# Validation set: Average loss: 0.3532, Accuracy: 4278/5000 (86%)
#
# Epoch: 13
# Training set: Average loss: 0.3238
# Validation set: Average loss: 0.3310, Accuracy: 4281/5000 (86%)
#
# Epoch: 14
# Training set: Average loss: 0.3392
# Validation set: Average loss: 0.3171, Accuracy: 4280/5000 (86%)
#
# Epoch: 15
# Training set: Average loss: 0.3218
# Validation set: Average loss: 0.3290, Accuracy: 4272/5000 (85%)
#
# Epoch: 16
# Training set: Average loss: 0.3183
# Validation set: Average loss: 0.3375, Accuracy: 4279/5000 (86%)
#
# Epoch: 17
# Training set: Average loss: 0.3288
# Validation set: Average loss: 0.3544, Accuracy: 4290/5000 (86%)
#
# Epoch: 18
# Training set: Average loss: 0.3236
# Validation set: Average loss: 0.3488, Accuracy: 4280/5000 (86%)
#
# Epoch: 19
# Training set: Average loss: 0.3249
# Validation set: Average loss: 0.3452, Accuracy: 4287/5000 (86%)
#
# Epoch: 20
# Training set: Average loss: 0.3226
# Validation set: Average loss: 0.3502, Accuracy: 4283/5000 (86%)
#
# Epoch: 21
# Training set: Average loss: 0.3135
# Validation set: Average loss: 0.3529, Accuracy: 4296/5000 (86%)
#
# Epoch: 22
# Training set: Average loss: 0.3289
# Validation set: Average loss: 0.3551, Accuracy: 4294/5000 (86%)
#
# Epoch: 23
# Training set: Average loss: 0.3251
# Validation set: Average loss: 0.3580, Accuracy: 4291/5000 (86%)
#
# Epoch: 24
# Training set: Average loss: 0.3299
# Validation set: Average loss: 0.3709, Accuracy: 4294/5000 (86%)
#
# Epoch: 25
# Training set: Average loss: 0.3168
# Validation set: Average loss: 0.3530, Accuracy: 4277/5000 (86%)
#
# Epoch: 26
# Training set: Average loss: 0.3222
# Validation set: Average loss: 0.3663, Accuracy: 4292/5000 (86%)
#
# Epoch: 27
# Training set: Average loss: 0.3381
# Validation set: Average loss: 0.3717, Accuracy: 4280/5000 (86%)
#
# Epoch: 28
# Training set: Average loss: 0.3222
# Validation set: Average loss: 0.3487, Accuracy: 4299/5000 (86%)
#
# Epoch: 29
# Training set: Average loss: 0.3310
# Validation set: Average loss: 0.3512, Accuracy: 4285/5000 (86%)
#
# Epoch: 30
# Training set: Average loss: 0.3299
# Validation set: Average loss: 0.3536, Accuracy: 4290/5000 (86%)
#
# Epoch: 31
# Training set: Average loss: 0.3256
# Validation set: Average loss: 0.3549, Accuracy: 4289/5000 (86%)
#
# Epoch: 32
# Training set: Average loss: 0.3264
# Validation set: Average loss: 0.3554, Accuracy: 4284/5000 (86%)
#
# Epoch: 33
# Training set: Average loss: 0.3269
# Validation set: Average loss: 0.3526, Accuracy: 4296/5000 (86%)
#
# Epoch: 34
# Training set: Average loss: 0.3287
# Validation set: Average loss: 0.3550, Accuracy: 4287/5000 (86%)
#
# Epoch: 35
# Training set: Average loss: 0.3341
# Validation set: Average loss: 0.3765, Accuracy: 4288/5000 (86%)
#
# Epoch: 36
# Training set: Average loss: 0.3317
# Validation set: Average loss: 0.3588, Accuracy: 4291/5000 (86%)
#
# Epoch: 37
# Training set: Average loss: 0.3233
# Validation set: Average loss: 0.3549, Accuracy: 4285/5000 (86%)
#
# Epoch: 38
# Training set: Average loss: 0.3366
# Validation set: Average loss: 0.3578, Accuracy: 4279/5000 (86%)
#
# Epoch: 39
# Training set: Average loss: 0.3478
# Validation set: Average loss: 0.3593, Accuracy: 4274/5000 (85%)
#
# Epoch: 40
# Training set: Average loss: 0.3387
# Validation set: Average loss: 0.3603, Accuracy: 4284/5000 (86%)
#
# Epoch: 41
# Training set: Average loss: 0.3347
# Validation set: Average loss: 0.3571, Accuracy: 4273/5000 (85%)
#
# Epoch: 42
# Training set: Average loss: 0.3267
# Validation set: Average loss: 0.3582, Accuracy: 4293/5000 (86%)
#
# Epoch: 43
# Training set: Average loss: 0.3350
# Validation set: Average loss: 0.3618, Accuracy: 4279/5000 (86%)
#
# Epoch: 44
# Training set: Average loss: 0.3260
# Validation set: Average loss: 0.4024, Accuracy: 4294/5000 (86%)
#
# Epoch: 45
# Training set: Average loss: 0.3438
# Validation set: Average loss: 0.3688, Accuracy: 4267/5000 (85%)
#
# Epoch: 46
# Training set: Average loss: 0.3421
# Validation set: Average loss: 0.3816, Accuracy: 4278/5000 (86%)
#
# Epoch: 47
# Training set: Average loss: 0.3362
# Validation set: Average loss: 0.3835, Accuracy: 4307/5000 (86%)
#
# Epoch: 48
# Training set: Average loss: 0.3482
# Validation set: Average loss: 0.3416, Accuracy: 4274/5000 (85%)
#
# Epoch: 49
# Training set: Average loss: 0.3400
# Validation set: Average loss: 0.3903, Accuracy: 4282/5000 (86%)
#
# Epoch: 50
# Training set: Average loss: 0.3432
# Validation set: Average loss: 0.4009, Accuracy: 4281/5000 (86%)

# %%
#Đồ thị accuracy tương ứng với các cách khởi tạo khác nhau
plt.plot(acc1, label = "Not using Optuna", linestyle="-.")
plt.plot(acc11, label = "Using Optuna", linestyle="-")
plt.xlabel("epoch")
plt.ylabel("Accuracy")
plt.legend()

# %%
def get_metrics(y_test, y_pred):
    print('ACCURACY_SCORE: ', round(accuracy_score(y_test, y_pred), 4))
    print('F1_SCORE: ', round(f1_score(y_test, y_pred, average='macro'), 4))
    print('CONFUSION_MATRIX:\n', confusion_matrix(y_test, y_pred),'\n')
    print(classification_report(y_test, y_pred, digits=4), '\n')

# %%
def _evaluate(model, x_test):
  model.eval()
  x = torch.Tensor(x_test).float()
  predictions = [1 if i>0.5 else 0 for i in model(x).data]
  predictions = torch.tensor(predictions)
  print('Evaluation on test dataset')
  get_metrics(y_test, predictions)

  # Plot the confusion matrix
  classes=['0','1']
  cm = confusion_matrix(y_test, predictions.numpy())
  plt.imshow(cm, interpolation="nearest", cmap=plt.cm.Blues)
  plt.colorbar()
  tick_marks = np.arange(2)
  plt.xticks(tick_marks, classes, rotation=85)
  plt.yticks(tick_marks, classes)
  plt.xlabel("Predicted")
  plt.ylabel("Actual")
  plt.show()
_evaluate(model, x_test)
# Out:
# Evaluation on test dataset
# ACCURACY_SCORE:  0.8562
# F1_SCORE:  0.7875
# CONFUSION_MATRIX:
#  [[3562  249]
#  [ 470  719]]
#
#               precision    recall  f1-score   support
#
#            0     0.8834    0.9347    0.9083      3811
#            1     0.7428    0.6047    0.6667      1189
#
#     accuracy                         0.8562      5000
#    macro avg     0.8131    0.7697    0.7875      5000
# weighted avg     0.8500    0.8562    0.8509      5000

# %% [markdown]
# **Nhận xét**: Độ chính xác đã được cải thiện với siêu tham số được tìm kiếm dựa trên optuna

# %% [markdown]
# ##10) Deploy model sử dụng flask ap. Tham khảo [Flaskapp tutorial](https://drive.google.com/file/d/1AZNtzrmnhJ-OBgijWoaAqXbPhJ6xL0Po/view?usp=sharing).

# %%
from PIL import Image
import numpy as np
from flask import Flask, request
import flask
import json

# %% [markdown]
# file index.html

# %%
<!DOCTYPE html>
<html>
<body>
    <h3>Income Prediction Form</h3>

<div>
  <form action="/result" method="POST">
    <label for="age">Age</label>
    <input type="text" id="age" name="age">
    <br>
    <label for="w_class">Working Class</label>
    <select id="w_class" name="w_class">
      <option value="0">Federal-gov</option>
      <option value="1">Local-gov</option>
      <option value="2">Never-worked</option>
      <option value="3">Private</option>
      <option value="4">Self-emp-inc</option>
      <option value="5">Self-emp-not-inc</option>
      <option value="6">State-gov</option>
      <option value="7">Without-pay</option>
    </select>
    <br>
    <label for="edu">Education</label>
    <select id="edu" name="edu">
      <option value="0">10th</option>
      <option value="1">11th</option>
      <option value="2">12th</option>
      <option value="3">1st-4th</option>
      <option value="4">5th-6th</option>
      <option value="5">7th-8th</option>
      <option value="6">9th</option>
      <option value="7">Assoc-acdm</option>
      <option value="8">Assoc-voc</option>
      <option value="9">Bachelors</option>
      <option value="10">Doctorate</option>
      <option value="11">HS-grad</option>
      <option value="12">Masters</option>
      <option value="13">Preschool</option>
      <option value="14">Prof-school</option>
      <option value="15">16 - Some-college</option>
    </select>
    <br>
    <label for="martial_stat">Marital Status</label>
    <select id="martial_stat" name="martial_stat">
      <option value="0">divorced</option>
      <option value="1">married</option>
      <option value="2">not married</option>
    </select>
    <br>
    <label for="occup">Occupation</label>
    <select id="occup" name="occup">
      <option value="0">Adm-clerical</option>
      <option value="1">Armed-Forces</option>
      <option value="2">Craft-repair</option>
      <option value="3">Exec-managerial</option>
      <option value="4">Farming-fishing</option>
      <option value="5">Handlers-cleaners</option>
      <option value="6">Machine-op-inspct</option>
      <option value="7">Other-service</option>
      <option value="8">Priv-house-serv</option>
      <option value="9">Prof-specialty</option>
      <option value="10">Protective-serv</option>
      <option value="11">Sales</option>
      <option value="12">Tech-support</option>
      <option value="13">Transport-moving</option>
    </select>
    <br>
    <label for="relation">Relationship</label>
    <select id="relation" name="relation">
      <option value="0">Husband</option>
      <option value="1">Not-in-family</option>
      <option value="2">Other-relative</option>
      <option value="3">Own-child</option>
      <option value="4">Unmarried</option>
      <option value="5">Wife</option>
    </select>
    <br>
    <label for="race">Race</label>
    <select id="race" name="race">
      <option value="0">Amer Indian Eskimo</option>
      <option value="1">Asian Pac Islander</option>
      <option value="2">Black</option>
      <option value="3">Other</option>
      <option value="4">White</option>
    </select>
    <br>
    <label for="gender">Gender</label>
    <select id="gender" name="gender">
      <option value="0">Female</option>
      <option value="1">Male</option>
    </select>
    <br>
    <label for="c_gain">Capital Gain </label>
    <input type="text" id="c_gain" name="c_gain">btw:[0-99999]
    <br>
    <label for="c_loss">Capital Loss </label>
    <input type="text" id="c_loss" name="c_loss">btw:[0-4356]
    <br>
    <label for="hours_per_week">Hours per Week </label>
    <input type="text" id="hours_per_week" name="hours_per_week">btw:[1-99]
    <br>
    <label for="native-country">Native Country</label>
    <select id="native-country" name="native-country">
      <option value="0">Cambodia</option>
      <option value="1">Canada</option>
      <option value="2">China</option>
      <option value="3">Columbia</option>
      <option value="4">Cuba</option>
      <option value="5">Dominican Republic</option>
      <option value="6">Ecuador</option>
      <option value="7">El Salvadorr</option>
      <option value="8">England</option>
      <option value="9">France</option>
      <option value="10">Germany</option>
      <option value="11">Greece</option>
      <option value="12">Guatemala</option>
      <option value="13">Haiti</option>
      <option value="14">Netherlands</option>
      <option value="15">Honduras</option>
      <option value="16">HongKong</option>
      <option value="17">Hungary</option>
      <option value="18">India</option>
      <option value="19">Iran</option>
      <option value="20">Ireland</option>
      <option value="21">Italy</option>
      <option value="22">Jamaica</option>
      <option value="23">Japan</option>
      <option value="24">Laos</option>
      <option value="25">Mexico</option>
      <option value="26">Nicaragua</option>
      <option value="27">Outlying-US(Guam-USVI-etc)</option>
      <option value="28">Peru</option>
      <option value="29">Philippines</option>
      <option value="30">Poland</option>
      <option value="11">Portugal</option>
      <option value="32">Puerto-Rico</option>
      <option value="33">Scotland</option>
      <option value="34">South</option>
      <option value="35">Taiwan</option>
      <option value="36">Thailand</option>
      <option value="37">Trinadad&Tobago</option>
      <option value="38">United States</option>
      <option value="39">Vietnam</option>
      <option value="40">Yugoslavia</option>
    </select>
    <br>
    <input type="submit" value="Submit">
  </form>
</div>
</body>
</html>

# %%
#prediction function
def ValuePredictor(to_predict_list):
    to_predict = np.array(to_predict_list).reshape(1,12)
    loaded_model = pickle.load(open("model.pkl","rb"))
    result = loaded_model.predict(to_predict)
    return result[0]


@app.route('/result',methods = ['POST'])
def result():
    if request.method == 'POST':
        to_predict_list = request.form.to_dict()
        to_predict_list=list(to_predict_list.values())
        to_predict_list = list(map(int, to_predict_list))
        result = ValuePredictor(to_predict_list)
        
        if int(result)==1:
            prediction='Income more than 50K'
        else:
            prediction='Income less that 50K'
            
        return render_template("result.html",prediction=prediction)
