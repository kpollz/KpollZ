# %% [markdown]
# # 1. Lý thuyết
#
# **1) Để khởi tạo model trong tensorflow chúng ta sử dụng class nào?**
#
# A. Sequential hoặc Model
#
# B. Dense
#
# C. Adam
#
# D. Variable
#
# **2) Điểm khác biệt giữa fit và fit_generator trong tensorflow là gì ?**
#
# A. fit sẽ yêu cầu load toàn bộ dữ liệu lên RAM trong khi fit_generator sẽ sử dụng một hàm generator để sinh dữ liệu tại mỗi mini-batch. Từ đó giúp tiết kiệm bộ nhớ.
#
# B. fit sẽ sử dụng hàm generator để sinh dữ liệu tại thời điểm huấn luyện còn fit_generator sẽ load toàn bộ dữ liệu.
#
# C. fit sẽ huấn luyện model theo mini-batch còn fit_generator thì huấn luyện trên toàn bộ dataset.
#
# D. trong hàm fit chúng ta có thể khai báo tập validation dataset còn trong fit_generator thì không.
#
#
# **3) Các modules chính trong tensorflow dùng để xây dựng và huấn luyện model.**
#
# A. `tf.keras.layers`: khởi tạo activation function; `tf.keras.Sequential`: khởi tạo model; `tf.keras.activations`: để khởi tạo các layers; `tf.keras.optimizers`: Khởi tạo optimizer cho bài toán tối ưu loss function; `tf.keras.losses`: khởi tạo loss function; `tf.keras.preprocessing`: Preprocessing data.
#
# B. `tf.keras.layers`: để khởi tạo các layers; `tf.keras.Sequential`: khởi tạo model; `tf.keras.activations`: khởi tạo activation function; `tf.keras.optimizers`: Khởi tạo optimizer cho bài toán tối ưu loss function; `tf.keras.losses`: khởi tạo loss function; `tf.keras.preprocessing`: Preprocessing data.
#
# C. `tf.keras.layers`: để khởi tạo các layers; `tf.keras.Sequential`: Preprocessing data; `tf.keras.activations`: khởi tạo activation function; `tf.keras.optimizers`: Khởi tạo optimizer cho bài toán tối ưu loss function; `tf.keras.losses`: khởi tạo loss function; `tf.keras.preprocessing`: khởi tạo model
#
# D. `tf.keras.layers`: để khởi tạo các layers; `tf.keras.Sequential`: khởi tạo model; `tf.keras.activations`: khởi tạo activation function; `tf.keras.optimizers`: khởi tạo loss function; `tf.keras.losses`: Khởi tạo optimizer cho bài toán tối ưu loss function; `tf.keras.preprocessing`: Preprocessing data.
#
#
# **4) Các bước trong huấn luyện model bao gồm:**
#
# A. 1. Train/test data split --> 2. Initialize the optimizer algorithm --> 3. Build up model architecture --> 4. Train model on train --> 5. Evaluation on test --> 6. Save and use trained model
#
# B. 1. Train/test data split --> 2. Build up model architecture --> 3. Train model on train --> 4. Initialize the optimizer algorithm --> 5. Evaluation on test --> 6. Save and use trained model
#
# C. 1. Train/test data split --> 2. Build up model architecture --> 3. Initialize the optimizer algorithm --> 4. Evaluation on test --> 5. Train model on train --> 6. Save and use trained model
#
# D. 1. Train/test data split --> 2. Build up model architecture --> 3. Initialize the optimizer algorithm --> 4. Train model on train --> 5. Evaluation on test --> 6. Save and use trained model
#
# **5) Ý nghĩa của tham số epochs và batch_size trong huấn luyện mô hình là gì?**
#
# A. epochs là kích thước của một mini-batch, batch_size là số lượt lặp lại toàn bộ dữ liệu khi huấn luyện.
#
# B. epochs là số lượt lặp lại toàn bộ dữ liệu validation khi huấn luyện, batch_size là kích thước của một mini-batch.
#
# C. epochs là số lượt lặp lại toàn bộ dữ liệu train khi huấn luyện, batch_size là kích thước của một mini-batch.
#
# D. epochs là số lượng vòng lặp, mỗi vòng lặp là một lượt fit mini-batch, trên bộ dữ liệu khi huấn luyện; batch_size là kích thước của một mini-batch.

# %% [markdown]
# # 2. Thực hành
#
# 6) Khởi tạo một tensor 3 chiều với định dạng là float và kích thước là 32x32x3
#
# 7) Nếu coi tensor trên là một bức ảnh RGB với số channel là 3 ở cuối. Hãy truy suất các ma trận ảnh tương ứng với mỗi kênh R, G, B.
#
# 8) Thực hiện tích hadamard và tích thông thường giữa ma trận R và G.
#
# 9) Từ bộ dữ liệu [Income-Classification](https://www.kaggle.com/t/090688c8d33a40b68be9e271d6ba6bae) hãy chuẩn hóa dữ liệu và phân chia tập train/test theo tỷ lệ 80/20.
#
# 10) Xây dựng một mạng deep-neural-network để huấn luyện mô hình trên dữ liệu train và đánh giá mô hình trên dữ liệu test.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf

# %%
# 6

A = tf.random.normal([32, 32, 3], dtype = tf.float32)

# %%
R = A[:, :, 0]

# %%
G = A[:, :, 1]

# %%
B = A[:, :, 2]

# %%
# 8

print('R * G', R*G)
print('R @ G', R@G)
# Out:
# R * G tf.Tensor(
# [[-3.6166647e-01  3.9400953e-01  1.4308443e+00 ...  1.1807086e-03
#    2.5873262e-02 -1.6603535e+00]
#  [-1.9561070e-01  4.0777124e-02  3.6336473e-01 ... -7.3499006e-01
#    2.2891695e+00  6.4106393e-01]
#  [ 1.4050637e-01 -8.0200893e-01 -5.2286293e-02 ...  3.2447946e-01
#    1.7822169e+00  9.9827337e-01]
#  ...
#  [-8.0699509e-01 -4.6708487e-02  1.0777047e+00 ... -3.6014676e-01
#   -2.8439796e-01 -7.2464675e-01]
#  [ 6.1062500e-02  5.4396857e-02  3.0252263e-01 ... -1.3365896e-01
#   -1.5784349e+00  4.6172678e-01]
#  [ 7.4835461e-01  6.4856850e-02  5.7687330e-01 ...  4.0535957e-01
#    2.2801884e-01  1.6983923e+00]], shape=(32, 32), dtype=float32)
# R @ G tf.Tensor(
# [[ -2.2602136    1.1516299    6.175816   ...   0.99513936  -2.214986
#    -1.8853033 ]
#  [ -4.209339    -0.8228769    6.3649073  ...   8.831466    -2.447908
#    -1.598307  ]
#  [ -8.216156   -10.680135     9.674291   ...   6.918947     0.34434482
#    -8.373481  ]
#  ...
#  [ -3.1287096   -7.774568    14.2535715  ...   3.7464352   -3.2390795
#     8.689595  ]
#  [ -0.30296326   0.08924291  -7.6206226  ...   1.987883    -6.1307697
#    13.309517  ]
#  [ -7.339148     5.3535824    7.2422976  ...  -2.3207443   -4.4065223
#     4.147361  ]], shape=(32, 32), dtype=float32)

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import utils
from tensorflow.keras import optimizers

import pandas as pd
import numpy as np

# Set random seed for reproducability
tensorflow.random.set_seed(0)

print("Libraries imported.")
print('Keras version:',keras.__version__)
print('TensorFlow version:',tensorflow.__version__)
# Out:
# Libraries imported.
# Keras version: 2.7.0
# TensorFlow version: 2.7.0

# %%
# %cd /content/drive/MyDrive/TwDS
# Out:
# /content/drive/MyDrive/TwDS

# %%
# !ls
# Out:
# sample_submission.csv  test.csv  train.csv

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    ID  age work_type  ...  hrs_per_week nationality  target_income
# 0   0   45   Private  ...            40          US              0
# 1   1   23   Private  ...            30          US              0
# 2   2   22   Private  ...            20       South              0
# 3   3   27   Private  ...            40          US              0
# 4   4   18   Private  ...            20          US              0
#
# [5 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   25000 non-null  int64
#  1   age                  25000 non-null  int64
#  2   work_type            25000 non-null  object
#  3   final_weight         25000 non-null  int64
#  4   education            25000 non-null  object
#  5   total_education_yrs  25000 non-null  int64
#  6   marital_state        25000 non-null  object
#  7   job                  25000 non-null  object
#  8   status               25000 non-null  object
#  9   ethnicity            25000 non-null  object
#  10  sex                  25000 non-null  object
#  11  capital_gain         25000 non-null  int64
#  12  capital_loss         25000 non-null  int64
#  13  hrs_per_week         25000 non-null  int64
#  14  nationality          25000 non-null  object
#  15  target_income        25000 non-null  int64
# dtypes: int64(8), object(8)
# memory usage: 3.1+ MB

# %%
df.describe()
# Out:
#                  ID           age  ...  hrs_per_week  target_income
# count  25000.000000  25000.000000  ...  25000.000000    25000.00000
# mean   12499.500000     38.568800  ...     40.392200        0.23944
# std     7217.022701     13.642694  ...     12.350547        0.42675
# min        0.000000     17.000000  ...      1.000000        0.00000
# 25%     6249.750000     28.000000  ...     40.000000        0.00000
# 50%    12499.500000     37.000000  ...     40.000000        0.00000
# 75%    18749.250000     48.000000  ...     45.000000        0.00000
# max    24999.000000     90.000000  ...     99.000000        1.00000
#
# [8 rows x 8 columns]

# %%
df['target_income'].unique()
# Out:
# array([0, 1])

# %%
ed = ['work_type', 'education', 'marital_state', 'job', 'status', 'ethnicity', 'nationality', 'sex']

df = pd.get_dummies(df, columns=ed)

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['ID', 'target_income'], axis=1)
y = df['target_income']

x_train, x_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.20, 
                                                    random_state=42)
print('X train shape: ', x_train.shape)
print('y train shape: ', y_train.shape)
# Out:
# X train shape:  (20000, 108)
# y train shape:  (20000,)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

y_train = utils.to_categorical(y_train)
y_test = utils.to_categorical(y_test)

# %%
model = Sequential()
model.add(Dense(128, input_dim=108, activation='relu'))
model.add(Dense(64, activation='relu'))
# model.add(Dense(32, activation='relu'))
model.add(Dense(2, activation='sigmoid'))

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               13952
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 22,338
# Trainable params: 22,338
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
learning_rate = 0.001
opt = optimizers.Adam(lr=learning_rate)

model.compile(loss='binary_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

num_epochs = 100
history = model.fit(x_train, y_train, epochs=num_epochs, batch_size=32, validation_data=(x_test, y_test))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/100
# 625/625 [==============================] - 3s 4ms/step - loss: 273.1653 - accuracy: 0.7261 - val_loss: 117.8564 - val_accuracy: 0.2376
# Epoch 2/100
# 625/625 [==============================] - 2s 4ms/step - loss: 149.2332 - accuracy: 0.7444 - val_loss: 119.3966 - val_accuracy: 0.7980
# Epoch 3/100
# 625/625 [==============================] - 2s 3ms/step - loss: 137.8900 - accuracy: 0.7392 - val_loss: 38.9400 - val_accuracy: 0.7880
# Epoch 4/100
# 625/625 [==============================] - 2s 3ms/step - loss: 121.4137 - accuracy: 0.7297 - val_loss: 49.4839 - val_accuracy: 0.7952
# Epoch 5/100
# 625/625 [==============================] - 2s 4ms/step - loss: 107.7646 - accuracy: 0.7330 - val_loss: 43.9633 - val_accuracy: 0.7976
# Epoch 6/100
# 625/625 [==============================] - 2s 3ms/step - loss: 100.7362 - accuracy: 0.7451 - val_loss: 49.9148 - val_accuracy: 0.7996
# Epoch 7/100
# 625/625 [==============================] - 2s 3ms/step - loss: 83.8280 - accuracy: 0.7451 - val_loss: 106.9233 - val_accuracy: 0.2376
# Epoch 8/100
# 625/625 [==============================] - 2s 3ms/step - loss: 67.4273 - accuracy: 0.7323 - val_loss: 71.6265 - val_accuracy: 0.7984
# Epoch 9/100
# 625/625 [==============================] - 2s 4ms/step - loss: 58.1283 - accuracy: 0.7176 - val_loss: 84.8103 - val_accuracy: 0.2392
# Epoch 10/100
# 625/625 [==============================] - 2s 4ms/step - loss: 58.4489 - accuracy: 0.7276 - val_loss: 44.1466 - val_accuracy: 0.7978
# Epoch 11/100
# 625/625 [==============================] - 2s 3ms/step - loss: 51.7518 - accuracy: 0.7301 - val_loss: 73.4729 - val_accuracy: 0.2376
# Epoch 12/100
# 625/625 [==============================] - 2s 4ms/step - loss: 38.4823 - accuracy: 0.7420 - val_loss: 33.2608 - val_accuracy: 0.7776
# Epoch 13/100
# 625/625 [==============================] - 2s 4ms/step - loss: 30.9120 - accuracy: 0.7452 - val_loss: 39.6696 - val_accuracy: 0.7996
# Epoch 14/100
# 625/625 [==============================] - 2s 3ms/step - loss: 24.8517 - accuracy: 0.7432 - val_loss: 6.2260 - val_accuracy: 0.6800
# Epoch 15/100
# 625/625 [==============================] - 2s 3ms/step - loss: 26.5560 - accuracy: 0.7412 - val_loss: 33.1858 - val_accuracy: 0.7914
# Epoch 16/100
# 625/625 [==============================] - 2s 3ms/step - loss: 17.6966 - accuracy: 0.7451 - val_loss: 20.5023 - val_accuracy: 0.8018
# Epoch 17/100
# 625/625 [==============================] - 2s 3ms/step - loss: 13.9001 - accuracy: 0.7467 - val_loss: 10.2694 - val_accuracy: 0.7996
# Epoch 18/100
# 625/625 [==============================] - 2s 3ms/step - loss: 13.2004 - accuracy: 0.7515 - val_loss: 15.2000 - val_accuracy: 0.7950
# Epoch 19/100
# 625/625 [==============================] - 2s 4ms/step - loss: 11.1694 - accuracy: 0.7387 - val_loss: 10.3222 - val_accuracy: 0.7796
# Epoch 20/100
# 625/625 [==============================] - 2s 3ms/step - loss: 10.5175 - accuracy: 0.7530 - val_loss: 3.4925 - val_accuracy: 0.7820
# Epoch 21/100
# 625/625 [==============================] - 2s 3ms/step - loss: 9.6311 - accuracy: 0.7431 - val_loss: 8.0501 - val_accuracy: 0.7872
# Epoch 22/100
# 625/625 [==============================] - 2s 3ms/step - loss: 7.4086 - accuracy: 0.7500 - val_loss: 10.3260 - val_accuracy: 0.2532
# Epoch 23/100
# 625/625 [==============================] - 2s 3ms/step - loss: 6.5913 - accuracy: 0.7497 - val_loss: 9.4213 - val_accuracy: 0.7962
# Epoch 24/100
# 625/625 [==============================] - 2s 4ms/step - loss: 4.6835 - accuracy: 0.7570 - val_loss: 6.7159 - val_accuracy: 0.7924
# Epoch 25/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.6660 - accuracy: 0.7497 - val_loss: 13.1402 - val_accuracy: 0.7786
# Epoch 26/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.8553 - accuracy: 0.7411 - val_loss: 4.0837 - val_accuracy: 0.8076
# Epoch 27/100
# 625/625 [==============================] - 2s 4ms/step - loss: 4.5569 - accuracy: 0.7569 - val_loss: 1.0533 - val_accuracy: 0.7710
# Epoch 28/100
# 625/625 [==============================] - 2s 4ms/step - loss: 2.7888 - accuracy: 0.7557 - val_loss: 6.2221 - val_accuracy: 0.7898
# Epoch 29/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.0903 - accuracy: 0.7543 - val_loss: 4.6932 - val_accuracy: 0.8064
# Epoch 30/100
# 625/625 [==============================] - 3s 5ms/step - loss: 2.7684 - accuracy: 0.7697 - val_loss: 1.9174 - val_accuracy: 0.6330
# Epoch 31/100
# 625/625 [==============================] - 4s 7ms/step - loss: 2.6920 - accuracy: 0.7594 - val_loss: 1.2999 - val_accuracy: 0.8034
# Epoch 32/100
# 625/625 [==============================] - 5s 7ms/step - loss: 1.7745 - accuracy: 0.7662 - val_loss: 0.5288 - val_accuracy: 0.7942
# Epoch 33/100
# 625/625 [==============================] - 5s 8ms/step - loss: 2.0578 - accuracy: 0.7664 - val_loss: 6.4779 - val_accuracy: 0.7710
# Epoch 34/100
# 625/625 [==============================] - 4s 7ms/step - loss: 1.8671 - accuracy: 0.7690 - val_loss: 0.7852 - val_accuracy: 0.8056
# Epoch 35/100
# 625/625 [==============================] - 5s 8ms/step - loss: 1.4006 - accuracy: 0.7753 - val_loss: 2.0537 - val_accuracy: 0.8048
# Epoch 36/100
# 625/625 [==============================] - 4s 6ms/step - loss: 1.1407 - accuracy: 0.7832 - val_loss: 2.1535 - val_accuracy: 0.8010
# Epoch 37/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.8993 - accuracy: 0.7734 - val_loss: 0.5046 - val_accuracy: 0.7996
# Epoch 38/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.5233 - accuracy: 0.7972 - val_loss: 0.5011 - val_accuracy: 0.7988
# Epoch 39/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4995 - accuracy: 0.7962 - val_loss: 0.4877 - val_accuracy: 0.8032
# Epoch 40/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4918 - accuracy: 0.7997 - val_loss: 0.4854 - val_accuracy: 0.8000
# Epoch 41/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4945 - accuracy: 0.7984 - val_loss: 0.4959 - val_accuracy: 0.7952
# Epoch 42/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4921 - accuracy: 0.7977 - val_loss: 0.4846 - val_accuracy: 0.8048
# Epoch 43/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4894 - accuracy: 0.8009 - val_loss: 0.4863 - val_accuracy: 0.8036
# Epoch 44/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4919 - accuracy: 0.8001 - val_loss: 0.4834 - val_accuracy: 0.8060
# Epoch 45/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4936 - accuracy: 0.7979 - val_loss: 0.4838 - val_accuracy: 0.8074
# Epoch 46/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4920 - accuracy: 0.7994 - val_loss: 0.4911 - val_accuracy: 0.8004
# Epoch 47/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4945 - accuracy: 0.7975 - val_loss: 0.4840 - val_accuracy: 0.8056
# Epoch 48/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4970 - accuracy: 0.7969 - val_loss: 0.4844 - val_accuracy: 0.8032
# Epoch 49/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4966 - accuracy: 0.7962 - val_loss: 0.4920 - val_accuracy: 0.7996
# Epoch 50/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4968 - accuracy: 0.7972 - val_loss: 0.4979 - val_accuracy: 0.7980
# Epoch 51/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4935 - accuracy: 0.7979 - val_loss: 0.4855 - val_accuracy: 0.7990
# Epoch 52/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4990 - accuracy: 0.7972 - val_loss: 0.5084 - val_accuracy: 0.7812
# Epoch 53/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5006 - accuracy: 0.7933 - val_loss: 0.4875 - val_accuracy: 0.8004
# Epoch 54/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.4986 - accuracy: 0.7953 - val_loss: 0.4863 - val_accuracy: 0.8022
# Epoch 55/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.4985 - accuracy: 0.7951 - val_loss: 0.4917 - val_accuracy: 0.8012
# Epoch 56/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.4977 - accuracy: 0.7972 - val_loss: 0.4985 - val_accuracy: 0.7964
# Epoch 57/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.5040 - accuracy: 0.7972 - val_loss: 0.4838 - val_accuracy: 0.8020
# Epoch 58/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.4973 - accuracy: 0.7969 - val_loss: 0.4836 - val_accuracy: 0.8038
# Epoch 59/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5115 - accuracy: 0.7982 - val_loss: 0.4859 - val_accuracy: 0.8000
# Epoch 60/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.4937 - accuracy: 0.7997 - val_loss: 0.4832 - val_accuracy: 0.8044
# Epoch 61/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.4925 - accuracy: 0.7983 - val_loss: 0.5049 - val_accuracy: 0.7940
# Epoch 62/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.4930 - accuracy: 0.7991 - val_loss: 0.4977 - val_accuracy: 0.7968
# Epoch 63/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4926 - accuracy: 0.7972 - val_loss: 0.4958 - val_accuracy: 0.7944
# Epoch 64/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4969 - accuracy: 0.7965 - val_loss: 0.4830 - val_accuracy: 0.8050
# Epoch 65/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4929 - accuracy: 0.7970 - val_loss: 0.4867 - val_accuracy: 0.8022
# Epoch 66/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.5077 - accuracy: 0.7929 - val_loss: 0.5420 - val_accuracy: 0.7690
# Epoch 67/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5219 - accuracy: 0.7891 - val_loss: 0.5052 - val_accuracy: 0.7972
# Epoch 68/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4941 - accuracy: 0.7975 - val_loss: 0.4870 - val_accuracy: 0.8034
# Epoch 69/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4933 - accuracy: 0.7982 - val_loss: 0.4826 - val_accuracy: 0.8070
# Epoch 70/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4988 - accuracy: 0.7966 - val_loss: 0.4842 - val_accuracy: 0.8056
# Epoch 71/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4960 - accuracy: 0.7962 - val_loss: 0.4844 - val_accuracy: 0.8032
# Epoch 72/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4940 - accuracy: 0.7989 - val_loss: 0.4851 - val_accuracy: 0.8032
# Epoch 73/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4936 - accuracy: 0.7968 - val_loss: 0.5100 - val_accuracy: 0.7828
# Epoch 74/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4925 - accuracy: 0.7980 - val_loss: 0.4845 - val_accuracy: 0.8040
# Epoch 75/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4927 - accuracy: 0.7982 - val_loss: 0.4851 - val_accuracy: 0.8032
# Epoch 76/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4927 - accuracy: 0.8000 - val_loss: 0.4966 - val_accuracy: 0.7994
# Epoch 77/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4946 - accuracy: 0.7972 - val_loss: 0.4841 - val_accuracy: 0.8068
# Epoch 78/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4939 - accuracy: 0.7983 - val_loss: 0.4875 - val_accuracy: 0.8030
# Epoch 79/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4920 - accuracy: 0.7995 - val_loss: 0.5218 - val_accuracy: 0.7846
# Epoch 80/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4951 - accuracy: 0.7990 - val_loss: 0.4875 - val_accuracy: 0.8006
# Epoch 81/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4913 - accuracy: 0.7983 - val_loss: 0.4857 - val_accuracy: 0.8010
# Epoch 82/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4951 - accuracy: 0.7989 - val_loss: 0.4928 - val_accuracy: 0.7990
# Epoch 83/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5003 - accuracy: 0.7970 - val_loss: 0.4873 - val_accuracy: 0.8032
# Epoch 84/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4925 - accuracy: 0.8002 - val_loss: 0.4827 - val_accuracy: 0.8070
# Epoch 85/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4948 - accuracy: 0.7986 - val_loss: 0.4874 - val_accuracy: 0.7962
# Epoch 86/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4905 - accuracy: 0.8006 - val_loss: 0.4840 - val_accuracy: 0.8042
# Epoch 87/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4899 - accuracy: 0.8008 - val_loss: 0.4826 - val_accuracy: 0.8058
# Epoch 88/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4917 - accuracy: 0.7990 - val_loss: 0.4901 - val_accuracy: 0.8020
# Epoch 89/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4950 - accuracy: 0.7983 - val_loss: 0.4849 - val_accuracy: 0.8032
# Epoch 90/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4927 - accuracy: 0.7983 - val_loss: 0.4824 - val_accuracy: 0.8036
# Epoch 91/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4904 - accuracy: 0.8004 - val_loss: 0.4828 - val_accuracy: 0.8082
# Epoch 92/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4893 - accuracy: 0.8013 - val_loss: 0.4896 - val_accuracy: 0.8004
# Epoch 93/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4886 - accuracy: 0.8018 - val_loss: 0.4825 - val_accuracy: 0.8048
# Epoch 94/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4937 - accuracy: 0.7989 - val_loss: 0.4824 - val_accuracy: 0.8062
# Epoch 95/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4896 - accuracy: 0.8008 - val_loss: 0.4884 - val_accuracy: 0.7970
# Epoch 96/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4897 - accuracy: 0.8006 - val_loss: 0.4859 - val_accuracy: 0.7970
# Epoch 97/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4893 - accuracy: 0.8018 - val_loss: 0.5003 - val_accuracy: 0.7940
# Epoch 98/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4900 - accuracy: 0.8007 - val_loss: 0.4882 - val_accuracy: 0.8022
# Epoch 99/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4884 - accuracy: 0.8006 - val_loss: 0.4826 - val_accuracy: 0.8044
# Epoch 100/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4867 - accuracy: 0.8024 - val_loss: 0.4825 - val_accuracy: 0.8062

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

epoch_nums = range(1,num_epochs+1)
training_loss = history.history["loss"]
validation_loss = history.history["val_loss"]
plt.plot(epoch_nums, training_loss)
plt.plot(epoch_nums, validation_loss)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training', 'validation'], loc='upper right')
plt.show()

# %%
# Tensorflow doesn't have a built-in confusion matrix metric, so we'll use SciKit-Learn
import numpy as np
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline


class_probabilities = model.predict(x_test)
predictions = np.argmax(class_probabilities, axis=1)
true_labels = np.argmax(y_test, axis=1)

# Plot the confusion matrix
cm = confusion_matrix(true_labels, predictions)
plt.imshow(cm, interpolation="nearest", cmap=plt.cm.Blues)
plt.colorbar()
tick_marks = np.arange(2)
plt.xticks(tick_marks, ['0', '1'], rotation=85)
plt.yticks(tick_marks, ['0', '1'])
plt.xlabel("Predicted Species")
plt.ylabel("Actual Species")
plt.show()

# %% [markdown]
# # chữa bài: Chưa đầu tư vào thử nghiệm xử lý cũng như normalize dữ liệu. Nên thử nghiệm thay đổi tham số mô hình, nhận xét kết quả
