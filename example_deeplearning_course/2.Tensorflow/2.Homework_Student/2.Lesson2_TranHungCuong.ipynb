# %% [markdown]
# # 1. Lý thuyết
#
# **1) Để khởi tạo model trong tensorflow chúng ta sử dụng class nào?**
#
# **A. Sequential hoặc Model**
#
# B. Dense
#
# C. Adam
#
# D. Variable
#
# **2) Điểm khác biệt giữa fit và fit_generator trong tensorflow là gì ?**
#
# **A. fit sẽ yêu cầu load toàn bộ dữ liệu lên RAM trong khi fit_generator sẽ sử dụng một hàm generator để sinh dữ liệu tại mỗi mini-batch. Từ đó giúp tiết kiệm bộ nhớ.**
#
# B. fit sẽ sử dụng hàm generator để sinh dữ liệu tại thời điểm huấn luyện còn fit_generator sẽ load toàn bộ dữ liệu.
#
# C. fit sẽ huấn luyện model theo mini-batch còn fit_generator thì huấn luyện trên toàn bộ dataset.
#
# D. trong hàm fit chúng ta có thể khai báo tập validation dataset còn trong fit_generator thì không.
#
#
# **3) Các modules chính trong tensorflow dùng để xây dựng và huấn luyện model.**
#
# A. `tf.keras.layers`: khởi tạo activation function; `tf.keras.Sequential`: khởi tạo model; `tf.keras.activations`: để khởi tạo các layers; `tf.keras.optimizers`: Khởi tạo optimizer cho bài toán tối ưu loss function; `tf.keras.losses`: khởi tạo loss function; `tf.keras.preprocessing`: Preprocessing data.
#
# **B. `tf.keras.layers`: để khởi tạo các layers; `tf.keras.Sequential`: khởi tạo model; `tf.keras.activations`: khởi tạo activation function; `tf.keras.optimizers`: Khởi tạo optimizer cho bài toán tối ưu loss function; `tf.keras.losses`: khởi tạo loss function; `tf.keras.preprocessing`: Preprocessing data.**
#
# C. `tf.keras.layers`: để khởi tạo các layers; `tf.keras.Sequential`: Preprocessing data; `tf.keras.activations`: khởi tạo activation function; `tf.keras.optimizers`: Khởi tạo optimizer cho bài toán tối ưu loss function; `tf.keras.losses`: khởi tạo loss function; `tf.keras.preprocessing`: khởi tạo model
#
# D. `tf.keras.layers`: để khởi tạo các layers; `tf.keras.Sequential`: khởi tạo model; `tf.keras.activations`: khởi tạo activation function; `tf.keras.optimizers`: khởi tạo loss function; `tf.keras.losses`: Khởi tạo optimizer cho bài toán tối ưu loss function; `tf.keras.preprocessing`: Preprocessing data.
#
#
# **4) Các bước trong huấn luyện model bao gồm:**
#
# A. 1. Train/test data split --> 2. Initialize the optimizer algorithm --> 3. Build up model architecture --> 4. Train model on train --> 5. Evaluation on test --> 6. Save and use trained model
#
# B. 1. Train/test data split --> 2. Build up model architecture --> 3. Train model on train --> 4. Initialize the optimizer algorithm --> 5. Evaluation on test --> 6. Save and use trained model
#
# C. 1. Train/test data split --> 2. Build up model architecture --> 3. Initialize the optimizer algorithm --> 4. Evaluation on test --> 5. Train model on train --> 6. Save and use trained model
#
# **D. 1. Train/test data split --> 2. Build up model architecture --> 3. Initialize the optimizer algorithm --> 4. Train model on train --> 5. Evaluation on test --> 6. Save and use trained model**
#
# **5) Ý nghĩa của tham số epochs và batch_size trong huấn luyện mô hình là gì?**
#
# A. epochs là kích thước của một mini-batch, batch_size là số lượt lặp lại toàn bộ dữ liệu khi huấn luyện.
#
# B. epochs là số lượt lặp lại toàn bộ dữ liệu validation khi huấn luyện, batch_size là kích thước của một mini-batch.
#
# **C. epochs là số lượt lặp lại toàn bộ dữ liệu train khi huấn luyện, batch_size là kích thước của một mini-batch.**
#
# D. epochs là số lượng vòng lặp, mỗi vòng lặp là một lượt fit mini-batch, trên bộ dữ liệu khi huấn luyện; batch_size là kích thước của một mini-batch.

# %% [markdown]
# # 2. Thực hành

# %% [markdown]
# **6) Khởi tạo một tensor 3 chiều với định dạng là float và kích thước là 32x32x3**

# %%
#Cách 1
import tensorflow as tf
A = tf.random.uniform([32,32,3],dtype=tf.float32)

# %%
print(A)
# Out:
# tf.Tensor(
# [[[0.62807    0.88468206 0.663962  ]
#   [0.46255064 0.9276829  0.39001632]
#   [0.49230516 0.8510319  0.08197761]
#   ...
#   [0.6086122  0.14606285 0.19259727]
#   [0.6855471  0.39651024 0.26473546]
#   [0.9131317  0.53803825 0.5255525 ]]
#
#  [[0.3330146  0.811715   0.20803928]
#   [0.30500174 0.6749339  0.9784262 ]
#   [0.613606   0.2650069  0.4189254 ]
#   ...
#   [0.12582743 0.9465258  0.5380436 ]
#   [0.67712235 0.8549267  0.6181264 ]
#   [0.15492058 0.72520936 0.405635  ]]
#
#  [[0.7761109  0.8956413  0.39342642]
#   [0.26463807 0.5516243  0.73096263]
#   [0.9347745  0.23618889 0.70285046]
#   ...
#   [0.47090316 0.47961497 0.68791676]
#   [0.46821463 0.6530255  0.3580612 ]
#   [0.93745315 0.5352411  0.46757185]]
#
#  ...
#
#  [[0.43968952 0.6948042  0.3777269 ]
#   [0.6189513  0.19854033 0.77795315]
#   [0.5565691  0.8808892  0.43107522]
#   ...
#   [0.40970492 0.7526989  0.6466222 ]
#   [0.14880574 0.7007917  0.9634583 ]
#   [0.47251403 0.6542057  0.41687393]]
# ...

# %%
#Cách 2
A = tf.random.normal([32,32,3], dtype=tf.float32)

# %%
print(A)
# Out:
# tf.Tensor(
# [[[-1.6736369  -0.83492744 -0.8765859 ]
#   [ 1.0888457  -0.03815489  1.5090089 ]
#   [-0.08668132  0.3228533  -0.48220578]
#   ...
#   [-0.3683957  -1.9447997  -0.15463799]
#   [-1.5109737   1.2308925  -0.74693775]
#   [ 0.50761867 -1.6560496   0.6664714 ]]
#
#  [[-0.835211   -2.1410542  -0.2979921 ]
#   [ 0.39475915 -0.40201914 -0.2735855 ]
#   [ 0.20750609 -0.39355668 -0.13327754]
#   ...
#   [ 1.391811   -1.259512   -1.4560885 ]
#   [-0.8012637   0.69891644  0.53957427]
#   [ 0.57964504  1.3937995  -1.1871417 ]]
#
#  [[-0.92766434  0.7444948  -0.81432873]
#   [ 0.07313947 -0.24556358 -1.920993  ]
#   [-0.6358594  -0.5517431   0.25826555]
#   ...
#   [-0.81265724 -1.4542261  -1.7002221 ]
#   [ 0.03075371 -0.01433132 -0.6488401 ]
#   [-0.82080483 -0.5371344   0.54058504]]
#
#  ...
#
#  [[-0.07497285 -1.1754892  -0.3695468 ]
#   [ 0.38427854  0.63566744 -0.14670731]
#   [ 0.4235391   0.15983693  0.7965892 ]
#   ...
#   [-0.04548972 -1.1848292  -0.37101114]
# ...

# %% [markdown]
# **7) Nếu coi tensor trên là một bức ảnh RGB với số channel là 3 ở cuối. Hãy truy suất các ma trận ảnh tương ứng với mỗi kênh R, G, B.**

# %%
R_matrix = A[:,:,0]
print(R_matrix)
# Out:
# tf.Tensor(
# [[-1.6736369   1.0888457  -0.08668132 ... -0.3683957  -1.5109737
#    0.50761867]
#  [-0.835211    0.39475915  0.20750609 ...  1.391811   -0.8012637
#    0.57964504]
#  [-0.92766434  0.07313947 -0.6358594  ... -0.81265724  0.03075371
#   -0.82080483]
#  ...
#  [-0.07497285  0.38427854  0.4235391  ... -0.04548972  0.51525223
#   -2.0227163 ]
#  [-0.67987424  0.08450184 -0.19635403 ...  0.5489795  -0.7760429
#    0.21385597]
#  [ 0.14749499 -0.38255277  0.02687696 ...  0.42711166  1.3173227
#   -0.30786076]], shape=(32, 32), dtype=float32)

# %%
print(R_matrix.shape)
# Out:
# (32, 32)

# %%
G_matrix = A[:,:,1]
print(G_matrix)
# Out:
# tf.Tensor(
# [[-0.83492744 -0.03815489  0.3228533  ... -1.9447997   1.2308925
#   -1.6560496 ]
#  [-2.1410542  -0.40201914 -0.39355668 ... -1.259512    0.69891644
#    1.3937995 ]
#  [ 0.7444948  -0.24556358 -0.5517431  ... -1.4542261  -0.01433132
#   -0.5371344 ]
#  ...
#  [-1.1754892   0.63566744  0.15983693 ... -1.1848292  -0.7097268
#    0.6532364 ]
#  [ 0.7078933   1.4662018   0.19726089 ...  2.2666695   0.9394036
#   -0.42927524]
#  [-0.77069676 -0.12900132  0.05798149 ... -0.56980264 -0.18187715
#    0.9629667 ]], shape=(32, 32), dtype=float32)

# %%
print(G_matrix.shape)
# Out:
# (32, 32)

# %%
B_matrix = A[:,:,2]
print(B_matrix)
# Out:
# tf.Tensor(
# [[-0.8765859   1.5090089  -0.48220578 ... -0.15463799 -0.74693775
#    0.6664714 ]
#  [-0.2979921  -0.2735855  -0.13327754 ... -1.4560885   0.53957427
#   -1.1871417 ]
#  [-0.81432873 -1.920993    0.25826555 ... -1.7002221  -0.6488401
#    0.54058504]
#  ...
#  [-0.3695468  -0.14670731  0.7965892  ... -0.37101114  0.1548858
#   -0.5547129 ]
#  [ 1.735002    0.15518872  0.7278895  ...  1.1668465  -0.25563905
#   -0.9359019 ]
#  [-0.76550657 -0.73277736  0.5225724  ... -0.24687643  0.5282714
#    1.9270393 ]], shape=(32, 32), dtype=float32)

# %%
print(B_matrix.shape)
# Out:
# (32, 32)

# %% [markdown]
# **8) Thực hiện tích hadamard và tích thông thường giữa ma trận R và G.**

# %%
#Tích hadamard 
RG= R_matrix*G_matrix
print(RG)
# Out:
# tf.Tensor(
# [[ 1.3973653e+00 -4.1544784e-02 -2.7985351e-02 ...  7.1645582e-01
#   -1.8598462e+00 -8.4064168e-01]
#  [ 1.7882320e+00 -1.5870073e-01 -8.1665412e-02 ... -1.7530026e+00
#   -5.6001633e-01  8.0790901e-01]
#  [-6.9064128e-01 -1.7960390e-02  3.5083100e-01 ...  1.1817874e+00
#   -4.4074137e-04  4.4088253e-01]
#  ...
#  [ 8.8129766e-02  2.4427335e-01  6.7697190e-02 ...  5.3897548e-02
#   -3.6568832e-01 -1.3213118e+00]
#  [-4.8127842e-01  1.2389675e-01 -3.8732972e-02 ...  1.2443552e+00
#   -7.2901750e-01 -9.1803074e-02]
#  [-1.1367391e-01  4.9349811e-02  1.5583661e-03 ... -2.4336936e-01
#   -2.3959090e-01 -2.9645965e-01]], shape=(32, 32), dtype=float32)

# %%
#Tích thông thường
RG= R_matrix@G_matrix
print(RG)
# Out:
# tf.Tensor(
# [[-5.2630744   4.349326   -5.2939734  ... -3.9976668  -0.47701827
#    3.3662648 ]
#  [-2.5627685   2.0875266  -4.086799   ... -1.5152422  -2.0625868
#   13.377512  ]
#  [ 0.04212954  4.1316605   0.12749644 ... 12.453129   -1.5185214
#    3.2624388 ]
#  ...
#  [ 3.9696581   5.847095   -0.80628663 ...  6.6327124   1.0160162
#    1.820923  ]
#  [-0.75983834 -0.70829725 -2.1562452  ...  3.5566068  -2.3510494
#    4.1370754 ]
#  [-1.6129001   7.384731   -5.409307   ...  3.8442903  -3.9070587
#    2.032311  ]], shape=(32, 32), dtype=float32)

# %% [markdown]
# **9) Từ bộ dữ liệu [Income-Classification](https://www.kaggle.com/t/090688c8d33a40b68be9e271d6ba6bae) hãy chuẩn hóa dữ liệu và phân chia tập train/test theo tỷ lệ 80/20**.

# %% [markdown]
# - Mô tả: Sự bất bình đẳng về tài sản và thu nhập là một mối quan tâm sâu sắc của các chính phủ đặc biệt là ở các quốc gia đang phát triển như Mĩ và Châu Âu. Nguyên tắc phổ quát trong bình đẳng thu nhập đảm bảo phát triển bền vững và cải thiện sự ổn định kinh tế của một quốc gia. Việc áp dụng các kỹ thuật học máy cung cấp giải pháp cho vấn đề bình đẳng thu nhập là khả thi và nhiều triển vọng.
#
# - Mục tiêu: Xây dựng bộ phân loại dự đoán liệu thu nhập hàng năm của một người trưởng thành lớn hơn hay nhỏ hơn $50k dựa trên dữ liệu được cung cấp.

# %%
from google.colab import drive
import os
drive.mount("/content/drive")
folder_path = "/content/drive/MyDrive/Deep learning K1"
os.chdir(folder_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Working with data
import numpy as np
import pandas as pd

# Visualizations
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
# %matplotlib inline

# Ignore warnings
import warnings
warnings.filterwarnings('ignore');

# %%
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.datasets import make_classification
import tensorflow
from tensorflow import keras

# %%
from sklearn.model_selection import train_test_split
from keras.layers import Dropout

# %% [markdown]
# #1.Đọc dữ liệu

# %%
#Đọc dữ liệu
d_train = pd.read_csv("train.csv")
d_train.head()
# Out:
#    ID  age work_type  ...  hrs_per_week nationality  target_income
# 0   0   45   Private  ...            40          US              0
# 1   1   23   Private  ...            30          US              0
# 2   2   22   Private  ...            20       South              0
# 3   3   27   Private  ...            40          US              0
# 4   4   18   Private  ...            20          US              0
#
# [5 rows x 16 columns]

# %% [markdown]
# #2.Xử lý dữ liệu

# %% [markdown]
# #2.1 Mô tả dữ liệu

# %%
d_train.describe()
# Out:
#                  ID           age  ...  hrs_per_week  target_income
# count  25000.000000  25000.000000  ...  25000.000000    25000.00000
# mean   12499.500000     38.568800  ...     40.392200        0.23944
# std     7217.022701     13.642694  ...     12.350547        0.42675
# min        0.000000     17.000000  ...      1.000000        0.00000
# 25%     6249.750000     28.000000  ...     40.000000        0.00000
# 50%    12499.500000     37.000000  ...     40.000000        0.00000
# 75%    18749.250000     48.000000  ...     45.000000        0.00000
# max    24999.000000     90.000000  ...     99.000000        1.00000
#
# [8 rows x 8 columns]

# %% [markdown]
# Có sự chênh lệch lớn giữa `max` và phân vị 75% ở hai thuộc tính `capital_gain`	và `capital_loss`.

# %%
#Thông tin của các thuộc tính
d_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   25000 non-null  int64
#  1   age                  25000 non-null  int64
#  2   work_type            25000 non-null  object
#  3   final_weight         25000 non-null  int64
#  4   education            25000 non-null  object
#  5   total_education_yrs  25000 non-null  int64
#  6   marital_state        25000 non-null  object
#  7   job                  25000 non-null  object
#  8   status               25000 non-null  object
#  9   ethnicity            25000 non-null  object
#  10  sex                  25000 non-null  object
#  11  capital_gain         25000 non-null  int64
#  12  capital_loss         25000 non-null  int64
#  13  hrs_per_week         25000 non-null  int64
#  14  nationality          25000 non-null  object
# ...

# %% [markdown]
# Dữ liệu không bị thiếu

# %% [markdown]
# Từ kết quả trên, chúng ta có thể thấy rằng không có giá trị nào bị thiếu trong tập dữ liệu (train và test) nhưng thay vào đó, các giá trị bị thiếu có dạng '?', vì vậy ta cần xử lý giá trị này.

# %% [markdown]
# Xóa cột `ID'

# %%
d_train = d_train.drop(['ID'], axis = 1)

# %%
d_train.head()
# Out:
#    age work_type  final_weight  ... hrs_per_week  nationality target_income
# 0   45   Private        175925  ...           40           US             0
# 1   23   Private        113601  ...           30           US             0
# 2   22   Private        112137  ...           20        South             0
# 3   27   Private        153078  ...           40           US             0
# 4   18   Private        375515  ...           20           US             0
#
# [5 rows x 15 columns]

# %% [markdown]
# #2.2.Vẽ biểu đồ cho các thuộc tính số

# %%
rcParams['figure.figsize'] = 15, 8
d_train[['age',		'final_weight',	'total_education_yrs',	'capital_gain',	'capital_loss',	'hrs_per_week']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc5d01714d0>,
# ...
#       dtype=object)

# %% [markdown]
# Từ biểu đồ histogams ta có nhận xét:
#
# - Nhóm thuộc tính `age` thành các bins (3 bins)
#
# - `Capital Gain` and và `Capital Loss` sai lệch, cần phải xử lý
#
# - Hai thuộc tính `education`	và `total_education_yr` tương đương nhau.
#
# - 'Final Weight' bị lệch trái
#
# - `Hours per Week` có thể chia thành 3 bins

# %% [markdown]
# ###Age

# %% [markdown]
# Ta chia thuộc tính `age` thành 3 bins
# 1. 0-25: Young
# 2. 25-50: Adult
# 3. 50-100: Old

# %%
d_train['age'] = pd.cut(d_train['age'], bins = [0, 25, 50, 100], labels = ['Young', 'Adult', 'Old'])

# %%
sns.countplot(x = 'age', hue = 'target_income', data = d_train)

# %% [markdown]
# ### hours per Week

# %% [markdown]
# Nhìn vào lược đồ của thuộc tính này, ta có thể chia làm 3 bins:`0-30`, `30-40`, và `40-100` (Phân phối chuẩn).

# %%
d_train['hrs_per_week'] = pd.cut(d_train['hrs_per_week'], 
                                   bins = [0, 30, 40, 100], 
                                   labels = ['Lesser Hours', 'Normal Hours', 'Extra Hours'])

# %%
sns.countplot(x = 'hrs_per_week', hue = 'target_income', data = d_train)

# %% [markdown]
# Từ biểu đố này ta thấy nếu làm thêm giờ thì sẽ có xu hướng kếm được nhiều hơn $50k so với người làm ít giờ.

# %% [markdown]
# Các thuộc tính số còn lại ta sẽ chuẩn hóa theo Minmax

# %% [markdown]
# ###final_weight

# %%
#version 2: Xóa thuộc tính 
plt.matshow(d_train.corr())
plt.colorbar()
plt.xticks(np.arange(len(d_train.corr().columns)), d_train.corr().columns.values, rotation = 45) 
plt.yticks(np.arange(len(d_train.corr().columns)), d_train.corr().columns.values) 
for (i, j), corr in np.ndenumerate(d_train.corr()):
    plt.text(j, i, '{:0.1f}'.format(corr), ha='center', va='center', color='white', fontsize=14)

# %%
d_train = d_train.drop(['final_weight'], axis = 1)

# %%
d_train.head()
# Out:
#      age work_type     education  ...  hrs_per_week nationality target_income
# 0  Adult   Private       HS-grad  ...  Normal Hours          US             0
# 1  Young   Private  Some-college  ...  Lesser Hours          US             0
# 2  Young   Private  Some-college  ...  Lesser Hours       South             0
# 3  Adult   Private   Prof-school  ...  Normal Hours          US             0
# 4  Young   Private          11th  ...  Lesser Hours          US             0
#
# [5 rows x 14 columns]

# %% [markdown]
# #2.3.Các thuộc tính phân loại

# %% [markdown]
# ### work_type

# %%
sns.countplot(x = 'work_type', hue = 'target_income', data = d_train)

# %% [markdown]
# Thuộc tính này có 2 giá trị `Without-pay` và `Never-worked`có số lần xuất hiện không đáng kể nên ta có thể xóa 2 giá trị này.

# %%
d_train = d_train.drop(d_train[d_train['work_type'] == 'Without-pay'].index)
d_train = d_train.drop(d_train[d_train['work_type'] == 'Never-worked'].index)

# %%
d_train.head()
# Out:
#      age work_type     education  ...  hrs_per_week nationality target_income
# 0  Adult   Private       HS-grad  ...  Normal Hours          US             0
# 1  Young   Private  Some-college  ...  Lesser Hours          US             0
# 2  Young   Private  Some-college  ...  Lesser Hours       South             0
# 3  Adult   Private   Prof-school  ...  Normal Hours          US             0
# 4  Young   Private          11th  ...  Lesser Hours          US             0
#
# [5 rows x 14 columns]

# %% [markdown]
# ### `education` và `education number`

# %%
sns.countplot(x = 'education', hue = 'target_income', data = d_train)

# %%
education_classes = d_train['education'].unique()
for edu_class in education_classes:
    print("Trình độ {} có Education number là {}"
          .format(edu_class, d_train[d_train['education'] == edu_class]['total_education_yrs'].unique()))
# Out:
# Trình độ HS-grad có Education number là [9]
# Trình độ Some-college có Education number là [10]
# Trình độ Prof-school có Education number là [15]
# Trình độ 11th có Education number là [7]
# Trình độ Bachelors có Education number là [13]
# Trình độ Masters có Education number là [14]
# Trình độ 9th có Education number là [5]
# Trình độ Doctorate có Education number là [16]
# Trình độ 7th-8th có Education number là [4]
# Trình độ 10th có Education number là [6]
# Trình độ 1st-4th có Education number là [2]
# Trình độ Assoc-acdm có Education number là [12]
# Trình độ Assoc-voc có Education number là [11]
# Trình độ 12th có Education number là [8]
# Trình độ 5th-6th có Education number là [3]
# Trình độ Preschool có Education number là [1]

# %% [markdown]
# Hai thuộc tính này tương đương nên ta giữ lại một

# %%
d_train.drop(['total_education_yrs'], axis = 1, inplace = True)
d_train['education'].replace([' 11th', ' 9th', ' 7th-8th', ' 5th-6th', ' 10th', ' 1st-4th', ' Preschool', ' 12th'],
                             ' School', inplace = True)
d_train['education'].value_counts()
# Out:
# HS-grad         8054
# Some-college    5667
# Bachelors       4053
# Masters         1323
# Assoc-voc       1059
# 11th             871
# Assoc-acdm       825
# 10th             727
# 7th-8th          464
# Prof-school      460
# 9th              411
# 12th             333
# Doctorate        307
# 5th-6th          263
# 1st-4th          130
# Preschool         38
# Name: education, dtype: int64

# %%
d_train.head()
# Out:
#      age work_type     education  ...  hrs_per_week nationality target_income
# 0  Adult   Private       HS-grad  ...  Normal Hours          US             0
# 1  Young   Private  Some-college  ...  Lesser Hours          US             0
# 2  Young   Private  Some-college  ...  Lesser Hours       South             0
# 3  Adult   Private   Prof-school  ...  Normal Hours          US             0
# 4  Young   Private          11th  ...  Lesser Hours          US             0
#
# [5 rows x 13 columns]

# %%
d_train['education'].replace(['11th', '9th', '7th-8th', '5th-6th', '10th', '1st-4th', 'Preschool', '12th'], 'School', inplace = True)

# %%
d_train.head()
# Out:
#      age work_type     education  ...  hrs_per_week nationality target_income
# 0  Adult   Private       HS-grad  ...  Normal Hours          US             0
# 1  Young   Private  Some-college  ...  Lesser Hours          US             0
# 2  Young   Private  Some-college  ...  Lesser Hours       South             0
# 3  Adult   Private   Prof-school  ...  Normal Hours          US             0
# 4  Young   Private        School  ...  Lesser Hours          US             0
#
# [5 rows x 13 columns]

# %% [markdown]
# ### `Marital Status` và `Relationship`

# %%
d_train['marital_state'].value_counts()
# Out:
# Married-civ-spouse       11481
# Never-married             8211
# Divorced                  3415
# Separated                  783
# Widowed                    757
# Married-spouse-absent      322
# Married-AF-spouse           16
# Name: marital_state, dtype: int64

# %%
d_train['status'].value_counts()
# Out:
# Husband           10116
# Not-in-family      6358
# Own-child          3897
# Unmarried          2645
# Wife               1197
# Other-relative      772
# Name: status, dtype: int64

# %% [markdown]
# Ta giữ nguyên hai thuộc tính này

# %% [markdown]
# ### Job

# %%
plt.xticks(rotation = 45)
sns.countplot(x = 'job', hue = 'target_income', data = d_train)

# %% [markdown]
# ###ethnicity

# %%
sns.countplot(x = 'ethnicity', hue = 'target_income', data = d_train)

# %% [markdown]
# Bộ dữ liệu bao gồm phần lớn thông tin về chủng tộc da trắng trong khi tất cả các chủng tộc khác có số lượng ít hơn. Do đó, ta sẽ kết hợp tất cả dữ liệu chủng tộc khác thành một nhóm mới.

# %%
d_train['ethnicity'].unique()
d_train['ethnicity'].replace([' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo', ' Other'],' Other', inplace = True)

# %% [markdown]
# ###Sex

# %%
sns.countplot(x = 'sex', hue = 'target_income', data = d_train)

# %% [markdown]
# Thuộc tính này ta giữ nguyên, nam giới thu nhập tốt hơn so với nữ giới

# %%
country_count = d_train['nationality'].value_counts()
country_count
# Out:
# US                            22382
# Mexico                          489
# ?                               443
# Philippines                     152
# Germany                         104
# Canada                           95
# Puerto-Rico                      91
# El-Salvador                      83
# India                            79
# Cuba                             78
# England                          73
# South                            63
# China                            61
# Italy                            59
# Jamaica                          57
# Dominican-Republic               53
# Japan                            48
# Guatemala                        48
# Columbia                         46
# Poland                           46
# Vietnam                          45
# Haiti                            33
# Iran                             33
# Taiwan                           33
# Portugal                         28
# Nicaragua                        26
# ...

# %%
plt.bar(country_count.index, country_count.values)
plt.xticks(rotation = 90)
plt.xlabel('nationality')
plt.ylabel('Count')
plt.title('Tổng số người lớn từ mỗi quốc gia')
# Out:
# Text(0.5, 1.0, 'Tổng số người lớn từ mỗi quốc gia')

# %%
countries = np.array(d_train['nationality'].unique())
countries = np.delete(countries, 0)

# %%
d_train['nationality'].replace(countries, 'Other', inplace = True)

# %%
sns.countplot(x = 'nationality', hue = 'target_income', data = d_train)

# %%
d_train.head()
# Out:
#      age work_type     education  ...  hrs_per_week nationality target_income
# 0  Adult   Private       HS-grad  ...  Normal Hours          US             0
# 1  Young   Private  Some-college  ...  Lesser Hours          US             0
# 2  Young   Private  Some-college  ...  Lesser Hours       Other             0
# 3  Adult   Private   Prof-school  ...  Normal Hours          US             0
# 4  Young   Private        School  ...  Lesser Hours          US             0
#
# [5 rows x 13 columns]

# %% [markdown]
# #2.4.Thuộc tính mục tiêu

# %%
rcParams['figure.figsize'] = 10, 5
d_train[['target_income']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc5ce7ceb10>]],
#       dtype=object)

# %%
print('Tổng số quan sát : {}\n'.format(len(d_train)))

print('Số người thu nhập >50K : {}%\n'.format(
    round((len(d_train[d_train['target_income']==1])/32561)*100, 2)))

print('Số người thu nhập <=50K : {}%'.format(
    round((len(d_train[d_train['target_income']==0])/32561)*100, 2)))
# Out:
# Tổng số quan sát : 24985
#
# Số người thu nhập >50K : 18.38%
#
# Số người thu nhập <=50K : 58.35%

# %% [markdown]
# Đây là bài toán phân loại nhị phân với hai classes:
# - 0: Thu nhập dưới 50K đôla
# - 1: Thu nhập trên 50K đôla
#
# Bộ dữ liệu này không bị mất cân bằng nghiêm trọng giữa các lớp. Một số thước đo phù hợp để đánh giá mô hình là:
# - Accuracy
# - f1-score
# - ROC và AUC

# %% [markdown]
# #2.5.Phân chia tập dữ liệu

# %%
dtrain = d_train.drop(['target_income'], axis = 1)
y_train = d_train['target_income']

# %%
dtrain.head(10)
# Out:
#      age work_type     education  ... capital_loss  hrs_per_week nationality
# 0  Adult   Private       HS-grad  ...            0  Normal Hours          US
# 1  Young   Private  Some-college  ...            0  Lesser Hours          US
# 2  Young   Private  Some-college  ...            0  Lesser Hours       Other
# 3  Adult   Private   Prof-school  ...            0  Normal Hours          US
# 4  Young   Private        School  ...            0  Lesser Hours          US
# 5  Adult   Private     Bachelors  ...            0   Extra Hours          US
# 6  Adult   Private        School  ...            0  Normal Hours          US
# 7  Adult   Private     Bachelors  ...            0   Extra Hours          US
# 8    Old   Private     Bachelors  ...         1977   Extra Hours          US
# 9    Old         ?       HS-grad  ...            0  Normal Hours          US
#
# [10 rows x 12 columns]

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(dtrain, y_train, test_size=0.2)

# %%
print(Xtrain.shape, Xtest.shape)
# Out:
# (19988, 12) (4997, 12)

# %%
print(ytrain.shape, ytest.shape)
# Out:
# (19988,) (4997,)

# %%
Xtrain.head()
# Out:
#          age  work_type     education  ... capital_loss  hrs_per_week nationality
# 13438    Old    Private       HS-grad  ...            0  Lesser Hours          US
# 23438    Old    Private        School  ...            0  Normal Hours       Other
# 10504  Adult    Private       Masters  ...            0  Normal Hours          US
# 8767   Young  Local-gov        School  ...            0  Normal Hours          US
# 18136  Adult    Private  Some-college  ...            0  Normal Hours          US
#
# [5 rows x 12 columns]

# %%
#Loại bỏ khoảng trống không cần thiết
Xtrain=Xtrain.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
Xtest=Xtest.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
Xtrain.isin(['?']).sum()
# Out:
# age                 0
# work_type        1065
# education           0
# marital_state       0
# job              1065
# status              0
# ethnicity           0
# sex                 0
# capital_gain        0
# capital_loss        0
# hrs_per_week        0
# nationality         0
# dtype: int64

# %%
Xtest.isin(['?']).sum()
# Out:
# age                0
# work_type        314
# education          0
# marital_state      0
# job              314
# status             0
# ethnicity          0
# sex                0
# capital_gain       0
# capital_loss       0
# hrs_per_week       0
# nationality        0
# dtype: int64

# %%
# Thay thế '?' bằng np.nan
Xtrain = Xtrain.replace(to_replace='?', value=np.nan)
Xtest = Xtest.replace(to_replace='?', value=np.nan)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="most_frequent")

# %%
imputer.fit(Xtrain[['work_type']])
imputer.fit(Xtrain[['job']])
#imputer.fit(Xtrain[['nationality']])
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
Xtrain['work_type'] = imputer.transform(Xtrain[['work_type']])
Xtrain['job'] = imputer.transform(Xtrain[['job']])
#Xtrain['nationality'] = imputer.transform(Xtrain[['nationality']])

# %%
Xtest['work_type'] = imputer.transform(Xtest[['work_type']])
Xtest['job'] = imputer.transform(Xtest[['job']])
#Xtest['nationality'] = imputer.transform(Xtest[['nationality']])

# %%
Xtrain.isin(['?']).sum()
# Out:
# age              0
# work_type        0
# education        0
# marital_state    0
# job              0
# status           0
# ethnicity        0
# sex              0
# capital_gain     0
# capital_loss     0
# hrs_per_week     0
# nationality      0
# dtype: int64

# %%
Xtest.isin(['?']).sum()
# Out:
# age              0
# work_type        0
# education        0
# marital_state    0
# job              0
# status           0
# ethnicity        0
# sex              0
# capital_gain     0
# capital_loss     0
# hrs_per_week     0
# nationality      0
# dtype: int64

# %% [markdown]
# Dữ liệu đã được xử lý

# %%
Xtrain.head()
# Out:
#          age  work_type     education  ... capital_loss  hrs_per_week nationality
# 13438    Old    Private       HS-grad  ...            0  Lesser Hours          US
# 23438    Old    Private        School  ...            0  Normal Hours       Other
# 10504  Adult    Private       Masters  ...            0  Normal Hours          US
# 8767   Young  Local-gov        School  ...            0  Normal Hours          US
# 18136  Adult    Private  Some-college  ...            0  Normal Hours          US
#
# [5 rows x 12 columns]

# %%
Xtest.head()
# Out:
#          age    work_type    education  ... capital_loss  hrs_per_week nationality
# 9124   Adult      Private  Prof-school  ...            0   Extra Hours          US
# 10117  Adult      Private    Bachelors  ...            0  Lesser Hours          US
# 4945   Adult      Private      HS-grad  ...            0   Extra Hours          US
# 6960   Adult  Federal-gov    Bachelors  ...            0  Normal Hours          US
# 8552   Adult      Private      HS-grad  ...            0  Normal Hours          US
#
# [5 rows x 12 columns]

# %% [markdown]
# #2.6.Chuyển đổi dữ liệu

# %%
#Đưa dữ liệu về dạng chuẩn
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(Xtrain[['final_weight','capital_gain', 'capital_loss']])

# %%
#Version 2
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(Xtrain[['capital_gain', 'capital_loss']])
# Out:
# StandardScaler()

# %%
input_minmax_xtrain = scaler.transform(Xtrain[['capital_gain', 'capital_loss']])
scaled_xtrain = pd.DataFrame(input_minmax_xtrain,columns=['capital_gain', 'capital_loss'])

# %%
input_minmax_xtest = scaler.transform(Xtest[['capital_gain', 'capital_loss']])
scaled_xtest = pd.DataFrame(input_minmax_xtest,columns=['capital_gain', 'capital_loss'])

# %%
Xtrain_minmax_scaled = scaled_xtrain.join(Xtrain.drop(['capital_gain', 'capital_loss'],axis=1))

# %%
Xtest_minmax_scaled = scaled_xtest.join(Xtest.drop(['capital_gain', 'capital_loss'],axis=1))

# %%
#Version 2
Xtrain_minmax_scaled.head()
# Out:
#    capital_gain  capital_loss    age  ... sex  hrs_per_week nationality
# 0      -0.14483     -0.214738  Adult  ...   M  Normal Hours          US
# 1      -0.14483     -0.214738  Young  ...   M  Lesser Hours          US
# 2      -0.14483     -0.214738  Young  ...   F  Lesser Hours       Other
# 3      -0.14483     -0.214738  Adult  ...   M  Normal Hours          US
# 4      -0.14483     -0.214738  Young  ...   F  Lesser Hours          US
#
# [5 rows x 12 columns]

# %%
Xtrain_minmax_scaled.head()
# Out:
#    capital_gain  capital_loss    age  ... sex  hrs_per_week nationality
# 0      -0.14483     -0.214738  Adult  ...   M  Normal Hours          US
# 1      -0.14483     -0.214738  Young  ...   M  Lesser Hours          US
# 2      -0.14483     -0.214738  Young  ...   F  Lesser Hours       Other
# 3      -0.14483     -0.214738  Adult  ...   M  Normal Hours          US
# 4      -0.14483     -0.214738  Young  ...   F  Lesser Hours          US
#
# [5 rows x 12 columns]

# %%
print(Xtrain_minmax_scaled.shape, Xtest_minmax_scaled.shape)
# Out:
# (19988, 12) (4997, 12)

# %%
Xtrain_minmax_scaled.columns
# Out:
# Index(['capital_gain', 'capital_loss', 'age', 'work_type', 'education',
#        'marital_state', 'job', 'status', 'ethnicity', 'sex', 'hrs_per_week',
#        'nationality'],
#       dtype='object')

# %%
Xtest_minmax_scaled.columns
# Out:
# Index(['capital_gain', 'capital_loss', 'age', 'work_type', 'education',
#        'marital_state', 'job', 'status', 'ethnicity', 'sex', 'hrs_per_week',
#        'nationality'],
#       dtype='object')

# %%
Xtrain_minmax_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19988 entries, 0 to 19987
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   final_weight   19988 non-null  float64
#  1   capital_gain   19988 non-null  float64
#  2   capital_loss   19988 non-null  float64
#  3   age            15960 non-null  category
#  4   work_type      15960 non-null  object
#  5   education      15960 non-null  object
#  6   marital_state  15960 non-null  object
#  7   job            15960 non-null  object
#  8   status         15960 non-null  object
#  9   ethnicity      15960 non-null  object
#  10  sex            15960 non-null  object
#  11  hrs_per_week   15960 non-null  category
#  12  nationality    15960 non-null  object
# dtypes: category(2), float64(3), object(8)
# memory usage: 1.7+ MB

# %%
Xtest_minmax_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4997 entries, 0 to 4996
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   final_weight   4997 non-null   float64
#  1   capital_gain   4997 non-null   float64
#  2   capital_loss   4997 non-null   float64
#  3   age            996 non-null    category
#  4   work_type      996 non-null    object
#  5   education      996 non-null    object
#  6   marital_state  996 non-null    object
#  7   job            996 non-null    object
#  8   status         996 non-null    object
#  9   ethnicity      996 non-null    object
#  10  sex            996 non-null    object
#  11  hrs_per_week   996 non-null    category
#  12  nationality    996 non-null    object
# dtypes: category(2), float64(3), object(8)
# memory usage: 439.5+ KB

# %%
#Chuyển ữ liệu về dạng 0-1
X_train = pd.get_dummies(Xtrain_minmax_scaled)
X_test = pd.get_dummies(Xtest_minmax_scaled)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (19988, 61) (4997, 61)

# %%
X_train.head()
# Out:
#    capital_gain  capital_loss  ...  nationality_Other  nationality_US
# 0     -0.145946     -0.211515  ...                  0               1
# 1     -0.145946     -0.211515  ...                  0               1
# 2     -0.145946     -0.211515  ...                  0               0
# 3     -0.145946     -0.211515  ...                  0               0
# 4     -0.145946     -0.211515  ...                  0               1
#
# [5 rows x 61 columns]

# %% [markdown]
# ###Version 3

# %%
#Đọc dữ liệu
d_trainV3 = pd.read_csv("train.csv")
d_trainV3.head(10)
# Out:
#    ID  age work_type  ...  hrs_per_week nationality  target_income
# 0   0   45   Private  ...            40          US              0
# 1   1   23   Private  ...            30          US              0
# 2   2   22   Private  ...            20       South              0
# 3   3   27   Private  ...            40          US              0
# 4   4   18   Private  ...            20          US              0
# 5   5   44   Private  ...            48          US              0
# 6   6   27   Private  ...            40          US              0
# 7   7   38   Private  ...            50          US              1
# 8   8   59   Private  ...            50          US              1
# 9   9   69         ?  ...            40          US              0
#
# [10 rows x 16 columns]

# %%
col_names = d_trainV3.columns
for c in col_names:
	d_trainV3[c] = d_trainV3[c].replace("?", np.NaN)

d_trainV3 = d_trainV3.apply(lambda x:x.fillna(x.value_counts().index[0]))

# %%
d_trainV3.head(10)
# Out:
#    ID  age work_type  ...  hrs_per_week nationality  target_income
# 0   0   45   Private  ...            40          US              0
# 1   1   23   Private  ...            30          US              0
# 2   2   22   Private  ...            20       South              0
# 3   3   27   Private  ...            40          US              0
# 4   4   18   Private  ...            20          US              0
# 5   5   44   Private  ...            48          US              0
# 6   6   27   Private  ...            40          US              0
# 7   7   38   Private  ...            50          US              1
# 8   8   59   Private  ...            50          US              1
# 9   9   69   Private  ...            40          US              0
#
# [10 rows x 16 columns]

# %%
d_trainV3.replace(['Divorced', 'Married-AF-spouse', 
              'Married-civ-spouse', 'Married-spouse-absent', 
              'Never-married','Separated','Widowed'],
             ['divorced','married','married','married',
              'not married','not married','not married'], inplace = True)
d_trainV3.head(10)
# Out:
#    ID  age work_type  ...  hrs_per_week nationality  target_income
# 0   0   45   Private  ...            40          US              0
# 1   1   23   Private  ...            30          US              0
# 2   2   22   Private  ...            20       South              0
# 3   3   27   Private  ...            40          US              0
# 4   4   18   Private  ...            20          US              0
# 5   5   44   Private  ...            48          US              0
# 6   6   27   Private  ...            40          US              0
# 7   7   38   Private  ...            50          US              1
# 8   8   59   Private  ...            50          US              1
# 9   9   69   Private  ...            40          US              0
#
# [10 rows x 16 columns]

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelEncoder = LabelEncoder()
category_col =['work_type', 'ethnicity','marital_state', 'sex'] 

for col in category_col:
    d_trainV3[col] = labelEncoder.fit_transform(d_trainV3[col])

# %%
d_trainV3.head(10)
# Out:
#    ID  age  work_type  ...  hrs_per_week nationality  target_income
# 0   0   45          3  ...            40          US              0
# 1   1   23          3  ...            30          US              0
# 2   2   22          3  ...            20       South              0
# 3   3   27          3  ...            40          US              0
# 4   4   18          3  ...            20          US              0
# 5   5   44          3  ...            48          US              0
# 6   6   27          3  ...            40          US              0
# 7   7   38          3  ...            50          US              1
# 8   8   59          3  ...            50          US              1
# 9   9   69          3  ...            40          US              0
#
# [10 rows x 16 columns]

# %%
category_col =['work_type', 'education', 'job',
               'status','nationality'] 

d_trainV3_1 = pd.get_dummies(d_trainV3, columns=category_col, drop_first=True)

# %%
d_trainV3_1.head(10)
# Out:
#    ID  age  ...  nationality_Vietnam  nationality_Yugoslavia
# 0   0   45  ...                    0                       0
# 1   1   23  ...                    0                       0
# 2   2   22  ...                    0                       0
# 3   3   27  ...                    0                       0
# 4   4   18  ...                    0                       0
# 5   5   44  ...                    0                       0
# 6   6   27  ...                    0                       0
# 7   7   38  ...                    0                       0
# 8   8   59  ...                    0                       0
# 9   9   69  ...                    0                       0
#
# [10 rows x 91 columns]

# %%
dataframe=d_trainV3_1.drop('final_weight',1)
dataframe =dataframe[[c for c in dataframe if c not in ['target_income']] + ['target_income']]
dataframe.head(20)
# Out:
#     ID  age  ...  nationality_Yugoslavia  target_income
# 0    0   45  ...                       0              0
# 1    1   23  ...                       0              0
# 2    2   22  ...                       0              0
# 3    3   27  ...                       0              0
# 4    4   18  ...                       0              0
# 5    5   44  ...                       0              0
# 6    6   27  ...                       0              0
# 7    7   38  ...                       0              1
# 8    8   59  ...                       0              1
# 9    9   69  ...                       0              0
# 10  10   73  ...                       0              0
# 11  11   37  ...                       0              0
# 12  12   52  ...                       0              0
# 13  13   24  ...                       0              0
# 14  14   28  ...                       0              0
# 15  15   27  ...                       0              0
# ...

# %%
dataframe = dataframe.drop(['ID'], axis = 1)

# %%
dataframe.head()
# Out:
#    age  total_education_yrs  ...  nationality_Yugoslavia  target_income
# 0   45                    9  ...                       0              0
# 1   23                   10  ...                       0              0
# 2   22                   10  ...                       0              0
# 3   27                   15  ...                       0              0
# 4   18                    7  ...                       0              0
#
# [5 rows x 89 columns]

# %%
xtrain = dataframe.drop(['target_income'], axis = 1)
ytrain = dataframe['target_income']

# %%
X_trainV3, X_testV3, y_trainV3, y_testV3 = train_test_split(xtrain, ytrain, test_size=0.2)

# %% [markdown]
# #2.7.Ghi dữ liệu

# %%
#Version 1
X_train.to_csv("xtrain.csv", index=None)
ytrain.to_csv("ytrain.csv", index=None)

# %%
X_test.to_csv("xtest.csv", index=None)
ytest.to_csv("ytest.csv", index=None)

# %%
#Version 2
X_train.to_csv("xtrain2.csv", index=None)
ytrain.to_csv("ytrain2.csv", index=None)
X_test.to_csv("xtest2.csv", index=None)
ytest.to_csv("ytest2.csv", index=None)

# %%
#Version 3
X_trainV3.to_csv("xtrain3.csv", index=None)
y_trainV3.to_csv("ytrain3.csv", index=None)
X_testV3.to_csv("xtest3.csv", index=None)
y_testV3.to_csv("ytest3.csv", index=None)

# %% [markdown]
# **10) Xây dựng một mạng deep-neural-network để huấn luyện mô hình trên dữ liệu train và đánh giá mô hình trên dữ liệu test.**

# %% [markdown]
# Đọc dữ liệu sau khi đã được chuẩn hóa và phân chia 80:20

# %%
Xtrain = pd.read_csv("xtrain.csv")
ytrain = pd.read_csv("ytrain.csv")

# %%
Xtest = pd.read_csv("xtest.csv")
ytest = pd.read_csv("ytest.csv")

# %%
Xtrain = pd.read_csv("xtrain2.csv")
ytrain = pd.read_csv("ytrain2.csv")
Xtest = pd.read_csv("xtest2.csv")
ytest = pd.read_csv("ytest2.csv")

# %%
Xtrain = pd.read_csv("xtrain3.csv")
ytrain = pd.read_csv("ytrain3.csv")
Xtest = pd.read_csv("xtest3.csv")
ytest = pd.read_csv("ytest3.csv")

# %%
Xtrain.head()
# Out:
#    final_weight  capital_gain  ...  nationality_Other  nationality_US
# 0      0.654607      -0.14495  ...                  0               1
# 1     -0.901896      -0.14495  ...                  0               1
# 2     -0.044830      -0.14495  ...                  1               0
# 3      0.079688      -0.14495  ...                  0               1
# 4      0.207515      -0.14495  ...                  0               0
#
# [5 rows x 62 columns]

# %% [markdown]
# Chia tập train thành tập xtrain và Xval

# %%
Xtrain, Xval, ytrain, yval = train_test_split(Xtrain, ytrain, test_size=0.15)

# %%
print(Xtrain.shape, Xval.shape)
# Out:
# (16989, 62) (2999, 62)

# %% [markdown]
# Thiết lập mô hình

# %%
# Initialising the ANN - start the sequential model
classifier = Sequential()

# Adding the input layer
classifier.add(Dense(units = 6, activation = 'relu', input_dim = Xtrain.shape[1]))
classifier.add(Dropout(0.3))
# Adding hidden layers
#classifier.add(Dense(units = 128, activation = 'relu'))
#classifier.add(Dropout(0.3))

classifier.add(Dense(units = 6, activation = 'relu'))
#classifier.add(Dropout(0.3))
#classifier.add(Dense(units = 32, activation = 'relu'))

#Adding the output layer
classifier.add(Dense(units = 1,  activation = 'sigmoid'))

classifier.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_65 (Dense)            (None, 6)                 378
#
#  dropout_26 (Dropout)        (None, 6)                 0
#
#  dense_66 (Dense)            (None, 6)                 42
#
#  dense_67 (Dense)            (None, 1)                 7
#
# ...
# Total params: 427
# Trainable params: 427
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Lựa chọn hàm loss và độ đo

# %%
opt = tensorflow.keras.optimizers.Adam()

# %%
classifier.compile(optimizer = opt, loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# Huấn luyện mô hình (tìm bộ tham số tốt nhất cho mô hình)

# %%
#Version 1
his = classifier.fit(Xtrain, ytrain, batch_size = 10, epochs = 100, validation_data=(Xval, yval))
val_acc_per_epoch = his.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Epoch 1/100
# 1699/1699 [==============================] - 4s 2ms/step - loss: 0.5600 - accuracy: 0.7618 - val_loss: 0.5320 - val_accuracy: 0.7626
# Epoch 2/100
# 1699/1699 [==============================] - 6s 4ms/step - loss: 0.5159 - accuracy: 0.7824 - val_loss: 0.5005 - val_accuracy: 0.7949
# Epoch 3/100
# 1699/1699 [==============================] - 3s 2ms/step - loss: 0.5013 - accuracy: 0.7917 - val_loss: 0.4961 - val_accuracy: 0.8029
# Epoch 4/100
# 1699/1699 [==============================] - 3s 2ms/step - loss: 0.4996 - accuracy: 0.7919 - val_loss: 0.4937 - val_accuracy: 0.8069
# Epoch 5/100
# 1699/1699 [==============================] - 3s 2ms/step - loss: 0.4931 - accuracy: 0.7948 - val_loss: 0.4913 - val_accuracy: 0.8036
# Epoch 6/100
# 1699/1699 [==============================] - 3s 2ms/step - loss: 0.4902 - accuracy: 0.8003 - val_loss: 0.4921 - val_accuracy: 0.8056
# Epoch 7/100
# ...

# %%
#Version 2
his = classifier.fit(Xtrain, ytrain, batch_size = 10, epochs = 100, validation_data=(Xval, yval))
val_acc_per_epoch = his.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Epoch 1/100
# 1699/1699 [==============================] - 8s 4ms/step - loss: 0.5485 - accuracy: 0.7588 - val_loss: 0.5156 - val_accuracy: 0.7699
# Epoch 2/100
# 1699/1699 [==============================] - 5s 3ms/step - loss: 0.5202 - accuracy: 0.7726 - val_loss: 0.4946 - val_accuracy: 0.7993
# Epoch 3/100
# 1699/1699 [==============================] - 3s 2ms/step - loss: 0.5083 - accuracy: 0.7917 - val_loss: 0.4852 - val_accuracy: 0.8146
# Epoch 4/100
# 1699/1699 [==============================] - 3s 2ms/step - loss: 0.5017 - accuracy: 0.7982 - val_loss: 0.4807 - val_accuracy: 0.8149
# Epoch 5/100
# 1699/1699 [==============================] - 3s 2ms/step - loss: 0.4963 - accuracy: 0.7998 - val_loss: 0.4788 - val_accuracy: 0.8139
# Epoch 6/100
# 1699/1699 [==============================] - 3s 2ms/step - loss: 0.4933 - accuracy: 0.8026 - val_loss: 0.4769 - val_accuracy: 0.8103
# Epoch 7/100
# ...

# %%
his = classifier.fit(Xtrain, ytrain, batch_size = 10, epochs = best_epoch, validation_data=(Xval, yval))
# Out:
# Epoch 1/100
# 1699/1699 [==============================] - 3s 2ms/step - loss: 0.4752 - accuracy: 0.8099 - val_loss: 0.4902 - val_accuracy: 0.8063
# Epoch 2/100
# 1699/1699 [==============================] - 3s 2ms/step - loss: 0.4733 - accuracy: 0.8112 - val_loss: 0.4913 - val_accuracy: 0.8079
# Epoch 3/100
# 1699/1699 [==============================] - 3s 2ms/step - loss: 0.4738 - accuracy: 0.8117 - val_loss: 0.4905 - val_accuracy: 0.8073
# Epoch 4/100
# 1699/1699 [==============================] - 3s 2ms/step - loss: 0.4774 - accuracy: 0.8095 - val_loss: 0.4919 - val_accuracy: 0.8066
# Epoch 5/100
# 1699/1699 [==============================] - 3s 2ms/step - loss: 0.4749 - accuracy: 0.8108 - val_loss: 0.4926 - val_accuracy: 0.8069
# Epoch 6/100
# 1699/1699 [==============================] - 3s 2ms/step - loss: 0.4744 - accuracy: 0.8115 - val_loss: 0.4913 - val_accuracy: 0.8079
# Epoch 7/100
# ...

# %%
#Version 2
his = classifier.fit(Xtrain, ytrain, batch_size = 10, epochs = best_epoch, validation_data=(Xval, yval))
# Out:
# Epoch 1/30
# 1699/1699 [==============================] - 4s 3ms/step - loss: 0.4759 - accuracy: 0.8112 - val_loss: 0.4704 - val_accuracy: 0.8149
# Epoch 2/30
# 1699/1699 [==============================] - 3s 2ms/step - loss: 0.4761 - accuracy: 0.8099 - val_loss: 0.4709 - val_accuracy: 0.8159
# Epoch 3/30
# 1699/1699 [==============================] - 3s 2ms/step - loss: 0.4759 - accuracy: 0.8111 - val_loss: 0.4702 - val_accuracy: 0.8159
# Epoch 4/30
# 1699/1699 [==============================] - 3s 2ms/step - loss: 0.4767 - accuracy: 0.8089 - val_loss: 0.4706 - val_accuracy: 0.8163
# Epoch 5/30
# 1699/1699 [==============================] - 4s 2ms/step - loss: 0.4761 - accuracy: 0.8101 - val_loss: 0.4698 - val_accuracy: 0.8153
# Epoch 6/30
# 1699/1699 [==============================] - 3s 2ms/step - loss: 0.4741 - accuracy: 0.8119 - val_loss: 0.4703 - val_accuracy: 0.8153
# Epoch 7/30
# ...

# %% [markdown]
# Mô hình không có hiện tượng overfitting

# %%
# Version 1
fig = plt.figure()
numOfEpoch = best_epoch
plt.plot(np.arange(0, numOfEpoch), his.history['loss'], label='training loss')
plt.plot(np.arange(0, numOfEpoch), his.history['val_loss'], label='validation loss')
plt.plot(np.arange(0, numOfEpoch), his.history['accuracy'], label='accuracy')
plt.plot(np.arange(0, numOfEpoch), his.history['val_accuracy'], label='validation accuracy')
plt.title('Accuracy and Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss|Accuracy')
plt.legend()

# %%
# Version 2
fig = plt.figure()
numOfEpoch = best_epoch
plt.plot(np.arange(0, numOfEpoch), his.history['loss'], label='training loss')
plt.plot(np.arange(0, numOfEpoch), his.history['val_loss'], label='validation loss')
plt.plot(np.arange(0, numOfEpoch), his.history['accuracy'], label='accuracy')
plt.plot(np.arange(0, numOfEpoch), his.history['val_accuracy'], label='validation accuracy')
plt.title('Accuracy and Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss|Accuracy')
plt.legend()

# %% [markdown]
# #Đánh giá mô hình trên tập test

# %%
def _scores(model, Xtest):
  # predict probabilities for test set
  yhat_probs = model.predict(Xtest)
  yhat_probs= (yhat_probs >= 0.5)

  # predict crisp classes for test set
  #yhat_classes = classifier.predict_classes(testX, verbose=0)
  yhat_classes = yhat_probs
  # reduce to 1d array
  yhat_probs = yhat_probs[:, 0]
  yhat_classes = yhat_classes[:, 0]
  
  # accuracy: (tp + tn) / (p + n)
  accuracy = accuracy_score(ytest, yhat_classes)
  print('Accuracy: %f' % accuracy)

  # precision tp / (tp + fp)
  precision = precision_score(ytest, yhat_classes)
  print('Precision: %f' % precision)

  # recall: tp / (tp + fn)
  recall = recall_score(ytest, yhat_classes)
  print('Recall: %f' % recall)

  # f1: 2 tp / (2 tp + fp + fn)
  f1 = f1_score(ytest, yhat_classes)
  print('F1 score: %f' % f1)
  
  # ROC AUC
  auc = roc_auc_score(ytest, yhat_probs)
  print('ROC AUC: %f' % auc)
  # confusion matrix
  matrix = confusion_matrix(ytest, yhat_classes)
  print(matrix)

# %%
#version 1
_scores(classifier, Xtest)
# Out:
# Accuracy: 0.813088
# Precision: 0.828431
# Recall: 0.281198
# F1 score: 0.419876
# ROC AUC: 0.631376
# [[3725   70]
#  [ 864  338]]

# %%
#Version 2
_scores(classifier, Xtest)
# Out:
# Accuracy: 0.803882
# Precision: 0.788413
# Recall: 0.258892
# F1 score: 0.389788
# ROC AUC: 0.618358
# [[3704   84]
#  [ 896  313]]

# %%
#Version 1
from sklearn.metrics import roc_curve, auc
plt.figure(figsize = (12, 5))
plt.plot([0,1], [0,1], 'r--')
probs = classifier.predict(Xtest)
# Reading probability of second class
fpr, tpr, thresholds = roc_curve(ytest, probs)
roc_auc = auc(fpr, tpr)
label = 'MLP AUC:' + ' {0:.2f}'.format(roc_auc)
plt.plot(fpr, tpr, label = label, linewidth = 4)

plt.xlabel('False Positive Rate', fontsize = 16)
plt.ylabel('True Positive Rate', fontsize = 16)
plt.title('Receiver Operating Characteristic', fontsize = 16)
plt.legend(loc = 'lower right', fontsize = 16)
