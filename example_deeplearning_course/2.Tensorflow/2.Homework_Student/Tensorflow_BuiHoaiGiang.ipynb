# %% [markdown]
# # 1. Lý thuyết
#
# **1) Để khởi tạo model trong tensorflow chúng ta sử dụng class nào?**
#
# A. Sequential hoặc Model
#
# B. Dense
#
# C. Adam
#
# D. Variable
#
# **2) Điểm khác biệt giữa fit và fit_generator trong tensorflow là gì ?**
#
# A. fit sẽ yêu cầu load toàn bộ dữ liệu lên RAM trong khi fit_generator sẽ sử dụng một hàm generator để sinh dữ liệu tại mỗi mini-batch. Từ đó giúp tiết kiệm bộ nhớ.
#
# B. fit sẽ sử dụng hàm generator để sinh dữ liệu tại thời điểm huấn luyện còn fit_generator sẽ load toàn bộ dữ liệu.
#
# C. fit sẽ huấn luyện model theo mini-batch còn fit_generator thì huấn luyện trên toàn bộ dataset.
#
# D. trong hàm fit chúng ta có thể khai báo tập validation dataset còn trong fit_generator thì không.
#
#
# **3) Các modules chính trong tensorflow dùng để xây dựng và huấn luyện model.**
#
# A. `tf.keras.layers`: khởi tạo activation function; `tf.keras.Sequential`: khởi tạo model; `tf.keras.activations`: để khởi tạo các layers; `tf.keras.optimizers`: Khởi tạo optimizer cho bài toán tối ưu loss function; `tf.keras.losses`: khởi tạo loss function; `tf.keras.preprocessing`: Preprocessing data.
#
# B. `tf.keras.layers`: để khởi tạo các layers; `tf.keras.Sequential`: khởi tạo model; `tf.keras.activations`: khởi tạo activation function; `tf.keras.optimizers`: Khởi tạo optimizer cho bài toán tối ưu loss function; `tf.keras.losses`: khởi tạo loss function; `tf.keras.preprocessing`: Preprocessing data.
#
# C. `tf.keras.layers`: để khởi tạo các layers; `tf.keras.Sequential`: Preprocessing data; `tf.keras.activations`: khởi tạo activation function; `tf.keras.optimizers`: Khởi tạo optimizer cho bài toán tối ưu loss function; `tf.keras.losses`: khởi tạo loss function; `tf.keras.preprocessing`: khởi tạo model
#
# D. `tf.keras.layers`: để khởi tạo các layers; `tf.keras.Sequential`: khởi tạo model; `tf.keras.activations`: khởi tạo activation function; `tf.keras.optimizers`: khởi tạo loss function; `tf.keras.losses`: Khởi tạo optimizer cho bài toán tối ưu loss function; `tf.keras.preprocessing`: Preprocessing data.
#
#
# **4) Các bước trong huấn luyện model bao gồm:**
#
# A. 1. Train/test data split --> 2. Initialize the optimizer algorithm --> 3. Build up model architecture --> 4. Train model on train --> 5. Evaluation on test --> 6. Save and use trained model
#
# B. 1. Train/test data split --> 2. Build up model architecture --> 3. Train model on train --> 4. Initialize the optimizer algorithm --> 5. Evaluation on test --> 6. Save and use trained model
#
# C. 1. Train/test data split --> 2. Build up model architecture --> 3. Initialize the optimizer algorithm --> 4. Evaluation on test --> 5. Train model on train --> 6. Save and use trained model
#
# D. 1. Train/test data split --> 2. Build up model architecture --> 3. Initialize the optimizer algorithm --> 4. Train model on train --> 5. Evaluation on test --> 6. Save and use trained model
#
# **5) Ý nghĩa của tham số epochs và batch_size trong huấn luyện mô hình là gì?**
#
# A. epochs là kích thước của một mini-batch, batch_size là số lượt lặp lại toàn bộ dữ liệu khi huấn luyện.
#
# B. epochs là số lượt lặp lại toàn bộ dữ liệu validation khi huấn luyện, batch_size là kích thước của một mini-batch.
#
# C. epochs là số lượt lặp lại toàn bộ dữ liệu train khi huấn luyện, batch_size là kích thước của một mini-batch.
#
# D. epochs là số lượng vòng lặp, mỗi vòng lặp là một lượt fit mini-batch, trên bộ dữ liệu khi huấn luyện; batch_size là kích thước của một mini-batch.

# %% [markdown]
# # 2. Thực hành
#
# 6) Khởi tạo một tensor 3 chiều với định dạng là float và kích thước là 32x32x3
#
# 7) Nếu coi tensor trên là một bức ảnh RGB với số channel là 3 ở cuối. Hãy truy suất các ma trận ảnh tương ứng với mỗi kênh R, G, B.
#
# 8) Thực hiện tích hadamard và tích thông thường giữa ma trận R và G.
#
# 9) Từ bộ dữ liệu [Income-Classification](https://www.kaggle.com/t/090688c8d33a40b68be9e271d6ba6bae) hãy chuẩn hóa dữ liệu và phân chia tập train/test theo tỷ lệ 80/20.
#
# 10) Xây dựng một mạng deep-neural-network để huấn luyện mô hình trên dữ liệu train và đánh giá mô hình trên dữ liệu test.

# %% [markdown]
# # 1.Lý thuyết
# 1. A
# 2. A
# 3. C
# 4. D
# 5. D

# %% [markdown]
# # Chữa: Đáp án đúng câu 3 là B, câu 5 là C

# %% [markdown]
# # 2.Thực hành

# %%
#6 Khởi tạo một tensor 3 chiều với định dạng là float và kích thước là 32x32x3
import tensorflow as tf
A = tf.random.normal([32, 32, 3])
A.shape
# Out:
# TensorShape([32, 32, 3])

# %%
#7 Nếu coi tensor trên là một bức ảnh RGB với số channel là 3 ở cuối. Hãy truy suất các ma trận ảnh tương ứng với mỗi kênh R, G, B.
for i in range (1,4):
  print(A[-1 + i:i, :, :])
# Out:
# tf.Tensor(
# [[[-1.3167561   0.8646474   0.4126793 ]
#   [-1.1234787   0.72380584 -0.8012281 ]
#   [ 0.29349554  0.66057754 -0.6426139 ]
#   [ 1.031425    0.27344742 -1.1571645 ]
#   [ 2.1789951   0.44216177 -0.56055576]
#   [ 0.0273506  -0.06252204  0.6674715 ]
#   [-0.77758574 -1.3950517   0.23635265]
#   [-1.1227449   0.17889273 -0.49404776]
#   [-0.2910802   0.13083608  0.47976908]
#   [ 0.44436365 -0.3186877   0.03565621]
#   [-0.20438516 -0.2115843   0.6626161 ]
#   [ 0.99682605 -0.2411234  -0.44038057]
#   [ 0.2664066   0.25938898 -0.74784935]
#   [-1.1062003   0.06911774 -1.1418676 ]
#   [-0.38811612 -0.756548    0.4232129 ]
#   [-0.446248    0.6470941  -0.07486736]
#   [ 0.23889892  0.6347743   1.8988564 ]
#   [ 0.4778219  -0.90589035  0.13235174]
#   [-0.04440456  0.46584424 -2.7188232 ]
#   [ 1.970843    1.1571854  -0.12196755]
#   [ 0.6456303   0.33909565 -0.02953926]
#   [ 1.0164888  -1.2005957  -2.9358895 ]
#   [-0.15528601 -2.6329856   0.44621676]
#   [-0.5089568  -0.25851086  1.4665674 ]
#   [ 0.8928867   0.3331224   0.1141679 ]
#   [-0.784588    0.04129236  0.9108904 ]
#   [-0.1699849   0.7569045   1.02838   ]
#   [ 0.9812137   0.34214196 -0.35290965]
#   [ 1.3159258   0.6018059   0.3483437 ]
#   [ 1.5101196   0.16904147 -0.26040214]
#   [-0.06144996  0.2697052   2.280841  ]
#   [-0.42888984 -0.7564699   0.31417388]
#   [-3.1707501   1.4523534   0.1264107 ]
#   [-0.33527365  0.07149483  0.02138796]
#   [-1.4074311   1.8118955  -0.52856344]
#   [ 0.15061805 -1.0494587  -1.0067033 ]
#   [ 0.730617    1.0325782  -0.18733536]
#   [ 0.7130707   0.6956002  -0.35793367]
#   [-0.2096198   0.552897    1.2496797 ]
#   [ 0.67062926  0.87030053  0.29756483]
#   [-0.152092    0.07383945  1.1581411 ]]], shape=(1, 32, 3), dtype=float32)

# %%
#8 Thực hiện tích hadamard và tích thông thường giữa ma trận R và G.
R = A[:1, :, :]
G = A[1:2, :, :]

(R*G).shape
# Out:
# TensorShape([1, 32, 3])

# %%
#9 Từ bộ dữ liệu Income-Classification hãy chuẩn hóa dữ liệu và phân chia tập train/test theo tỷ lệ 80/20.

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Income Classification/train.csv')
df.head()
# Out:
#    ID  age work_type  ...  hrs_per_week nationality  target_income
# 0   0   45   Private  ...            40          US              0
# 1   1   23   Private  ...            30          US              0
# 2   2   22   Private  ...            20       South              0
# 3   3   27   Private  ...            40          US              0
# 4   4   18   Private  ...            20          US              0
#
# [5 rows x 16 columns]

# %%
#phân chia tập train/test theo tỷ lệ 80/20
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.2, stratify = df['target_income'])

print(df_train.shape)
print(df_test.shape)
# Out:
# (20000, 16)
# (5000, 16)

# %%
#10 Xây dựng một mạng deep-neural-network để huấn luyện mô hình trên dữ liệu train và đánh giá mô hình trên dữ liệu test

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import imblearn
from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, LabelEncoder 
from sklearn.preprocessing import StandardScaler
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Lấy list names của các biến phân loại và biến liên tục.
cat_names = list(df.select_dtypes('object').columns)
num_names = list(df.select_dtypes(['float', 'int']).columns)
print(cat_names)
# Out:
# ['work_type', 'education', 'marital_state', 'job', 'status', 'ethnicity', 'sex', 'nationality']

# %%
# categorical_columns = ['work_type', 'education', 'marital_state','job','status','ethnicity','sex', 'nationality']

le = LabelEncoder()

df[cat_names] = df[cat_names].apply(le.fit_transform)

# %%
df.head()
# Out:
#    ID  age  work_type  ...  hrs_per_week  nationality  target_income
# 0   0   45          4  ...            40           39              0
# 1   1   23          4  ...            30           39              0
# 2   2   22          4  ...            20           35              0
# 3   3   27          4  ...            40           39              0
# 4   4   18          4  ...            20           39              0
#
# [5 rows x 16 columns]

# %%
features = ['age','work_type','final_weight','education','total_education_yrs',
            'marital_state','job','status','ethnicity','sex','capital_gain','capital_loss', 'hrs_per_week','nationality']
label = 'target_income'

# %%
#phân chia tập train/test theo tỷ lệ 80/20 sau khi đã encoder

x_train, x_test, y_train, y_test = train_test_split(df[features].values,
                                                     df[label].values,
                                                     test_size = 0.2,
                                                     stratify = df['target_income'],
                                                     random_state=0)

print(df_train.shape)
print(df_test.shape)
# Out:
# (20000, 16)
# (5000, 16)

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import utils
from tensorflow.keras import optimizers

# Set random seed for reproducability
tensorflow.random.set_seed(0)

print("Libraries imported.")
print('Keras version:',keras.__version__)
print('TensorFlow version:',tensorflow.__version__)
# Out:
# Libraries imported.
# Keras version: 2.7.0
# TensorFlow version: 2.7.0

# %%
# Set data types for float features
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Set data types for categorical labels
y_train = utils.to_categorical(y_train)
y_test = utils.to_categorical(y_test)

# %%
hl = 10 # Number of hidden layer nodes

model = Sequential()
model.add(Dense(hl, input_dim=len(features), activation='relu'))
model.add(Dense(hl, input_dim=hl, activation='relu'))
model.add(Dense(2, input_dim=hl, activation='softmax'))

print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 10)                150
#
#  dense_4 (Dense)             (None, 10)                110
#
#  dense_5 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 282
# Trainable params: 282
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#train model

learning_rate = 0.001
opt = optimizers.Adam(lr=learning_rate)

model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# Train the model over 50 epochs using 10-observation batches and using the test holdout dataset for validation
num_epochs = 50
history = model.fit(x_train, y_train, epochs=num_epochs, batch_size=10, validation_data=(x_test, y_test))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/50
# 2000/2000 [==============================] - 10s 4ms/step - loss: 98.3684 - accuracy: 0.6255 - val_loss: 4.2999 - val_accuracy: 0.7674
# Epoch 2/50
# 2000/2000 [==============================] - 5s 3ms/step - loss: 1.4000 - accuracy: 0.6999 - val_loss: 0.5035 - val_accuracy: 0.8034
# Epoch 3/50
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.5204 - accuracy: 0.7956 - val_loss: 0.4893 - val_accuracy: 0.8052
# Epoch 4/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.5016 - accuracy: 0.7946 - val_loss: 0.4814 - val_accuracy: 0.8042
# Epoch 5/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5283 - accuracy: 0.7789 - val_loss: 0.5135 - val_accuracy: 0.7864
# Epoch 6/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5450 - accuracy: 0.7688 - val_loss: 0.5407 - val_accuracy: 0.7674
# Epoch 7/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5462 - accuracy: 0.7642 - val_loss: 0.5420 - val_accuracy: 0.7664
# Epoch 8/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5592 - accuracy: 0.7630 - val_loss: 0.5413 - val_accuracy: 0.7670
# Epoch 9/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.5500 - accuracy: 0.7623 - val_loss: 0.5490 - val_accuracy: 0.7616
# Epoch 10/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5627 - accuracy: 0.7616 - val_loss: 0.5492 - val_accuracy: 0.7614
# Epoch 11/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5494 - accuracy: 0.7614 - val_loss: 0.5450 - val_accuracy: 0.7644
# Epoch 12/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5540 - accuracy: 0.7635 - val_loss: 0.5505 - val_accuracy: 0.7606
# Epoch 13/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 14/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5505 - val_accuracy: 0.7606
# Epoch 15/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 16/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 17/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 18/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 19/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5504 - accuracy: 0.7606 - val_loss: 0.5506 - val_accuracy: 0.7606
# Epoch 20/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5506 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 21/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 22/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 23/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5505 - val_accuracy: 0.7606
# Epoch 24/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5506 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 25/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 26/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 27/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 28/50
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 29/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 30/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 31/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5505 - val_accuracy: 0.7606
# Epoch 32/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 33/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 34/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 35/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5506 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 36/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5506 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 37/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 38/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 39/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 40/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 41/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5506 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 42/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 43/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 44/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5505 - val_accuracy: 0.7606
# Epoch 45/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5506 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 46/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5506 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 47/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 48/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 49/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.5505 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606
# Epoch 50/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.5506 - accuracy: 0.7606 - val_loss: 0.5504 - val_accuracy: 0.7606

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

epoch_nums = range(1,num_epochs+1)
training_loss = history.history["loss"]
validation_loss = history.history["val_loss"]
plt.plot(epoch_nums, training_loss)
plt.plot(epoch_nums, validation_loss)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training', 'validation'], loc='upper right')
plt.show()

# %% [markdown]
# # Chữa: Nên hiển thị kết quả acc của mô hình sau khi đã huấn luyện. CÓ thể đưa ra một vài nhận xét. Thử nghiệm thêm thay đổi tham số của mô hình cũng như normalize dữ liệu
