# %% [markdown]
# # I. Lý thuyết
#
# 1) Tại sao mô hình R-CNN lại có tốc độ xử lý chậm?
#
# A. Do R-CNN sử dụng các backbone rất nặng.
#
# B. Do các vùng region proposal được dự báo bounding box và phân loại nhãn một cách độc lập.
#
# C. Do thuật toán Selective Search là một phương pháp heuristic nên rất chậm
#
# D. Do mô hình tách biệt giữa dự báo bounding box và phân loại nhãn
#
# => Đáp án B
#
# 2) Chỉ số mAP trong các thuật toán object detection được tính toán theo cách nào ?
#
# A. Tính toán chỉ số AP trên từng category: Sắp xếp các Prediction Boxes của một category theo điểm số xác suất giảm dần. Thực hiện matching các Prediction Box với Ground Truth Box sao cho nếu IoU > 0.5 thì được xem là positive và trái lại là negative. Nếu Positive thì Precision sẽ có tử và mẫu cùng tăng lên 1 trong khi Recall có tử số tăng lên 1. Nếu Negative thì Precision có tử giữ nguyên và mẫu tăng lên 1 trong khi Recall không thay đổi. mAP bằng trung bình AP của toàn bộ các category.
#
# B. Tính toán chỉ số AP trên từng category: Sắp xếp các Prediction Boxes của một category theo điểm số xác suất giảm dần. Thực hiện matching các Prediction Box với Ground Truth Box sao cho nếu IoU > 0.5 thì được xem là positive và trái lại là negative. Nếu Positive thì Precision sẽ có tử số tăng lên 1 và mẫu giữ nguyên trong khi Recall có tử số tăng lên 1. Nếu Negative thì Precision có tử giữ nguyên và mẫu tăng lên 1 trong khi Recall không thay đổi. mAP bằng trung bình AP của toàn bộ các category.
#
# C. Tính toán chỉ số AP trên từng category: Sắp xếp các Prediction Boxes của một category theo điểm số xác suất giảm dần. Thực hiện matching các Prediction Box với Ground Truth Box sao cho nếu IoU > 0.5 thì được xem là positive và trái lại là negative. Nếu Positive thì Precision sẽ có tử và mẫu cùng tăng lên 1 trong khi Recall có tử giữ nguyên lên 1. Nếu Negative thì Precision có tử giữ nguyên và mẫu tăng lên 1 trong khi Recall không thay đổi. mAP bằng trung bình AP của toàn bộ các category.
#
# D. Tính toán chỉ số AP trên từng category: Sắp xếp các Prediction Boxes của một category theo điểm số xác suất giảm dần. Thực hiện matching các Prediction Box với Ground Truth Box sao cho nếu IoU > 0.5 thì được xem là positive và trái lại là negative. Nếu Positive thì Precision sẽ có tử và mẫu cùng tăng lên 1 trong khi Recall có tử số tăng lên 1. Nếu Negative thì Precision có tử giữ nguyên và mẫu tăng lên 1 trong khi Recall không thay đổi. Tính AP = diện tích dưới đường cong Precion Recall. mAP bằng trung bình AP của toàn bộ các category.
#
# => Đáp án D
#
# 3) Phương pháp Non Max Suppression sẽ làm gì để giảm thiểu số lượng các bounding box ?
#
# A. Dựa vào mức độ overlapping giữa các bounding box để loại bỏ những bounding box có mức độ chồng lấn nhau lớn.
#
# B. Dựa vào mức độ overlapping giữa các bounding box để loại bỏ những bounding box có mức độ chồng lấn nhau nhỏ.
#
# C. Dựa vào diện tích để loại bỏ các bounding box nhỏ dưới một ngưỡng cho trước.
#
# D. Dựa vào mức độ overlapping để giữ lại một bounding box có điểm số cao hơn nếu chúng chồng lấn nhau lớn.
#
# => Đáp án D
#
# 4) Trong mô hình Faster R-CNN chúng ta thêm một nhánh mạng RPN có tác dụng gì?
#
# A. Dự báo ra các vùng Region of Interest có khả năng cao chứa vật thể.
#
# B. Dự báo xác xuất cho toàn bộ các pixel nằm trên feature map.
#
# C. Dự báo bounding box và nhãn cho các vùng Region of Interest có khả năng cao chứa vật thể.
#
# D. Điều chỉnh lại kích thước của các bounding box từ anchor box.
#
# => Đáp án A
#
# 5) Anchor Box là gì?
#
# A. Là những hình chữ nhật giúp xác định vị trí của vật thể
#
# B. Là những hình chữ nhật với kích thước xác định trước gắn liền với một pixel để làm cơ sở điều chỉnh phần bù (offset) của các tọa độ nhằm dự báo bounding box.
#
# C. Là những hình chữ nhật phác thảo hình dạng của bounding box cần dự báo.
#
# D. Là hình chữ nhật gắn liền với một pixel để làm cơ sở dự báo bounding box.
#
# => Đáp án B

# %% [markdown]
# # II. Thực hành
#
# Các câu bên dưới qui ước chung bounding box đều có tọa độ là (x, y, w, h) lần lượt tương ứng với (x, y) là điểm top-left và (w, h) là kích thước chiều rộng và cao.
#
# 6) Xây dựng hàm tính toán IoU giữa hai bounding box.
#
# 7) Giả sử các bounding box dự báo cho một category có tọa độ lần lượt là:
#
# [10, 10, 50, 20], [15, 15, 55, 25], [50, 20, 20, 25], [20, 50, 20, 50], [30, 20, 10, 10]
#
# Các bounding box ground truth lần lượt là:
#
# [10, 10, 45, 25], [45, 20, 20, 25], [30, 25, 10, 10]
#
# Hãy thực hiện vẽ đường cong Precision Recall curve và xây dựng thuật toán tính giá trị AP.
#
# 8) Thực hiện visualize các anchor box có tỷ lệ aspect ratio (tỷ lệ width/height) lần lượt là 1, 2, 1/2 trên một feature map kích thước 20 x 20
#
# 9) Từ bộ dữ liệu [Vinbigdata-chest-xray](https://www.kaggle.com/c/vinbigdata-chest-xray-abnormalities-detection/data) bao gồm các tọa độ bounding box của 14 nhãn của các loại bệnh khác nhau được chuẩn đoán trên ảnh chụp chest X-ray. Thực hiện biến đổi file dữ liệu train.csv sang định dạng COCO json format. Chi tiết mô tả về dữ liệu bạn đọc ở tab data link trên.
#
# 10) Hãy xây dựng thuật toán object detection để  hỗ trợ bác sĩ chuẩn đoán bệnh. Để không phải download dữ liệu, bạn nên run một notebook trên kaggle và trích dẫn link sang bài làm của bạn.

# %% [markdown]
# ##6. Xây dựng hàm IoU

# %%
# bounding box 1 has coordinate of (x1, y1, w1, h1)
# bounding box 2 has coordinate of (x2, y2, w2, h2)
def iou_calculation(box1,box2):
  area1 = box1[2]*box1[3]
  area2 = box2[2]*box2[3]
  # area of intersection
  x3 = max(box1[0],box2[0])
  y3 = max(box1[1],box2[1]) 
  x4 = min(box1[0]+box1[2],box2[0]+box2[2])
  y4 = min(box1[1]+box1[3],box2[1]+box2[3])
  w = max(0,x4-x3)
  h = max(0,y4-y3)
  inter_area = w*h
  # union of intersection
  union_area = area1 + area2 - inter_area
  # IoU
  IoU = inter_area / union_area
  return IoU

# %% [markdown]
# ##7. Vẽ Precision Recall curve và xây dựng thuật toán tính giá trị AP.

# %%
 # Choose the iou threshold = 0.5 
 iou_calculation([10, 10, 50, 20], [10, 10, 45, 25])
# Out:
# 0.7346938775510204

# %%
iou_calculation([15, 15, 55, 25], [30, 25, 10, 10])
# Out:
# 0.07272727272727272

# %%
iou_calculation([50, 20, 20, 25], [45, 20, 20, 25])
# Out:
# 0.6

# %%
iou_calculation([20, 50, 20, 50], [30, 25, 10, 10])
# Out:
# 0.0

# %%
iou_calculation([30, 20, 10, 10], [30, 25, 10, 10])
# Out:
# 0.3333333333333333

# %%
precisions = [1/1, 1/2, 2/3, 2/4, 2/5]
recalls = [1/3, 1/3, 2/3, 2/3, 2/3]

# %%
import matplotlib.pyplot as plt
plt.plot(recalls, precisions, 'ro-')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision Recall Curve')
# Out:
# Text(0.5, 1.0, 'Precision Recall Curve')

# %%
# Compute AP value
def AP_computing(re,pre):
  re.insert(0,0.0)
  re.append(1.0)
  mre = re[:]
  pre.insert(0,0.0)
  pre.append(0.0)
  mpre = pre[:]
  for i in range(len(mpre)-2,0,-1):
    mpre[i] = max(mpre[i], mpre[i+1])

  i_list = []
  for i in range(1,len(mre),1):
    if mre[i] != mre[i-1]:
      i_list.append(i)
  
  ap = 0.0
  for i in i_list:
    ap += ((mre[i]-mre[i-1])*mpre[i])
  return print('AP value is: ', ap)

# %%
AP_computing(recalls,precisions)
# Out:
# AP value is:  0.5555555555555556

# %% [markdown]
# ## 8. Visualize các anchor box có tỷ lệ aspect ratio (tỷ lệ width/height) lần lượt là 1, 2, 1/2 trên một feature map kích thước 20 x 20

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np

# %%
img = cv2.imread('/content/drive/MyDrive/test/test/000004.jpg')
img = cv2.resize(img,(512,512))
plt.imshow(img)

# %%
# Visualize
r = img.shape[0]//20
anchors = [[1,1], [1,2], [2,1]]
for anchor in anchors:
  w = anchor[0]*5
  h = anchor[1]*5
  start_point = (int((5-w/2+0.5)*r),int((5-h/2+0.5)*r))
  end_point = (int((5+w/2+0.5)*r),int((5+h/2+0.5)*r))
  thickness = 2
  color = (255, 0, 0)
  anchor_img = cv2.rectangle(img,start_point,end_point,color,thickness)
plt.imshow(anchor_img)

# %% [markdown]
# ## 9. Biến đổi file dữ liệu train.csv sang định dạng COCO json format

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/train.csv')
df
# Out:
#                                image_id          class_name  class_id rad_id  \
# 0      50a418190bc3fb1ef1633bf9678929b3          No finding        14    R11
# 1      21a10246a5ec7af151081d0cd6d65dc9          No finding        14     R7
# 2      9a5094b2563a1ef3ff50dc5c7ff71345        Cardiomegaly         3    R10
# 3      051132a778e61a86eb147c7c6f564dfe  Aortic enlargement         0    R10
# 4      063319de25ce7edb9b1c6b8881290140          No finding        14    R10
# ...                                 ...                 ...       ...    ...
# 67909  936fd5cff1c058d39817a08f58b72cae          No finding        14     R1
# 67910  ca7e72954550eeb610fe22bf0244b7fa          No finding        14     R1
# 67911  aa17d5312a0fb4a2939436abca7f9579          No finding        14     R8
# 67912  4b56bc6d22b192f075f13231419dfcc8        Cardiomegaly         3     R8
# 67913  5e272e3adbdaafb07a7e84a9e62b1a4c          No finding        14    R16
#
#         x_min   y_min   x_max   y_max
# 0         NaN     NaN     NaN     NaN
# 1         NaN     NaN     NaN     NaN
# 2       691.0  1375.0  1653.0  1831.0
# 3      1264.0   743.0  1611.0  1019.0
# 4         NaN     NaN     NaN     NaN
# ...       ...     ...     ...     ...
# 67909     NaN     NaN     NaN     NaN
# 67910     NaN     NaN     NaN     NaN
# 67911     NaN     NaN     NaN     NaN
# 67912   771.0   979.0  1680.0  1311.0
# 67913     NaN     NaN     NaN     NaN
#
# [67914 rows x 8 columns]

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
import numpy as np
import json
import pandas as pd

path = '/content/drive/MyDrive/train.csv' # the path to the CSV file
save_json_path = 'traincoco.json'

data = pd.read_csv(path)

images = []
categories = []
annotations = []

category = {}
category["supercategory"] = 'none'
category["id"] = 0
category["name"] = 'None'
categories.append(category)

data['annid'] = data.index

def image(row):
    image = {}
    image["height"] = 'NaN'
    image["width"] = 'NaN'
    image["id"] = row.image_id
    image["class_name"] = row.class_name
    return image

def category(row):
    category = {}
    category["supercategory"] = 'None'
    category["id"] = row.class_id
    category["name"] = row.class_name
    return category

def annotation(row):
    annotation = {}
    area = (row.x_max -row.x_min)*(row.y_max - row.y_min)
    annotation["segmentation"] = []
    annotation["iscrowd"] = 0
    annotation["area"] = area
    annotation["image_id"] = row.image_id

    annotation["bbox"] = [row.x_min, row.y_min, row.x_max -row.x_min,row.y_max-row.y_min]

    annotation["category_id"] = row.class_id
    annotation["id"] = row.annid
    return annotation

for row in data.itertuples():
    annotations.append(annotation(row))

imagedf = data.drop_duplicates(subset=['image_id']).sort_values(by='image_id')
for row in imagedf.itertuples():
    images.append(image(row))

catdf = data.drop_duplicates(subset=['class_id']).sort_values(by='class_id')
for row in catdf.itertuples():
    categories.append(category(row))

data_coco = {}
data_coco["images"] = images
data_coco["categories"] = categories
data_coco["annotations"] = annotations


json.dump(data_coco, open(save_json_path, "w"), indent=4)

# %%
print('Converting CSV file to COCO json format successfully !')
# Out:
# Converting CSV file to COCO json format successfully !

# %%
data_coco
# Out:
# Converting CSV file to COCO json format successfully !
# {'annotations': [{'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 0,
#    'image_id': '50a418190bc3fb1ef1633bf9678929b3',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 1,
#    'image_id': '21a10246a5ec7af151081d0cd6d65dc9',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 438672.0,
#    'bbox': [691.0, 1375.0, 962.0, 456.0],
#    'category_id': 3,
#    'id': 2,
#    'image_id': '9a5094b2563a1ef3ff50dc5c7ff71345',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 95772.0,
#    'bbox': [1264.0, 743.0, 347.0, 276.0],
#    'category_id': 0,
#    'id': 3,
#    'image_id': '051132a778e61a86eb147c7c6f564dfe',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 4,
#    'image_id': '063319de25ce7edb9b1c6b8881290140',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 24320.0,
#    'bbox': [627.0, 357.0, 320.0, 76.0],
#    'category_id': 11,
#    'id': 5,
#    'image_id': '1c32170b4af4ce1a3030eb8167753b06',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 1618084.0,
#    'bbox': [1347.0, 245.0, 841.0, 1924.0],
#    'category_id': 5,
#    'id': 6,
#    'image_id': '0c7a38f293d5f5e4846aa4ca6db4daf1',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 15576.0,
#    'bbox': [557.0, 2352.0, 118.0, 132.0],
#    'category_id': 8,
#    'id': 7,
#    'image_id': '47ed17dcb2cbeec15182ed335a8b5a9e',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 41280.0,
#    'bbox': [1329.0, 743.0, 192.0, 215.0],
#    'category_id': 0,
#    'id': 8,
#    'image_id': 'd3637a1935a905b3c326af31389cb846',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 115401.0,
#    'bbox': [1857.0, 1607.0, 269.0, 429.0],
#    'category_id': 13,
#    'id': 9,
#    'image_id': 'afb6230703512afc370f236e8fe98806',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 57873.0,
#    'bbox': [600.0, 1332.0, 303.0, 191.0],
#    'category_id': 7,
#    'id': 10,
#    'image_id': '7c1add6833d5f0102b0d3619a1682a64',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 154440.0,
#    'bbox': [393.0, 283.0, 429.0, 360.0],
#    'category_id': 13,
#    'id': 11,
#    'image_id': '18a61a07e6f5f13ebfee57fa36cd8b6f',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 12,
#    'image_id': '5550a493b1c4554da469a072fdfab974',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 13,
#    'image_id': '869f39afbdd8783b531530942eda8bad',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 46435.0,
#    'bbox': [1292.0, 554.0, 185.0, 251.0],
#    'category_id': 0,
#    'id': 14,
#    'image_id': '321c111713c3ee5385db0effb54ff568',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 15,
#    'image_id': 'f55460fccf2d3c591f57f9c0de2c37c2',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 16,
#    'image_id': 'cdbacab6bf30170ef0ba9fd1d195d270',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 2003859.0,
#    'bbox': [331.0, 462.0, 1053.0, 1903.0],
#    'category_id': 1,
#    'id': 17,
#    'image_id': '80caa435b6ab5edaff4a0a758ffaec6e',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 163954.0,
#    'bbox': [1635.0, 673.0, 343.0, 478.0],
#    'category_id': 0,
#    'id': 18,
#    'image_id': '5da264775732004f1b724b660138854a',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 64410.0,
#    'bbox': [1390.0, 878.0, 226.0, 285.0],
#    'category_id': 0,
#    'id': 19,
#    'image_id': 'fb8e11c6b2886b2d41b379e0598669b9',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 413168.0,
#    'bbox': [1044.0, 1579.0, 1054.0, 392.0],
#    'category_id': 3,
#    'id': 20,
#    'image_id': '0622cd29e4e0e4f198abf15614819ae8',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 21,
#    'image_id': 'c6e0ab2470d98a6a8c701e774df929cc',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 16576.0,
#    'bbox': [1155.0, 204.0, 259.0, 64.0],
#    'category_id': 11,
#    'id': 22,
#    'image_id': '347180362348e522905047dde655b6d7',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 23,
#    'image_id': '5e56b7582a7cb3616e69cf95cb544a17',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 24,
#    'image_id': 'fc06d54844aee54acd87466f59acfc5b',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 25,
#    'image_id': '5ce53167cb33fa63c59af857d7236416',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 26,
#    'image_id': '63d5b6f568f005932b9246bcb40eee68',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 86881.0,
#    'bbox': [615.0, 800.0, 283.0, 307.0],
#    'category_id': 13,
#    'id': 27,
#    'image_id': '22b8e616a61bbc4caaed0cf23b7159df',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 28,
#    'image_id': '9b85b7ef757927db44393d03083a757c',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 29,
#    'image_id': 'fdd5c663764c4f333a42250ad5a67790',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 30,
#    'image_id': 'b911c2fdb0b80d9c7214a859aced0a8a',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 364146.0,
#    'bbox': [0.0, 839.0, 274.0, 1329.0],
#    'category_id': 9,
#    'id': 31,
#    'image_id': 'c394eadea89e5795c8037280492d116d',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 32,
#    'image_id': '5d03f4c2d353a2ddfdc4ba932e5b1029',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 33,
#    'image_id': '42d472bdda3ad93dac63c8e5e29977bb',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 34,
#    'image_id': '2b1293d9c276e5439e499f58ce2e31ab',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 35,
#    'image_id': 'e4b12e030788bbd71f7ad72fa1ee5a71',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 82935.0,
#    'bbox': [2233.0, 1536.0, 285.0, 291.0],
#    'category_id': 7,
#    'id': 36,
#    'image_id': 'be1bb194dfb986bf7554b491852b8901',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 510374.0,
#    'bbox': [1768.0, 1137.0, 578.0, 883.0],
#    'category_id': 6,
#    'id': 37,
#    'image_id': 'd7aea6f37597df566725da73655edcc2',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 38,
#    'image_id': 'a2a8eb578628cb2c353e6b6dc311de5c',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 615672.0,
#    'bbox': [1898.0, 850.0, 503.0, 1224.0],
#    'category_id': 9,
#    'id': 39,
#    'image_id': '8ae85268313b0db2f58d2193aab645c9',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 2914.0,
#    'bbox': [376.0, 1867.0, 62.0, 47.0],
#    'category_id': 8,
#    'id': 40,
#    'image_id': '8e063eadea9a6aeb684c893c8598be3e',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 601839.0,
#    'bbox': [655.0, 1188.0, 699.0, 861.0],
#    'category_id': 10,
#    'id': 41,
#    'image_id': '04bb8bd7ee6f88a16623fe5c6dd4da91',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 918791.0,
#    'bbox': [1656.0, 1510.0, 907.0, 1013.0],
#    'category_id': 10,
#    'id': 42,
#    'image_id': 'bd6eb525438d6da1ced0ed1810857772',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 628667.0,
#    'bbox': [1109.0, 1552.0, 1307.0, 481.0],
#    'category_id': 3,
#    'id': 43,
#    'image_id': '4016b176eaf40d514b0559a0aeb48f21',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 44,
#    'image_id': 'ad2367bde2706f692c2e1a1d12c492b9',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 488030.0,
#    'bbox': [707.0, 1316.0, 1319.0, 370.0],
#    'category_id': 3,
#    'id': 45,
#    'image_id': '25f2c7b53a6ed09a9aaf73c30357aaf6',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 46,
#    'image_id': 'd86c7405606f965ab7300ef1eacbcacc',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 391956.0,
#    'bbox': [862.0, 1829.0, 1101.0, 356.0],
#    'category_id': 3,
#    'id': 47,
#    'image_id': '18ee9ef3baea468de2087e0edd85e919',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 32955.0,
#    'bbox': [132.0, 1870.0, 169.0, 195.0],
#    'category_id': 11,
#    'id': 48,
#    'image_id': '7eda1e28e4cee7d8016276c87b76259f',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 49,
#    'image_id': '77c3750fdc5ae970693a6d7080ef702c',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 50,
#    'image_id': 'd35342287accb789782fee0e4a8b1031',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 72094.0,
#    'bbox': [531.0, 938.0, 319.0, 226.0],
#    'category_id': 7,
#    'id': 51,
#    'image_id': 'abb91bdaa9d02f50bde1eaa88e13afab',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 52785.0,
#    'bbox': [1148.0, 491.0, 207.0, 255.0],
#    'category_id': 0,
#    'id': 52,
#    'image_id': '98d44861c84d532bcca874fcde5e5f42',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 98952.0,
#    'bbox': [1433.0, 792.0, 266.0, 372.0],
#    'category_id': 0,
#    'id': 53,
#    'image_id': '222b7757f55bee221e7aba69fc9928d0',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 54,
#    'image_id': '73a4407a2df891526e94ba4541023f49',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 27729.0,
#    'bbox': [1909.0, 1696.0, 117.0, 237.0],
#    'category_id': 10,
#    'id': 55,
#    'image_id': '9b9f47628be6a48ddb41aec8ba39b454',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 2754.0,
#    'bbox': [796.0, 1078.0, 54.0, 51.0],
#    'category_id': 8,
#    'id': 56,
#    'image_id': 'd106ec9b305178f3da060efe3191499a',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 57,
#    'image_id': '9fbeb619ac9a406375ef5d6447227b5b',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 58,
#    'image_id': '82bc4f8652641af7cf061ab4b6ead271',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 218832.0,
#    'bbox': [1202.0, 1090.0, 388.0, 564.0],
#    'category_id': 8,
#    'id': 59,
#    'image_id': 'f32ab457c492c30221d3a89fe7c6b25a',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 137880.0,
#    'bbox': [1250.0, 643.0, 383.0, 360.0],
#    'category_id': 0,
#    'id': 60,
#    'image_id': 'b9f09915187c2cc01e958da90d97ac89',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 287060.0,
#    'bbox': [895.0, 1285.0, 926.0, 310.0],
#    'category_id': 3,
#    'id': 61,
#    'image_id': 'f769eea17a2e7678f481f386c3c6261c',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 62,
#    'image_id': 'cc9b6ee01a01702434ad789eef9432fb',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 514025.0,
#    'bbox': [1455.0, 1360.0, 709.0, 725.0],
#    'category_id': 10,
#    'id': 63,
#    'image_id': '6900482a91a538ead56b483f77bcf289',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 64,
#    'image_id': 'e3ac18fd134bcb699760db4ef362e14f',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 65,
#    'image_id': '2561ba15f063a8e3a0322ad943738bb5',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 9680.0,
#    'bbox': [2123.0, 922.0, 110.0, 88.0],
#    'category_id': 8,
#    'id': 66,
#    'image_id': 'a3f5ac68c8d1b1805be21f18c47fc186',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 67,
#    'image_id': '764205f702d380f8a4da5cffa538f48d',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 117729.0,
#    'bbox': [1142.0, 738.0, 309.0, 381.0],
#    'category_id': 0,
#    'id': 68,
#    'image_id': '0cfae3f740f87ca3b96dec765d06fad0',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 315980.0,
#    'bbox': [593.0, 1597.0, 518.0, 610.0],
#    'category_id': 5,
#    'id': 69,
#    'image_id': '0a14aeaf02d42990d8bb5d55270b7274',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 105794.0,
#    'bbox': [1293.0, 748.0, 338.0, 313.0],
#    'category_id': 0,
#    'id': 70,
#    'image_id': 'aa3535cb70d8142fdbdac165de546a8c',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 20224.0,
#    'bbox': [692.0, 860.0, 158.0, 128.0],
#    'category_id': 13,
#    'id': 71,
#    'image_id': '75de97fbdf15aa3e1927a97ff9479327',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 72,
#    'image_id': '59979178089975839bbc17e5cb88faf2',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 1168000.0,
#    'bbox': [876.0, 1810.0, 1460.0, 800.0],
#    'category_id': 3,
#    'id': 73,
#    'image_id': 'ebf4ffbcf6de699bf9deab70f0dee8ff',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 113770.0,
#    'bbox': [1244.0, 522.0, 367.0, 310.0],
#    'category_id': 6,
#    'id': 74,
#    'image_id': 'd77ef79ee4580a65dcb1e0e26b91d017',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 480912.0,
#    'bbox': [1544.0, 962.0, 466.0, 1032.0],
#    'category_id': 0,
#    'id': 75,
#    'image_id': 'bb315b4bc113c0506a9e24593cb06a6b',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 45080.0,
#    'bbox': [1468.0, 1616.0, 230.0, 196.0],
#    'category_id': 8,
#    'id': 76,
#    'image_id': '9598f874069cca35ff56d54925d35ccb',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 77,
#    'image_id': '0890c2d68d17561848b25c61fb1da200',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 78,
#    'image_id': '0ec928d72a4d206fe1b87ab683171004',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 48094.0,
#    'bbox': [1972.0, 401.0, 278.0, 173.0],
#    'category_id': 11,
#    'id': 79,
#    'image_id': 'b42e930c16c0166dbeae813b47bb8b07',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 218152.0,
#    'bbox': [1426.0, 916.0, 407.0, 536.0],
#    'category_id': 0,
#    'id': 80,
#    'image_id': '5bf3368744630f459a499ccdccc9cdf1',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 83381.0,
#    'bbox': [598.0, 318.0, 419.0, 199.0],
#    'category_id': 11,
#    'id': 81,
#    'image_id': 'def03f80d3b78a52a6f9af13565343ff',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 750.0,
#    'bbox': [378.0, 899.0, 25.0, 30.0],
#    'category_id': 8,
#    'id': 82,
#    'image_id': 'd07557904cbe57fc1bdebac1e8aeefa1',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 60996.0,
#    'bbox': [15.0, 1731.0, 221.0, 276.0],
#    'category_id': 10,
#    'id': 83,
#    'image_id': 'b48d6f9b38b698b6ac534ec7ded5c4e8',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 50600.0,
#    'bbox': [1519.0, 933.0, 253.0, 200.0],
#    'category_id': 13,
#    'id': 84,
#    'image_id': 'b3cc453518cf826875edcd3d5778ee87',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 85,
#    'image_id': 'b76a2de0cd2d3a9625e7df015ccf3816',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 86,
#    'image_id': '2d8289dc0a35bc2c7d3b0afb4d0c25fb',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 87,
#    'image_id': '20294a6c521b2ffc8ee2e7e1cac1fc50',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 88,
#    'image_id': 'b5a0555e2c623c355901601a907c6342',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 215600.0,
#    'bbox': [709.0, 2037.0, 392.0, 550.0],
#    'category_id': 9,
#    'id': 89,
#    'image_id': '5a0fbc7c40ea94bef4c8342d47c05b26',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 90,
#    'image_id': 'b31653be8e7a18487acbed2f8260c5ef',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 91,
#    'image_id': '2b73e82661e82f7c15c3ddaa15926d35',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 92,
#    'image_id': '7b6c00f300b0aa2c2c2bd0b51edea43a',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 32430.0,
#    'bbox': [285.0, 1986.0, 138.0, 235.0],
#    'category_id': 10,
#    'id': 93,
#    'image_id': '28d769becacfbdeebab6d3fda7322cf7',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 94,
#    'image_id': '890c7efc23b2a23439c301dca707c33f',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 223929.0,
#    'bbox': [2154.0, 855.0, 537.0, 417.0],
#    'category_id': 13,
#    'id': 95,
#    'image_id': '37233691ba64ed88b4e05882d7e41d61',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 96,
#    'image_id': '69f5d29210d98df18120534adb990291',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 97,
#    'image_id': '189e409214f5a4639d821a34064d9140',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 98553.0,
#    'bbox': [1333.0, 757.0, 273.0, 361.0],
#    'category_id': 0,
#    'id': 98,
#    'image_id': 'c5c36ce7f8adbd045bfe59a325eeae47',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 133320.0,
#    'bbox': [1378.0, 756.0, 303.0, 440.0],
#    'category_id': 0,
#    'id': 99,
#    'image_id': 'a84c5a7adea6bbde88dc2ac6747ca443',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 29478.0,
#    'bbox': [1144.0, 338.0, 289.0, 102.0],
#    'category_id': 11,
#    'id': 100,
#    'image_id': '2d063af5457785f5c76ae1e6c06c0037',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 101,
#    'image_id': 'c438d1ff72b5848adb7a063ebc90cd12',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 102,
#    'image_id': 'abdc33338a055571bf9fae0f09eb0bd5',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 103,
#    'image_id': 'd40b35c2f594b89524c67af46ac342f6',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 335124.0,
#    'bbox': [439.0, 1810.0, 522.0, 642.0],
#    'category_id': 6,
#    'id': 104,
#    'image_id': 'eb6c714df22142229464c6b83e47d7d6',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 105,
#    'image_id': '6ec4a6b5d3180220d6debf958d147c25',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 47526.0,
#    'bbox': [583.0, 696.0, 267.0, 178.0],
#    'category_id': 13,
#    'id': 106,
#    'image_id': '56923ac65e4a3bf6e8ec0af530c4a205',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 16506.0,
#    'bbox': [1015.0, 432.0, 262.0, 63.0],
#    'category_id': 11,
#    'id': 107,
#    'image_id': '231a4b73de5ac7e0218f736b6b6ff1f2',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 108,
#    'image_id': 'c113ff68c59ef8d40cd4c0bd6e021a6e',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 2150.0,
#    'bbox': [969.0, 950.0, 43.0, 50.0],
#    'category_id': 2,
#    'id': 109,
#    'image_id': '2e285b95faad220e17e6cbfbe514733e',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 110,
#    'image_id': '469999b0e3acee129f96aceaa99eba0d',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 111,
#    'image_id': '5e9fc4e951e8048c756407f2044e11b4',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 18216.0,
#    'bbox': [568.0, 1067.0, 198.0, 92.0],
#    'category_id': 13,
#    'id': 112,
#    'image_id': '8cc5ee4cf5c697d98d7c85951aa4f8d7',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 27360.0,
#    'bbox': [2275.0, 2715.0, 152.0, 180.0],
#    'category_id': 10,
#    'id': 113,
#    'image_id': '999612f847684578b1fdcf2d9d4d4994',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 114,
#    'image_id': '436c7165593cde9087c4b4cce3a9fe0c',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 115,
#    'image_id': '9f9d3d28dce21c8666f9eeb04af69040',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 358280.0,
#    'bbox': [1472.0, 1526.0, 520.0, 689.0],
#    'category_id': 4,
#    'id': 116,
#    'image_id': 'bd3fe876153eeddad8bab49b129ea081',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 117,
#    'image_id': '0d6acec8422b6fb8e214f770a1ff7d2d',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 13965.0,
#    'bbox': [1661.0, 568.0, 105.0, 133.0],
#    'category_id': 8,
#    'id': 118,
#    'image_id': '604340ab6423f81a91ac72182163e9a4',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 119,
#    'image_id': '9ff7d07078bc454c9261e29ecf89f55a',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 57150.0,
#    'bbox': [1381.0, 749.0, 225.0, 254.0],
#    'category_id': 0,
#    'id': 120,
#    'image_id': '723f93a3f0e3905c498839d23b961631',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 335891.0,
#    'bbox': [1365.0, 977.0, 383.0, 877.0],
#    'category_id': 5,
#    'id': 121,
#    'image_id': 'bdd0bebed953f69413213d387c9717e7',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 122,
#    'image_id': 'f04c6687c5179de2c61c1dd4ae20c758',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 122177.0,
#    'bbox': [857.0, 1143.0, 383.0, 319.0],
#    'category_id': 13,
#    'id': 123,
#    'image_id': '1ee956f957e7b9ec0787e07fe2b76135',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 124,
#    'image_id': 'f16f3e2e2b4edc07e2ce6b7c490fb025',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 151638.0,
#    'bbox': [1124.0, 945.0, 398.0, 381.0],
#    'category_id': 0,
#    'id': 125,
#    'image_id': '89e6ab133f587191383608ee04cea79a',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 126,
#    'image_id': 'cc98da13c817495f32b5ccab2b009cd3',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 127,
#    'image_id': '6f71690bf34f0ebf5b14c1ad0ffea243',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 128,
#    'image_id': 'd334ba0862d6d00b86cac697698a5fca',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 78810.0,
#    'bbox': [1185.0, 787.0, 222.0, 355.0],
#    'category_id': 0,
#    'id': 129,
#    'image_id': '34e932d09ab7cbec0edaaf188dc8a407',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 228690.0,
#    'bbox': [841.0, 510.0, 605.0, 378.0],
#    'category_id': 0,
#    'id': 130,
#    'image_id': '51a8d7259a0a6deac20b7c4979a7e847',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 131,
#    'image_id': '1edd41fbc11831eeb7b70e45bc91214d',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 71820.0,
#    'bbox': [679.0, 843.0, 189.0, 380.0],
#    'category_id': 9,
#    'id': 132,
#    'image_id': '42c049fd05428f7d606e9da4a95a8c3b',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 491260.0,
#    'bbox': [1248.0, 1392.0, 1210.0, 406.0],
#    'category_id': 3,
#    'id': 133,
#    'image_id': '33403064ce25caa5fda270e6158c6b03',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 96104.0,
#    'bbox': [467.0, 1125.0, 328.0, 293.0],
#    'category_id': 13,
#    'id': 134,
#    'image_id': 'f90442f2620175fa21b6afeda865df11',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 135,
#    'image_id': '5576d293dfccbc926d92d3ec0d20b9af',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 92664.0,
#    'bbox': [1397.0, 849.0, 264.0, 351.0],
#    'category_id': 0,
#    'id': 136,
#    'image_id': 'fa4c38b3c5e53e1e84bd0923f2d8e480',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 154880.0,
#    'bbox': [1431.0, 1373.0, 605.0, 256.0],
#    'category_id': 13,
#    'id': 137,
#    'image_id': 'bc2be005526db7ab9d5ec6741ddee945',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 11792.0,
#    'bbox': [118.0, 1928.0, 88.0, 134.0],
#    'category_id': 10,
#    'id': 138,
#    'image_id': 'a4fc9faa46af26c5fc462772d88d0af3',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 18212.0,
#    'bbox': [1726.0, 1143.0, 116.0, 157.0],
#    'category_id': 11,
#    'id': 139,
#    'image_id': '4b56bc6d22b192f075f13231419dfcc8',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 140,
#    'image_id': '32f643fbd7e99181193edf3720888743',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 408680.0,
#    'bbox': [910.0, 1854.0, 1202.0, 340.0],
#    'category_id': 3,
#    'id': 141,
#    'image_id': 'f1be25d4ee46f32d585fd6c809c92329',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 41888.0,
#    'bbox': [386.0, 672.0, 224.0, 187.0],
#    'category_id': 13,
#    'id': 142,
#    'image_id': '23f267e42a7e9f496aa143fe11f241ff',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 926136.0,
#    'bbox': [793.0, 1233.0, 1368.0, 677.0],
#    'category_id': 3,
#    'id': 143,
#    'image_id': 'b80be20a79e5a7539bd00f4907b444b2',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 144,
#    'image_id': '43d334915f96e4cd350534dd47173791',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 77274.0,
#    'bbox': [1206.0, 724.0, 243.0, 318.0],
#    'category_id': 0,
#    'id': 145,
#    'image_id': '389f167c16b70e1eb1aa219fedc373b7',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 262584.0,
#    'bbox': [404.0, 1550.0, 521.0, 504.0],
#    'category_id': 7,
#    'id': 146,
#    'image_id': 'd47efdd2527ed1646f31bec6dcbbcdc1',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 125760.0,
#    'bbox': [991.0, 435.0, 160.0, 786.0],
#    'category_id': 9,
#    'id': 147,
#    'image_id': '53d0c95f346e365f81fb95c5c6a6d027',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 148,
#    'image_id': 'b06682799382cfff3e10529b11f93490',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 149,
#    'image_id': '14783d2f57f9c689d827892bbe112cb8',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 150,
#    'image_id': '389526ec796c3955a9a89a66f04bc247',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 151,
#    'image_id': '565f761092a0cbc6f85c8195de091343',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 136452.0,
#    'bbox': [1244.0, 739.0, 332.0, 411.0],
#    'category_id': 0,
#    'id': 152,
#    'image_id': '9c83d9f88170cd38f7bca54fe27dc48a',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 153,
#    'image_id': 'e38e7ca1d5326e8212c188887cec3ef6',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 307818.0,
#    'bbox': [1533.0, 1113.0, 349.0, 882.0],
#    'category_id': 7,
#    'id': 154,
#    'image_id': 'ab730707fed0edaf38a9b788b226b9f2',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 2460.0,
#    'bbox': [1220.0, 346.0, 82.0, 30.0],
#    'category_id': 11,
#    'id': 155,
#    'image_id': '31901b2d1d2eb92c235f47f498b907c0',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 156,
#    'image_id': '0a695a94168b32705b91779586c6b2e7',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 231693.0,
#    'bbox': [881.0, 546.0, 231.0, 1003.0],
#    'category_id': 9,
#    'id': 157,
#    'image_id': 'ba46dcb445340df33566b52d7192ab6e',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 12474.0,
#    'bbox': [589.0, 2050.0, 81.0, 154.0],
#    'category_id': 11,
#    'id': 158,
#    'image_id': '3a9cdb601e0845a3e6b45c808fb75bc4',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 91694.0,
#    'bbox': [2357.0, 329.0, 254.0, 361.0],
#    'category_id': 9,
#    'id': 159,
#    'image_id': 'c41d4f698ccccbf7068c44c8c14f4e16',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 160,
#    'image_id': 'eaf829bee4a01226020af0b13daa49d3',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 14125.0,
#    'bbox': [706.0, 291.0, 125.0, 113.0],
#    'category_id': 13,
#    'id': 161,
#    'image_id': 'b57e21ea64ba9736e0711bdbbe53c221',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 349050.0,
#    'bbox': [611.0, 1305.0, 975.0, 358.0],
#    'category_id': 3,
#    'id': 162,
#    'image_id': 'fc217b20fc08dbe61924444274fb1c92',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 163,
#    'image_id': '9d35317bc33f38271a0d6df1b9a9f470',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 164,
#    'image_id': '62eaa7c251280aa3c31139ea3f81f391',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 883581.0,
#    'bbox': [752.0, 540.0, 769.0, 1149.0],
#    'category_id': 0,
#    'id': 165,
#    'image_id': 'b73e16e580992f545e375c2d3d6f7387',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 166,
#    'image_id': '56a0fef52403bf8a7bfb6ce0500e8da4',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 167,
#    'image_id': '102a115e13edadc89540c060affec761',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 168,
#    'image_id': '88d218de86341304f817a7fb7a6e2fc1',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 103680.0,
#    'bbox': [862.0, 513.0, 480.0, 216.0],
#    'category_id': 11,
#    'id': 169,
#    'image_id': '4a46cdf01cee2a200f00daedf11576a9',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 97755.0,
#    'bbox': [1724.0, 771.0, 285.0, 343.0],
#    'category_id': 0,
#    'id': 170,
#    'image_id': 'd54f205e3f01d2ead98f02fc1bd4c164',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 40920.0,
#    'bbox': [108.0, 1810.0, 132.0, 310.0],
#    'category_id': 11,
#    'id': 171,
#    'image_id': '82624b37dc4d0169f3fe6fd87dcb5208',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 42846.0,
#    'bbox': [1481.0, 875.0, 193.0, 222.0],
#    'category_id': 0,
#    'id': 172,
#    'image_id': '381e9c224c892d437f498779e349469e',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 2585.0,
#    'bbox': [2243.0, 1742.0, 47.0, 55.0],
#    'category_id': 8,
#    'id': 173,
#    'image_id': '2ad18a594cbaf3c6d6145a7775829554',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 4758.0,
#    'bbox': [713.0, 1634.0, 78.0, 61.0],
#    'category_id': 8,
#    'id': 174,
#    'image_id': '15c3fc505c414c69ba757cb3be3ed213',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 42174.0,
#    'bbox': [1073.0, 691.0, 198.0, 213.0],
#    'category_id': 0,
#    'id': 175,
#    'image_id': '2fd3d0e3b5de5535994ac58f2bd175da',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 176,
#    'image_id': '869e17be9aa482c5962a79762d403859',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 177,
#    'image_id': '5aa01ff5b1023118f8f0a880f1eb339f',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 178,
#    'image_id': '00dc70e84d141255f7fc6f8038bdd72e',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 179,
#    'image_id': '1b09f8963f072c7caf4ecc685910fb15',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 180,
#    'image_id': 'af5b3774027bc0def0cb71e87d5bc0a3',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 373262.0,
#    'bbox': [869.0, 1702.0, 967.0, 386.0],
#    'category_id': 3,
#    'id': 181,
#    'image_id': '1302aab3d9d19f6bcb9db728e3ce6306',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 23345.0,
#    'bbox': [237.0, 1998.0, 145.0, 161.0],
#    'category_id': 10,
#    'id': 182,
#    'image_id': 'b455c6067fa5e154a2c48ac187029022',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 268768.0,
#    'bbox': [852.0, 1108.0, 908.0, 296.0],
#    'category_id': 3,
#    'id': 183,
#    'image_id': '9a6ef2893ef45236c5eb1141db74c9aa',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 184,
#    'image_id': '08d0eab34ea5bab14e7e56dabafcdb7f',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 185,
#    'image_id': 'f4e913c031f50fa859d8c775cf716974',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 195780.0,
#    'bbox': [614.0, 475.0, 502.0, 390.0],
#    'category_id': 11,
#    'id': 186,
#    'image_id': '9246c1061217b8131ccdaea80327e24d',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 21158.0,
#    'bbox': [354.0, 2213.0, 142.0, 149.0],
#    'category_id': 10,
#    'id': 187,
#    'image_id': '5156d69e540648eb952371ec5c80bc81',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 415452.0,
#    'bbox': [761.0, 1570.0, 1068.0, 389.0],
#    'category_id': 3,
#    'id': 188,
#    'image_id': '1c1ef26e3b3323f74041f6dd2371cd24',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 424580.0,
#    'bbox': [1060.0, 1688.0, 1196.0, 355.0],
#    'category_id': 3,
#    'id': 189,
#    'image_id': 'b50d4c9c23a26b4391d508a5d6a32f7a',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 190,
#    'image_id': '4fca8a77e10e418e3851c65c0f42fc23',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 86080.0,
#    'bbox': [1078.0, 803.0, 269.0, 320.0],
#    'category_id': 0,
#    'id': 191,
#    'image_id': '07ac9545dcc585901865f7f958a7857d',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 192,
#    'image_id': '3e300793e970e7916c36a57fe350f688',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 193,
#    'image_id': '823feb835c8aea70c0ac4f9678d39879',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 553500.0,
#    'bbox': [1183.0, 1238.0, 1107.0, 500.0],
#    'category_id': 3,
#    'id': 194,
#    'image_id': 'b40a6f0ea09c4d305ef296e0d8b73cde',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 195,
#    'image_id': '19092706cfc4df42ae8f3302eb73bbd3',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 196,
#    'image_id': '7b28527cbbf8fdd46cae166b95e1bf64',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 197,
#    'image_id': '5c9b1df128d0506902cbed4462273b49',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 521559.0,
#    'bbox': [955.0, 2124.0, 1233.0, 423.0],
#    'category_id': 3,
#    'id': 198,
#    'image_id': '6833c509c10b569d6167db70b83ee5d5',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 199,
#    'image_id': 'a7bba955cdf410ec6da045191a8c056c',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 200,
#    'image_id': '012969950fbdd28bb50cfa447877cd4e',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 104700.0,
#    'bbox': [1526.0, 769.0, 300.0, 349.0],
#    'category_id': 0,
#    'id': 201,
#    'image_id': '00aca42a24e4ea6066cca2546150c36e',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 30738.0,
#    'bbox': [1915.0, 1177.0, 141.0, 218.0],
#    'category_id': 2,
#    'id': 202,
#    'image_id': 'db49c96665f4fe0ff5f4420578e2f185',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 4290.0,
#    'bbox': [1577.0, 1890.0, 65.0, 66.0],
#    'category_id': 8,
#    'id': 203,
#    'image_id': 'cca122e46a24a6ccfeba9ade9f7b933c',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 204,
#    'image_id': '6f693ffb135213d759427b3e0d26904e',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 205,
#    'image_id': '8626cbfd0205ec64b6fb89650aacabf0',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 206,
#    'image_id': '23ed5844d016867059889d56e64df1b9',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 207,
#    'image_id': '644ce5af82ecc76391728df8cd2bfb3d',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 208,
#    'image_id': 'ae46578e2d798368f43af12ffb20c976',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 414963.0,
#    'bbox': [759.0, 1589.0, 981.0, 423.0],
#    'category_id': 3,
#    'id': 209,
#    'image_id': '6a4f9965e83bfad45d66d4afa5d28cc5',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 210,
#    'image_id': '55522f91d2da99602696a2c6b0b5f42a',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 211,
#    'image_id': '9dd6f4b67f9e9c24acb0499a7d8812eb',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 166000.0,
#    'bbox': [1789.0, 533.0, 400.0, 415.0],
#    'category_id': 12,
#    'id': 212,
#    'image_id': '6e4391555899c8474c4d32f42b2ba21b',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 78624.0,
#    'bbox': [1351.0, 825.0, 273.0, 288.0],
#    'category_id': 0,
#    'id': 213,
#    'image_id': 'b770403a1d0ab861f1944f8b896afcae',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 214,
#    'image_id': '8da36a523c6b7ccc9f3589a4d129c96d',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 215,
#    'image_id': 'c0b8111730c30c21085c38b81f432aa9',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 216,
#    'image_id': '57249e369cd43410e8005dc512375ff0',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 11484.0,
#    'bbox': [496.0, 1495.0, 87.0, 132.0],
#    'category_id': 10,
#    'id': 217,
#    'image_id': '8036ddc6d564439af50497faef05eec3',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 42000.0,
#    'bbox': [1927.0, 1393.0, 105.0, 400.0],
#    'category_id': 9,
#    'id': 218,
#    'image_id': 'aa1ebd488f7f3cab0aa784073b0a9d70',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 69632.0,
#    'bbox': [981.0, 610.0, 272.0, 256.0],
#    'category_id': 11,
#    'id': 219,
#    'image_id': '014e3dd712dc90f61da7ce8747d8c4c0',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 21182.0,
#    'bbox': [1723.0, 2135.0, 119.0, 178.0],
#    'category_id': 11,
#    'id': 220,
#    'image_id': '76f366130d836a1ae9d12749d0150eb1',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 96250.0,
#    'bbox': [1173.0, 863.0, 275.0, 350.0],
#    'category_id': 0,
#    'id': 221,
#    'image_id': '6f322939176779d7af4f7c76701fa91d',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 335360.0,
#    'bbox': [594.0, 1595.0, 1048.0, 320.0],
#    'category_id': 3,
#    'id': 222,
#    'image_id': '3c98c90840a9290511ae8192107f8250',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 749738.0,
#    'bbox': [2085.0, 1308.0, 643.0, 1166.0],
#    'category_id': 10,
#    'id': 223,
#    'image_id': '6a956ce4e56235dd8de081a965a36c2a',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 224,
#    'image_id': '25ea0b3ba039f05031bd95927a978073',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 225,
#    'image_id': 'fe67a20679c1eed6e19ee55f776d0f6d',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 417226.0,
#    'bbox': [786.0, 1580.0, 919.0, 454.0],
#    'category_id': 3,
#    'id': 226,
#    'image_id': '511e8b50c9a7ecee4e1a8621f262e9ad',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 303160.0,
#    'bbox': [1051.0, 1577.0, 1144.0, 265.0],
#    'category_id': 3,
#    'id': 227,
#    'image_id': 'd61eb45d47ad48020286203b1f1362f8',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 228,
#    'image_id': '1ae368aaa68a19e19664f5f0648e863f',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 9048.0,
#    'bbox': [1635.0, 1002.0, 156.0, 58.0],
#    'category_id': 2,
#    'id': 229,
#    'image_id': '0a411e44ec67f3d5d80a5b3d5a3edca3',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 458850.0,
#    'bbox': [1279.0, 671.0, 570.0, 805.0],
#    'category_id': 0,
#    'id': 230,
#    'image_id': 'e685922feb4f7e397cd47ac418342071',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 525504.0,
#    'bbox': [689.0, 1358.0, 1088.0, 483.0],
#    'category_id': 3,
#    'id': 231,
#    'image_id': 'b73e16e580992f545e375c2d3d6f7387',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 5846.0,
#    'bbox': [2048.0, 673.0, 79.0, 74.0],
#    'category_id': 13,
#    'id': 232,
#    'image_id': '543c0591a8706112a0e71620509a398f',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 233,
#    'image_id': '253d35b7096d0957bd79cfb4b1c954e1',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 234,
#    'image_id': 'a751b16e4a8cfa7956561dea5bf0cbb3',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 235,
#    'image_id': '380b4b9ed2f96b1efe6af2687d808e33',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 236,
#    'image_id': 'c76f9bb22dfaa73cd8810e299cc0bd53',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 288119.0,
#    'bbox': [237.0, 1128.0, 481.0, 599.0],
#    'category_id': 8,
#    'id': 237,
#    'image_id': '3a302fbbbf3364aa1a7731b59e6b98ec',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 347060.0,
#    'bbox': [907.0, 1577.0, 1036.0, 335.0],
#    'category_id': 3,
#    'id': 238,
#    'image_id': '21992194880ed480bd0232be383b8268',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 302289.0,
#    'bbox': [1277.0, 1395.0, 1011.0, 299.0],
#    'category_id': 3,
#    'id': 239,
#    'image_id': '2c475d89c90a50567ba0cf5ddd62f68a',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 240,
#    'image_id': 'b131cff616a9379108b498f995025957',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 241,
#    'image_id': '9e83685b659621945abb3edbd792cf0b',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 242,
#    'image_id': '32a4977ad96250a4796f588b135d7067',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 48048.0,
#    'bbox': [821.0, 235.0, 286.0, 168.0],
#    'category_id': 11,
#    'id': 243,
#    'image_id': 'c5010a72f3e20e9b59d7bb991d3c633b',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 132300.0,
#    'bbox': [519.0, 528.0, 378.0, 350.0],
#    'category_id': 13,
#    'id': 244,
#    'image_id': '415f0f58066bad3d69bd5fac2c80574b',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 245,
#    'image_id': '850ef50fc6c7b3e33e34fc5f283086c3',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 52891.0,
#    'bbox': [1148.0, 814.0, 233.0, 227.0],
#    'category_id': 0,
#    'id': 246,
#    'image_id': '969d075666dedd66f4c1c6ad0b1e7052',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 247,
#    'image_id': '44fd18e81fd09c367a5a9651d3e61ee4',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 248,
#    'image_id': '535bc2dc2e6af4fa80186254f4d8b0f4',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 46311.0,
#    'bbox': [789.0, 301.0, 359.0, 129.0],
#    'category_id': 11,
#    'id': 249,
#    'image_id': '0abd4fc2425edd5c2efb2c149e9319c6',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 83520.0,
#    'bbox': [957.0, 1174.0, 290.0, 288.0],
#    'category_id': 0,
#    'id': 250,
#    'image_id': 'a824f7f43552c3af8d846dd1cc0f0c11',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 23450.0,
#    'bbox': [1006.0, 773.0, 175.0, 134.0],
#    'category_id': 0,
#    'id': 251,
#    'image_id': '7043451da60cb89537435829965759c3',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 359118.0,
#    'bbox': [1289.0, 497.0, 562.0, 639.0],
#    'category_id': 9,
#    'id': 252,
#    'image_id': '872fcda56bcda425012eef3cbf6ebf95',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 94864.0,
#    'bbox': [1624.0, 1236.0, 242.0, 392.0],
#    'category_id': 7,
#    'id': 253,
#    'image_id': 'd015e02257639b55b196e26820e10081',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 254,
#    'image_id': 'f929582316eea29fe0b7a4701347d0bb',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 92140.0,
#    'bbox': [965.0, 662.0, 271.0, 340.0],
#    'category_id': 0,
#    'id': 255,
#    'image_id': '5c31e0c3f7beb95833196c55509dc127',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 256,
#    'image_id': '1bb7079ab131dd4c4151b2a6838538bd',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 257,
#    'image_id': 'c2c3e9e459681d13dc94b916a3689de4',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 258,
#    'image_id': '7686dfb913f7e7bfdcd9cf85e7946d28',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': nan,
#    'bbox': [nan, nan, nan, nan],
#    'category_id': 14,
#    'id': 259,
#    'image_id': '67fbbda75755440dbea348c3fd5d1e2d',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 102784.0,
#    'bbox': [593.0, 855.0, 352.0, 292.0],
#    'category_id': 7,
#    'id': 260,
#    'image_id': '352ab0683046ce107942e9e477007b72',
#    'iscrowd': 0,
#    'segmentation': []},
#   {'area': 90960.0,
# ...
#    'height': 'NaN',
#    'id': '0ee9cd1ab91572c302f60669056aa3f2',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0eeff8568b00af202ecfd1adb1028f76',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0ef13359541e4c9886d255ade0a95aba',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0ef876519b3f362667b32a91c1bc997b',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0eff8de4b1964a09bc67fc2dcdd233d5',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f028c151463fe718bdc384a9a8a0209',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f03e1f69371e5c554e2cbd56d52fa23',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f08bc7ac92a1678c2c3307c181580e7',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f0aebf828076b819da84cf9e3b4b59c',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f0d638b06992220e2adbbe574bc3c99',
#    'width': 'NaN'},
#   {'class_name': 'Lung Opacity',
#    'height': 'NaN',
#    'id': '0f186e3eba8d9ebd51feed957204ddbf',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f1d4b4d710b982a1786054c5357f427',
#    'width': 'NaN'},
#   {'class_name': 'Cardiomegaly',
#    'height': 'NaN',
#    'id': '0f1eba57237922d0f9ec0dee62793435',
#    'width': 'NaN'},
#   {'class_name': 'Cardiomegaly',
#    'height': 'NaN',
#    'id': '0f26e889539ff64afd23927ee40436b8',
#    'width': 'NaN'},
#   {'class_name': 'Aortic enlargement',
#    'height': 'NaN',
#    'id': '0f27846dfa86e51c27db5fe4ea5a52ad',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f27e4b742995aef46336c6c408f842a',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f34355eca9e6fb0fabab21711f0a2ec',
#    'width': 'NaN'},
#   {'class_name': 'Nodule/Mass',
#    'height': 'NaN',
#    'id': '0f389422bffe0f96dc3da175550e0c5b',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f3b0c1a84dad0b7dcb76973836c0618',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f3b6a40134f9192e47ca830e9ee317b',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f40c3c2b03230017b246e09bc8aa455',
#    'width': 'NaN'},
#   {'class_name': 'Cardiomegaly',
#    'height': 'NaN',
#    'id': '0f45742c4d100eeee221f8853d79c9d4',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f48cb3124f7e8c3a849f120c36dcda5',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f492b0760a2c4894f9f34c5e99837d5',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f4f55a6f4ee73564de09ab3ecfe77a3',
#    'width': 'NaN'},
#   {'class_name': 'Nodule/Mass',
#    'height': 'NaN',
#    'id': '0f4fd2b86df83111f83444ee90edbea1',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f50af01ab50e9bbfc0365b7541f9fb4',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f517bc215689e9cb1533ee2209bc0ea',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f5d4ad2f835ff55264f9b9ea6db827f',
#    'width': 'NaN'},
#   {'class_name': 'Aortic enlargement',
#    'height': 'NaN',
#    'id': '0f5f23a027345ba0f0a63f1eca460b0c',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f60923f18f4faefedce426bf207621a',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f74b308c0c28cbf2bd49ff4a8a68dbd',
#    'width': 'NaN'},
#   {'class_name': 'Cardiomegaly',
#    'height': 'NaN',
#    'id': '0f76d35a022a7188cad9a83e283fdc8f',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f7ab20fb85469481df0c23360fac949',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f7fb15a86f8ada0c84933a6523f22d3',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f80dbcaeb8424d1ade057857e621e04',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f814da049ccab4171ed331c749f0eb9',
#    'width': 'NaN'},
#   {'class_name': 'Pleural effusion',
#    'height': 'NaN',
#    'id': '0f81902a673f0d826b55ea9dc9da297b',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f841fcf5b68b1fbda85e6dcdcb3c4fd',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f8a78e1090c840b4455772fe92d7586',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f8b02f3b044159efc833bcb01d477f6',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f91c90caeb1104e32750f538f729331',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0f93eb9cff59e441d5f41792181fae97',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0fa3a43de5d5204d9be82a1969c1b6c8',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0fa549b115a4c943bd8bac3974f5e2ad',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0fa646e920286af9f1496ca1e7b5c8be',
#    'width': 'NaN'},
#   {'class_name': 'Aortic enlargement',
#    'height': 'NaN',
#    'id': '0fafbbfb67745f8c29351f9f7263b82f',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0fb17f7ef84cea21569bbcb3fbdd9032',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0fb6d9a425117670ba7c249b35523434',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0fb9235fdd9d442cb03f221a12e67d04',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0fc090ef0e517dd49fccac8ba9524b2e',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0fc0f4210dcff423c932da548b73d8fa',
#    'width': 'NaN'},
#   {'class_name': 'Calcification',
#    'height': 'NaN',
#    'id': '0fca086ebe001f784d428aa9973ba691',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0fcb5f06dba5a03b16df46dc966a3996',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0fd2b97a8922f5adb6ffc5ef5a7de5d2',
#    'width': 'NaN'},
#   {'class_name': 'Pleural thickening',
#    'height': 'NaN',
#    'id': '0fd981034f74251d4a5d72891940d585',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0fd9a013a22a1527f8814702fbb62149',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0fd9b262a5d0490716641cde0a167eaa',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0fdba5b4298773f488709251e49b26a2',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0fdd9e832730bf843067512577cf31cd',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0fde596e9d333383384858c74e80b4ff',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '0ff665352a064500b5ad8feee653a48d',
#    'width': 'NaN'},
#   {'class_name': 'Aortic enlargement',
#    'height': 'NaN',
#    'id': '0ffa24230f7064bcdb313507dce02ae3',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10058b093368fbcf159b0ff8eff23692',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '1011ae892025e8bc5cd3686ba304f5a1',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10137d91f76a4457acf44e15fa3ddc71',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '101462261ea1428181e14ed048dcf5e9',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '1019251f7cf5b19559ea93c212428bdb',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '101d984c4172312c93efdd42e37e203b',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '101dd0689c22255c9dafaa937283caf3',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '101f2420808891cab10b4b2f0c1d2875',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '102341f3585d122b732b94d7281d98ef',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '1025d5d08103bc7d79d1853d368b42e8',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '102a115e13edadc89540c060affec761',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '102c6818153a5df4c097033ff758ef21',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '102cbcda64728d1f29cab99f4614e141',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '1032d2676b0d91406a3b7ec5438f77e7',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10387d064935914e96534db4f8625a6b',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '1038d42bccd9b51c786f23fa24aec9e0',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10391940445815818da5bf094b4a8cb5',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '103b82bef40be1f5f109bf5d9768030f',
#    'width': 'NaN'},
#   {'class_name': 'Aortic enlargement',
#    'height': 'NaN',
#    'id': '103fb193578933a2d53ae31ff0fc3319',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '1042eb8ffeadf2c7f54f7e776a449b05',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10481bbf2c17d9d41683301f92a9c26d',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '104860ff1aa7436fb5cf53175e39d427',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '1049692f29ed7540074d4b0b623cae6e',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10498c5c45827c22489639065f90d70b',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '1049b2ea72618fc2406996e0d869d317',
#    'width': 'NaN'},
#   {'class_name': 'Lung Opacity',
#    'height': 'NaN',
#    'id': '104b915269077619e2b3bbf641506327',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '104d4e165637f627df4040652d2b40e8',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '105810a967e0610034f957f3c3ceceb7',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '105a6ffa3024a21b53f0dc40a35b23b1',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '105a734d1de02e6681c11743d5da094f',
#    'width': 'NaN'},
#   {'class_name': 'Pleural thickening',
#    'height': 'NaN',
#    'id': '105c3102661ee24684dc180a32dc7119',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '105f9fe36756b114e8cf80558cffec15',
#    'width': 'NaN'},
#   {'class_name': 'Cardiomegaly',
#    'height': 'NaN',
#    'id': '1060e455b64eea9e29ca4a3e05b47557',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '106110eb5e2871e4d1aa45d9ef8ef277',
#    'width': 'NaN'},
#   {'class_name': 'Nodule/Mass',
#    'height': 'NaN',
#    'id': '1066a058b5bae597f2dbb33780c2577d',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '1067fc1a24a63bbc6de0c2d31b141e3f',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10686e7ea44bdd90fb5c73759ce2ae8f',
#    'width': 'NaN'},
#   {'class_name': 'Atelectasis',
#    'height': 'NaN',
#    'id': '106a3da41d2e3d9f508c09b28e8abdaf',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '106f429f6701dbf750e07d6746082995',
#    'width': 'NaN'},
#   {'class_name': 'Cardiomegaly',
#    'height': 'NaN',
#    'id': '1070b419b62a9b7b1a8e71cd9504ffb8',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '107161d70e8adfb758fe9afcd854b387',
#    'width': 'NaN'},
#   {'class_name': 'Pleural effusion',
#    'height': 'NaN',
#    'id': '1071b3b85121012c5061894bf3b8704b',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '1072da8bf618f814cf7cc3068410d82a',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '1075dde8870f9418d888dcb90c568172',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '1075e57aefb1b18d57f274a66a43c682',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '107b954f19deca54c77c6bbeafb7ca2d',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '107d6440fa2c7799ba5de06fd8a996e7',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '107d7671377160a4a5d708849ed5d331',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '1080bdf43ca7ca09d585bb32301f61cc',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '108216287b3eabf0f407e6fd8f5e4e4d',
#    'width': 'NaN'},
#   {'class_name': 'Aortic enlargement',
#    'height': 'NaN',
#    'id': '1085585ceaf60941fd14db7ad3bb2f49',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '1088f189daf4ad7593e680fcff81e6ca',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10898f48f4d75139b29732592f307e88',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '109905458873872aa344241bfbd1a86d',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '109a5db6641f01cb8199508aa8fa0a93',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10a9deeff36b74a822157517ded59b66',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10ab779d6ca517c05e324e6386218974',
#    'width': 'NaN'},
#   {'class_name': 'Pleural thickening',
#    'height': 'NaN',
#    'id': '10ab7eaa1ef08dea7a899cc893564838',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10ad2392bd8169775aea678815bdc0ce',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10b414d8343ab3a51cba5d5f84986ec4',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10c2c095faefa7a57e1869682ccfb033',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10c3f0fd6aa8692d67b5796f78a6b827',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10c4ce27df80f3551ec62c7bf2272008',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10cc041e1091e152559dd5affd6c708f',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10d100f6b480361b2b5c9e1ce4f4f9f2',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10d147dc17cedd31c86cc0a33815a1b7',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10ddfd44af9ff919ef88218b88211151',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10e27c80d083c9c43c2c95984c8e2dfd',
#    'width': 'NaN'},
#   {'class_name': 'Other lesion',
#    'height': 'NaN',
#    'id': '10e7dac260f11046164aa94f2d8add9f',
#    'width': 'NaN'},
#   {'class_name': 'Pleural thickening',
#    'height': 'NaN',
#    'id': '10e8248185760938d4cae1f0462af88a',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10eee9c43ac039dd0d0514d2e0f1eba0',
#    'width': 'NaN'},
#   {'class_name': 'Other lesion',
#    'height': 'NaN',
#    'id': '10f28558b1667b3d30d9e4c44f7a5bc6',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10f8f81191e4116a4b9715bce27f4638',
#    'width': 'NaN'},
#   {'class_name': 'No finding',
#    'height': 'NaN',
#    'id': '10fa1e4bf25d6d057c88210c3a1fc645',
#    'width': 'NaN'},
#   ...]}

# %% [markdown]
# ## 10. Xây dựng thuật toán object detection để hỗ trợ bác sĩ chuẩn đoán bệnh
