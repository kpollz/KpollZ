# %% [markdown]
# # 1. Example

# %% [markdown]
# # 2. Practice

# %% [markdown]
# Từ bộ dữ liệu về `Dog and Cat` được cung cấp tại [Dog and Cat](https://github.com/ardamavi/Dog-Cat-Classifier/tree/master/Data/Train_Data). Bạn hãy tạo một iterator dataset sao cho trước khi lấy ra một bức ảnh thì sẽ thực hiện một số phép biến đổi như rotate, horizontal flip, random crop,....
