# %% [markdown]
# # 1. Data Structure
#
# Cho một dictionary gồm tên và điểm số.

# %%
points = {'an': 9, 'binh': 7, 'khanh': 8, 'linh': 10, 'huyen': 6}

# %% [markdown]
# 1. Hãy sắp xếp dictionary trên theo điểm số tăng dần.
# 2. Hãy tạo một dictionary có key là điểm số và giá trị là tên.
#
# Tiếp theo, cho một list như sau:

# %%
target = ['vi', 'mot', 'cong', 'dong', 'AI', 'vung', 'vung', 'manh', 'manh', 'hon']

# %% [markdown]
# 3. Tìm các giá trị duy nhất của list đó.
# 4. Đếm số lần lặp lại của mỗi phần tử trong list.
# 5. Tạo ra một list mới mà nếu phần tử đó đã xuất hiện trong list rồi thì chỉ lấy duy nhất giá trị bắt gặp đầu tiên.

# %% [markdown]
# Cho một đoạn văn bản như sau:

# %%
'Machine Learning Algorithms to Practice là một cuốn sách cân bằng giữa lý thuyết và thực hành'

# %% [markdown]
# 6. Hãy phân chia câu văn trên thành một list mà mỗi một từ trong câu là một phần tử của list.
# 7. Đảo ngược vị trí các từ trong list vừa tạo được.
#
# Tiếp theo, tính các giá trị sau:
# 8. Giá trị: $n! = 1\times 2 \times 3 \dots \times n$
# 9. Tích của các số chẵn liên tiếp nhỏ hơn $n$.
# 10. Tích của các số lẻ liên tiếp nhỏ hơn $n$.

# %% [markdown]
# # 2. Class and Module
#
# 1. Hãy xây dựng một class AI với hai thuộc tính là algorithm (tên thuật toán) và model_type (dạng thuật toán dự báo hay phân loại) trong hàm tạo (_constructor_).
#
# 2. Viết thêm hai phương thức cho class AI là `fit` (huấn luyện) với đầu vào là các tham số `model, X_train, y_train` và `predict` (dự báo) với đầu vào là các tham số `model, X_pred`. (Không cần phải lấy dữ liệu thật, chỉ cần print ra các đối số bên trong mỗi hàm).
#
# 3. Khởi tạo object cho class AI và gọi các hàm phương thức vừa thêm mới trong câu lệnh `if __name__ == '__main__'`.
#
# 4. Xây dựng một class DeepLearning kế thừa từ AI. Trong class này có một hàm mở rộng là `train_on_epoch` (huấn luyện trên từng epoch) với đầu vào là `model, X_train, y_train, epoch` và hàm viết đè là `fit` có thêm tham số `learning_rate`.
#
# 5. Tổ chức project thành các module, những module này gồm các files:
# - `model.py`: chứa class `DeepLearning` và class `AI`.
# - `dataset.py`: chứa class `Dataset`, tự xây dựng hàm tạo cho class này với hai thuộc tính là `input_datas` và `labels`.
# - `train.py`: import hai class là `DeepLearning` và `Dataset` từ hai module `model.py` và `dataset.py`, khởi tạo các object của hai class này và sử dụng các hàm phương thức của nó.

# %% [markdown]
# # 3. Matrix and vector

# %% [markdown]
# ## 3.1. Practice
#
# Một vài bài tập dưới đây sẽ giúp bạn ôn lại kiến thức tốt hơn. Bạn thực hành bài tập trên đồng thời pytorch và tensorflow.
#
# 1. Khởi tạo một số vô hướng, một véc tơ có độ dài là $3$ và một ma trận bất kỳ có kích thước là $2\times 3$.
# 2. Tính tích giữa véc tơ và ma trận.
# 3. Tính tổng các dòng và tổng các cột của ma trận.
# 4. Tính chuẩn bậc 2 của véc tơ.
# 5. Reshape lại kích thước của véc tơ thành ma trận có số dòng là 1.
#
# **Phần giải bài tập trên pytorch:**

# %% [markdown]
# **Phần giải bài tập trên tensorflow:**

# %% [markdown]
# ## 3.2. Theory

# %% [markdown]
# 6. Chứng minh rằng nếu $\mathbf{A}$ là một ma trận vuông thì $\mathbf{A} + \mathbf{A}^{\top}$ là một ma trận đối xứng.
# 7. Cho $\mathbf{A}, \mathbf{B}, \mathbf{C}$ là ba ma trận có kích thước lần lượt là $m \times n$, $n \times p$ và $p \times q$ chứng minh rằng $\mathbf{ABC} = (\mathbf{A}\mathbf{B})\mathbf{C} = \mathbf{A}(\mathbf{B}\mathbf{C})$
# 8. $\mathbf{trace}$ của ma trận là tổng các phần tử nằm trên đường chéo chính ( phần tử mà có index dòng bằng cột). Chứng minh rằng: $\mathbf{trace(AB) = trace(BA)}$
# 9. Chứng minh: $\mathbf{A} \odot \mathbf{(B+C)} = \mathbf{A} \odot \mathbf{B} + \mathbf{A} \odot \mathbf{C}$
# 10. Chứng minh: $\mathbf{A} \odot (\mathbf{B} \odot \mathbf{C})= (\mathbf{A} \odot \mathbf{B}) \odot \mathbf{C}$
