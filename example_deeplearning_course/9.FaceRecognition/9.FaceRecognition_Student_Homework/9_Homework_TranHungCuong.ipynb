# %% [markdown]
# # I. Lý thuyết
#
# 1) Sự khác biệt chính giữa hai bài toán Face Recognition và Face Verification là gì ?
#
# A. Bài toán Face Recognition nhằm trả lời cho câu hỏi ảnh đầu vào là ai trong số K người và bài toán Face Verification nhằm xác thực ảnh đầu vào có phải là một người nào đó cụ thể hay không ?
#
# **B. Bài toán Face Verification nhằm trả lời cho câu hỏi ảnh đầu vào là ai trong số K người và bài toán Face Recognition nhằm xác thực ảnh đầu vào có phải là một người nào đó cụ thể hay không ?**
#
# C. Bài toán Face Recognition được sử dụng trong các ứng dụng mở khóa điện thoại, còn Face Verification được sử dụng trong chấm công.
#
# D. Bài toán Face Recognition và Face Verification là như nhau và có thể thay thế lẫn nhau.
#
# 2) Phương pháp one-shot learning có đặc điểm là gì ?
#
# **A. Đầu vào là một vài bức ảnh tương ứng với mỗi một người và xây dựng một mạng deep neural để phân loại các bức ảnh đó.**
#
# B. Dữ liệu đầu vào bao gồm các bức ảnh sao cho mỗi bức ảnh thuộc về một người và xây dựng một mạng deep neural để phân loại các bức ảnh đó.
#
# C. Mỗi người cố một số lượng ảnh đầu vào là bằng nhau và xây dựng một mạng deep neural để phân loại các bức ảnh đó.
#
# D. Dữ liệu đầu vào bao gồm các bức ảnh ngẫu nhiên chưa được gán nhãn thuộc về một nhóm người.
#
# 3) Nhận định nào sau đây về phương pháp huấn luyện Siamese Network là đúng?
#
# A. Luôn truyền vào một cặp ảnh thuộc về hai người khác nhau để học biểu diễn.
#
# B. Luôn truyền vào một cặp ảnh thuộc về cùng một người để học biểu diễn.
#
# C. Truyền vào hai ảnh input vào hai network khác nhau nhằm học các biểu diễn sao cho sẽ giống nhau nếu thuộc cùng một người và cách xa nhau nếu thuộc về hai người khác biệt.
#
# **D. Truyền vào một cặp ảnh input vào một mạng neural duy nhất nhằm học các biểu diễn sao cho sẽ giống nhau nếu thuộc cùng một người và cách xa nhau nếu thuộc về hai người khác biệt.**
#
# 4) Để tính toán sự khác biệt giữa hai véc tơ chúng ta có thể dùng hàm số dạng nào?
#
# A. Tích có hướng giữa hai véc tơ
#
# B. Tích inner product giữa hai véc tơ.
#
# C. Các hàm norm Lp (p < 1), hàm cosine-similarity
#
# **D. Các hàm norm Lp (p >= 1), hàm cosine-similarity**
#
# 5) Tại sao trong triplet loss chúng ta lại cần cộng thêm giá trị alpha vào bất phương trình?
#
# **A. Để gia tăng sự cách biệt giữa khoảng cách d(Anchor, Negative) so với  d(Anchor, Positive) ít nhất bằng alpha và tránh trường hợp học về chung một biểu diễn véc tơ duy nhất.**
#
# B. Để thu hẹp sự cách biệt giữa khoảng cách d(Anchor, Negative) so với  d(Anchor, Positive) ít nhất bằng alpha và tránh trường hợp học về chung một biểu diễn véc tơ duy nhất.
#
# C. Để gia tăng sự cách biệt giữa khoảng cách d(Anchor, Negative) so với  d(Anchor, Positive) ít nhất bằng alpha và tránh trường hợp học về chung một biểu diễn véc tơ 0.
#
# D. Để thu hẹp sự cách biệt giữa khoảng cách d(Anchor, Negative) so với  d(Anchor, Positive) ít nhất bằng alpha và tránh trường hợp học về chung một biểu diễn véc tơ 0.

# %% [markdown]
# # 1 A 2 B

# %% [markdown]
# # II. Thực hành
#
# ##6) Hãy đọc và tổng kết những ý chính trong paper [ArcFace: Additive Angular Margin Loss for Deep Face Recognition, CVPR 2019, Jiankang Deng et al](https://openaccess.thecvf.com/content_CVPR_2019/papers/Deng_ArcFace_Additive_Angular_Margin_Loss_for_Deep_Face_Recognition_CVPR_2019_paper.pdf)

# %% [markdown]
# Bài báo đề xuất cách tiếp cận dựa trên hàm lỗi mới: Additive Angular Margin Loss (ArcFace) to obtain highly discriminative features for face recognition.

# %% [markdown]
# Hàm loss function truyền thống
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Hàm loss cải tiến:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Mô hình đề xuất của ArcFace

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# So sánh giữa softmax và ArcFace
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Mô hình mới cho kết quả phân lớp tốt hơn (tách biệt giữa các khuôn mặt)

# %% [markdown]
# So sánh với một số hàm loss khác
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Kết quả thử nghiệm
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Từ bảng kết quả trên chứng tỏ rằng phương pháp ArcFace cho kết quả tốt hơn.

# %% [markdown]
# ##7) Hãy lựa chọn một bộ dữ liệu về face bất kì trên [kaggle](https://www.kaggle.com/search?q=Face+dataset) nhằm phục vụ xây dựng mô hình Face Recognition. Hãy thực hiện phân tích bộ dữ liệu bằng cách mô tả dữ liệu,  thống kê về dữ liệu, vẽ biểu đồ và đưa ra các nhận xét về bộ dữ liệu.
#
# ##8) Thuật toán Face Recognition sẽ tốt hơn nếu các ảnh đầu vào đã được crop về vùng chứa face.Sử dụng mô hình Rentinaface trong Face Detection, hãy crop face theo bouding box và resize về chung một kích thước 512x512. Sau đó lưu lại để làm dữ liệu huấn luyên mô hình Face Recognition.

# %%
from google.colab import drive
import os
drive.mount("/content/drive")
folder_path = "/content/drive/MyDrive/DLK1/Olivetti/"
os.chdir(folder_path)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data=np.load("olivetti_faces.npy")
target=np.load("olivetti_faces_target.npy")

# %%
print("There are {} images in the dataset".format(len(data)))
print("There are {} unique targets in the dataset".format(len(np.unique(target))))
print("Size of each image is {}x{}".format(data.shape[1],data.shape[2]))
print("Pixel values were scaled to [0,1] interval. e.g:{}".format(data[0][0,:4]))
# Out:
# There are 400 images in the dataset
# There are 40 unique targets in the dataset
# Size of each image is 64x64
# Pixel values were scaled to [0,1] interval. e.g:[0.30991736 0.3677686  0.41735536 0.44214877]

# %%
def show_40_distinct_people(images, unique_ids):
    #Creating 4X10 subplots in  18x9 figure size
    fig, axarr=plt.subplots(nrows=4, ncols=10, figsize=(18, 9))
    #For easy iteration flattened 4X10 subplots matrix to 40 array
    axarr=axarr.flatten()
    
    #iterating over user ids
    for unique_id in unique_ids:
        image_index=unique_id*10
        axarr[unique_id].imshow(images[image_index], cmap='gray')
        axarr[unique_id].set_xticks([])
        axarr[unique_id].set_yticks([])
        axarr[unique_id].set_title("face id:{}".format(unique_id))
    plt.suptitle("There are 40 distinct people in the dataset")

# %%
show_40_distinct_people(data, np.unique(target))

# %%
def show_10_faces_of_n_subject(images, subject_ids):
    cols=10# each subject has 10 distinct face images
    rows=(len(subject_ids)*10)/cols #
    rows=int(rows)
    
    fig, axarr=plt.subplots(nrows=rows, ncols=cols, figsize=(18,9))
    #axarr=axarr.flatten()
    
    for i, subject_id in enumerate(subject_ids):
        for j in range(cols):
            image_index=subject_id*10 + j
            axarr[i,j].imshow(images[image_index], cmap="gray")
            axarr[i,j].set_xticks([])
            axarr[i,j].set_yticks([])
            axarr[i,j].set_title("face id:{}".format(subject_id))

# %%
show_10_faces_of_n_subject(images=data, subject_ids=[0,5, 21, 24, 36])

# %%
from sklearn.model_selection import train_test_split

# %%
X=data.reshape((data.shape[0],data.shape[1]*data.shape[2]))
print("X shape:",X.shape)
# Out:
# X shape: (400, 4096)

# %%
X_train, X_test, y_train, y_test=train_test_split(X, target, test_size=0.3, stratify=target, random_state=0)
print("X_train shape:",X_train.shape)
print("y_train shape:{}".format(y_train.shape))
# Out:
# X_train shape: (280, 4096)
# y_train shape:(280,)

# %% [markdown]
# ##9) Hãy xây dựng một mô hình Face Recognition theo phương pháp few-shot learning.

# %%
# !git clone https://github.com/few-shot-learning/Keras-FewShotLearning.git
# %cd Keras-FewShotLearning
! curl -sSL https://raw.githubusercontent.com/python-poetry/poetry/master/get-poetry.py | python
! $HOME/.poetry/bin/poetry config virtualenvs.create false --local
! $HOME/.poetry/bin/poetry add protobuf==3.10.0  # Fix for colab version
! $HOME/.poetry/bin/poetry add gpumonitor  # Fix for colab version
# Out:
# Cloning into 'Keras-FewShotLearning'...
# remote: Enumerating objects: 1631, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 1631 (delta 25), reused 28 (delta 14), pack-reused 1574
# Receiving objects: 100% (1631/1631), 1.99 MiB | 2.34 MiB/s, done.
# Resolving deltas: 100% (947/947), done.
# /content/Keras-FewShotLearning
# Retrieving Poetry metadata
#
# This installer is deprecated. Poetry versions installed using this script will not be able to use 'self update' command to upgrade to 1.2.0a1 or later.
# # Welcome to Poetry!
#
# This will download and install the latest version of Poetry,
# a dependency and package manager for Python.
#
# It will add the `poetry` command to Poetry's bin directory, located at:
#
# $HOME/.poetry/bin
#
# This path will then be added to your `PATH` environment variable by
# modifying the profile file located at:
#
# $HOME/.profile
#
# You can uninstall at any time by executing this script with the --uninstall option,
# and these changes will be reverted.
#
# Installing version: 1.1.13
#   - Downloading poetry-1.1.13-linux.tar.gz (97.93MB)
#
# Poetry (1.1.13) is installed now. Great!
#
# To get started you need Poetry's bin directory ($HOME/.poetry/bin) in your `PATH`
# environment variable. Next time you log in this will be done
# automatically.
#
# To configure your current shell run `source $HOME/.poetry/env`
#
# Skipping virtualenv creation, as specified in config file.
#
# Updating dependencies
# Resolving dependencies... (222.0s)
#
# Writing lock file
#
# Package operations: 13 installs, 90 updates, 1 removal
#
#   • Removing atomicwrites (1.4.0): Pending...
#   • Removing atomicwrites (1.4.0): Removing...
#   • Removing atomicwrites (1.4.0)
#   • Updating zipp (3.7.0 -> 3.1.0): Pending...
#   • Updating zipp (3.7.0 -> 3.1.0): Downloading... 0%
#   • Updating zipp (3.7.0 -> 3.1.0): Downloading... 100%
#   • Updating zipp (3.7.0 -> 3.1.0): Downloading... 100%
#   • Updating zipp (3.7.0 -> 3.1.0): Installing...
#   • Updating zipp (3.7.0 -> 3.1.0)
#   • Updating attrs (21.4.0 -> 19.3.0): Pending...
#   • Updating importlib-metadata (4.11.3 -> 1.6.1): Pending...
#   • Updating parso (0.8.3 -> 0.7.0): Pending...
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Pending...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating importlib-metadata (4.11.3 -> 1.6.1): Pending...
#   • Updating parso (0.8.3 -> 0.7.0): Pending...
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Pending...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating attrs (21.4.0 -> 19.3.0): Downloading... 0%
#   • Updating importlib-metadata (4.11.3 -> 1.6.1): Pending...
#   • Updating parso (0.8.3 -> 0.7.0): Pending...
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Pending...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating importlib-metadata (4.11.3 -> 1.6.1): Pending...
#   • Updating parso (0.8.3 -> 0.7.0): Pending...
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Pending...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating attrs (21.4.0 -> 19.3.0): Downloading... 100%
#   • Updating importlib-metadata (4.11.3 -> 1.6.1): Pending...
#   • Updating parso (0.8.3 -> 0.7.0): Pending...
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Pending...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating importlib-metadata (4.11.3 -> 1.6.1): Pending...
#   • Updating parso (0.8.3 -> 0.7.0): Pending...
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Pending...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating attrs (21.4.0 -> 19.3.0): Downloading... 100%
#   • Updating importlib-metadata (4.11.3 -> 1.6.1): Pending...
#   • Updating parso (0.8.3 -> 0.7.0): Pending...
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Pending...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating importlib-metadata (4.11.3 -> 1.6.1): Pending...
#   • Updating parso (0.8.3 -> 0.7.0): Pending...
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Pending...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating attrs (21.4.0 -> 19.3.0): Installing...
#   • Updating importlib-metadata (4.11.3 -> 1.6.1): Pending...
#   • Updating parso (0.8.3 -> 0.7.0): Pending...
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Pending...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Downloading... 0%
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating parso (0.8.3 -> 0.7.0): Pending...
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Downloading... 0%
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating importlib-metadata (4.11.3 -> 1.6.1): Downloading... 0%
#   • Updating parso (0.8.3 -> 0.7.0): Pending...
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Downloading... 0%
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Downloading... 100%
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating parso (0.8.3 -> 0.7.0): Pending...
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Downloading... 100%
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating importlib-metadata (4.11.3 -> 1.6.1): Downloading... 100%
#   • Updating parso (0.8.3 -> 0.7.0): Pending...
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Downloading... 100%
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating parso (0.8.3 -> 0.7.0): Pending...
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Downloading... 100%
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating importlib-metadata (4.11.3 -> 1.6.1): Downloading... 100%
#   • Updating parso (0.8.3 -> 0.7.0): Pending...
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Downloading... 100%
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Downloading... 100%
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating parso (0.8.3 -> 0.7.0): Downloading... 0%
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Downloading... 100%
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Downloading... 100%
#   • Updating pyparsing (3.0.7 -> 2.4.7): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Downloading... 0%
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Pending...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Downloading... 0%
#   • Updating pyparsing (3.0.7 -> 2.4.7): Downloading... 0%
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Downloading... 0%
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Installing...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Downloading... 0%
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Downloading... 0%
#   • Updating parso (0.8.3 -> 0.7.0): Downloading... 0%
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Installing...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Downloading... 0%
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Downloading... 0%
#   • Updating importlib-metadata (4.11.3 -> 1.6.1): Installing...
#   • Updating parso (0.8.3 -> 0.7.0): Downloading... 0%
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Installing...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Downloading... 0%
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Downloading... 0%
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Downloading... 0%
#   • Updating pyparsing (3.0.7 -> 2.4.7): Downloading... 100%
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Downloading... 0%
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Downloading... 100%
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Downloading... 100%
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Installing...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Downloading... 100%
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Downloading... 100%
#   • Updating parso (0.8.3 -> 0.7.0): Downloading... 100%
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Installing...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Downloading... 100%
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Downloading... 100%
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Installing...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Downloading... 100%
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Downloading... 100%
#   • Updating parso (0.8.3 -> 0.7.0): Downloading... 100%
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Installing...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Downloading... 100%
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Downloading... 100%
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Installing...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Installing...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Downloading... 100%
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Installing...
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Installing...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Downloading... 100%
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Installing...
#   • Updating parso (0.8.3 -> 0.7.0): Installing...
#   • Updating ptyprocess (0.7.0 -> 0.6.0): Installing...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Downloading... 100%
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Installing...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Installing...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Installing...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Installing...
#   • Updating pyparsing (3.0.7 -> 2.4.7): Installing...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Installing...
#   • Updating ptyprocess (0.7.0 -> 0.6.0)
#   • Updating pyparsing (3.0.7 -> 2.4.7): Installing...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Installing...
#   • Updating traitlets (5.1.1 -> 4.3.3): Pending...
#   • Updating parso (0.8.3 -> 0.7.0): Installing...
#   • Updating ptyprocess (0.7.0 -> 0.6.0)
#   • Updating pyparsing (3.0.7 -> 2.4.7): Installing...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Installing...
#   • Updating traitlets (5.1.1 -> 4.3.3): Pending...
#   • Updating importlib-metadata (4.11.3 -> 1.6.1)
#   • Updating parso (0.8.3 -> 0.7.0): Installing...
#   • Updating ptyprocess (0.7.0 -> 0.6.0)
#   • Updating pyparsing (3.0.7 -> 2.4.7): Installing...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Installing...
#   • Updating traitlets (5.1.1 -> 4.3.3): Pending...
#   • Updating wcwidth (0.2.5 -> 0.2.4): Pending...
#   • Updating importlib-metadata (4.11.3 -> 1.6.1)
#   • Updating parso (0.8.3 -> 0.7.0): Installing...
#   • Updating ptyprocess (0.7.0 -> 0.6.0)
#   • Updating pyparsing (3.0.7 -> 2.4.7): Installing...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Installing...
#   • Updating traitlets (5.1.1 -> 4.3.3): Pending...
#   • Updating wcwidth (0.2.5 -> 0.2.4): Pending...
#   • Updating attrs (21.4.0 -> 19.3.0)
#   • Updating importlib-metadata (4.11.3 -> 1.6.1)
#   • Updating parso (0.8.3 -> 0.7.0): Installing...
#   • Updating ptyprocess (0.7.0 -> 0.6.0)
#   • Updating pyparsing (3.0.7 -> 2.4.7): Installing...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Installing...
#   • Updating traitlets (5.1.1 -> 4.3.3): Pending...
#   • Updating wcwidth (0.2.5 -> 0.2.4): Pending...
#   • Updating wcwidth (0.2.5 -> 0.2.4): Pending...
#   • Updating traitlets (5.1.1 -> 4.3.3): Downloading... 0%
#   • Updating wcwidth (0.2.5 -> 0.2.4): Pending...
#   • Updating wcwidth (0.2.5 -> 0.2.4): Pending...
#   • Updating traitlets (5.1.1 -> 4.3.3): Downloading... 100%
#   • Updating wcwidth (0.2.5 -> 0.2.4): Pending...
#   • Updating wcwidth (0.2.5 -> 0.2.4): Pending...
#   • Updating traitlets (5.1.1 -> 4.3.3): Downloading... 100%
#   • Updating wcwidth (0.2.5 -> 0.2.4): Pending...
#   • Updating wcwidth (0.2.5 -> 0.2.4): Pending...
#   • Updating traitlets (5.1.1 -> 4.3.3): Installing...
#   • Updating wcwidth (0.2.5 -> 0.2.4): Pending...
#   • Updating wcwidth (0.2.5 -> 0.2.4): Downloading... 0%
#   • Updating wcwidth (0.2.5 -> 0.2.4): Downloading... 100%
#   • Updating wcwidth (0.2.5 -> 0.2.4): Downloading... 100%
#   • Updating wcwidth (0.2.5 -> 0.2.4): Installing...
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Installing...
#   • Updating traitlets (5.1.1 -> 4.3.3): Installing...
#   • Updating wcwidth (0.2.5 -> 0.2.4): Installing...
#   • Updating pyparsing (3.0.7 -> 2.4.7)
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Installing...
#   • Updating traitlets (5.1.1 -> 4.3.3): Installing...
#   • Updating wcwidth (0.2.5 -> 0.2.4): Installing...
#   • Updating ptyprocess (0.7.0 -> 0.6.0)
#   • Updating pyparsing (3.0.7 -> 2.4.7)
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Installing...
#   • Updating traitlets (5.1.1 -> 4.3.3): Installing...
#   • Updating wcwidth (0.2.5 -> 0.2.4): Installing...
#   • Updating parso (0.8.3 -> 0.7.0)
#   • Updating ptyprocess (0.7.0 -> 0.6.0)
#   • Updating pyparsing (3.0.7 -> 2.4.7)
#   • Updating pyrsistent (0.18.1 -> 0.16.0): Installing...
#   • Updating traitlets (5.1.1 -> 4.3.3): Installing...
#   • Updating wcwidth (0.2.5 -> 0.2.4): Installing...
#   • Updating wcwidth (0.2.5 -> 0.2.4): Installing...
#   • Updating traitlets (5.1.1 -> 4.3.3)
#   • Updating wcwidth (0.2.5 -> 0.2.4): Installing...
#   • Updating wcwidth (0.2.5 -> 0.2.4)
#   • Updating traitlets (5.1.1 -> 4.3.3)
#   • Updating wcwidth (0.2.5 -> 0.2.4)
#   • Updating pyrsistent (0.18.1 -> 0.16.0)
#   • Updating traitlets (5.1.1 -> 4.3.3)
#   • Updating wcwidth (0.2.5 -> 0.2.4)
#   • Updating jedi (0.18.1 -> 0.17.0): Pending...
#   • Updating jsonschema (4.3.3 -> 3.2.0): Pending...
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Pending...
#   • Updating markupsafe (2.0.1 -> 1.1.1): Pending...
#   • Updating packaging (21.3 -> 20.4): Pending...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Pending...
#   • Updating markupsafe (2.0.1 -> 1.1.1): Pending...
#   • Updating packaging (21.3 -> 20.4): Pending...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Pending...
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Downloading... 0%
#   • Updating markupsafe (2.0.1 -> 1.1.1): Pending...
#   • Updating packaging (21.3 -> 20.4): Pending...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Pending...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Pending...
#   • Updating packaging (21.3 -> 20.4): Downloading... 0%
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Pending...
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Downloading... 0%
#   • Updating markupsafe (2.0.1 -> 1.1.1): Pending...
#   • Updating packaging (21.3 -> 20.4): Downloading... 0%
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Pending...
#   • Updating jsonschema (4.3.3 -> 3.2.0): Downloading... 0%
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Downloading... 0%
#   • Updating markupsafe (2.0.1 -> 1.1.1): Pending...
#   • Updating packaging (21.3 -> 20.4): Downloading... 0%
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Pending...
#   • Updating packaging (21.3 -> 20.4): Downloading... 0%
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Pending...
#   • Updating markupsafe (2.0.1 -> 1.1.1): Downloading... 0%
#   • Updating packaging (21.3 -> 20.4): Downloading... 0%
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Pending...
#   • Updating jsonschema (4.3.3 -> 3.2.0): Downloading... 0%
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Downloading... 0%
#   • Updating markupsafe (2.0.1 -> 1.1.1): Downloading... 0%
#   • Updating packaging (21.3 -> 20.4): Downloading... 0%
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Pending...
#   • Updating jedi (0.18.1 -> 0.17.0): Downloading... 0%
#   • Updating jsonschema (4.3.3 -> 3.2.0): Downloading... 0%
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Downloading... 0%
#   • Updating markupsafe (2.0.1 -> 1.1.1): Downloading... 0%
#   • Updating packaging (21.3 -> 20.4): Downloading... 0%
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Pending...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating packaging (21.3 -> 20.4): Downloading... 0%
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating markupsafe (2.0.1 -> 1.1.1): Downloading... 100%
#   • Updating packaging (21.3 -> 20.4): Downloading... 0%
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating packaging (21.3 -> 20.4): Downloading... 0%
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating markupsafe (2.0.1 -> 1.1.1): Downloading... 100%
#   • Updating packaging (21.3 -> 20.4): Downloading... 0%
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating packaging (21.3 -> 20.4): Downloading... 100%
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating packaging (21.3 -> 20.4): Downloading... 100%
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating packaging (21.3 -> 20.4): Downloading... 100%
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating markupsafe (2.0.1 -> 1.1.1): Installing...
#   • Updating packaging (21.3 -> 20.4): Downloading... 100%
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating packaging (21.3 -> 20.4): Installing...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Downloading... 0%
#   • Updating markupsafe (2.0.1 -> 1.1.1): Installing...
#   • Updating packaging (21.3 -> 20.4): Installing...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating jsonschema (4.3.3 -> 3.2.0): Downloading... 100%
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Downloading... 0%
#   • Updating markupsafe (2.0.1 -> 1.1.1): Installing...
#   • Updating packaging (21.3 -> 20.4): Installing...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating markupsafe (2.0.1 -> 1.1.1): Installing...
#   • Updating packaging (21.3 -> 20.4): Installing...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Downloading... 100%
#   • Updating markupsafe (2.0.1 -> 1.1.1): Installing...
#   • Updating packaging (21.3 -> 20.4): Installing...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating markupsafe (2.0.1 -> 1.1.1): Installing...
#   • Updating packaging (21.3 -> 20.4): Installing...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Downloading... 100%
#   • Updating markupsafe (2.0.1 -> 1.1.1): Installing...
#   • Updating packaging (21.3 -> 20.4): Installing...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Downloading... 100%
#   • Updating markupsafe (2.0.1 -> 1.1.1): Installing...
#   • Updating packaging (21.3 -> 20.4): Installing...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating jsonschema (4.3.3 -> 3.2.0): Downloading... 100%
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Downloading... 100%
#   • Updating markupsafe (2.0.1 -> 1.1.1): Installing...
#   • Updating packaging (21.3 -> 20.4): Installing...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating markupsafe (2.0.1 -> 1.1.1): Installing...
#   • Updating packaging (21.3 -> 20.4): Installing...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Installing...
#   • Updating markupsafe (2.0.1 -> 1.1.1): Installing...
#   • Updating packaging (21.3 -> 20.4): Installing...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Installing...
#   • Updating markupsafe (2.0.1 -> 1.1.1): Installing...
#   • Updating packaging (21.3 -> 20.4): Installing...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating jsonschema (4.3.3 -> 3.2.0): Installing...
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Installing...
#   • Updating markupsafe (2.0.1 -> 1.1.1): Installing...
#   • Updating packaging (21.3 -> 20.4): Installing...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 0%
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 100%
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Downloading... 100%
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Installing...
#   • Updating jsonschema (4.3.3 -> 3.2.0): Installing...
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Installing...
#   • Updating markupsafe (2.0.1 -> 1.1.1): Installing...
#   • Updating packaging (21.3 -> 20.4): Installing...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Installing...
#   • Updating jedi (0.18.1 -> 0.17.0): Downloading... 100%
#   • Updating jsonschema (4.3.3 -> 3.2.0): Installing...
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Installing...
#   • Updating markupsafe (2.0.1 -> 1.1.1): Installing...
#   • Updating packaging (21.3 -> 20.4): Installing...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Installing...
#   • Updating jsonschema (4.3.3 -> 3.2.0): Installing...
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Installing...
#   • Updating markupsafe (2.0.1 -> 1.1.1): Installing...
#   • Updating packaging (21.3 -> 20.4): Installing...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Installing...
#   • Updating jedi (0.18.1 -> 0.17.0): Downloading... 100%
#   • Updating jsonschema (4.3.3 -> 3.2.0): Installing...
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Installing...
#   • Updating markupsafe (2.0.1 -> 1.1.1): Installing...
#   • Updating packaging (21.3 -> 20.4): Installing...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Installing...
#   • Updating jsonschema (4.3.3 -> 3.2.0): Installing...
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Installing...
#   • Updating markupsafe (2.0.1 -> 1.1.1): Installing...
#   • Updating packaging (21.3 -> 20.4): Installing...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Installing...
#   • Updating jedi (0.18.1 -> 0.17.0): Installing...
#   • Updating jsonschema (4.3.3 -> 3.2.0): Installing...
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Installing...
#   • Updating markupsafe (2.0.1 -> 1.1.1): Installing...
#   • Updating packaging (21.3 -> 20.4): Installing...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Installing...
#   • Updating packaging (21.3 -> 20.4): Installing...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Installing...
#   • Updating markupsafe (2.0.1 -> 1.1.1)
#   • Updating packaging (21.3 -> 20.4): Installing...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Installing...
#   • Updating python-dateutil (2.8.2 -> 2.8.1): Pending...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Installing...
#   • Updating python-dateutil (2.8.2 -> 2.8.1): Pending...
#   • Updating packaging (21.3 -> 20.4)
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Installing...
#   • Updating python-dateutil (2.8.2 -> 2.8.1): Pending...
#   • Updating pyzmq (22.3.0 -> 19.0.1): Pending...
#   • Updating pyzmq (22.3.0 -> 19.0.1): Pending...
#   • Updating python-dateutil (2.8.2 -> 2.8.1): Downloading... 0%
#   • Updating pyzmq (22.3.0 -> 19.0.1): Pending...
#   • Updating pyzmq (22.3.0 -> 19.0.1): Pending...
#   • Updating python-dateutil (2.8.2 -> 2.8.1): Downloading... 100%
#   • Updating pyzmq (22.3.0 -> 19.0.1): Pending...
#   • Updating pyzmq (22.3.0 -> 19.0.1): Pending...
#   • Updating python-dateutil (2.8.2 -> 2.8.1): Downloading... 100%
#   • Updating pyzmq (22.3.0 -> 19.0.1): Pending...
#   • Updating pyzmq (22.3.0 -> 19.0.1): Pending...
#   • Updating python-dateutil (2.8.2 -> 2.8.1): Installing...
#   • Updating pyzmq (22.3.0 -> 19.0.1): Pending...
#   • Updating pyzmq (22.3.0 -> 19.0.1): Downloading... 0%
#   • Updating pyzmq (22.3.0 -> 19.0.1): Downloading... 100%
#   • Updating pyzmq (22.3.0 -> 19.0.1): Downloading... 100%
#   • Updating pyzmq (22.3.0 -> 19.0.1): Installing...
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Installing...
#   • Updating markupsafe (2.0.1 -> 1.1.1)
#   • Updating packaging (21.3 -> 20.4)
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Installing...
#   • Updating python-dateutil (2.8.2 -> 2.8.1): Installing...
#   • Updating pyzmq (22.3.0 -> 19.0.1): Installing...
#   • Updating jsonschema (4.3.3 -> 3.2.0)
#   • Updating jupyter-core (4.9.2 -> 4.6.3): Installing...
#   • Updating markupsafe (2.0.1 -> 1.1.1)
#   • Updating packaging (21.3 -> 20.4)
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5): Installing...
#   • Updating python-dateutil (2.8.2 -> 2.8.1): Installing...
#   • Updating pyzmq (22.3.0 -> 19.0.1): Installing...
#   • Updating tornado (5.1.1 -> 6.0.4): Pending...
#   • Updating tornado (5.1.1 -> 6.0.4): Downloading... 0%
#   • Updating tornado (5.1.1 -> 6.0.4): Downloading... 100%
#   • Updating tornado (5.1.1 -> 6.0.4): Downloading... 100%
#   • Updating tornado (5.1.1 -> 6.0.4): Installing...
#   • Updating python-dateutil (2.8.2 -> 2.8.1): Installing...
#   • Updating pyzmq (22.3.0 -> 19.0.1): Installing...
#   • Updating tornado (5.1.1 -> 6.0.4): Installing...
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5)
#   • Updating python-dateutil (2.8.2 -> 2.8.1): Installing...
#   • Updating pyzmq (22.3.0 -> 19.0.1): Installing...
#   • Updating tornado (5.1.1 -> 6.0.4): Installing...
#   • Updating pyzmq (22.3.0 -> 19.0.1): Installing...
#   • Updating tornado (5.1.1 -> 6.0.4): Installing...
#   • Updating python-dateutil (2.8.2 -> 2.8.1)
#   • Updating pyzmq (22.3.0 -> 19.0.1): Installing...
#   • Updating tornado (5.1.1 -> 6.0.4): Installing...
#   • Updating markupsafe (2.0.1 -> 1.1.1)
#   • Updating packaging (21.3 -> 20.4)
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5)
#   • Updating python-dateutil (2.8.2 -> 2.8.1)
#   • Updating pyzmq (22.3.0 -> 19.0.1): Installing...
#   • Updating tornado (5.1.1 -> 6.0.4): Installing...
#   • Updating jupyter-core (4.9.2 -> 4.6.3)
#   • Updating markupsafe (2.0.1 -> 1.1.1)
#   • Updating packaging (21.3 -> 20.4)
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5)
#   • Updating python-dateutil (2.8.2 -> 2.8.1)
#   • Updating pyzmq (22.3.0 -> 19.0.1): Installing...
#   • Updating tornado (5.1.1 -> 6.0.4): Installing...
#   • Updating jsonschema (4.3.3 -> 3.2.0)
#   • Updating jupyter-core (4.9.2 -> 4.6.3)
#   • Updating markupsafe (2.0.1 -> 1.1.1)
#   • Updating packaging (21.3 -> 20.4)
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5)
#   • Updating python-dateutil (2.8.2 -> 2.8.1)
#   • Updating pyzmq (22.3.0 -> 19.0.1): Installing...
#   • Updating tornado (5.1.1 -> 6.0.4): Installing...
#   • Updating jedi (0.18.1 -> 0.17.0)
#   • Updating jsonschema (4.3.3 -> 3.2.0)
#   • Updating jupyter-core (4.9.2 -> 4.6.3)
#   • Updating markupsafe (2.0.1 -> 1.1.1)
#   • Updating packaging (21.3 -> 20.4)
#   • Updating prompt-toolkit (1.0.18 -> 3.0.5)
#   • Updating python-dateutil (2.8.2 -> 2.8.1)
#   • Updating pyzmq (22.3.0 -> 19.0.1): Installing...
#   • Updating tornado (5.1.1 -> 6.0.4): Installing...
#   • Updating tornado (5.1.1 -> 6.0.4): Installing...
#   • Updating pyzmq (22.3.0 -> 19.0.1)
#   • Updating tornado (5.1.1 -> 6.0.4): Installing...
#   • Updating tornado (5.1.1 -> 6.0.4)
#   • Updating bleach (4.1.0 -> 3.1.5): Pending...
#   • Updating certifi (2021.10.8 -> 2020.4.5.2): Pending...
#   • Updating defusedxml (0.7.1 -> 0.6.0): Pending...
#   • Updating entrypoints (0.4 -> 0.3): Pending...
#   • Updating idna (2.10 -> 2.9): Pending...
#   • Updating ipython (5.5.0 -> 7.16.3): Pending...
#   • Updating certifi (2021.10.8 -> 2020.4.5.2): Pending...
#   • Updating defusedxml (0.7.1 -> 0.6.0): Pending...
#   • Updating entrypoints (0.4 -> 0.3): Pending...
#   • Updating idna (2.10 -> 2.9): Pending...
#   • Updating ipython (5.5.0 -> 7.16.3): Pending...
#   • Updating bleach (4.1.0 -> 3.1.5): Downloading... 0%
#   • Updating certifi (2021.10.8 -> 2020.4.5.2): Pending...
#   • Updating defusedxml (0.7.1 -> 0.6.0): Pending...
#   • Updating entrypoints (0.4 -> 0.3): Pending...
#   • Updating idna (2.10 -> 2.9): Pending...
#   • Updating ipython (5.5.0 -> 7.16.3): Pending...
#   • Updating entrypoints (0.4 -> 0.3): Pending...
#   • Updating idna (2.10 -> 2.9): Pending...
#   • Updating ipython (5.5.0 -> 7.16.3): Pending...
#   • Updating defusedxml (0.7.1 -> 0.6.0): Downloading... 0%
#   • Updating entrypoints (0.4 -> 0.3): Pending...
#   • Updating idna (2.10 -> 2.9): Pending...
#   • Updating ipython (5.5.0 -> 7.16.3): Pending...
#   • Updating entrypoints (0.4 -> 0.3): Pending...
#   • Updating idna (2.10 -> 2.9): Pending...
#   • Updating ipython (5.5.0 -> 7.16.3): Pending...
#   • Updating defusedxml (0.7.1 -> 0.6.0): Downloading... 100%
#   • Updating entrypoints (0.4 -> 0.3): Pending...
#   • Updating idna (2.10 -> 2.9): Pending...
#   • Updating ipython (5.5.0 -> 7.16.3): Pending...
#   • Updating defusedxml (0.7.1 -> 0.6.0): Downloading... 100%
#   • Updating entrypoints (0.4 -> 0.3): Pending...
#   • Updating idna (2.10 -> 2.9): Pending...
#   • Updating ipython (5.5.0 -> 7.16.3): Pending...
#   • Updating certifi (2021.10.8 -> 2020.4.5.2): Downloading... 0%
#   • Updating defusedxml (0.7.1 -> 0.6.0): Downloading... 100%
#   • Updating entrypoints (0.4 -> 0.3): Pending...
#   • Updating idna (2.10 -> 2.9): Pending...
#   • Updating ipython (5.5.0 -> 7.16.3): Pending...
#   • Updating idna (2.10 -> 2.9): Pending...
#   • Updating ipython (5.5.0 -> 7.16.3): Pending...
#   • Updating entrypoints (0.4 -> 0.3): Downloading... 0%
#   • Updating idna (2.10 -> 2.9): Pending...
#   • Updating ipython (5.5.0 -> 7.16.3): Pending...
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating entrypoints (0.4 -> 0.3): Downloading... 0%
#   • Updating idna (2.10 -> 2.9): Pending...
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating defusedxml (0.7.1 -> 0.6.0): Downloading... 100%
#   • Updating entrypoints (0.4 -> 0.3): Downloading... 0%
#   • Updating idna (2.10 -> 2.9): Pending...
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating idna (2.10 -> 2.9): Downloading... 0%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating entrypoints (0.4 -> 0.3): Downloading... 0%
#   • Updating idna (2.10 -> 2.9): Downloading... 0%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating defusedxml (0.7.1 -> 0.6.0): Installing...
#   • Updating entrypoints (0.4 -> 0.3): Downloading... 0%
#   • Updating idna (2.10 -> 2.9): Downloading... 0%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating idna (2.10 -> 2.9): Downloading... 0%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating entrypoints (0.4 -> 0.3): Downloading... 100%
#   • Updating idna (2.10 -> 2.9): Downloading... 0%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating idna (2.10 -> 2.9): Downloading... 0%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating entrypoints (0.4 -> 0.3): Downloading... 100%
#   • Updating idna (2.10 -> 2.9): Downloading... 0%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating idna (2.10 -> 2.9): Downloading... 100%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating certifi (2021.10.8 -> 2020.4.5.2): Downloading... 0%
#   • Updating defusedxml (0.7.1 -> 0.6.0): Installing...
#   • Updating entrypoints (0.4 -> 0.3): Downloading... 100%
#   • Updating idna (2.10 -> 2.9): Downloading... 100%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating bleach (4.1.0 -> 3.1.5): Downloading... 100%
#   • Updating certifi (2021.10.8 -> 2020.4.5.2): Downloading... 0%
#   • Updating defusedxml (0.7.1 -> 0.6.0): Installing...
#   • Updating entrypoints (0.4 -> 0.3): Downloading... 100%
#   • Updating idna (2.10 -> 2.9): Downloading... 100%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating idna (2.10 -> 2.9): Downloading... 100%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating certifi (2021.10.8 -> 2020.4.5.2): Downloading... 0%
#   • Updating defusedxml (0.7.1 -> 0.6.0): Installing...
#   • Updating entrypoints (0.4 -> 0.3): Downloading... 100%
#   • Updating idna (2.10 -> 2.9): Downloading... 100%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating bleach (4.1.0 -> 3.1.5): Downloading... 100%
#   • Updating certifi (2021.10.8 -> 2020.4.5.2): Downloading... 0%
#   • Updating defusedxml (0.7.1 -> 0.6.0): Installing...
#   • Updating entrypoints (0.4 -> 0.3): Downloading... 100%
#   • Updating idna (2.10 -> 2.9): Downloading... 100%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating idna (2.10 -> 2.9): Downloading... 100%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating entrypoints (0.4 -> 0.3): Installing...
#   • Updating idna (2.10 -> 2.9): Downloading... 100%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating defusedxml (0.7.1 -> 0.6.0): Installing...
#   • Updating entrypoints (0.4 -> 0.3): Installing...
#   • Updating idna (2.10 -> 2.9): Downloading... 100%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating certifi (2021.10.8 -> 2020.4.5.2): Downloading... 100%
#   • Updating defusedxml (0.7.1 -> 0.6.0): Installing...
#   • Updating entrypoints (0.4 -> 0.3): Installing...
#   • Updating idna (2.10 -> 2.9): Downloading... 100%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating idna (2.10 -> 2.9): Installing...
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating certifi (2021.10.8 -> 2020.4.5.2): Downloading... 100%
#   • Updating defusedxml (0.7.1 -> 0.6.0): Installing...
#   • Updating entrypoints (0.4 -> 0.3): Installing...
#   • Updating idna (2.10 -> 2.9): Installing...
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating bleach (4.1.0 -> 3.1.5): Installing...
#   • Updating certifi (2021.10.8 -> 2020.4.5.2): Downloading... 100%
#   • Updating defusedxml (0.7.1 -> 0.6.0): Installing...
#   • Updating entrypoints (0.4 -> 0.3): Installing...
#   • Updating idna (2.10 -> 2.9): Installing...
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating defusedxml (0.7.1 -> 0.6.0): Installing...
#   • Updating entrypoints (0.4 -> 0.3): Installing...
#   • Updating idna (2.10 -> 2.9): Installing...
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating certifi (2021.10.8 -> 2020.4.5.2): Downloading... 100%
#   • Updating defusedxml (0.7.1 -> 0.6.0): Installing...
#   • Updating entrypoints (0.4 -> 0.3): Installing...
#   • Updating idna (2.10 -> 2.9): Installing...
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating defusedxml (0.7.1 -> 0.6.0): Installing...
#   • Updating entrypoints (0.4 -> 0.3): Installing...
#   • Updating idna (2.10 -> 2.9): Installing...
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating certifi (2021.10.8 -> 2020.4.5.2): Installing...
#   • Updating defusedxml (0.7.1 -> 0.6.0): Installing...
#   • Updating entrypoints (0.4 -> 0.3): Installing...
#   • Updating idna (2.10 -> 2.9): Installing...
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 0%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 100%
#   • Updating ipython (5.5.0 -> 7.16.3): Downloading... 100%
#   • Updating ipython (5.5.0 -> 7.16.3): Installing...
#   • Updating entrypoints (0.4 -> 0.3): Installing...
#   • Updating idna (2.10 -> 2.9): Installing...
#   • Updating ipython (5.5.0 -> 7.16.3): Installing...
#   • Updating defusedxml (0.7.1 -> 0.6.0)
#   • Updating entrypoints (0.4 -> 0.3): Installing...
#   • Updating idna (2.10 -> 2.9): Installing...
#   • Updating ipython (5.5.0 -> 7.16.3): Installing...
#   • Updating jinja2 (2.11.3 -> 2.11.2): Pending...
#   • Updating jinja2 (2.11.3 -> 2.11.2): Downloading... 0%
#   • Updating jinja2 (2.11.3 -> 2.11.2): Downloading... 100%
#   • Updating jinja2 (2.11.3 -> 2.11.2): Downloading... 100%
#   • Updating jinja2 (2.11.3 -> 2.11.2): Installing...
#   • Updating defusedxml (0.7.1 -> 0.6.0)
#   • Updating entrypoints (0.4 -> 0.3): Installing...
#   • Updating idna (2.10 -> 2.9): Installing...
#   • Updating ipython (5.5.0 -> 7.16.3): Installing...
#   • Updating jinja2 (2.11.3 -> 2.11.2): Installing...
#   • Updating certifi (2021.10.8 -> 2020.4.5.2)
#   • Updating defusedxml (0.7.1 -> 0.6.0)
#   • Updating entrypoints (0.4 -> 0.3): Installing...
#   • Updating idna (2.10 -> 2.9): Installing...
#   • Updating ipython (5.5.0 -> 7.16.3): Installing...
#   • Updating jinja2 (2.11.3 -> 2.11.2): Installing...
#   • Updating jupyter-client (5.3.5 -> 6.1.3): Pending...
#   • Updating jupyter-client (5.3.5 -> 6.1.3): Downloading... 0%
#   • Updating jupyter-client (5.3.5 -> 6.1.3): Downloading... 100%
#   • Updating jupyter-client (5.3.5 -> 6.1.3): Downloading... 100%
#   • Updating jupyter-client (5.3.5 -> 6.1.3): Installing...
#   • Updating ipython (5.5.0 -> 7.16.3): Installing...
#   • Updating jinja2 (2.11.3 -> 2.11.2): Installing...
#   • Updating jupyter-client (5.3.5 -> 6.1.3): Installing...
#   • Updating idna (2.10 -> 2.9)
#   • Updating ipython (5.5.0 -> 7.16.3): Installing...
#   • Updating jinja2 (2.11.3 -> 2.11.2): Installing...
#   • Updating jupyter-client (5.3.5 -> 6.1.3): Installing...
#   • Updating nbformat (5.2.0 -> 5.0.7): Pending...
#   • Updating nbformat (5.2.0 -> 5.0.7): Downloading... 0%
#   • Updating certifi (2021.10.8 -> 2020.4.5.2)
#   • Updating defusedxml (0.7.1 -> 0.6.0)
#   • Updating entrypoints (0.4 -> 0.3): Installing...
#   • Updating idna (2.10 -> 2.9)
#   • Updating ipython (5.5.0 -> 7.16.3): Installing...
#   • Updating jinja2 (2.11.3 -> 2.11.2): Installing...
#   • Updating jupyter-client (5.3.5 -> 6.1.3): Installing...
#   • Updating nbformat (5.2.0 -> 5.0.7): Downloading... 0%
#   • Updating bleach (4.1.0 -> 3.1.5)
#   • Updating certifi (2021.10.8 -> 2020.4.5.2)
#   • Updating defusedxml (0.7.1 -> 0.6.0)
#   • Updating entrypoints (0.4 -> 0.3): Installing...
#   • Updating idna (2.10 -> 2.9)
#   • Updating ipython (5.5.0 -> 7.16.3): Installing...
#   • Updating jinja2 (2.11.3 -> 2.11.2): Installing...
#   • Updating jupyter-client (5.3.5 -> 6.1.3): Installing...
#   • Updating nbformat (5.2.0 -> 5.0.7): Downloading... 0%
#   • Updating pandocfilters (1.5.0 -> 1.4.2): Pending...
#   • Updating pandocfilters (1.5.0 -> 1.4.2): Pending...
#   • Updating nbformat (5.2.0 -> 5.0.7): Downloading... 100%
#   • Updating pandocfilters (1.5.0 -> 1.4.2): Pending...
#   • Updating pandocfilters (1.5.0 -> 1.4.2): Pending...
#   • Updating nbformat (5.2.0 -> 5.0.7): Downloading... 100%
#   • Updating pandocfilters (1.5.0 -> 1.4.2): Pending...
#   • Updating pandocfilters (1.5.0 -> 1.4.2): Pending...
#   • Updating nbformat (5.2.0 -> 5.0.7): Installing...
#   • Updating pandocfilters (1.5.0 -> 1.4.2): Pending...
#   • Updating pandocfilters (1.5.0 -> 1.4.2): Downloading... 0%
#   • Updating pandocfilters (1.5.0 -> 1.4.2): Downloading... 100%
#   • Updating pandocfilters (1.5.0 -> 1.4.2): Downloading... 100%
#   • Updating pandocfilters (1.5.0 -> 1.4.2): Installing...
#   • Updating jinja2 (2.11.3 -> 2.11.2): Installing...
#   • Updating jupyter-client (5.3.5 -> 6.1.3): Installing...
#   • Updating nbformat (5.2.0 -> 5.0.7): Installing...
#   • Updating pandocfilters (1.5.0 -> 1.4.2): Installing...
#   • Updating ipython (5.5.0 -> 7.16.3)
#   • Updating jinja2 (2.11.3 -> 2.11.2): Installing...
#   • Updating jupyter-client (5.3.5 -> 6.1.3): Installing...
#   • Updating nbformat (5.2.0 -> 5.0.7): Installing...
#   • Updating pandocfilters (1.5.0 -> 1.4.2): Installing...
#   • Updating testpath (0.6.0 -> 0.4.4): Pending...
#   • Updating testpath (0.6.0 -> 0.4.4): Downloading... 0%
#   • Updating testpath (0.6.0 -> 0.4.4): Downloading... 100%
#   • Updating testpath (0.6.0 -> 0.4.4): Downloading... 100%
#   • Updating testpath (0.6.0 -> 0.4.4): Installing...
#   • Updating jupyter-client (5.3.5 -> 6.1.3): Installing...
#   • Updating nbformat (5.2.0 -> 5.0.7): Installing...
#   • Updating pandocfilters (1.5.0 -> 1.4.2): Installing...
#   • Updating testpath (0.6.0 -> 0.4.4): Installing...
#   • Updating jinja2 (2.11.3 -> 2.11.2)
#   • Updating jupyter-client (5.3.5 -> 6.1.3): Installing...
#   • Updating nbformat (5.2.0 -> 5.0.7): Installing...
#   • Updating pandocfilters (1.5.0 -> 1.4.2): Installing...
#   • Updating testpath (0.6.0 -> 0.4.4): Installing...
#   • Updating urllib3 (1.24.3 -> 1.25.9): Pending...
#   • Updating urllib3 (1.24.3 -> 1.25.9): Downloading... 0%
#   • Updating urllib3 (1.24.3 -> 1.25.9): Downloading... 100%
#   • Updating urllib3 (1.24.3 -> 1.25.9): Downloading... 100%
#   • Updating urllib3 (1.24.3 -> 1.25.9): Installing...
#   • Updating nbformat (5.2.0 -> 5.0.7): Installing...
#   • Updating pandocfilters (1.5.0 -> 1.4.2): Installing...
#   • Updating testpath (0.6.0 -> 0.4.4): Installing...
#   • Updating urllib3 (1.24.3 -> 1.25.9): Installing...
#   • Updating jupyter-client (5.3.5 -> 6.1.3)
#   • Updating nbformat (5.2.0 -> 5.0.7): Installing...
#   • Updating pandocfilters (1.5.0 -> 1.4.2): Installing...
#   • Updating testpath (0.6.0 -> 0.4.4): Installing...
#   • Updating urllib3 (1.24.3 -> 1.25.9): Installing...
#   • Updating idna (2.10 -> 2.9)
#   • Updating ipython (5.5.0 -> 7.16.3)
#   • Updating jinja2 (2.11.3 -> 2.11.2)
#   • Updating jupyter-client (5.3.5 -> 6.1.3)
#   • Updating nbformat (5.2.0 -> 5.0.7): Installing...
#   • Updating pandocfilters (1.5.0 -> 1.4.2): Installing...
#   • Updating testpath (0.6.0 -> 0.4.4): Installing...
#   • Updating urllib3 (1.24.3 -> 1.25.9): Installing...
#   • Updating entrypoints (0.4 -> 0.3)
#   • Updating idna (2.10 -> 2.9)
#   • Updating ipython (5.5.0 -> 7.16.3)
#   • Updating jinja2 (2.11.3 -> 2.11.2)
#   • Updating jupyter-client (5.3.5 -> 6.1.3)
#   • Updating nbformat (5.2.0 -> 5.0.7): Installing...
#   • Updating pandocfilters (1.5.0 -> 1.4.2): Installing...
#   • Updating testpath (0.6.0 -> 0.4.4): Installing...
#   • Updating urllib3 (1.24.3 -> 1.25.9): Installing...
#   • Updating pandocfilters (1.5.0 -> 1.4.2): Installing...
#   • Updating testpath (0.6.0 -> 0.4.4): Installing...
#   • Updating urllib3 (1.24.3 -> 1.25.9): Installing...
#   • Updating nbformat (5.2.0 -> 5.0.7)
#   • Updating pandocfilters (1.5.0 -> 1.4.2): Installing...
#   • Updating testpath (0.6.0 -> 0.4.4): Installing...
#   • Updating urllib3 (1.24.3 -> 1.25.9): Installing...
#   • Updating urllib3 (1.24.3 -> 1.25.9): Installing...
#   • Updating testpath (0.6.0 -> 0.4.4)
#   • Updating urllib3 (1.24.3 -> 1.25.9): Installing...
#   • Updating urllib3 (1.24.3 -> 1.25.9)
#   • Updating testpath (0.6.0 -> 0.4.4)
#   • Updating urllib3 (1.24.3 -> 1.25.9)
#   • Updating pandocfilters (1.5.0 -> 1.4.2)
#   • Updating testpath (0.6.0 -> 0.4.4)
#   • Updating urllib3 (1.24.3 -> 1.25.9)
#   • Updating cachetools (4.2.4 -> 4.1.0): Pending...
#   • Updating ipykernel (4.10.1 -> 5.3.0): Pending...
#   • Updating oauthlib (3.2.0 -> 3.1.0): Pending...
#   • Updating prometheus-client (0.13.1 -> 0.8.0): Pending...
#   • Updating requests (2.23.0 -> 2.24.0): Pending...
#   • Updating rsa (4.8 -> 4.6): Pending...
#   • Updating ipykernel (4.10.1 -> 5.3.0): Pending...
#   • Updating oauthlib (3.2.0 -> 3.1.0): Pending...
#   • Updating prometheus-client (0.13.1 -> 0.8.0): Pending...
#   • Updating requests (2.23.0 -> 2.24.0): Pending...
#   • Updating rsa (4.8 -> 4.6): Pending...
#   • Updating cachetools (4.2.4 -> 4.1.0): Downloading... 0%
#   • Updating ipykernel (4.10.1 -> 5.3.0): Pending...
#   • Updating oauthlib (3.2.0 -> 3.1.0): Pending...
#   • Updating prometheus-client (0.13.1 -> 0.8.0): Pending...
#   • Updating requests (2.23.0 -> 2.24.0): Pending...
#   • Updating rsa (4.8 -> 4.6): Pending...
#   • Updating ipykernel (4.10.1 -> 5.3.0): Pending...
#   • Updating oauthlib (3.2.0 -> 3.1.0): Pending...
#   • Updating prometheus-client (0.13.1 -> 0.8.0): Pending...
#   • Updating requests (2.23.0 -> 2.24.0): Pending...
#   • Updating rsa (4.8 -> 4.6): Pending...
#   • Updating cachetools (4.2.4 -> 4.1.0): Downloading... 100%
#   • Updating ipykernel (4.10.1 -> 5.3.0): Pending...
#   • Updating oauthlib (3.2.0 -> 3.1.0): Pending...
#   • Updating prometheus-client (0.13.1 -> 0.8.0): Pending...
#   • Updating requests (2.23.0 -> 2.24.0): Pending...
#   • Updating rsa (4.8 -> 4.6): Pending...
#   • Updating ipykernel (4.10.1 -> 5.3.0): Pending...
#   • Updating oauthlib (3.2.0 -> 3.1.0): Pending...
#   • Updating prometheus-client (0.13.1 -> 0.8.0): Pending...
#   • Updating requests (2.23.0 -> 2.24.0): Pending...
#   • Updating rsa (4.8 -> 4.6): Pending...
#   • Updating cachetools (4.2.4 -> 4.1.0): Downloading... 100%
#   • Updating ipykernel (4.10.1 -> 5.3.0): Pending...
#   • Updating oauthlib (3.2.0 -> 3.1.0): Pending...
#   • Updating prometheus-client (0.13.1 -> 0.8.0): Pending...
#   • Updating requests (2.23.0 -> 2.24.0): Pending...
#   • Updating rsa (4.8 -> 4.6): Pending...
#   • Updating ipykernel (4.10.1 -> 5.3.0): Pending...
#   • Updating oauthlib (3.2.0 -> 3.1.0): Pending...
#   • Updating prometheus-client (0.13.1 -> 0.8.0): Pending...
#   • Updating requests (2.23.0 -> 2.24.0): Pending...
#   • Updating rsa (4.8 -> 4.6): Pending...
#   • Updating cachetools (4.2.4 -> 4.1.0): Installing...
#   • Updating ipykernel (4.10.1 -> 5.3.0): Pending...
#   • Updating oauthlib (3.2.0 -> 3.1.0): Pending...
#   • Updating prometheus-client (0.13.1 -> 0.8.0): Pending...
#   • Updating requests (2.23.0 -> 2.24.0): Pending...
#   • Updating rsa (4.8 -> 4.6): Pending...
#   • Updating requests (2.23.0 -> 2.24.0): Pending...
#   • Updating rsa (4.8 -> 4.6): Pending...
#   • Updating prometheus-client (0.13.1 -> 0.8.0): Downloading... 0%
#   • Updating requests (2.23.0 -> 2.24.0): Pending...
#   • Updating rsa (4.8 -> 4.6): Pending...
#   • Updating rsa (4.8 -> 4.6): Downloading... 0%
#   • Updating prometheus-client (0.13.1 -> 0.8.0): Downloading... 0%
#   • Updating requests (2.23.0 -> 2.24.0): Pending...
#   • Updating rsa (4.8 -> 4.6): Downloading... 0%
#   • Updating oauthlib (3.2.0 -> 3.1.0): Downloading... 0%
#   • Updating prometheus-client (0.13.1 -> 0.8.0): Downloading... 0%
#   • Updating requests (2.23.0 -> 2.24.0): Pending...
#   • Updating rsa (4.8 -> 4.6): Downloading... 0%
#   • Updating rsa (4.8 -> 4.6): Downloading... 0%
#   • Updating requests (2.23.0 -> 2.24.0): Downloading... 0%
#   • Updating rsa (4.8 -> 4.6): Downloading... 0%
#   • Updating oauthlib (3.2.0 -> 3.1.0): Downloading... 0%
#   • Updating prometheus-client (0.13.1 -> 0.8.0): Downloading... 0%
#   • Updating requests (2.23.0 -> 2.24.0): Downloading... 0%
#   • Updating rsa (4.8 -> 4.6): Downloading... 0%
#   • Updating ipykernel (4.10.1 -> 5.3.0): Downloading... 0%
#   • Updating oauthlib (3.2.0 -> 3.1.0): Downloading... 0%
#   • Updating prometheus-client (0.13.1 -> 0.8.0): Downloading... 0%
#   • Updating requests (2.23.0 -> 2.24.0): Downloading... 0%
#   • Updating rsa (4.8 -> 4.6): Downloading... 0%
#   • Updating rsa (4.8 -> 4.6): Downloading... 100%
#   • Updating rsa (4.8 -> 4.6): Downloading... 100%
#   • Updating rsa (4.8 -> 4.6): Installing...
#   • Updating rsa (4.8 -> 4.6): Installing...
#   • Updating requests (2.23.0 -> 2.24.0): Downloading... 100%
#   • Updating rsa (4.8 -> 4.6): Installing...
#   • Updating requests (2.23.0 -> 2.24.0): Downloading... 100%
#   • Updating rsa (4.8 -> 4.6): Installing...
#   • Updating prometheus-client (0.13.1 -> 0.8.0): Downloading... 100%
#   • Updating requests (2.23.0 -> 2.24.0): Downloading... 100%
#   • Updating rsa (4.8 -> 4.6): Installing...
#   • Updating requests (2.23.0 -> 2.24.0): Downloading... 100%
#   • Updating rsa (4.8 -> 4.6): Installing...
#   • Updating prometheus-client (0.13.1 -> 0.8.0): Downloading... 100%
#   • Updating requests (2.23.0 -> 2.24.0): Downloading... 100%
# ...
#   • Updating pyyaml (3.13 -> 5.3.1): Installing...
#   • Installing flake8 (3.8.3): Installing...
#   • Installing gpumonitor (0.1.2): Installing...
#   • Updating imgaug (0.2.9 -> 0.4.0): Downloading... 0%
#   • Installing pytest-cov (2.10.0): Installing...
#   • Updating pyyaml (3.13 -> 5.3.1): Installing...
#   • Installing black (19.10b0): Installing...
#   • Installing flake8 (3.8.3): Installing...
#   • Installing gpumonitor (0.1.2): Installing...
#   • Updating imgaug (0.2.9 -> 0.4.0): Downloading... 0%
#   • Installing pytest-cov (2.10.0): Installing...
#   • Updating pyyaml (3.13 -> 5.3.1): Installing...
#   • Installing pytest-cov (2.10.0): Installing...
#   • Updating pyyaml (3.13 -> 5.3.1): Installing...
#   • Updating imgaug (0.2.9 -> 0.4.0): Downloading... 100%
#   • Installing pytest-cov (2.10.0): Installing...
#   • Updating pyyaml (3.13 -> 5.3.1): Installing...
#   • Installing pytest-cov (2.10.0): Installing...
#   • Updating pyyaml (3.13 -> 5.3.1): Installing...
#   • Updating imgaug (0.2.9 -> 0.4.0): Downloading... 100%
#   • Installing pytest-cov (2.10.0): Installing...
#   • Updating pyyaml (3.13 -> 5.3.1): Installing...
#   • Installing pytest-cov (2.10.0): Installing...
#   • Updating pyyaml (3.13 -> 5.3.1): Installing...
#   • Updating imgaug (0.2.9 -> 0.4.0): Installing...
#   • Installing pytest-cov (2.10.0): Installing...
#   • Updating pyyaml (3.13 -> 5.3.1): Installing...
#   • Updating imgaug (0.2.9 -> 0.4.0): Installing...
#   • Installing pytest-cov (2.10.0): Installing...
#   • Updating pyyaml (3.13 -> 5.3.1): Installing...
#   • Installing gpumonitor (0.1.2)
#   • Updating imgaug (0.2.9 -> 0.4.0): Installing...
#   • Installing pytest-cov (2.10.0): Installing...
#   • Updating pyyaml (3.13 -> 5.3.1): Installing...
#   • Updating seaborn (0.11.2 -> 0.10.1): Pending...
#   • Updating seaborn (0.11.2 -> 0.10.1): Downloading... 0%
#   • Updating seaborn (0.11.2 -> 0.10.1): Downloading... 100%
#   • Updating seaborn (0.11.2 -> 0.10.1): Downloading... 100%
#   • Updating seaborn (0.11.2 -> 0.10.1): Installing...
#   • Updating pyyaml (3.13 -> 5.3.1): Installing...
#   • Updating seaborn (0.11.2 -> 0.10.1): Installing...
#   • Installing pytest-cov (2.10.0)
#   • Updating pyyaml (3.13 -> 5.3.1): Installing...
#   • Updating seaborn (0.11.2 -> 0.10.1): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Pending...
#   • Installing gpumonitor (0.1.2)
#   • Updating imgaug (0.2.9 -> 0.4.0): Installing...
#   • Installing pytest-cov (2.10.0)
#   • Updating pyyaml (3.13 -> 5.3.1): Installing...
#   • Updating seaborn (0.11.2 -> 0.10.1): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Pending...
#   • Installing flake8 (3.8.3)
#   • Installing gpumonitor (0.1.2)
#   • Updating imgaug (0.2.9 -> 0.4.0): Installing...
#   • Installing pytest-cov (2.10.0)
#   • Updating pyyaml (3.13 -> 5.3.1): Installing...
#   • Updating seaborn (0.11.2 -> 0.10.1): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Pending...
#   • Installing tensorflow-addons (0.9.1): Pending...
#   • Installing tensorflow-addons (0.9.1): Pending...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 0%
#   • Installing tensorflow-addons (0.9.1): Pending...
#   • Installing flake8 (3.8.3)
#   • Installing gpumonitor (0.1.2)
#   • Updating imgaug (0.2.9 -> 0.4.0): Installing...
#   • Installing pytest-cov (2.10.0)
#   • Updating pyyaml (3.13 -> 5.3.1): Installing...
#   • Updating seaborn (0.11.2 -> 0.10.1): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 0%
#   • Installing tensorflow-addons (0.9.1): Pending...
#   • Installing black (19.10b0)
#   • Installing flake8 (3.8.3)
#   • Installing gpumonitor (0.1.2)
#   • Updating imgaug (0.2.9 -> 0.4.0): Installing...
#   • Installing pytest-cov (2.10.0)
#   • Updating pyyaml (3.13 -> 5.3.1): Installing...
#   • Updating seaborn (0.11.2 -> 0.10.1): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 0%
#   • Installing tensorflow-addons (0.9.1): Pending...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Pending...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Pending...
#   • Installing tensorflow-addons (0.9.1): Downloading... 0%
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Pending...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Pending...
#   • Installing tensorflow-addons (0.9.1): Downloading... 100%
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Pending...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Pending...
#   • Installing tensorflow-addons (0.9.1): Downloading... 100%
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Pending...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Pending...
#   • Installing tensorflow-addons (0.9.1): Installing...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Pending...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Downloading... 0%
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Downloading... 60%
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Downloading... 100%
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Downloading... 100%
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Installing tensorflow-addons (0.9.1): Installing...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 3%
#   • Installing tensorflow-addons (0.9.1): Installing...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Installing pytest-cov (2.10.0)
#   • Updating pyyaml (3.13 -> 5.3.1): Installing...
#   • Updating seaborn (0.11.2 -> 0.10.1): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 3%
#   • Installing tensorflow-addons (0.9.1): Installing...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating imgaug (0.2.9 -> 0.4.0)
#   • Installing pytest-cov (2.10.0)
#   • Updating pyyaml (3.13 -> 5.3.1): Installing...
#   • Updating seaborn (0.11.2 -> 0.10.1): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 3%
#   • Installing tensorflow-addons (0.9.1): Installing...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Pending...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Downloading... 0%
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Downloading... 50%
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Downloading... 100%
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Downloading... 100%
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Installing tensorflow-addons (0.9.1): Installing...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 7%
#   • Installing tensorflow-addons (0.9.1): Installing...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Installing tensorflow-addons (0.9.1): Installing...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 10%
#   • Installing tensorflow-addons (0.9.1): Installing...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Installing tensorflow-addons (0.9.1): Installing...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 14%
#   • Installing tensorflow-addons (0.9.1): Installing...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Installing tensorflow-addons (0.9.1): Installing...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 19%
#   • Installing tensorflow-addons (0.9.1): Installing...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Installing tensorflow-addons (0.9.1): Installing...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 20%
#   • Installing tensorflow-addons (0.9.1): Installing...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 20%
#   • Installing tensorflow-addons (0.9.1): Installing...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating seaborn (0.11.2 -> 0.10.1)
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 20%
#   • Installing tensorflow-addons (0.9.1): Installing...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 26%
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 30%
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating seaborn (0.11.2 -> 0.10.1)
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 30%
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating pyyaml (3.13 -> 5.3.1)
#   • Updating seaborn (0.11.2 -> 0.10.1)
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 30%
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 36%
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 40%
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 48%
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 50%
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0)
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0)
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 60%
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0)
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0)
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 70%
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0)
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0)
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 80%
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0)
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0)
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 90%
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0)
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0)
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 100%
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0)
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0)
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating tensorflow (2.8.0 -> 2.2.0): Downloading... 100%
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0)
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0): Installing...
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0)
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0)
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0)
#   • Updating tensorflow (2.8.0 -> 2.2.0): Installing...
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0)
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0)
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0)
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0)
#   • Updating tensorflow (2.8.0 -> 2.2.0)
#   • Installing tensorflow-addons (0.9.1)
#   • Updating tensorflow-datasets (4.0.1 -> 3.1.0)
#   • Updating tensorflow-probability (0.16.0 -> 0.9.0)
# Skipping virtualenv creation, as specified in config file.
# Using version ^0.1.2 for gpumonitor
#
# Updating dependencies
# Resolving dependencies... (1.0s)
#
# Writing lock file
#
# No dependencies to install or update

# %%
from pathlib import Path

import pandas as pd
import tensorflow as tf
import tensorflow_datasets as tfds
from functools import partial
from gpumonitor.callbacks.tf import TFGpuMonitorCallback
from tensorflow.keras.layers import Conv2D, Dropout, Flatten, GlobalMaxPooling2D, Input, MaxPooling2D
from tensorflow.keras.models import Sequential

from keras_fsl.utils.datasets import assign, cache, cache_with_tf_record, read_decode_and_crop_jpeg, transform

# %%
train_dataset = tfds.load(name="cifar10", split="train")
output_dir = Path("logs") / "benchmark_caching_performance"
(output_dir / "cifar10").mkdir(exist_ok=True, parents=True)
examples = []
for example in train_dataset:
    tf.io.write_file(str(output_dir / "cifar10" / example["id"].numpy().decode()), tf.io.encode_jpeg(example["image"]))
    examples += [{"id": example["id"].numpy().decode(), "label": example["label"].numpy()}]
# Out:
# Downloading and preparing dataset cifar10/3.0.2 (download: 162.17 MiB, generated: 132.40 MiB, total: 294.58 MiB) to /root/tensorflow_datasets/cifar10/3.0.2...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Extraction completed...', max=1.0, styl…
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.cs.toronto.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.2.incompleteBWEPWC/cifar10-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=50000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.2.incompleteBWEPWC/cifar10-test.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# Dataset cifar10 downloaded and prepared to /root/tensorflow_datasets/cifar10/3.0.2. Subsequent calls will reuse this data.

# %%
datasets = {
    key: pd.DataFrame(examples)
    .assign(filename=lambda df: str(output_dir / "cifar10") + "/" + df.id)
    .pipe(lambda df: tf.data.Dataset.from_tensor_slices(df.to_dict("list")))
    .map(assign(image=read_decode_and_crop_jpeg), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    .apply(cache_func)
    for key, cache_func in zip(
        ["tf_record_cache", "dataset_cache", "no_cache"],
        [cache_with_tf_record(output_dir / "tf_record_cache"), cache(output_dir / "dataset_cache"), lambda ds: ds],
    )
}
datasets.update({"baseline": train_dataset})
datasets = {
    key: dataset.map(
        transform(image=partial(tf.image.convert_image_dtype, dtype=tf.float32)),
        num_parallel_calls=tf.data.experimental.AUTOTUNE,
    )
    .map(
        lambda x: (
            tf.ensure_shape(x["image"], train_dataset.element_spec["image"].shape),
            tf.ensure_shape(x["label"], train_dataset.element_spec["label"].shape),
        ),
        num_parallel_calls=tf.data.experimental.AUTOTUNE,
    )
    .batch(64)
    for key, dataset in datasets.items()
}

# %%
model = Sequential(
    [
        Input(train_dataset.element_spec["image"].shape),
        Conv2D(filters=32, kernel_size=(3, 3), padding="same", activation="relu"),
        MaxPooling2D(pool_size=2),
        Dropout(0.3),
        Conv2D(filters=64, kernel_size=(3, 3), padding="same", activation="relu"),
        MaxPooling2D(pool_size=2),
        Dropout(0.3),
        Conv2D(filters=128, kernel_size=(3, 3), padding="same", activation="relu"),
        MaxPooling2D(pool_size=2),
        Dropout(0.3),
        Conv2D(filters=256, kernel_size=(3, 3), padding="same", activation="relu"),
        MaxPooling2D(pool_size=2),
        Dropout(0.3),
        GlobalMaxPooling2D(),
        Flatten(),
    ]
)
model.save_weights(str(output_dir / "initial_weights.h5"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 256)         295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 256)         0
# _________________________________________________________________
# global_max_pooling2d (Global (None, 256)               0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# =================================================================
# Total params: 388,416
# Trainable params: 388,416
# Non-trainable params: 0
# _________________________________________________________________

# %%
for key, dataset in datasets.items():
    print(f"Current cache: {key}")
    model.load_weights(str(output_dir / "initial_weights.h5"))
    model.compile(loss="sparse_categorical_crossentropy", optimizer="adam")
    model.fit(dataset.repeat(), steps_per_epoch=5, callbacks=[TFGpuMonitorCallback(delay=0.5)])

# %% [markdown]
# ##10) Huấn luyện mô hình theo phương pháp triplet loss function.

# %% [markdown]
# https://github.com/abhimanyu1996/Face-Recognition-using-triplet-loss/blob/master/Face_Recognition.ipynb

# %%
from google.colab import drive
import os
drive.mount("/content/drive")
folder_path = "/content/drive/MyDrive/DLK1/Face-Recognition/"
os.chdir(folder_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
import os
from sklearn.preprocessing import LabelEncoder

# %%
import zipfile
zip_ref = zipfile.ZipFile("data_1.zip", 'r')
zip_ref.extractall()
zip_ref.close()

# %%
face_cascade = cv2.CascadeClassifier('haar.xml')
f = cv2.imread("data/train/ben_afflek/httpwwwallposterscomimagesPostersPFjpg.jpg")
faces = face_cascade.detectMultiScale(f,1.3,5)
print(faces)
for x,y,w,h in faces:
    plt.imshow(f[y:y+h, x:x+w])
# Out:
# [[ 35  57 160 160]]

# %%
face_cascade = cv2.CascadeClassifier('haar.xml')
dirs = "data/train/"
img_size = 60

data = []
for name in os.listdir(dirs):
    for f in os.listdir(dirs+name):
        f = cv2.imread(os.path.join(dirs+name, f))
        faces = face_cascade.detectMultiScale(f,1.3,5)
        for x,y,w,h in faces:
            img = f[y:y+h, x:x+w]
            img = cv2.resize(img, (img_size,img_size))
            data.append((img, name))
            
df = pd.DataFrame(data, columns=["image", "name"])
print("Length:",len(df))
# Out:
# Length: 99

# %%
idx = 34
row = df.iloc[idx, :]
print("Name: ", row["name"])
print(row.image.shape)
for i in range(9):
  row = df.iloc[np.random.randint(0, len(df)), :]
  plt.subplot(3,3,i+1)
  plt.imshow(row.image)
# Out:
# Name:  jerry_seinfeld
# (60, 60, 3)

# %%
dirs = "data/val/"

data = []
for name in os.listdir(dirs):
    for f in os.listdir(dirs+name):
        f = cv2.imread(os.path.join(dirs+name, f))
        faces = face_cascade.detectMultiScale(f,1.3,5)
        for x,y,w,h in faces:
            img = f[y:y+h, x:x+w]
            img = cv2.resize(img, (img_size,img_size))
            data.append((img, name))
            
df_test = pd.DataFrame(data, columns=["image", "name"])
print("Test size: ", len(df_test))
# Out:
# Test size:  24

# %%
le = LabelEncoder()
le.fit(df["name"].values)
# Out:
# LabelEncoder()

# %%
x_train = list(df.image.values)
x_train = np.array(x_train)
x_train = x_train/255
print(x_train.shape)

y_train = le.transform(df["name"].values)
print(y_train.shape)
# Out:
# (99, 60, 60, 3)
# (99,)

# %%
x_test = list(df_test.image.values)
x_test = np.array(x_test)
x_test = x_test/255
print(x_test.shape)

y_test = le.transform(df_test["name"].values)
print(y_test.shape)
# Out:
# (24, 60, 60, 3)
# (24,)

# %%
people_num = len(np.unique(y_train))
people_num
# Out:
# 5

# %%
def get_model():
        model = tf.keras.Sequential()
        model.add(tf.keras.layers.Conv2D(64, kernel_size=3, strides=2, padding='same', input_shape=(img_size,img_size,3), activation='relu'))
        model.add(tf.keras.layers.Conv2D(128, kernel_size=3, strides=2, padding='same', activation='relu'))
        model.add(tf.keras.layers.Conv2D(64, kernel_size=3, strides=2, padding='same', activation='relu'))
        model.add(tf.keras.layers.Conv2D(64, kernel_size=1, strides=2, padding='same', activation='relu'))
        model.add(tf.keras.layers.Flatten())
        model.add(tf.keras.layers.Dense(256, activation='relu'))
        model.add(tf.keras.layers.Dropout(0.1))
        model.add(tf.keras.layers.Dense(128, activation='relu'))
        model.add(tf.keras.layers.Dropout(0.2))
        model.add(tf.keras.layers.Dense(people_num, activation="softmax"))

        model.summary()
        return model

# %%
from tensorflow.python.framework import ops

# %%
ops.reset_default_graph()
model = get_model()
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics = ['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 64)        1792
#
#  conv2d_1 (Conv2D)           (None, 15, 15, 128)       73856
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 64)          73792
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 64)          4160
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 256)               262400
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 449,541
# Trainable params: 449,541
# Non-trainable params: 0
# _________________________________________________________________

# %%
weight_dir = "weight_normal_model"
if not os.path.exists(weight_dir):
    os.mkdir(weight_dir)
    
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=weight_dir+'/checkpoint-{epoch:02d}.hdf5')

# %%
model.fit(x_train,y_train,validation_data=(x_test, y_test),epochs=50, batch_size=100, callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 1/1 [==============================] - 2s 2s/step - loss: 1.6071 - accuracy: 0.2424 - val_loss: 1.5838 - val_accuracy: 0.2083
# Epoch 2/50
# 1/1 [==============================] - 0s 490ms/step - loss: 1.5798 - accuracy: 0.3131 - val_loss: 1.5807 - val_accuracy: 0.2500
# Epoch 3/50
# 1/1 [==============================] - 0s 496ms/step - loss: 1.5562 - accuracy: 0.3535 - val_loss: 1.5377 - val_accuracy: 0.3333
# Epoch 4/50
# 1/1 [==============================] - 0s 493ms/step - loss: 1.5062 - accuracy: 0.3434 - val_loss: 1.4713 - val_accuracy: 0.4167
# Epoch 5/50
# 1/1 [==============================] - 1s 507ms/step - loss: 1.4637 - accuracy: 0.4545 - val_loss: 1.3875 - val_accuracy: 0.5417
# Epoch 6/50
# 1/1 [==============================] - 0s 477ms/step - loss: 1.4428 - accuracy: 0.4545 - val_loss: 1.2882 - val_accuracy: 0.4167
# Epoch 7/50
# 1/1 [==============================] - 0s 489ms/step - loss: 1.3613 - accuracy: 0.4646 - val_loss: 1.1897 - val_accuracy: 0.5417
# Epoch 8/50
# 1/1 [==============================] - 0s 484ms/step - loss: 1.2895 - accuracy: 0.5051 - val_loss: 1.0407 - val_accuracy: 0.7083
# Epoch 9/50
# 1/1 [==============================] - 0s 487ms/step - loss: 1.2805 - accuracy: 0.4949 - val_loss: 1.0087 - val_accuracy: 0.6250
# Epoch 10/50
# 1/1 [==============================] - 1s 501ms/step - loss: 1.1211 - accuracy: 0.5859 - val_loss: 0.9585 - val_accuracy: 0.6667
# Epoch 11/50
# 1/1 [==============================] - 1s 550ms/step - loss: 1.0912 - accuracy: 0.5455 - val_loss: 0.8712 - val_accuracy: 0.7083
# Epoch 12/50
# 1/1 [==============================] - 1s 536ms/step - loss: 1.0763 - accuracy: 0.5758 - val_loss: 0.7895 - val_accuracy: 0.7083
# Epoch 13/50
# 1/1 [==============================] - 0s 488ms/step - loss: 0.9768 - accuracy: 0.6061 - val_loss: 0.7662 - val_accuracy: 0.7500
# Epoch 14/50
# 1/1 [==============================] - 1s 541ms/step - loss: 1.0016 - accuracy: 0.6364 - val_loss: 0.6944 - val_accuracy: 0.7917
# Epoch 15/50
# 1/1 [==============================] - 1s 513ms/step - loss: 0.9334 - accuracy: 0.6162 - val_loss: 0.6757 - val_accuracy: 0.7917
# Epoch 16/50
# 1/1 [==============================] - 0s 491ms/step - loss: 0.8886 - accuracy: 0.5960 - val_loss: 0.5595 - val_accuracy: 0.7917
# Epoch 17/50
# 1/1 [==============================] - 0s 494ms/step - loss: 0.8080 - accuracy: 0.6869 - val_loss: 0.5019 - val_accuracy: 0.9167
# Epoch 18/50
# 1/1 [==============================] - 1s 527ms/step - loss: 0.7226 - accuracy: 0.6970 - val_loss: 0.4283 - val_accuracy: 0.8750
# Epoch 19/50
# 1/1 [==============================] - 1s 569ms/step - loss: 0.6956 - accuracy: 0.7374 - val_loss: 0.3923 - val_accuracy: 1.0000
# Epoch 20/50
# 1/1 [==============================] - 1s 525ms/step - loss: 0.6582 - accuracy: 0.7980 - val_loss: 0.3872 - val_accuracy: 0.8750
# Epoch 21/50
# 1/1 [==============================] - 1s 501ms/step - loss: 0.5875 - accuracy: 0.7778 - val_loss: 0.3366 - val_accuracy: 0.9583
# Epoch 22/50
# 1/1 [==============================] - 1s 531ms/step - loss: 0.5163 - accuracy: 0.8283 - val_loss: 0.2929 - val_accuracy: 0.9583
# Epoch 23/50
# 1/1 [==============================] - 0s 495ms/step - loss: 0.4181 - accuracy: 0.8485 - val_loss: 0.2067 - val_accuracy: 1.0000
# Epoch 24/50
# 1/1 [==============================] - 1s 569ms/step - loss: 0.4437 - accuracy: 0.8081 - val_loss: 0.1635 - val_accuracy: 1.0000
# Epoch 25/50
# 1/1 [==============================] - 0s 499ms/step - loss: 0.4181 - accuracy: 0.8283 - val_loss: 0.1528 - val_accuracy: 1.0000
# Epoch 26/50
# 1/1 [==============================] - 1s 527ms/step - loss: 0.3553 - accuracy: 0.8990 - val_loss: 0.1288 - val_accuracy: 0.9583
# Epoch 27/50
# 1/1 [==============================] - 1s 533ms/step - loss: 0.3527 - accuracy: 0.9192 - val_loss: 0.0882 - val_accuracy: 1.0000
# Epoch 28/50
# 1/1 [==============================] - 1s 507ms/step - loss: 0.2340 - accuracy: 0.9293 - val_loss: 0.0831 - val_accuracy: 1.0000
# Epoch 29/50
# 1/1 [==============================] - 1s 507ms/step - loss: 0.2679 - accuracy: 0.8990 - val_loss: 0.0786 - val_accuracy: 1.0000
# Epoch 30/50
# 1/1 [==============================] - 1s 551ms/step - loss: 0.1856 - accuracy: 0.9495 - val_loss: 0.0970 - val_accuracy: 0.9583
# Epoch 31/50
# 1/1 [==============================] - 1s 508ms/step - loss: 0.2513 - accuracy: 0.8889 - val_loss: 0.0758 - val_accuracy: 1.0000
# Epoch 32/50
# 1/1 [==============================] - 1s 508ms/step - loss: 0.1363 - accuracy: 0.9596 - val_loss: 0.0837 - val_accuracy: 1.0000
# Epoch 33/50
# 1/1 [==============================] - 1s 583ms/step - loss: 0.1726 - accuracy: 0.9596 - val_loss: 0.0571 - val_accuracy: 1.0000
# Epoch 34/50
# 1/1 [==============================] - 0s 483ms/step - loss: 0.2180 - accuracy: 0.9394 - val_loss: 0.0566 - val_accuracy: 1.0000
# Epoch 35/50
# 1/1 [==============================] - 0s 494ms/step - loss: 0.1411 - accuracy: 0.9495 - val_loss: 0.0483 - val_accuracy: 1.0000
# Epoch 36/50
# 1/1 [==============================] - 1s 546ms/step - loss: 0.1129 - accuracy: 0.9596 - val_loss: 0.0249 - val_accuracy: 1.0000
# Epoch 37/50
# 1/1 [==============================] - 0s 494ms/step - loss: 0.0920 - accuracy: 0.9697 - val_loss: 0.0405 - val_accuracy: 1.0000
# Epoch 38/50
# 1/1 [==============================] - 1s 525ms/step - loss: 0.1336 - accuracy: 0.9495 - val_loss: 0.0158 - val_accuracy: 1.0000
# Epoch 39/50
# 1/1 [==============================] - 0s 496ms/step - loss: 0.0795 - accuracy: 0.9798 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 40/50
# 1/1 [==============================] - 1s 512ms/step - loss: 0.0719 - accuracy: 0.9798 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 41/50
# 1/1 [==============================] - 1s 564ms/step - loss: 0.0609 - accuracy: 0.9899 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 42/50
# 1/1 [==============================] - 1s 555ms/step - loss: 0.1104 - accuracy: 0.9596 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 43/50
# 1/1 [==============================] - 0s 488ms/step - loss: 0.0486 - accuracy: 0.9798 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 44/50
# 1/1 [==============================] - 0s 488ms/step - loss: 0.0391 - accuracy: 0.9899 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 45/50
# 1/1 [==============================] - 1s 571ms/step - loss: 0.0589 - accuracy: 0.9899 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 46/50
# 1/1 [==============================] - 0s 485ms/step - loss: 0.0331 - accuracy: 0.9899 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 47/50
# 1/1 [==============================] - 0s 496ms/step - loss: 0.0441 - accuracy: 0.9798 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 48/50
# 1/1 [==============================] - 1s 565ms/step - loss: 0.0380 - accuracy: 0.9899 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 49/50
# 1/1 [==============================] - 1s 524ms/step - loss: 0.0319 - accuracy: 0.9899 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 50/50
# 1/1 [==============================] - 0s 486ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000

# %% [markdown]
# triplet_loss

# %%
def triplet_loss(y_true, y_pred, alpha = 0.2):
    total_lenght = y_pred.shape.as_list()[-1]
    anchor, positive, negative = y_pred[:,:int(1/3*total_lenght)], y_pred[:,int(1/3*total_lenght):int(2/3*total_lenght)], y_pred[:,int(2/3*total_lenght):]
    
    pos_dist = tf.reduce_sum(tf.square(anchor - positive), axis=-1)
    neg_dist = tf.reduce_sum(tf.square(anchor - negative), axis=-1)
    basic_loss = pos_dist - neg_dist + alpha
    loss = tf.reduce_sum(tf.maximum(basic_loss,0.0))
    return loss

# %%
def generate_triplets(x, y, num_same = 4, num_diff = 4):
    anchor_images = np.array([]).reshape((-1,)+ x.shape[1:])
    same_images = np.array([]).reshape((-1,)+ x.shape[1:])
    diff_images = np.array([]).reshape((-1,)+ x.shape[1:])
    
    for i in range(len(y)):
        point = y[i]        
        anchor = x[i]
        
        same_pairs = np.where(y == point)[0]
        same_pairs = np.delete(same_pairs , np.where(same_pairs == i))
        diff_pairs = np.where(y != point)[0]
               
        same = x[np.random.choice(same_pairs,num_same)]
        diff = x[np.random.choice(diff_pairs,num_diff)]
        
        anchor_images = np.concatenate((anchor_images, np.tile(anchor, (num_same * num_diff, 1, 1, 1) )), axis = 0)
                                       
        for s in same:
            same_images = np.concatenate((same_images, np.tile(s, (num_same, 1, 1, 1) )), axis = 0)
            
        diff_images = np.concatenate((diff_images, np.tile(diff, (num_diff, 1, 1, 1) )), axis = 0)
        
    return anchor_images, same_images, diff_images

# %%
anchor_images, same_images, diff_images = generate_triplets(x_train,y_train, num_same= 10, num_diff=10)
print(anchor_images.shape, same_images.shape, diff_images.shape)
# Out:
# (9900, 60, 60, 3) (9900, 60, 60, 3) (9900, 60, 60, 3)

# %%
idx = 90
plt.subplot(1,3,1)
plt.imshow(anchor_images[idx])

plt.subplot(1,3,2)
plt.imshow(same_images[idx])

plt.subplot(1,3,3)
plt.imshow(diff_images[idx])

# %%
def get_model():
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Conv2D(64, kernel_size=3, strides=2, padding='same', input_shape=(img_size,img_size,3), activation='relu'))
    model.add(tf.keras.layers.Conv2D(128, kernel_size=3, strides=2, padding='same', activation='relu'))
    model.add(tf.keras.layers.Conv2D(64, kernel_size=3, strides=2, padding='same', activation='relu'))
    model.add(tf.keras.layers.Conv2D(64, kernel_size=1, strides=2, padding='same', activation='relu'))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(512, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.1))
    model.add(tf.keras.layers.Dense(256, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.2))
    model.add(tf.keras.layers.Dense(128))
              
    model.summary()
    return model

# %%
ops.reset_default_graph()
anchor_input = tf.keras.layers.Input((img_size, img_size, 3), name='anchor_input')
positive_input = tf.keras.layers.Input((img_size, img_size, 3), name='positive_input')
negative_input = tf.keras.layers.Input((img_size, img_size, 3), name='negative_input')

shared_dnn = get_model()

encoded_anchor = shared_dnn(anchor_input)
encoded_positive = shared_dnn(positive_input)
encoded_negative = shared_dnn(negative_input)

merged_vector = tf.keras.layers.concatenate([encoded_anchor, encoded_positive, encoded_negative],
                                            axis=-1, name='merged_layer')

model = tf.keras.Model(inputs=[anchor_input,positive_input, negative_input], outputs=merged_vector)
model.summary()
model.compile(loss=triplet_loss, optimizer="adam")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 64)        1792
#
#  conv2d_1 (Conv2D)           (None, 15, 15, 128)       73856
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 64)          73792
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 64)          4160
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 512)               524800
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
# =================================================================
# Total params: 842,624
# Trainable params: 842,624
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  anchor_input (InputLayer)      [(None, 60, 60, 3)]  0           []
#
#  positive_input (InputLayer)    [(None, 60, 60, 3)]  0           []
#
#  negative_input (InputLayer)    [(None, 60, 60, 3)]  0           []
#
#  sequential (Sequential)        (None, 128)          842624      ['anchor_input[0][0]',
#                                                                   'positive_input[0][0]',
#                                                                   'negative_input[0][0]']
#
#  merged_layer (Concatenate)     (None, 384)          0           ['sequential[0][0]',
#                                                                   'sequential[1][0]',
#                                                                   'sequential[2][0]']
#
# ==================================================================================================
# Total params: 842,624
# Trainable params: 842,624
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
weight_dir = "weight_tripletloss_model"
if not os.path.exists(weight_dir):
    os.mkdir(weight_dir)
    
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=weight_dir+'/checkpoint-{epoch:02d}.hdf5')

# %%
Y_dummy = np.empty((anchor_images.shape[0],1))

model.fit([anchor_images,same_images,diff_images],y=Y_dummy, batch_size=128, epochs=2, callbacks=[checkpoint])
# Out:
# Epoch 1/2
# 78/78 [==============================] - 129s 2s/step - loss: 5.2757
# Epoch 2/2
# 78/78 [==============================] - 111s 1s/step - loss: 0.1885

# %%
anchor_model = tf.keras.Model(inputs = anchor_input, outputs=encoded_anchor)

# %%
pred = anchor_model.predict(x_train)
pred.shape
# Out:
# (99, 128)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pred_pca = pca.fit_transform(pred)

plt.scatter(pred_pca[:,0], pred_pca[:,1], c=y_train)

# %%
def encode_image(model ,img):
    encode = model.predict(img.reshape((1,)+ img.shape))
    return encode

# %%
def dist_imgs(anchor_enc, img_enc):
    return np.linalg.norm(img_enc - anchor_enc)

# %%
name_dict = {}
for i in set(df["name"].values):
    z = df[df["name"] == i].image
    img = np.array(list(z))/255
    enc = np.zeros((1,128))
    for j in range(len(z)):
        enc += encode_image(anchor_model,img[j])

    enc = enc/len(z)
    name_dict[i] = enc

# %%
pca = PCA(n_components=2)
pred_pca = pca.fit_transform(pred)

plt.scatter(pred_pca[:,0], pred_pca[:,1], c=y_train)

for val in name_dict.values():
  point = pca.transform(val)
  plt.scatter(point[0,0], point[0,1], s = [60], c='black')
plt.show()

# %%
def predict_image(model, img, dictionary):
    enc = encode_image(model, img)
    max_dist = 10000000
    max_name = None
    for name in dictionary:
        dist = dist_imgs(dictionary[name], enc)
        if max_dist > dist:
            max_dist = dist
            max_name = name
    
    return max_name, max_dist

# %%
idx = 70
img = x_train[idx]
plt.imshow(img)

n, d = predict_image(anchor_model, img, name_dict)
print("Predicted name:",n ," with distance", d)
print("Actual pred: ", le.inverse_transform(y_train[idx:idx+1]))
# Out:
# Predicted name: madonna  with distance 0.2950634863080786
# Actual pred:  ['madonna']
