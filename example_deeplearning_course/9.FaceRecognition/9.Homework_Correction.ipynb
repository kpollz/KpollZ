# %% [markdown]
# # I. Lý thuyết
#
# 1) Sự khác biệt chính giữa hai bài toán Face Recognition và Face Verification là gì ?
#
# A. Bài toán Face Recognition nhằm trả lời cho câu hỏi ảnh đầu vào là ai trong số K người và bài toán Face Verification nhằm xác thực ảnh đầu vào có phải là một người nào đó cụ thể hay không ?
#
# B. Bài toán Face Verification nhằm trả lời cho câu hỏi ảnh đầu vào là ai trong số K người và bài toán Face Recognition nhằm xác thực ảnh đầu vào có phải là một người nào đó cụ thể hay không ?
#
# C. Bài toán Face Recognition được sử dụng trong các ứng dụng mở khóa điện thoại, còn Face Verification được sử dụng trong chấm công.
#
# D. Bài toán Face Recognition và Face Verification là như nhau và có thể thay thế lẫn nhau.
#
# ĐA: A

# %% [markdown]
# 2) Phương pháp one-shot learning có đặc điểm là gì ?
#
# A. Đầu vào là một vài bức ảnh tương ứng với mỗi một người và xây dựng một mạng deep neural để phân loại các bức ảnh đó.
#
# B. Dữ liệu đầu vào bao gồm các bức ảnh sao cho mỗi bức ảnh thuộc về một người và xây dựng một mạng deep neural để phân loại các bức ảnh đó.
#
# C. Mỗi người có một số lượng ảnh đầu vào là bằng nhau và xây dựng một mạng deep neural để phân loại các bức ảnh đó.
#
# D. Dữ liệu đầu vào bao gồm các bức ảnh ngẫu nhiên chưa được gán nhãn thuộc về một nhóm người.
#
# ĐA: B

# %% [markdown]
# 3) Nhận định nào sau đây về phương pháp huấn luyện Siamese Network là đúng?
#
# A. Luôn truyền vào một cặp ảnh thuộc về hai người khác nhau để học biểu diễn.
#
# B. Luôn truyền vào một cặp ảnh thuộc về cùng một người để học biểu diễn.
#
# C. Truyền vào hai ảnh input vào hai network khác nhau nhằm học các biểu diễn sao cho sẽ giống nhau nếu thuộc cùng một người và cách xa nhau nếu thuộc về hai người khác biệt.
#
# D. Truyền vào một cặp ảnh input vào một mạng neural duy nhất nhằm học các biểu diễn sao cho sẽ giống nhau nếu thuộc cùng một người và cách xa nhau nếu thuộc về hai người khác biệt.
#
# ĐA: D

# %% [markdown]
# 4) Để tính toán sự khác biệt giữa hai véc tơ chúng ta có thể dùng hàm số dạng nào?
#
# A. Tích có hướng giữa hai véc tơ
#
# B. Tích inner product giữa hai véc tơ.
#
# C. Các hàm norm Lp (p < 1), hàm cosine-similarity
#
# D. Các hàm norm Lp (p >= 1), hàm cosine-similarity
#
# ĐA: D

# %% [markdown]
# 5) Tại sao trong triplet loss chúng ta lại cần cộng thêm giá trị alpha vào bất phương trình?
#
# A. Để gia tăng sự cách biệt giữa khoảng cách d(Anchor, Negative) so với  d(Anchor, Positive) ít nhất bằng alpha và tránh trường hợp học về chung một biểu diễn véc tơ duy nhất.
#
# B. Để thu hẹp sự cách biệt giữa khoảng cách d(Anchor, Negative) so với  d(Anchor, Positive) ít nhất bằng alpha và tránh trường hợp học về chung một biểu diễn véc tơ duy nhất.
#
# C. Để gia tăng sự cách biệt giữa khoảng cách d(Anchor, Negative) so với  d(Anchor, Positive) ít nhất bằng alpha và tránh trường hợp học về chung một biểu diễn véc tơ 0.
#
# D. Để thu hẹp sự cách biệt giữa khoảng cách d(Anchor, Negative) so với  d(Anchor, Positive) ít nhất bằng alpha và tránh trường hợp học về chung một biểu diễn véc tơ 0.
#
# ĐA: A

# %% [markdown]
# # II. Thực hành
#
# 6) Hãy đọc và tổng kết những ý chính trong paper [ArcFace: Additive Angular Margin Loss for Deep Face Recognition, CVPR 2019, Jiankang Deng et al](https://openaccess.thecvf.com/content_CVPR_2019/papers/Deng_ArcFace_Additive_Angular_Margin_Loss_for_Deep_Face_Recognition_CVPR_2019_paper.pdf)
#
# 7) Hãy lựa chọn một bộ dữ liệu về face bất kì trên [kaggle](https://www.kaggle.com/search?q=Face+dataset) nhằm phục vụ xây dựng mô hình Face Recognition. Hãy thực hiện phân tích bộ dữ liệu bằng cách mô tả dữ liệu,  thống kê về dữ liệu, vẽ biểu đồ và đưa ra các nhận xét về bộ dữ liệu.
#
# 8) Thuật toán Face Recognition sẽ tốt hơn nếu các ảnh đầu vào đã được crop về vùng chứa face.Sử dụng mô hình Rentinaface trong Face Detection, hãy crop face theo bouding box và resize về chung một kích thước 512x512. Sau đó lưu lại để làm dữ liệu huấn luyên mô hình Face Recognition.
#
# 9) Hãy xây dựng một mô hình Face Recognition theo phương pháp few-shot learning.
#
# 10) Huấn luyện mô hình theo phương pháp triplet loss function.

# %% [markdown]
# # 6 Paper summarize arcface

# %% [markdown]
# https://docs.google.com/document/d/1R0F_4F3iQ6OaprYF_VsDKaVjmi_1rOczztZQVpgpvMw/edit?usp=sharing

# %% [markdown]
# # 7 Dataset visualization and description

# %% [markdown]
# Source dataset [pins face recognition](https://www.kaggle.com/datasets/hereisburak/pins-face-recognition) Bao gồm 17534 ảnh của 105 người nổi tiếng được thu tập trên trang pinterest. Bộ dữ liệu đa dạng các tư thế và màu sắc: ảnh đen trắng, ảnh màu và ảnh chụp khuôn mặt với các góc độ nghiêng trái, phải; xoay trái ,xoay phải; nhìn thẳng; đội mũ, đeo kính,...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/DeepLearning2/data
# Out:
# /content/drive/MyDrive/Colab Notebooks/DeepLearning2/data

# %%
# !ls
# Out:
# 105_classes_pins_dataset_crop	  grades.csv
# archive.zip			  income_classification
# bike-share.csv			  lfw_224.zip
# daily-bike-share.csv		  penguins.csv
# detr				  pins_face_data
# detr_best_0.pth			  Pytorch_Retinaface
# diabetes.csv			  sample_submission.csv
# dogvscat			  seeds.csv
# glint360k_224.zip		  shapes
# global-wheat-detection		  train.csv
# global-wheat-detection-convertor  vggface2_224.zip
# global-wheat-detection.zip	  yolov5

# %%
# !unzip archive.zip -d pins_face_data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: pins_face_data/105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner37_964.jpg
#   inflating: pins_face_data/105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner38_965.jpg
#   inflating: pins_face_data/105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner39_966.jpg
#   inflating: pins_face_data/105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner3_956.jpg
#   inflating: pins_face_data/105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner41_968.jpg
#   inflating: pins_face_data/105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner42_969.jpg
#   inflating: pins_face_data/105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner44_970.jpg
#   inflating: pins_face_data/105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner45_971.jpg
#   inflating: pins_face_data/105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner46_972.jpg
# ...

# %%
import os

main_folder = 'pins_face_data/105_classes_pins_dataset/'

listdir = sorted(os.listdir(main_folder))

# %%
#Số lượng class
print(len(listdir))
# Out:
# 105

# %%
#Số lượng trung bình ảnh của mỗi người
import pandas as pd

people=[]
count_imgs=[]
for person_name in listdir:
  num_imgs=len(os.listdir(os.path.join(main_folder, person_name)))
  people.append(person_name)
  count_imgs.append(num_imgs)
df = pd.DataFrame({'person': people, 'num_imgs': count_imgs}).sort_values('num_imgs')

# %% [markdown]
# Visualization

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 20))
plt.barh(df['person'], df['num_imgs'])
plt.xlabel('Person')
plt.ylabel('Number of images')
plt.yticks(rotation=0)
plt.title('Number of Image each person')
# Out:
# Text(0.5, 1.0, 'Number of Image each person')

# %% [markdown]
# Thống kê mô tả

# %%
df.describe()
# Out:
#          num_imgs
# count  105.000000
# mean   166.990476
# std     34.128855
# min     86.000000
# 25%    141.000000
# 50%    169.000000
# 75%    192.000000
# max    237.000000

# %% [markdown]
# Như vậy trung bình mỗi người bao gồm 166 ảnh. Trong đó thấp nhất là 86 và cao nhất là 237 ảnh.

# %% [markdown]
# #8 Crop face

# %%
#crop face 
# !git clone https://github.com/biubug6/Pytorch_Retinaface.git
# !pip install retina-face

# %%
from retinaface import RetinaFace
import cv2
import numpy as np
import torch

# make square bounding box
def make_square(b, h, w, scale=1.1):
  '''
    # b: bounding box include (x1, y1, x2, y2)
    # w, h: width and height of the image
    # scale: the rate of expand image size
  '''
  x1, y1, x2, y2 = b
  cx, cy = (x1+x2)/2, (y1+y2)/2
  expand = max((x2-x1), (y2-y1))
  x1, x2 = cx-expand*scale, cx+expand*scale
  y1, y2 = cy-expand*scale, cy+expand*scale
  x1 = max(x1, 0)
  x2 = min(x2, w)
  y1 = max(y1, 0)
  y2 = min(y2, h)
  return list(map(int, (x1, y1, x2, y2)))

data_folder = '/content/drive/MyDrive/Colab Notebooks/DeepLearning2/data/pins_face_data/105_classes_pins_dataset'
data_folder_new='/content/drive/MyDrive/Colab Notebooks/DeepLearning2/data/105_classes_pins_dataset_crop/'
if not os.path.exists(data_folder_new):
  os.makedirs(data_folder_new)
for id in os.listdir(data_folder):
  print(id)
  os.makedirs(os.path.join(data_folder_new, id))
  for img_name in os.listdir(os.path.join(data_folder, id)):
    image_path=os.path.join(data_folder,id,img_name)
    img_raw = cv2.imread(image_path, cv2.IMREAD_COLOR)
    img = np.float32(img_raw)
    im_height, im_width, _ = img.shape

    resp = RetinaFace.detect_faces(image_path)
    # print(resp)
    if isinstance(resp, tuple):
      cv2.imwrite(os.path.join(data_folder_new, id, img_name), img_raw)
    else:
      for i, (k, face) in enumerate(resp.items()):
        bbox = face['facial_area']
        b = make_square(bbox, im_height, im_width, scale = 1.1)
        cropped_image = img_raw[int(b[1]):int(b[3]), int(b[0]):int(b[2])]
        img_name_bbox = img_name.split('.')[0] + '_' + str(i) + '.jpg'
        cv2.imwrite(os.path.join(data_folder_new, id, img_name_bbox), cropped_image)
# Out:
# pins_Adriana Lima
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created
# retinaface.h5 will be downloaded from the url https://github.com/serengil/deepface_models/releases/download/v1.0/retinaface.h5
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/retinaface.h5
# To: /root/.deepface/weights/retinaface.h5
# 100%|██████████| 119M/119M [00:02<00:00, 46.6MB/s]
# pins_Alex Lawther
# pins_Alexandra Daddario
# pins_Alvaro Morte
# pins_Amanda Crew
# pins_Andy Samberg
# pins_Anne Hathaway
# pins_Anthony Mackie
# pins_Avril Lavigne
# pins_Ben Affleck
# pins_Bill Gates
# pins_Bobby Morley
# pins_Brenton Thwaites
# pins_Brian J. Smith
# pins_Brie Larson
# pins_Chris Evans
# pins_Chris Hemsworth
# pins_Chris Pratt
# pins_Christian Bale
# pins_Cristiano Ronaldo
# pins_Danielle Panabaker
# pins_Dominic Purcell
# pins_Dwayne Johnson
# pins_Eliza Taylor
# pins_Elizabeth Lail
# pins_Emilia Clarke
# pins_Emma Stone
# ...

# %% [markdown]
# #9 One shot learning

# %%
import numpy as np
import torch
from torch.utils.data import DataLoader, random_split
import torchvision
import torchvision.transforms as T
from torchvision.datasets import ImageFolder
from torchvision.utils import make_grid, save_image
import matplotlib.pyplot as plt

# %%
stats = ([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
size = 224
batch_size=64
channels = 3

transformer = T.Compose([
    T.Resize(size), 
    T.CenterCrop(size),
    T.ToTensor(),
    T.Normalize(*stats)
])

# %%
dataset = ImageFolder(main_folder, transform=transformer)
classes = dataset.classes

len(dataset), dataset[0][0].size()
# Out:
# (17534, torch.Size([3, 224, 224]))

# %%
def denormal(image):
    image = image.numpy().transpose(1, 2, 0)
    mean = [0.485, 0.456, 0.406]
    std = [0.229, 0.224, 0.225]
    
    image = image * std + mean
    image = np.clip(image, 0, 1)
    return image

def denormalize(x, mean=stats[0], std=stats[1]):
    # 3, H, W, B
    ten = x.clone().permute(1, 2, 3, 0)
    for t, m, s in zip(ten, mean, std):
        t.mul_(s).add_(m)
    # B, 3, H, W
    return torch.clamp(ten, 0, 1).permute(3, 0, 1, 2)

# %%
idx =  -1#@param
img, lbl = dataset[idx]

plt.imshow(denormal(img))
plt.title(dataset.classes[lbl])
plt.axis('off');

# %%
torch.manual_seed(42)
num_val = int(len(dataset) * 0.1)
dataset, val_ds = random_split(dataset, [len(dataset) - num_val, num_val])

# %%
dl = DataLoader(dataset, batch_size=batch_size, shuffle=True, pin_memory=True, num_workers=3)
val_dl = DataLoader(val_ds, batch_size=batch_size, shuffle=False, pin_memory=False, num_workers=3)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
def show_batch(dl):
    for images, labels in dl:
        fig, ax = plt.subplots(figsize=(12, 12))
        ax.set_xticks([]); ax.set_yticks([])
        denorm_images = denormalize(images)
        ax.imshow(make_grid(denorm_images[:64], nrow=8).permute(1, 2, 0).clamp(0,1))
        break

# %%
#Show batch
show_batch(dl)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
from torchsummary import summary
from glob import glob
from tqdm.notebook import tqdm

# %%
class FaceRecog(nn.Module):
    def __init__(self, num_classes, pretrained=True):
        super().__init__()
        # Use a pretrained model
        self.resnet34 = models.resnet18(True)
        self.features = nn.Sequential(*list(self.resnet34.children())[:-1])
        # Replace last layer
        self.classifier = nn.Sequential(nn.Flatten(),
                                         nn.Linear(self.resnet34.fc.in_features, num_classes))

    def forward(self, x):
        x = self.features(x)
        y = self.classifier(x)
        return y
    
    def summary(self, input_size):
        return summary(self, input_size)

# %%
model = FaceRecog(num_classes=len(classes)).to(device)
model.summary((3, 224, 224))
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#             Conv2d-2         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-3         [-1, 64, 112, 112]             128
#        BatchNorm2d-4         [-1, 64, 112, 112]             128
#               ReLU-5         [-1, 64, 112, 112]               0
#               ReLU-6         [-1, 64, 112, 112]               0
#          MaxPool2d-7           [-1, 64, 56, 56]               0
#          MaxPool2d-8           [-1, 64, 56, 56]               0
#             Conv2d-9           [-1, 64, 56, 56]          36,864
#            Conv2d-10           [-1, 64, 56, 56]          36,864
# ...

# %%
learning_rate = 1e-4
n_epochs = 20

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def train(epoch, n_epochs, model, dl, loss_func, device, optimizer, ds=dataset):
    model.train(True)
    torch.set_grad_enabled(True)
    
    epoch_loss = 0.0
    epochs_acc = 0
    
    tq_batch = tqdm(dl, total=len(dl))
    for images, labels in tq_batch:
        images = images.to(device)
        labels = labels.to(device)
        
        optimizer.zero_grad()
        outs = model(images)
        _, preds = torch.max(outs, 1)
        
        loss = loss_func(outs, labels)

        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()
        epochs_acc += torch.sum(preds == labels).item()
        
        tq_batch.set_description(f'Epoch [{epoch + 1}/{n_epochs}]')
        tq_batch.set_postfix_str('loss = {:.4f}'.format(loss.item()))

            
    epoch_loss = epoch_loss / len(dl)
    epochs_acc = epochs_acc / len(ds)

    return epoch_loss, epochs_acc

# %%
def evaluate(model, dl, loss_func, device, ds=val_ds):

    model.train(False)

    epoch_loss = 0
    epochs_acc = 0
    tq_batch = tqdm(dl, total=len(dl), leave=False)
    for images, labels in tq_batch:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        _, preds = torch.max(outputs, 1)
        loss = loss_func(outputs, labels)

        epoch_loss += loss.item()
        epochs_acc += torch.sum(preds == labels).item()
        tq_batch.set_description(f'Evaluate Model')
        
    epoch_loss = epoch_loss / len(dl)
    epochs_acc = epochs_acc / len(ds)

    return epoch_loss, epochs_acc

# %%
def fit(n_epochs, model, train_dataloader, valid_dataloader, loss_func, device, optimizer):
    
    history = []
    val_loss_ref = float('inf')
    patient = 5
    for epoch in range(n_epochs):
        torch.cuda.empty_cache()
        loss, acc = train(epoch, n_epochs, model, train_dataloader, loss_func, device, optimizer)
        
        torch.cuda.empty_cache()
        val_loss, val_acc = evaluate(model, valid_dataloader, loss_func, device)
        
        history.append({'loss': loss, 'acc': acc, 'val_loss': val_loss, 'val_acc': val_acc})

        statement = "[loss]={:.4f} - [acc]={:.4f} - \
[val_loss]={:.4f} - [val_acc]={:.4f}".format(loss, acc, val_loss, val_acc,)
        print(statement)
        ####### Checkpoint
        if val_loss < val_loss_ref:
            patient = 5
            val_loss_ref = val_loss
            model_path = './Face_Recognition_checkpoint.pth'
            torch.save(model.state_dict(), model_path)
            print(f"[INFO] Saving model dict, Epoch={epoch + 1}")
        else:
            if patient == 0: 
                break
            print(f"[INFO] {patient} lives left!")
            patient -= 1
            

    return history

# %%
res = fit(n_epochs, model, dl, val_dl, criterion, device, optimizer)
# Out:
#   0%|          | 0/247 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#   0%|          | 0/28 [00:00<?, ?it/s]
# [loss]=3.2623 - [acc]=0.3146 - [val_loss]=2.1725 - [val_acc]=0.5590
# [INFO] Saving model dict, Epoch=1
# ...
#   0%|          | 0/28 [00:00<?, ?it/s]
# [loss]=1.3049 - [acc]=0.7875 - [val_loss]=1.0975 - [val_acc]=0.7912
# [INFO] Saving model dict, Epoch=2
# ...
#   0%|          | 0/28 [00:00<?, ?it/s]
# [loss]=0.4323 - [acc]=0.9547 - [val_loss]=0.7649 - [val_acc]=0.8437
# [INFO] Saving model dict, Epoch=3
# ...
#   0%|          | 0/28 [00:00<?, ?it/s]
# ...

# %%
#Show results
def show_results(history):
    accuracy = [res['acc'] for res in history]
    losses = [res['loss'] for res in history]
    val_accuracy = [res['val_acc'] for res in history]
    val_losses = [res['val_loss'] for res in history]
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 5))
    ax1.plot(losses, '-o', label = 'Loss')
    ax1.plot(val_losses, '-o', label = 'Validation Loss')
    ax1.legend()

    ax2.plot(100 * np.array(accuracy), '-o', label = 'Accuracy')
    ax2.plot(100 * np.array(val_accuracy), '-o', label = 'Validation Accuracy')
    ax2.legend();
    
    fig.show()

# %%
show_results(res)

# %%
y_test, y_pred = [], []
for imgs, lbls in tqdm(val_dl):
    imgs = imgs.to(device)
    outs = model(imgs)
    _, preds = torch.max(outs, dim = 1)
    y_test += lbls.tolist()
    y_pred += preds.tolist()
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
loss, acc = evaluate(model, val_dl, criterion, device)
print(f'loss: {loss} - acc: {acc}')
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# loss: 0.3859656815017973 - acc: 0.9075869937250428

# %%
#show some sample
from termcolor import colored
for i, name in enumerate(classes):
    name = name.split("_")[-1]
    classes[i] = name
idx = 16
for imgs, lbls in val_dl:
    imgs = imgs.to(device)
    outs = model(imgs)
    _, preds = torch.max(outs, dim = 1)
    fig, ax = plt.subplots(figsize=(12, 12))
    ax.set_xticks([]); ax.set_yticks([])
    denorm_images = denormalize(imgs.cpu())
    ax.imshow(make_grid(denorm_images[:idx], nrow=8).permute(1, 2, 0).clamp(0,1))
    for p, lbl in zip(preds[:idx], lbls[:idx]):
        if lbl == p.cpu():
            print(colored(classes[p], 'green'))
        else:
            print(colored(classes[p], 'red'), colored(classes[lbl], 'blue'))
    break
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Taylor Swift
# Megan Fox
# Andy Samberg
# Josh Radnor
# elizabeth olsen
# kiernen shipka Gwyneth Paltrow
# Cristiano Ronaldo
# Amanda Crew
# Tom Hardy
# Hugh Jackman
# Zac Efron
# Alvaro Morte
# Alexandra Daddario
# Jason Momoa
# ellen page
# Henry Cavil

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87        19
#            1       0.79      1.00      0.88        11
#            2       0.95      1.00      0.98        21
#            3       0.94      1.00      0.97        17
#            4       0.92      0.92      0.92        12
#            5       0.88      0.93      0.90        15
#            6       0.94      0.85      0.89        20
#            7       1.00      1.00      1.00        10
#            8       0.88      1.00      0.93         7
#            9       1.00      0.71      0.83        17
#           10       1.00      1.00      1.00        13
#           11       0.75      0.94      0.83        16
#           12       0.94      0.94      0.94        17
#           13       0.80      0.80      0.80        10
#           14       0.86      0.80      0.83        15
#           15       0.89      0.70      0.78        23
# ...

# %% [markdown]
# #10.triplet loss facenet

# %%
criterion = nn.TripletMarginLoss()

# %%
res = fit(n_epochs, model, dl, val_dl, criterion, device, optimizer)
# Out:
#   0%|          | 0/247 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#   0%|          | 0/28 [00:00<?, ?it/s]
# [loss]=0.0004 - [acc]=1.0000 - [val_loss]=0.3132 - [val_acc]=0.9184
# [INFO] Saving model dict, Epoch=1
# ...
#   0%|          | 0/28 [00:00<?, ?it/s]
# [loss]=0.0003 - [acc]=1.0000 - [val_loss]=0.3174 - [val_acc]=0.9207
# [INFO] 5 lives left!
# ...
#   0%|          | 0/28 [00:00<?, ?it/s]
# [loss]=0.0003 - [acc]=1.0000 - [val_loss]=0.3118 - [val_acc]=0.9196
# [INFO] Saving model dict, Epoch=3
# ...
#   0%|          | 0/28 [00:00<?, ?it/s]
# ...

# %%
loss, acc = evaluate(model, val_dl, criterion, device)
print(f'loss: {loss} - acc: {acc}')
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# loss: 0.22244866864223564 - acc: 0.9429549343981746

# %%
#show some sample
from termcolor import colored
for i, name in enumerate(classes):
    name = name.split("_")[-1]
    classes[i] = name
idx = 16
for imgs, lbls in val_dl:
    imgs = imgs.to(device)
    outs = model(imgs)
    _, preds = torch.max(outs, dim = 1)
    fig, ax = plt.subplots(figsize=(12, 12))
    ax.set_xticks([]); ax.set_yticks([])
    denorm_images = denormalize(imgs.cpu())
    ax.imshow(make_grid(denorm_images[:idx], nrow=8).permute(1, 2, 0).clamp(0,1))
    for p, lbl in zip(preds[:idx], lbls[:idx]):
        if lbl == p.cpu():
            print(colored(classes[p], 'green'))
        else:
            print(colored(classes[p], 'red'), colored(classes[lbl], 'blue'))
    break
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Mark Ruffalo
# barack obama
# Natalie Dormer
# Chris Evans
# Anne Hathaway
# Lili Reinhart
# Krysten Ritter
# Emma Watson
# Lindsey Morgan
# Amanda Crew
# Chris Evans Emilia Clarke
# alycia dabnem carey
# Jennifer Lawrence
# Keanu Reeves
# Rebecca Ferguson
# Maisie Williams

# %%
# Kết quả cho tốt hơn khi sử dụng one shot learning
